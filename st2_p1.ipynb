# %%
import numpy as np
import pandas as pd
import os
import pickle
import logging
import heapq
from datetime import datetime
from collections import Counter, defaultdict
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
import seaborn as sns
import time
import math
from gensim.models import Word2Vec
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import ast
import sys
import gc
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
logger = logging.getLogger(__name__)

input_path = "./"
output_path = "./rec/content-recommendations"
top_n = 20

if not os.path.exists(output_path):
    os.makedirs(output_path)

# Improved similarity threshold based on empirical testing
similarity_threshold = 0.25
word2vec_dim = 100
rating_threshold = 3.5  # Threshold for binary classification (like/dislike)

# Memory monitoring function
def log_memory_usage(message="Current memory usage"):
    """Log current memory usage"""
    try:
        import psutil
        process = psutil.Process(os.getpid())
        memory_info = process.memory_info()
        memory_usage_mb = memory_info.rss / 1024 / 1024
        logger.info(f"{message}: {memory_usage_mb:.2f} MB")
    except ImportError:
        logger.warning("psutil not available for memory monitoring")

def load_data():
    data = {}
    
    movie_features_path = os.path.join(input_path, './processed/processed_movie_features.csv')
    if os.path.exists(movie_features_path):
        # Use optimized loading for large CSV files
        data['movie_features'] = pd.read_csv(movie_features_path, 
                                            dtype={'movieId': int, 'token_count': int})
        
        # Use safer and more memory-efficient parsing of lists
        data['movie_features']['tokens'] = data['movie_features']['tokens'].apply(
            lambda x: ast.literal_eval(x) if isinstance(x, str) else []
        )
        data['movie_features']['top_keywords'] = data['movie_features']['top_keywords'].apply(
            lambda x: ast.literal_eval(x) if isinstance(x, str) else []
        )
        logger.info(f"Loaded features for {len(data['movie_features'])} movies")
    else:
        logger.error(f"File not found: {movie_features_path}")
        sys.exit(1)
    
    ratings_path = os.path.join(input_path, './processed/normalized_ratings.csv')
    if os.path.exists(ratings_path):
        # Load ratings in chunks to save memory
        chunk_size = 100000
        chunks = []
        for chunk in pd.read_csv(ratings_path, chunksize=chunk_size):
            chunks.append(chunk)
            # Force garbage collection after each chunk
            gc.collect()
        
        data['ratings'] = pd.concat(chunks)
        logger.info(f"Loaded {len(data['ratings'])} ratings from {len(data['ratings']['userId'].unique())} users")
    else:
        logger.error(f"File not found: {ratings_path}")
        sys.exit(1)
    
    if 'ratings' in data:
        # Sort by timestamp if available for temporal split
        if 'timestamp' in data['ratings'].columns:
            data['ratings'] = data['ratings'].sort_values('timestamp')
        
        # Use a more robust user-level train-test split
        # Create a user-level split instead of randomly dividing all ratings
        all_user_ids = data['ratings']['userId'].unique()

        # Set a random seed for reproducibility
        np.random.seed(42)
        np.random.shuffle(all_user_ids)

        # 80% of users for training, 20% for testing
        split_idx = int(len(all_user_ids) * 0.8)
        train_users = all_user_ids[:split_idx]
        test_users = all_user_ids[split_idx:]

        # For users in test set, take 80% of their ratings for training
        train_ratings_main = data['ratings'][data['ratings']['userId'].isin(train_users)]
        
        # For users in test set, split their ratings 80/20
        test_user_ratings = data['ratings'][data['ratings']['userId'].isin(test_users)]
        test_user_train = []
        test_user_test = []
        
        for user_id in test_users:
            user_data = test_user_ratings[test_user_ratings['userId'] == user_id]
            if len(user_data) < 5:  # Skip users with very few ratings
                continue
                
            # Sort by timestamp if available for a more realistic test
            if 'timestamp' in user_data.columns:
                user_data = user_data.sort_values('timestamp')
                
            # Take first 80% for training, last 20% for testing
            split_idx = int(len(user_data) * 0.8)
            test_user_train.append(user_data.iloc[:split_idx])
            test_user_test.append(user_data.iloc[split_idx:])
        
        # Combine all training sets
        data['train_ratings'] = pd.concat([train_ratings_main] + test_user_train) if test_user_train else train_ratings_main
        data['test_ratings'] = pd.concat(test_user_test) if test_user_test else pd.DataFrame()
        
        logger.info(f"Created train set with {len(data['train_ratings'])} ratings from {len(data['train_ratings']['userId'].unique())} users")
        logger.info(f"Created test set with {len(data['test_ratings'])} ratings from {len(data['test_ratings']['userId'].unique())} users")
        
        # Force garbage collection
        gc.collect()
    
    return data

def calculate_log_likelihood(movie_features, corpus_word_counts, batch_size=100):
    """
    Calculate log-likelihood scores for words in each movie.
    Optimized implementation with TF-IDF weighting.
    """
    start_time = time.time()
    
    total_corpus_size = sum(corpus_word_counts.values())
    total_movies = len(movie_features)
    
    # Calculate document frequency for each word
    doc_freq = defaultdict(int)
    for _, row in movie_features.iterrows():
        tokens = row['tokens']
        unique_tokens = set(tokens)
        for word in unique_tokens:
            doc_freq[word] += 1
    
    # Calculate IDF values
    idf_values = {}
    for word, df in doc_freq.items():
        idf_values[word] = math.log(total_movies / (df + 1))
    
    movie_ll_values = {}
    
    for batch_start in range(0, total_movies, batch_size):
        batch_end = min(batch_start + batch_size, total_movies)
        batch = movie_features.iloc[batch_start:batch_end]
        
        for _, row in batch.iterrows():
            movie_id = row['movieId']
            tokens = row['tokens']
            
            if not tokens:
                continue
            
            movie_word_counts = Counter(tokens)
            movie_size = sum(movie_word_counts.values())
            
            movie_ll_tfidf = {}
            
            for word, count in movie_word_counts.items():
                # Calculate log-likelihood
                a = count
                b = corpus_word_counts[word] - count
                c = movie_size
                d = total_corpus_size - movie_size
                
                e1 = c * (a + b) / (c + d)
                e2 = d * (a + b) / (c + d)
                
                ll = 0
                if a > 0 and e1 > 0:
                    ll += a * math.log(a / e1)
                if b > 0 and e2 > 0:
                    ll += b * math.log(b / e2)
                
                # Scale by 2
                ll = 2 * ll
                
                # Get IDF value
                idf = idf_values.get(word, 0)
                
                # Multiply LL by IDF for combined weighting
                movie_ll_tfidf[word] = ll * idf
            
            movie_ll_values[movie_id] = movie_ll_tfidf
        
        elapsed = time.time() - start_time
        progress = batch_end / total_movies * 100
        remaining = elapsed / (batch_end - batch_start) * (total_movies - batch_end) if batch_end < total_movies else 0
        logger.info(f"Processed {batch_end}/{total_movies} movies ({progress:.1f}%) - Elapsed: {elapsed:.2f}s - Est. remaining: {remaining:.2f}s")
        
        # Garbage collection
        gc.collect()
    
    return movie_ll_values

def train_word2vec(movie_features, vector_size=100, batch_size=1000):
    """
    Train a Word2Vec model on movie tokens with improved parameters.
    """
    start_time = time.time()
    
    tokenized_corpus = []
    total_movies = len(movie_features)
    
    # Process in batches to save memory
    for i in range(0, total_movies, batch_size):
        batch_end = min(i + batch_size, total_movies)
        batch = movie_features.iloc[i:batch_end]
        
        batch_tokens = list(batch['tokens'])
        tokenized_corpus.extend(batch_tokens)
        
        # Log progress
        progress = batch_end / total_movies * 100
        logger.info(f"Preparing corpus: {batch_end}/{total_movies} movies ({progress:.1f}%)")
        
        # Garbage collection after each batch
        gc.collect()
    
    total_tokens = sum(len(tokens) for tokens in tokenized_corpus)
    logger.info(f"Training Word2Vec on corpus with {total_tokens} tokens")
    
    # Improved Word2Vec parameters
    word2vec_model = Word2Vec(
        sentences=tokenized_corpus,
        vector_size=vector_size,
        window=8,        # Increased context window 
        min_count=3,     # Include words that appear at least 3 times
        workers=8,       # Parallelize training
        epochs=20,       # More training epochs for better vectors
        sg=1,            # Use skip-gram (better for semantic relations)
        hs=1,            # Use hierarchical softmax for efficiency
        negative=15      # Number of negative samples
    )
    
    # Clean up the corpus to save memory
    del tokenized_corpus
    gc.collect()
    
    elapsed = time.time() - start_time
    logger.info(f"Word2Vec model training completed in {elapsed:.2f}s")
    
    return word2vec_model

def generate_movie_vectors(movie_ll_values, word2vec_model, movie_features, corpus_word_counts, batch_size=100):
    """
    Generate movie feature vectors combining log-likelihood and Word2Vec.
    Improved with TF-IDF weighting and normalization.
    """
    start_time = time.time()
    
    movie_vectors = {}
    successful_vectors = 0
    no_words_found = 0
    low_ll_sum = 0
    
    movie_ids = list(movie_ll_values.keys())
    total_movies = len(movie_ids)
    total_corpus_size = sum(corpus_word_counts.values())
    
    for batch_start in range(0, total_movies, batch_size):
        batch_end = min(batch_start + batch_size, total_movies)
        batch_movie_ids = movie_ids[batch_start:batch_end]

        for movie_id in batch_movie_ids:
            ll_values = movie_ll_values[movie_id]
            
            # Calculate IDF for each word in this movie
            idf = {word: math.log(total_corpus_size/(corpus_word_counts[word]+1)) 
                  for word in ll_values.keys()}
            
            # Combined score: LL * IDF
            combined_scores = {word: ll * idf[word] 
                              for word, ll in ll_values.items()}
            
            # Get top words by combined score
            top_words = sorted(combined_scores.items(), key=lambda x: x[1], reverse=True)[:500]
            
            if not top_words:
                no_words_found += 1
                continue
            
            weighted_vectors = []
            ll_sum = 0
            words_used = 0
            
            # Combine word vectors weighted by their scores
            for word, score in top_words:
                if score <= 0:
                    continue
                
                if word in word2vec_model.wv:
                    weighted_vectors.append(word2vec_model.wv[word] * score)
                    ll_sum += score
                    words_used += 1
            
            # Create the final vector as weighted average
            if weighted_vectors and ll_sum > 0:
                movie_vector = np.sum(weighted_vectors, axis=0) / ll_sum
                
                # Normalize to unit length for cosine similarity
                norm = np.linalg.norm(movie_vector)
                if norm > 0:
                    movie_vector = movie_vector / norm
                    movie_vectors[movie_id] = movie_vector
                    successful_vectors += 1
            else:
                low_ll_sum += 1
        
        elapsed = time.time() - start_time
        progress = batch_end / total_movies * 100
        remaining = elapsed / (batch_end - batch_start) * (total_movies - batch_end) if batch_end < total_movies else 0
        
        logger.info(f"Generated vectors: {batch_end}/{total_movies} movies ({progress:.1f}%) - Success: {successful_vectors}")
        
        # Garbage collection
        gc.collect()
    
    logger.info(f"Vector generation summary: Success: {successful_vectors}, No words: {no_words_found}, Low scores: {low_ll_sum}")
    return movie_vectors

def generate_user_vectors(movie_vectors, train_ratings, batch_size=100):
    """
    Generate user feature vectors based on rated movies.
    Improved with better weighting and bias adjustments.
    """
    start_time = time.time()
    
    user_vectors = {}
    successful_vectors = 0
    no_ratings_found = 0
    no_vectors_for_movies = 0
    low_weight_sum = 0
    
    # Create user_ratings_dict for faster lookups
    user_ratings_dict = defaultdict(dict)
    
    # Use chunks to process ratings to avoid memory issues
    ratings_chunks = np.array_split(train_ratings, max(1, len(train_ratings) // 100000))
    for chunk in ratings_chunks:
        for _, row in chunk.iterrows():
            user_id = row['userId']
            movie_id = row['movieId']
            rating = row['rating']
            user_ratings_dict[user_id][movie_id] = rating
        
        # Garbage collection after each chunk
        gc.collect()
    
    user_ids = list(user_ratings_dict.keys())
    total_users = len(user_ids)
    
    # Calculate global average rating
    all_ratings = [r for user_ratings in user_ratings_dict.values() for r in user_ratings.values()]
    global_avg_rating = np.mean(all_ratings) if all_ratings else 3.0
    
    for batch_start in range(0, total_users, batch_size):
        batch_end = min(batch_start + batch_size, total_users)
        batch_user_ids = user_ids[batch_start:batch_end]
        
        for user_id in batch_user_ids:
            user_ratings = user_ratings_dict[user_id]
            
            if len(user_ratings) == 0:
                no_ratings_found += 1
                continue
            
            # Calculate user's average rating
            user_avg_rating = np.mean(list(user_ratings.values()))
            # Calculate rating bias (how much higher/lower this user rates compared to global average)
            user_bias = user_avg_rating - global_avg_rating
            
            weighted_vectors = []
            weight_sum = 0
            movies_with_vectors = 0
            movies_without_vectors = 0
            
            for movie_id, rating in user_ratings.items():
                # Calculate normalized weight: adjust rating relative to user's average
                adjusted_rating = rating - user_avg_rating
                weight = adjusted_rating
                
                if movie_id not in movie_vectors:
                    movies_without_vectors += 1
                    continue
                else:
                    movies_with_vectors += 1
                
                if abs(weight) > 0.1:  # Only consider significant preferences
                    weighted_vectors.append(movie_vectors[movie_id] * weight)
                    weight_sum += abs(weight)
            
            if weighted_vectors and weight_sum > 0:
                user_vector = np.sum(weighted_vectors, axis=0) / weight_sum
                
                # Normalize vector
                norm = np.linalg.norm(user_vector)
                if norm > 0:
                    user_vector = user_vector / norm
                    user_vectors[user_id] = user_vector
                    successful_vectors += 1
            else:
                low_weight_sum += 1
        
        elapsed = time.time() - start_time
        progress = batch_end / total_users * 100
        remaining = elapsed / (batch_end - batch_start) * (total_users - batch_end) if batch_end < total_users else 0
        
        logger.info(f"Generated vectors: {batch_end}/{total_users} users ({progress:.1f}%) - Success: {successful_vectors}")
        
        # Garbage collection
        gc.collect()
    
    logger.info(f"User vector generation summary: Success: {successful_vectors}, No ratings: {no_ratings_found}, No movie vectors: {no_vectors_for_movies}, Low weights: {low_weight_sum}")
    
    # More aggressive cleanup
    del user_ratings_dict
    gc.collect()
    
    return user_vectors

def calculate_user_movie_similarity(user_vectors, movie_vectors, threshold=0.3, batch_size=50):
    """
    Calculate similarity between users and movies using improved methods.
    """
    start_time = time.time()
    
    user_movie_similarities = {}
    
    user_ids = list(user_vectors.keys())
    total_users = len(user_ids)
    total_movies = len(movie_vectors)
    
    # Convert movie vectors to a numpy array for faster batch computation
    movie_ids = list(movie_vectors.keys())
    movie_id_to_idx = {movie_id: i for i, movie_id in enumerate(movie_ids)}
    movie_vectors_array = np.array([movie_vectors[mid] for mid in movie_ids])
    
    for batch_start in range(0, total_users, batch_size):
        batch_end = min(batch_start + batch_size, total_users)
        batch_user_ids = user_ids[batch_start:batch_end]
        
        for user_id in batch_user_ids:
            user_vector = user_vectors[user_id]
            user_sims = {}
            
            # Fast matrix multiplication for all movies at once
            user_vector_array = np.array(user_vector).reshape(1, -1)
            similarities = np.dot(user_vector_array, movie_vectors_array.T)[0]
            
            # Apply threshold and store result
            for i, sim in enumerate(similarities):
                if sim > threshold:
                    movie_id = movie_ids[i]
                    user_sims[movie_id] = float(sim)
            
            user_movie_similarities[user_id] = user_sims
        
        elapsed = time.time() - start_time
        progress = batch_end / total_users * 100
        remaining = (elapsed / (batch_end - batch_start)) * (total_users - batch_end) if batch_end < total_users else 0
        
        avg_similarities = np.mean([len(user_sims) for user_sims in user_movie_similarities.values() if user_sims])
        logger.info(f"Calculated similarities: {batch_end}/{total_users} users ({progress:.1f}%) - Avg similarities per user: {avg_similarities:.1f}")
        
        # Garbage collection
        gc.collect()
    
    return user_movie_similarities

def get_user_rated_movies(user_id, train_ratings, cached_rated_movies=None):
    """Get movies rated by a user from training data"""
    if cached_rated_movies is None:
        cached_rated_movies = {}
        
    if user_id in cached_rated_movies:
        return cached_rated_movies[user_id]
    
    if train_ratings is None:
        return set()
    
    user_data = train_ratings[train_ratings['userId'] == user_id]
    rated_movies = set(user_data['movieId'].values)
    
    cached_rated_movies[user_id] = rated_movies
    
    return rated_movies

def get_top_n_recommendations(user_id, user_movie_similarities, train_ratings, cached_rated_movies=None, n=10):
    """Generate top N movie recommendations for a user"""
    if user_id not in user_movie_similarities:
        return []
    
    rated_movies = get_user_rated_movies(user_id, train_ratings, cached_rated_movies)
    
    user_sims = user_movie_similarities[user_id]
    
    # Exclude already rated movies
    candidates = [(movie_id, sim) for movie_id, sim in user_sims.items() 
                 if movie_id not in rated_movies]
    
    # Sort by similarity score
    recommendations = sorted(candidates, key=lambda x: x[1], reverse=True)
    
    return recommendations[:n]

def predict_rating(user_id, movie_id, user_movie_similarities, train_ratings, user_bias_dict=None):
    """
    Predict a user's rating for a movie with improved methods.
    Adds user bias correction for more accurate predictions.
    """
    # If no user bias dictionary is provided, create an empty one
    if user_bias_dict is None:
        user_bias_dict = {}
    
    # If we don't have similarity data for this user, use fallback
    if user_id not in user_movie_similarities:
        # If we have rating data, return user average
        user_train = train_ratings[train_ratings['userId'] == user_id]
        if len(user_train) > 0:
            return user_train['rating'].mean()
        return 3.0  # Default average
    
    # Get the user's bias if we have it, otherwise calculate it
    if user_id in user_bias_dict:
        user_bias = user_bias_dict[user_id]
    else:
        user_train = train_ratings[train_ratings['userId'] == user_id]
        if len(user_train) > 0:
            user_avg = user_train['rating'].mean()
            # Calculate global average
            global_avg = train_ratings['rating'].mean()
            user_bias = user_avg - global_avg
        else:
            user_bias = 0.0
        user_bias_dict[user_id] = user_bias
    
    # If we have similarity for this movie, use it
    if movie_id in user_movie_similarities[user_id]:
        sim_score = user_movie_similarities[user_id][movie_id]
        
        # Convert similarity (0-1) to rating scale (0.5-5.0)
        base_prediction = 0.5 + 4.5 * sim_score
        
        # Apply user bias correction (damped to avoid extreme predictions)
        bias_weight = 0.7  # How much to consider user bias (0-1)
        predicted_rating = base_prediction + (bias_weight * user_bias)
        
        # Ensure the rating is within bounds
        return max(0.5, min(5.0, predicted_rating))
    
    # If we don't have similarity for this movie, use user average
    user_train = train_ratings[train_ratings['userId'] == user_id]
    if len(user_train) > 0:
        return user_train['rating'].mean()
    
    # Last resort - global average
    return train_ratings['rating'].mean() if len(train_ratings) > 0 else 3.0

def generate_recommendations_for_all_users(user_movie_similarities, train_ratings, movie_features, n=10, batch_size=100):
    """Generate recommendations for all users with improved batch processing"""
    start_time = time.time()
    
    cached_rated_movies = {}
    
    user_ids = list(user_movie_similarities.keys())
    total_users = len(user_ids)
    
    all_recommendations = {}
    users_with_recommendations = 0
    
    for batch_start in range(0, total_users, batch_size):
        batch_end = min(batch_start + batch_size, total_users)
        batch_user_ids = user_ids[batch_start:batch_end]
        
        batch_start_time = time.time()
        
        for user_id in batch_user_ids:
            recommendations = get_top_n_recommendations(
                user_id, 
                user_movie_similarities, 
                train_ratings, 
                cached_rated_movies,
                n
            )
            
            if recommendations:
                all_recommendations[user_id] = recommendations
                users_with_recommendations += 1
        
        batch_time = time.time() - batch_start_time
        elapsed = time.time() - start_time
        progress = batch_end / total_users * 100
        remaining = batch_time * ((total_users - batch_end) / len(batch_user_ids)) if batch_end < total_users else 0
        
        logger.info(f"Generated recommendations: {batch_end}/{total_users} users ({progress:.1f}%) - Users with recs: {users_with_recommendations}")
        
        # Garbage collection
        gc.collect()
    
    return all_recommendations

def evaluate_with_rmse_mae(user_movie_similarities, train_ratings, test_ratings, batch_size=100, rating_threshold=3.5):
    """
    Evaluate recommendation model using RMSE, MAE, and classification metrics.
    Added precision, recall, F1, and accuracy calculations.
    """
    print("Evaluating recommendation model using enhanced metrics with batching...")
    start_time = time.time()
    
    # Initialize metrics
    squared_errors_sum = 0
    absolute_errors_sum = 0
    total_predictions = 0
    users_evaluated = 0
    
    # Classification metrics
    true_positives = 0
    false_positives = 0
    true_negatives = 0
    false_negatives = 0
    
    # Dictionary to cache user biases
    user_bias_dict = {}
    
    # Calculate global stats once
    global_avg_rating = train_ratings['rating'].mean()
    
    # Calculate user biases in advance
    for user_id in train_ratings['userId'].unique():
        user_ratings = train_ratings[train_ratings['userId'] == user_id]
        if len(user_ratings) > 0:
            user_avg = user_ratings['rating'].mean()
            user_bias_dict[user_id] = user_avg - global_avg_rating
    
    # Find common users between training and test sets that have similarity data
    test_users = set(test_ratings['userId'].unique())
    train_users = set(train_ratings['userId'].unique())
    similarity_users = set(user_movie_similarities.keys())
    
    common_users = test_users.intersection(train_users).intersection(similarity_users)
    
    logger.info(f"Train users: {len(train_users)}, Test users: {len(test_users)}, Similarity users: {len(similarity_users)}")
    logger.info(f"Common users for evaluation: {len(common_users)}")
    
    if len(common_users) == 0:
        logger.warning("No common users between train, test, and similarity data")
        # Use baseline prediction (global average) for all test ratings
        predictions = np.full(len(test_ratings), global_avg_rating)
        actuals = test_ratings['rating'].values
        
        # Calculate RMSE and MAE
        rmse = np.sqrt(np.mean((predictions - actuals) ** 2))
        mae = np.mean(np.abs(predictions - actuals))
        
        # Convert to binary for classification metrics
        binary_preds = (predictions > rating_threshold).astype(int)
        binary_actuals = (actuals > rating_threshold).astype(int)
        
        # Calculate classification metrics
        accuracy = np.mean(binary_preds == binary_actuals)
        
        true_pos = np.sum((binary_preds == 1) & (binary_actuals == 1))
        false_pos = np.sum((binary_preds == 1) & (binary_actuals == 0))
        true_neg = np.sum((binary_preds == 0) & (binary_actuals == 0))
        false_neg = np.sum((binary_preds == 0) & (binary_actuals == 1))
        
        precision = true_pos / (true_pos + false_pos) if (true_pos + false_pos) > 0 else 0
        recall = true_pos / (true_pos + false_neg) if (true_pos + false_neg) > 0 else 0
        f1 = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0
        
        logger.info(f"Baseline evaluation with global average ({global_avg_rating:.2f}):")
        logger.info(f"RMSE: {rmse:.4f}, MAE: {mae:.4f}")
        logger.info(f"Accuracy: {accuracy:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}, F1: {f1:.4f}")
        
        return {
            'rmse': rmse,
            'mae': mae,
            'accuracy': accuracy,
            'precision': precision,
            'recall': recall,
            'f1_score': f1,
            'num_predictions': len(test_ratings)
        }
    
    # Process common users in batches
    user_list = list(common_users)
    for batch_start in range(0, len(user_list), batch_size):
        batch_end = min(batch_start + batch_size, len(user_list))
        batch_users = user_list[batch_start:batch_end]
        
        logger.info(f"Evaluating batch {batch_start//batch_size + 1}: users {batch_start+1}-{batch_end} of {len(user_list)}")
        batch_start_time = time.time()
        
        batch_squared_errors = 0
        batch_absolute_errors = 0
        batch_predictions = 0
        batch_true_positives = 0
        batch_false_positives = 0
        batch_true_negatives = 0
        batch_false_negatives = 0
        
        for user_id in batch_users:
            user_test_ratings = test_ratings[test_ratings['userId'] == user_id]
            
            if len(user_test_ratings) == 0:
                continue
            
            for _, row in user_test_ratings.iterrows():
                movie_id = row['movieId']
                true_rating = row['rating']
                
                # Make prediction
                predicted_rating = predict_rating(user_id, movie_id, user_movie_similarities, train_ratings, user_bias_dict)
                
                # Calculate error
                squared_error = (predicted_rating - true_rating) ** 2
                absolute_error = abs(predicted_rating - true_rating)
                
                # Classification metrics
                binary_prediction = 1 if predicted_rating > rating_threshold else 0
                binary_actual = 1 if true_rating > rating_threshold else 0
                
                if binary_prediction == 1 and binary_actual == 1:
                    batch_true_positives += 1
                elif binary_prediction == 1 and binary_actual == 0:
                    batch_false_positives += 1
                elif binary_prediction == 0 and binary_actual == 0:
                    batch_true_negatives += 1
                elif binary_prediction == 0 and binary_actual == 1:
                    batch_false_negatives += 1
                
                # Accumulate errors
                batch_squared_errors += squared_error
                batch_absolute_errors += absolute_error
                batch_predictions += 1
            
            users_evaluated += 1
        
        # Accumulate batch results
        squared_errors_sum += batch_squared_errors
        absolute_errors_sum += batch_absolute_errors
        total_predictions += batch_predictions
        true_positives += batch_true_positives
        false_positives += batch_false_positives
        true_negatives += batch_true_negatives
        false_negatives += batch_false_negatives
        
        batch_time = time.time() - batch_start_time
        elapsed = time.time() - start_time
        progress = batch_end / len(user_list) * 100
        remaining = batch_time * ((len(user_list) - batch_end) / len(batch_users)) if batch_end < len(user_list) else 0
        
        if batch_predictions > 0:
            batch_rmse = np.sqrt(batch_squared_errors / batch_predictions)
            batch_mae = batch_absolute_errors / batch_predictions
            batch_accuracy = (batch_true_positives + batch_true_negatives) / batch_predictions
            
            logger.info(f"Batch metrics - RMSE: {batch_rmse:.4f}, MAE: {batch_mae:.4f}, Accuracy: {batch_accuracy:.4f}")
            logger.info(f"TP: {batch_true_positives}, FP: {batch_false_positives}, TN: {batch_true_negatives}, FN: {batch_false_negatives}")
        
        logger.info(f"Processed {batch_end}/{len(user_list)} users ({progress:.1f}%) - Elapsed: {elapsed:.2f}s - Est. remaining: {remaining:.2f}s")
        
        # Garbage collection
        gc.collect()
    
    # Calculate final metrics
    if total_predictions > 0:
        rmse = np.sqrt(squared_errors_sum / total_predictions)
        mae = absolute_errors_sum / total_predictions
        
        # Classification metrics
        accuracy = (true_positives + true_negatives) / total_predictions
        precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) > 0 else 0
        recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) > 0 else 0
        f1 = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0
    else:
        rmse = 0.0
        mae = 0.0
        accuracy = 0.0
        precision = 0.0
        recall = 0.0
        f1 = 0.0
    
    logger.info("\nEvaluation results:")
    logger.info(f"Users evaluated: {users_evaluated}")
    logger.info(f"Total predictions: {total_predictions}")
    logger.info(f"RMSE: {rmse:.4f}")
    logger.info(f"MAE: {mae:.4f}")
    logger.info(f"Accuracy: {accuracy:.4f}")
    logger.info(f"Precision: {precision:.4f}")
    logger.info(f"Recall: {recall:.4f}")
    logger.info(f"F1 Score: {f1:.4f}")
    logger.info(f"Confusion Matrix: [TP: {true_positives}, FP: {false_positives}, TN: {true_negatives}, FN: {false_negatives}]")
    
    metrics = {
        'rmse': rmse,
        'mae': mae,
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1,
        'true_positives': true_positives,
        'false_positives': false_positives,
        'true_negatives': true_negatives,
        'false_negatives': false_negatives,
        'num_users_evaluated': users_evaluated,
        'num_predictions': total_predictions
    }
    
    return metrics

# Main execution flow with all optimizations
log_memory_usage("Initial memory usage")

# Load data
data = load_data()
log_memory_usage("After loading data")

# Corpus word counts
if 'movie_features' in data:
    corpus_word_counts = Counter()
    
    batch_size = 1000
    total_movies = len(data['movie_features'])
    
    for i in range(0, total_movies, batch_size):
        batch_end = min(i + batch_size, total_movies)
        batch = data['movie_features'].iloc[i:batch_end]
        
        for tokens in batch['tokens']:
            corpus_word_counts.update(tokens)
    
    data['corpus_word_counts'] = corpus_word_counts
    
    with open(os.path.join(output_path, 'corpus_word_counts.pkl'), 'wb') as f:
        pickle.dump(corpus_word_counts, f)
    
    logger.info(f"Created corpus word counts with {len(corpus_word_counts)} unique words")
    gc.collect()
    log_memory_usage("After corpus word count")

# Calculate Log-Likelihood values
if 'movie_features' in data and 'corpus_word_counts' in data:
    movie_ll_values = calculate_log_likelihood(data['movie_features'], data['corpus_word_counts'], batch_size=100)
    data['movie_ll_values'] = movie_ll_values
    
    with open(os.path.join(output_path, 'movie_ll_values.pkl'), 'wb') as f:
        pickle.dump(movie_ll_values, f)
    
    logger.info(f"Calculated LL values for {len(movie_ll_values)} movies")
    gc.collect()
    log_memory_usage("After LL calculation")

# Train Word2Vec model
if 'movie_features' in data:
    word2vec_model = train_word2vec(data['movie_features'], word2vec_dim)
    data['word2vec_model'] = word2vec_model
    
    word2vec_path = os.path.join(output_path, 'word2vec_model')
    word2vec_model.save(word2vec_path)
    
    logger.info(f"Trained Word2Vec model with vector size {word2vec_dim}")
    gc.collect()
    log_memory_usage("After Word2Vec training")

# Generate movie vectors
if 'word2vec_model' in data and 'movie_ll_values' in data and 'corpus_word_counts' in data:
    movie_vectors = generate_movie_vectors(
        data['movie_ll_values'], 
        data['word2vec_model'],
        data['movie_features'],
        data['corpus_word_counts'],
        batch_size=100
    )
    data['movie_vectors'] = movie_vectors
    
    with open(os.path.join(output_path, 'movie_vectors.pkl'), 'wb') as f:
        pickle.dump(movie_vectors, f)
    
    logger.info(f"Generated vectors for {len(movie_vectors)} movies")
    
    # Create movie ID to index mapping
    movie_id_to_idx = {movie_id: i for i, movie_id in enumerate(movie_vectors.keys())}
    data['movie_id_to_idx'] = movie_id_to_idx
    
    with open(os.path.join(output_path, 'movie_id_to_idx.pkl'), 'wb') as f:
        pickle.dump(movie_id_to_idx, f)
    
    gc.collect()
    log_memory_usage("After movie vector generation")

# Generate user vectors
if 'movie_vectors' in data and 'train_ratings' in data:
    user_vectors = generate_user_vectors(data['movie_vectors'], data['train_ratings'], batch_size=100)
    data['user_vectors'] = user_vectors
    
    with open(os.path.join(output_path, 'user_vectors.pkl'), 'wb') as f:
        pickle.dump(user_vectors, f)
    
    logger.info(f"Generated vectors for {len(user_vectors)} users")
    
    # Create user ID to index mapping
    user_id_to_idx = {user_id: i for i, user_id in enumerate(user_vectors.keys())}
    data['user_id_to_idx'] = user_id_to_idx
    
    with open(os.path.join(output_path, 'user_id_to_idx.pkl'), 'wb') as f:
        pickle.dump(user_id_to_idx, f)
    
    gc.collect()
    log_memory_usage("After user vector generation")

# Calculate user-movie similarities
if 'user_vectors' in data and 'movie_vectors' in data:
    user_movie_similarities = calculate_user_movie_similarity(
        data['user_vectors'], 
        data['movie_vectors'], 
        threshold=similarity_threshold,
        batch_size=50
    )
    data['user_movie_similarities'] = user_movie_similarities
    
    with open(os.path.join(output_path, 'user_movie_similarities.pkl'), 'wb') as f:
        pickle.dump(user_movie_similarities, f)
    
    logger.info(f"Calculated similarities for {len(user_movie_similarities)} users")
    gc.collect()
    log_memory_usage("After similarity calculation")

# Generate recommendations
if 'user_movie_similarities' in data and 'train_ratings' in data:
    all_recommendations = generate_recommendations_for_all_users(
        data['user_movie_similarities'], 
        data['train_ratings'],
        data['movie_features'],
        n=top_n,
        batch_size=100
    )
    data['all_recommendations'] = all_recommendations
    
    with open(os.path.join(output_path, 'content_based_recommendations.pkl'), 'wb') as f:
        pickle.dump(all_recommendations, f)
    
    logger.info(f"Generated recommendations for {len(all_recommendations)} users")
    
    # Save to CSV in chunks for better memory handling
    recommendations_list = []
    
    chunk_size = 1000
    user_ids = list(all_recommendations.keys())
    total_users = len(user_ids)
    
    for chunk_start in range(0, total_users, chunk_size):
        chunk_end = min(chunk_start + chunk_size, total_users)
        user_chunk = user_ids[chunk_start:chunk_end]
        
        chunk_recommendations = []
        for user_id in user_chunk:
            for rank, (movie_id, score) in enumerate(all_recommendations[user_id], 1):
                movie_title = "Unknown"
                if 'movie_features' in data:
                    movie_row = data['movie_features'][data['movie_features']['movieId'] == movie_id]
                    if not movie_row.empty and 'title' in movie_row.columns:
                        movie_title = movie_row.iloc[0]['title']
                        
                chunk_recommendations.append({
                    'userId': user_id,
                    'movieId': movie_id,
                    'title': movie_title,
                    'rank': rank,
                    'similarity_score': score
                })
        
        recommendations_list.extend(chunk_recommendations)
        gc.collect()
    
    if recommendations_list:
        chunk_size = 10000
        total_recs = len(recommendations_list)
        
        for chunk_start in range(0, total_recs, chunk_size):
            chunk_end = min(chunk_start + chunk_size, total_recs)
            chunk = recommendations_list[chunk_start:chunk_end]
            
            chunk_df = pd.DataFrame(chunk)
            
            # Write header only for the first chunk
            if chunk_start == 0:
                chunk_df.to_csv(os.path.join(output_path, 'content_based_recommendations.csv'), index=False, mode='w')
            else:
                chunk_df.to_csv(os.path.join(output_path, 'content_based_recommendations.csv'), index=False, mode='a', header=False)
    
    del recommendations_list
    gc.collect()
    log_memory_usage("After recommendation generation")

# Evaluate the model
if 'user_movie_similarities' in data and 'train_ratings' in data and 'test_ratings' in data:
    logger.info("Running evaluation with enhanced metrics...")
    evaluation_metrics = evaluate_with_rmse_mae(
        data['user_movie_similarities'],
        data['train_ratings'],
        data['test_ratings'],
        batch_size=100,
        rating_threshold=rating_threshold
    )
    
    data['evaluation_metrics'] = evaluation_metrics
    
    logger.info("\nStored evaluation metrics:")
    for key, value in evaluation_metrics.items():
        logger.info(f"  {key}: {value}")
    
    # Save evaluation results
    evaluation_results = pd.DataFrame([evaluation_metrics])
    evaluation_results.to_csv(os.path.join(output_path, 'content_based_evaluation.csv'), index=False)
    
    # Create visualizations for evaluation metrics
    if 'rmse' in evaluation_metrics:
        # Plot confusion matrix
        plt.figure(figsize=(10, 8))
        cm = np.array([
            [evaluation_metrics.get('true_negatives', 0), evaluation_metrics.get('false_positives', 0)],
            [evaluation_metrics.get('false_negatives', 0), evaluation_metrics.get('true_positives', 0)]
        ])
        
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                   xticklabels=['Predicted Negative', 'Predicted Positive'],
                   yticklabels=['Actual Negative', 'Actual Positive'])
        plt.title('Confusion Matrix')
        plt.savefig(os.path.join(output_path, 'confusion_matrix.png'))
        plt.close()
        
        # Create a bar chart comparing all metrics
        metrics_to_plot = ['accuracy', 'precision', 'recall', 'f1_score']
        values = [evaluation_metrics.get(metric, 0) for metric in metrics_to_plot]
        
        plt.figure(figsize=(10, 6))
        colors = ['skyblue', 'lightgreen', 'salmon', 'gold']
        plt.bar(metrics_to_plot, values, color=colors)
        plt.ylim(0, 1)
        plt.title('Classification Performance Metrics')
        plt.grid(axis='y', alpha=0.3)
        plt.savefig(os.path.join(output_path, 'classification_metrics.png'))
        plt.close()
        
        logger.info("Created evaluation visualizations")
    
    gc.collect()
    log_memory_usage("After evaluation")

logger.info("Content-based recommendation pipeline completed successfully!")
# Out:
# 2025-04-26 00:40:02,969 : INFO : Initial memory usage: 320.52 MB
# 2025-04-26 00:40:04,329 : INFO : Loaded features for 21710 movies
# 2025-04-26 00:40:13,235 : INFO : Loaded 7242715 ratings from 50000 users
# 2025-04-26 00:40:31,219 : INFO : Created train set with 6946293 ratings from 50000 users
# 2025-04-26 00:40:31,223 : INFO : Created test set with 296422 ratings from 10000 users
# 2025-04-26 00:40:31,395 : INFO : After loading data: 948.94 MB
# 2025-04-26 00:40:31,499 : INFO : Created corpus word counts with 78298 unique words
# 2025-04-26 00:40:31,570 : INFO : After corpus word count: 940.04 MB
# 2025-04-26 00:40:32,129 : INFO : Processed 100/21710 movies (0.5%) - Elapsed: 0.56s - Est. remaining: 120.73s
# 2025-04-26 00:40:32,230 : INFO : Processed 200/21710 movies (0.9%) - Elapsed: 0.66s - Est. remaining: 141.70s
# 2025-04-26 00:40:32,339 : INFO : Processed 300/21710 movies (1.4%) - Elapsed: 0.77s - Est. remaining: 164.38s
# 2025-04-26 00:40:32,453 : INFO : Processed 400/21710 movies (1.8%) - Elapsed: 0.88s - Est. remaining: 187.70s
# 2025-04-26 00:40:32,561 : INFO : Processed 500/21710 movies (2.3%) - Elapsed: 0.99s - Est. remaining: 209.98s
# 2025-04-26 00:40:32,675 : INFO : Processed 600/21710 movies (2.8%) - Elapsed: 1.10s - Est. remaining: 233.10s
# 2025-04-26 00:40:32,784 : INFO : Processed 700/21710 movies (3.2%) - Elapsed: 1.21s - Est. remaining: 254.82s
# 2025-04-26 00:40:32,870 : INFO : Processed 800/21710 movies (3.7%) - Elapsed: 1.30s - Est. remaining: 271.65s
# 2025-04-26 00:40:32,957 : INFO : Processed 900/21710 movies (4.1%) - Elapsed: 1.39s - Est. remaining: 288.40s
# 2025-04-26 00:40:33,053 : INFO : Processed 1000/21710 movies (4.6%) - Elapsed: 1.48s - Est. remaining: 307.04s
# 2025-04-26 00:40:33,143 : INFO : Processed 1100/21710 movies (5.1%) - Elapsed: 1.57s - Est. remaining: 324.03s
# 2025-04-26 00:40:33,261 : INFO : Processed 1200/21710 movies (5.5%) - Elapsed: 1.69s - Est. remaining: 346.68s
# 2025-04-26 00:40:33,348 : INFO : Processed 1300/21710 movies (6.0%) - Elapsed: 1.78s - Est. remaining: 362.76s
# 2025-04-26 00:40:33,459 : INFO : Processed 1400/21710 movies (6.4%) - Elapsed: 1.89s - Est. remaining: 383.46s
# 2025-04-26 00:40:33,573 : INFO : Processed 1500/21710 movies (6.9%) - Elapsed: 2.00s - Est. remaining: 404.74s
# 2025-04-26 00:40:33,651 : INFO : Processed 1600/21710 movies (7.4%) - Elapsed: 2.08s - Est. remaining: 418.25s
# 2025-04-26 00:40:33,732 : INFO : Processed 1700/21710 movies (7.8%) - Elapsed: 2.16s - Est. remaining: 432.46s
# 2025-04-26 00:40:33,835 : INFO : Processed 1800/21710 movies (8.3%) - Elapsed: 2.26s - Est. remaining: 450.74s
# 2025-04-26 00:40:33,917 : INFO : Processed 1900/21710 movies (8.8%) - Elapsed: 2.35s - Est. remaining: 464.79s
# 2025-04-26 00:40:33,990 : INFO : Processed 2000/21710 movies (9.2%) - Elapsed: 2.42s - Est. remaining: 476.80s
# 2025-04-26 00:40:34,065 : INFO : Processed 2100/21710 movies (9.7%) - Elapsed: 2.49s - Est. remaining: 489.14s
# 2025-04-26 00:40:34,134 : INFO : Processed 2200/21710 movies (10.1%) - Elapsed: 2.56s - Est. remaining: 500.09s
# 2025-04-26 00:40:34,207 : INFO : Processed 2300/21710 movies (10.6%) - Elapsed: 2.64s - Est. remaining: 511.67s
# 2025-04-26 00:40:34,297 : INFO : Processed 2400/21710 movies (11.1%) - Elapsed: 2.73s - Est. remaining: 526.36s
# 2025-04-26 00:40:34,373 : INFO : Processed 2500/21710 movies (11.5%) - Elapsed: 2.80s - Est. remaining: 538.34s
# 2025-04-26 00:40:34,447 : INFO : Processed 2600/21710 movies (12.0%) - Elapsed: 2.88s - Est. remaining: 549.75s
# 2025-04-26 00:40:34,523 : INFO : Processed 2700/21710 movies (12.4%) - Elapsed: 2.95s - Est. remaining: 561.25s
# 2025-04-26 00:40:34,609 : INFO : Processed 2800/21710 movies (12.9%) - Elapsed: 3.04s - Est. remaining: 574.45s
# 2025-04-26 00:40:34,717 : INFO : Processed 2900/21710 movies (13.4%) - Elapsed: 3.15s - Est. remaining: 591.72s
# 2025-04-26 00:40:34,788 : INFO : Processed 3000/21710 movies (13.8%) - Elapsed: 3.22s - Est. remaining: 602.04s
# 2025-04-26 00:40:34,862 : INFO : Processed 3100/21710 movies (14.3%) - Elapsed: 3.29s - Est. remaining: 612.53s
# 2025-04-26 00:40:34,945 : INFO : Processed 3200/21710 movies (14.7%) - Elapsed: 3.37s - Est. remaining: 624.35s
# 2025-04-26 00:40:35,021 : INFO : Processed 3300/21710 movies (15.2%) - Elapsed: 3.45s - Est. remaining: 635.27s
# 2025-04-26 00:40:35,096 : INFO : Processed 3400/21710 movies (15.7%) - Elapsed: 3.53s - Est. remaining: 645.53s
# 2025-04-26 00:40:35,168 : INFO : Processed 3500/21710 movies (16.1%) - Elapsed: 3.60s - Est. remaining: 655.03s
# 2025-04-26 00:40:35,242 : INFO : Processed 3600/21710 movies (16.6%) - Elapsed: 3.67s - Est. remaining: 664.81s
# 2025-04-26 00:40:35,312 : INFO : Processed 3700/21710 movies (17.0%) - Elapsed: 3.74s - Est. remaining: 673.74s
# 2025-04-26 00:40:35,398 : INFO : Processed 3800/21710 movies (17.5%) - Elapsed: 3.83s - Est. remaining: 685.52s
# 2025-04-26 00:40:35,474 : INFO : Processed 3900/21710 movies (18.0%) - Elapsed: 3.90s - Est. remaining: 695.12s
# 2025-04-26 00:40:35,551 : INFO : Processed 4000/21710 movies (18.4%) - Elapsed: 3.98s - Est. remaining: 704.86s
# 2025-04-26 00:40:35,624 : INFO : Processed 4100/21710 movies (18.9%) - Elapsed: 4.05s - Est. remaining: 713.75s
# 2025-04-26 00:40:35,720 : INFO : Processed 4200/21710 movies (19.3%) - Elapsed: 4.15s - Est. remaining: 726.53s
# 2025-04-26 00:40:35,853 : INFO : Processed 4300/21710 movies (19.8%) - Elapsed: 4.28s - Est. remaining: 745.54s
# 2025-04-26 00:40:35,985 : INFO : Processed 4400/21710 movies (20.3%) - Elapsed: 4.41s - Est. remaining: 764.14s
# 2025-04-26 00:40:36,062 : INFO : Processed 4500/21710 movies (20.7%) - Elapsed: 4.49s - Est. remaining: 772.86s
# 2025-04-26 00:40:36,174 : INFO : Processed 4600/21710 movies (21.2%) - Elapsed: 4.60s - Est. remaining: 787.37s
# 2025-04-26 00:40:36,358 : INFO : Processed 4700/21710 movies (21.6%) - Elapsed: 4.79s - Est. remaining: 814.39s
# 2025-04-26 00:40:36,504 : INFO : Processed 4800/21710 movies (22.1%) - Elapsed: 4.93s - Est. remaining: 834.15s
# 2025-04-26 00:40:36,589 : INFO : Processed 4900/21710 movies (22.6%) - Elapsed: 5.02s - Est. remaining: 843.52s
# 2025-04-26 00:40:36,691 : INFO : Processed 5000/21710 movies (23.0%) - Elapsed: 5.12s - Est. remaining: 855.54s
# 2025-04-26 00:40:36,802 : INFO : Processed 5100/21710 movies (23.5%) - Elapsed: 5.23s - Est. remaining: 868.90s
# 2025-04-26 00:40:36,917 : INFO : Processed 5200/21710 movies (24.0%) - Elapsed: 5.35s - Est. remaining: 882.62s
# 2025-04-26 00:40:37,031 : INFO : Processed 5300/21710 movies (24.4%) - Elapsed: 5.46s - Est. remaining: 896.04s
# 2025-04-26 00:40:37,139 : INFO : Processed 5400/21710 movies (24.9%) - Elapsed: 5.57s - Est. remaining: 908.25s
# 2025-04-26 00:40:37,244 : INFO : Processed 5500/21710 movies (25.3%) - Elapsed: 5.67s - Est. remaining: 919.61s
# 2025-04-26 00:40:37,343 : INFO : Processed 5600/21710 movies (25.8%) - Elapsed: 5.77s - Est. remaining: 929.89s
# 2025-04-26 00:40:37,415 : INFO : Processed 5700/21710 movies (26.3%) - Elapsed: 5.84s - Est. remaining: 935.61s
# 2025-04-26 00:40:37,502 : INFO : Processed 5800/21710 movies (26.7%) - Elapsed: 5.93s - Est. remaining: 943.66s
# 2025-04-26 00:40:37,601 : INFO : Processed 5900/21710 movies (27.2%) - Elapsed: 6.03s - Est. remaining: 953.35s
# 2025-04-26 00:40:37,680 : INFO : Processed 6000/21710 movies (27.6%) - Elapsed: 6.11s - Est. remaining: 959.77s
# 2025-04-26 00:40:37,786 : INFO : Processed 6100/21710 movies (28.1%) - Elapsed: 6.21s - Est. remaining: 970.14s
# 2025-04-26 00:40:37,865 : INFO : Processed 6200/21710 movies (28.6%) - Elapsed: 6.29s - Est. remaining: 976.31s
# 2025-04-26 00:40:37,941 : INFO : Processed 6300/21710 movies (29.0%) - Elapsed: 6.37s - Est. remaining: 981.60s
# 2025-04-26 00:40:38,043 : INFO : Processed 6400/21710 movies (29.5%) - Elapsed: 6.47s - Est. remaining: 990.84s
# 2025-04-26 00:40:38,166 : INFO : Processed 6500/21710 movies (29.9%) - Elapsed: 6.60s - Est. remaining: 1003.13s
# 2025-04-26 00:40:38,255 : INFO : Processed 6600/21710 movies (30.4%) - Elapsed: 6.68s - Est. remaining: 1009.99s
# 2025-04-26 00:40:38,341 : INFO : Processed 6700/21710 movies (30.9%) - Elapsed: 6.77s - Est. remaining: 1016.27s
# 2025-04-26 00:40:38,412 : INFO : Processed 6800/21710 movies (31.3%) - Elapsed: 6.84s - Est. remaining: 1020.02s
# 2025-04-26 00:40:38,500 : INFO : Processed 6900/21710 movies (31.8%) - Elapsed: 6.93s - Est. remaining: 1026.15s
# 2025-04-26 00:40:38,571 : INFO : Processed 7000/21710 movies (32.2%) - Elapsed: 7.00s - Est. remaining: 1029.74s
# 2025-04-26 00:40:38,674 : INFO : Processed 7100/21710 movies (32.7%) - Elapsed: 7.10s - Est. remaining: 1037.71s
# 2025-04-26 00:40:38,750 : INFO : Processed 7200/21710 movies (33.2%) - Elapsed: 7.18s - Est. remaining: 1041.78s
# 2025-04-26 00:40:38,836 : INFO : Processed 7300/21710 movies (33.6%) - Elapsed: 7.27s - Est. remaining: 1046.91s
# 2025-04-26 00:40:38,917 : INFO : Processed 7400/21710 movies (34.1%) - Elapsed: 7.35s - Est. remaining: 1051.29s
# 2025-04-26 00:40:38,989 : INFO : Processed 7500/21710 movies (34.5%) - Elapsed: 7.42s - Est. remaining: 1054.11s
# 2025-04-26 00:40:39,072 : INFO : Processed 7600/21710 movies (35.0%) - Elapsed: 7.50s - Est. remaining: 1058.45s
# 2025-04-26 00:40:39,147 : INFO : Processed 7700/21710 movies (35.5%) - Elapsed: 7.58s - Est. remaining: 1061.47s
# 2025-04-26 00:40:39,228 : INFO : Processed 7800/21710 movies (35.9%) - Elapsed: 7.66s - Est. remaining: 1065.16s
# 2025-04-26 00:40:39,344 : INFO : Processed 7900/21710 movies (36.4%) - Elapsed: 7.77s - Est. remaining: 1073.52s
# 2025-04-26 00:40:39,428 : INFO : Processed 8000/21710 movies (36.8%) - Elapsed: 7.86s - Est. remaining: 1077.22s
# 2025-04-26 00:40:39,515 : INFO : Processed 8100/21710 movies (37.3%) - Elapsed: 7.94s - Est. remaining: 1081.17s
# 2025-04-26 00:40:39,588 : INFO : Processed 8200/21710 movies (37.8%) - Elapsed: 8.02s - Est. remaining: 1083.16s
# 2025-04-26 00:40:39,681 : INFO : Processed 8300/21710 movies (38.2%) - Elapsed: 8.11s - Est. remaining: 1087.56s
# 2025-04-26 00:40:39,759 : INFO : Processed 8400/21710 movies (38.7%) - Elapsed: 8.19s - Est. remaining: 1089.81s
# 2025-04-26 00:40:39,837 : INFO : Processed 8500/21710 movies (39.2%) - Elapsed: 8.27s - Est. remaining: 1092.00s
# 2025-04-26 00:40:39,917 : INFO : Processed 8600/21710 movies (39.6%) - Elapsed: 8.35s - Est. remaining: 1094.22s
# 2025-04-26 00:40:39,997 : INFO : Processed 8700/21710 movies (40.1%) - Elapsed: 8.43s - Est. remaining: 1096.25s
# 2025-04-26 00:40:40,070 : INFO : Processed 8800/21710 movies (40.5%) - Elapsed: 8.50s - Est. remaining: 1097.31s
# 2025-04-26 00:40:40,146 : INFO : Processed 8900/21710 movies (41.0%) - Elapsed: 8.58s - Est. remaining: 1098.46s
# 2025-04-26 00:40:40,239 : INFO : Processed 9000/21710 movies (41.5%) - Elapsed: 8.67s - Est. remaining: 1101.68s
# 2025-04-26 00:40:40,415 : INFO : Processed 9100/21710 movies (41.9%) - Elapsed: 8.84s - Est. remaining: 1115.24s
# 2025-04-26 00:40:40,528 : INFO : Processed 9200/21710 movies (42.4%) - Elapsed: 8.96s - Est. remaining: 1120.61s
# 2025-04-26 00:40:40,661 : INFO : Processed 9300/21710 movies (42.8%) - Elapsed: 9.09s - Est. remaining: 1128.15s
# 2025-04-26 00:40:40,763 : INFO : Processed 9400/21710 movies (43.3%) - Elapsed: 9.19s - Est. remaining: 1131.56s
# 2025-04-26 00:40:40,866 : INFO : Processed 9500/21710 movies (43.8%) - Elapsed: 9.30s - Est. remaining: 1134.93s
# 2025-04-26 00:40:40,975 : INFO : Processed 9600/21710 movies (44.2%) - Elapsed: 9.40s - Est. remaining: 1138.86s
# 2025-04-26 00:40:41,051 : INFO : Processed 9700/21710 movies (44.7%) - Elapsed: 9.48s - Est. remaining: 1138.61s
# 2025-04-26 00:40:41,137 : INFO : Processed 9800/21710 movies (45.1%) - Elapsed: 9.57s - Est. remaining: 1139.30s
# 2025-04-26 00:40:41,213 : INFO : Processed 9900/21710 movies (45.6%) - Elapsed: 9.64s - Est. remaining: 1138.70s
# 2025-04-26 00:40:41,289 : INFO : Processed 10000/21710 movies (46.1%) - Elapsed: 9.72s - Est. remaining: 1137.99s
# 2025-04-26 00:40:41,374 : INFO : Processed 10100/21710 movies (46.5%) - Elapsed: 9.80s - Est. remaining: 1138.19s
# 2025-04-26 00:40:41,459 : INFO : Processed 10200/21710 movies (47.0%) - Elapsed: 9.89s - Est. remaining: 1138.11s
# 2025-04-26 00:40:41,534 : INFO : Processed 10300/21710 movies (47.4%) - Elapsed: 9.96s - Est. remaining: 1136.83s
# 2025-04-26 00:40:41,618 : INFO : Processed 10400/21710 movies (47.9%) - Elapsed: 10.05s - Est. remaining: 1136.36s
# 2025-04-26 00:40:41,716 : INFO : Processed 10500/21710 movies (48.4%) - Elapsed: 10.15s - Est. remaining: 1137.29s
# 2025-04-26 00:40:41,837 : INFO : Processed 10600/21710 movies (48.8%) - Elapsed: 10.27s - Est. remaining: 1140.55s
# 2025-04-26 00:40:41,935 : INFO : Processed 10700/21710 movies (49.3%) - Elapsed: 10.36s - Est. remaining: 1141.16s
# 2025-04-26 00:40:42,017 : INFO : Processed 10800/21710 movies (49.7%) - Elapsed: 10.45s - Est. remaining: 1139.67s
# 2025-04-26 00:40:42,088 : INFO : Processed 10900/21710 movies (50.2%) - Elapsed: 10.52s - Est. remaining: 1136.91s
# 2025-04-26 00:40:42,203 : INFO : Processed 11000/21710 movies (50.7%) - Elapsed: 10.63s - Est. remaining: 1138.75s
# 2025-04-26 00:40:42,278 : INFO : Processed 11100/21710 movies (51.1%) - Elapsed: 10.71s - Est. remaining: 1136.05s
# 2025-04-26 00:40:42,353 : INFO : Processed 11200/21710 movies (51.6%) - Elapsed: 10.78s - Est. remaining: 1133.22s
# 2025-04-26 00:40:42,439 : INFO : Processed 11300/21710 movies (52.0%) - Elapsed: 10.87s - Est. remaining: 1131.42s
# 2025-04-26 00:40:42,566 : INFO : Processed 11400/21710 movies (52.5%) - Elapsed: 11.00s - Est. remaining: 1133.61s
# 2025-04-26 00:40:42,657 : INFO : Processed 11500/21710 movies (53.0%) - Elapsed: 11.09s - Est. remaining: 1131.95s
# 2025-04-26 00:40:42,737 : INFO : Processed 11600/21710 movies (53.4%) - Elapsed: 11.17s - Est. remaining: 1128.88s
# 2025-04-26 00:40:42,813 : INFO : Processed 11700/21710 movies (53.9%) - Elapsed: 11.24s - Est. remaining: 1125.39s
# 2025-04-26 00:40:42,899 : INFO : Processed 11800/21710 movies (54.4%) - Elapsed: 11.33s - Est. remaining: 1122.59s
# 2025-04-26 00:40:42,976 : INFO : Processed 11900/21710 movies (54.8%) - Elapsed: 11.40s - Est. remaining: 1118.82s
# 2025-04-26 00:40:43,047 : INFO : Processed 12000/21710 movies (55.3%) - Elapsed: 11.48s - Est. remaining: 1114.37s
# 2025-04-26 00:40:43,139 : INFO : Processed 12100/21710 movies (55.7%) - Elapsed: 11.57s - Est. remaining: 1111.67s
# 2025-04-26 00:40:43,237 : INFO : Processed 12200/21710 movies (56.2%) - Elapsed: 11.67s - Est. remaining: 1109.43s
# 2025-04-26 00:40:43,400 : INFO : Processed 12300/21710 movies (56.7%) - Elapsed: 11.83s - Est. remaining: 1113.10s
# 2025-04-26 00:40:43,515 : INFO : Processed 12400/21710 movies (57.1%) - Elapsed: 11.94s - Est. remaining: 1112.02s
# 2025-04-26 00:40:43,722 : INFO : Processed 12500/21710 movies (57.6%) - Elapsed: 12.15s - Est. remaining: 1119.16s
# 2025-04-26 00:40:43,795 : INFO : Processed 12600/21710 movies (58.0%) - Elapsed: 12.22s - Est. remaining: 1113.67s
# 2025-04-26 00:40:43,888 : INFO : Processed 12700/21710 movies (58.5%) - Elapsed: 12.32s - Est. remaining: 1109.75s
# 2025-04-26 00:40:44,026 : INFO : Processed 12800/21710 movies (59.0%) - Elapsed: 12.46s - Est. remaining: 1109.77s
# 2025-04-26 00:40:44,135 : INFO : Processed 12900/21710 movies (59.4%) - Elapsed: 12.56s - Est. remaining: 1106.92s
# 2025-04-26 00:40:44,243 : INFO : Processed 13000/21710 movies (59.9%) - Elapsed: 12.67s - Est. remaining: 1103.76s
# 2025-04-26 00:40:44,352 : INFO : Processed 13100/21710 movies (60.3%) - Elapsed: 12.78s - Est. remaining: 1100.49s
# 2025-04-26 00:40:44,459 : INFO : Processed 13200/21710 movies (60.8%) - Elapsed: 12.89s - Est. remaining: 1096.77s
# 2025-04-26 00:40:44,561 : INFO : Processed 13300/21710 movies (61.3%) - Elapsed: 12.99s - Est. remaining: 1092.47s
# 2025-04-26 00:40:44,668 : INFO : Processed 13400/21710 movies (61.7%) - Elapsed: 13.10s - Est. remaining: 1088.41s
# 2025-04-26 00:40:44,820 : INFO : Processed 13500/21710 movies (62.2%) - Elapsed: 13.25s - Est. remaining: 1087.79s
# 2025-04-26 00:40:44,967 : INFO : Processed 13600/21710 movies (62.6%) - Elapsed: 13.40s - Est. remaining: 1086.42s
# 2025-04-26 00:40:45,162 : INFO : Processed 13700/21710 movies (63.1%) - Elapsed: 13.59s - Est. remaining: 1088.70s
# 2025-04-26 00:40:45,267 : INFO : Processed 13800/21710 movies (63.6%) - Elapsed: 13.70s - Est. remaining: 1083.41s
# 2025-04-26 00:40:45,376 : INFO : Processed 13900/21710 movies (64.0%) - Elapsed: 13.81s - Est. remaining: 1078.21s
# 2025-04-26 00:40:45,475 : INFO : Processed 14000/21710 movies (64.5%) - Elapsed: 13.90s - Est. remaining: 1072.00s
# 2025-04-26 00:40:45,583 : INFO : Processed 14100/21710 movies (64.9%) - Elapsed: 14.01s - Est. remaining: 1066.35s
# 2025-04-26 00:40:45,694 : INFO : Processed 14200/21710 movies (65.4%) - Elapsed: 14.12s - Est. remaining: 1060.68s
# 2025-04-26 00:40:45,855 : INFO : Processed 14300/21710 movies (65.9%) - Elapsed: 14.28s - Est. remaining: 1058.49s
# 2025-04-26 00:40:45,972 : INFO : Processed 14400/21710 movies (66.3%) - Elapsed: 14.40s - Est. remaining: 1052.72s
# 2025-04-26 00:40:46,096 : INFO : Processed 14500/21710 movies (66.8%) - Elapsed: 14.53s - Est. remaining: 1047.27s
# 2025-04-26 00:40:46,223 : INFO : Processed 14600/21710 movies (67.3%) - Elapsed: 14.65s - Est. remaining: 1041.78s
# 2025-04-26 00:40:46,322 : INFO : Processed 14700/21710 movies (67.7%) - Elapsed: 14.75s - Est. remaining: 1034.09s
# 2025-04-26 00:40:46,410 : INFO : Processed 14800/21710 movies (68.2%) - Elapsed: 14.84s - Est. remaining: 1025.40s
# 2025-04-26 00:40:46,497 : INFO : Processed 14900/21710 movies (68.6%) - Elapsed: 14.93s - Est. remaining: 1016.45s
# 2025-04-26 00:40:46,579 : INFO : Processed 15000/21710 movies (69.1%) - Elapsed: 15.01s - Est. remaining: 1007.07s
# 2025-04-26 00:40:46,696 : INFO : Processed 15100/21710 movies (69.6%) - Elapsed: 15.12s - Est. remaining: 999.73s
# 2025-04-26 00:40:46,776 : INFO : Processed 15200/21710 movies (70.0%) - Elapsed: 15.20s - Est. remaining: 989.84s
# 2025-04-26 00:40:46,864 : INFO : Processed 15300/21710 movies (70.5%) - Elapsed: 15.29s - Est. remaining: 980.30s
# 2025-04-26 00:40:46,950 : INFO : Processed 15400/21710 movies (70.9%) - Elapsed: 15.38s - Est. remaining: 970.40s
# 2025-04-26 00:40:47,029 : INFO : Processed 15500/21710 movies (71.4%) - Elapsed: 15.46s - Est. remaining: 959.93s
# 2025-04-26 00:40:47,130 : INFO : Processed 15600/21710 movies (71.9%) - Elapsed: 15.56s - Est. remaining: 950.65s
# 2025-04-26 00:40:47,260 : INFO : Processed 15700/21710 movies (72.3%) - Elapsed: 15.69s - Est. remaining: 942.92s
# 2025-04-26 00:40:47,388 : INFO : Processed 15800/21710 movies (72.8%) - Elapsed: 15.82s - Est. remaining: 934.78s
# 2025-04-26 00:40:47,518 : INFO : Processed 15900/21710 movies (73.2%) - Elapsed: 15.95s - Est. remaining: 926.52s
# 2025-04-26 00:40:47,635 : INFO : Processed 16000/21710 movies (73.7%) - Elapsed: 16.06s - Est. remaining: 917.25s
# 2025-04-26 00:40:47,750 : INFO : Processed 16100/21710 movies (74.2%) - Elapsed: 16.18s - Est. remaining: 907.64s
# 2025-04-26 00:40:47,880 : INFO : Processed 16200/21710 movies (74.6%) - Elapsed: 16.31s - Est. remaining: 898.62s
# 2025-04-26 00:40:48,044 : INFO : Processed 16300/21710 movies (75.1%) - Elapsed: 16.47s - Est. remaining: 891.22s
# 2025-04-26 00:40:48,159 : INFO : Processed 16400/21710 movies (75.5%) - Elapsed: 16.59s - Est. remaining: 880.86s
# 2025-04-26 00:40:48,313 : INFO : Processed 16500/21710 movies (76.0%) - Elapsed: 16.74s - Est. remaining: 872.29s
# 2025-04-26 00:40:48,480 : INFO : Processed 16600/21710 movies (76.5%) - Elapsed: 16.91s - Est. remaining: 864.06s
# 2025-04-26 00:40:48,619 : INFO : Processed 16700/21710 movies (76.9%) - Elapsed: 17.05s - Est. remaining: 854.13s
# 2025-04-26 00:40:48,734 : INFO : Processed 16800/21710 movies (77.4%) - Elapsed: 17.16s - Est. remaining: 842.72s
# 2025-04-26 00:40:48,848 : INFO : Processed 16900/21710 movies (77.8%) - Elapsed: 17.28s - Est. remaining: 831.01s
# 2025-04-26 00:40:48,975 : INFO : Processed 17000/21710 movies (78.3%) - Elapsed: 17.40s - Est. remaining: 819.72s
# 2025-04-26 00:40:49,139 : INFO : Processed 17100/21710 movies (78.8%) - Elapsed: 17.57s - Est. remaining: 809.90s
# 2025-04-26 00:40:49,243 : INFO : Processed 17200/21710 movies (79.2%) - Elapsed: 17.67s - Est. remaining: 797.02s
# 2025-04-26 00:40:49,348 : INFO : Processed 17300/21710 movies (79.7%) - Elapsed: 17.78s - Est. remaining: 783.99s
# 2025-04-26 00:40:49,472 : INFO : Processed 17400/21710 movies (80.1%) - Elapsed: 17.90s - Est. remaining: 771.55s
# 2025-04-26 00:40:49,631 : INFO : Processed 17500/21710 movies (80.6%) - Elapsed: 18.06s - Est. remaining: 760.35s
# 2025-04-26 00:40:49,739 : INFO : Processed 17600/21710 movies (81.1%) - Elapsed: 18.17s - Est. remaining: 746.73s
# 2025-04-26 00:40:49,886 : INFO : Processed 17700/21710 movies (81.5%) - Elapsed: 18.32s - Est. remaining: 734.45s
# 2025-04-26 00:40:49,983 : INFO : Processed 17800/21710 movies (82.0%) - Elapsed: 18.41s - Est. remaining: 719.93s
# 2025-04-26 00:40:50,086 : INFO : Processed 17900/21710 movies (82.5%) - Elapsed: 18.52s - Est. remaining: 705.45s
# 2025-04-26 00:40:50,166 : INFO : Processed 18000/21710 movies (82.9%) - Elapsed: 18.60s - Est. remaining: 689.89s
# 2025-04-26 00:40:50,251 : INFO : Processed 18100/21710 movies (83.4%) - Elapsed: 18.68s - Est. remaining: 674.37s
# 2025-04-26 00:40:50,333 : INFO : Processed 18200/21710 movies (83.8%) - Elapsed: 18.76s - Est. remaining: 658.56s
# 2025-04-26 00:40:50,441 : INFO : Processed 18300/21710 movies (84.3%) - Elapsed: 18.87s - Est. remaining: 643.47s
# 2025-04-26 00:40:50,545 : INFO : Processed 18400/21710 movies (84.8%) - Elapsed: 18.97s - Est. remaining: 628.05s
# 2025-04-26 00:40:50,690 : INFO : Processed 18500/21710 movies (85.2%) - Elapsed: 19.12s - Est. remaining: 613.74s
# 2025-04-26 00:40:50,795 : INFO : Processed 18600/21710 movies (85.7%) - Elapsed: 19.22s - Est. remaining: 597.87s
# 2025-04-26 00:40:50,921 : INFO : Processed 18700/21710 movies (86.1%) - Elapsed: 19.35s - Est. remaining: 582.44s
# 2025-04-26 00:40:51,053 : INFO : Processed 18800/21710 movies (86.6%) - Elapsed: 19.48s - Est. remaining: 566.94s
# 2025-04-26 00:40:51,171 : INFO : Processed 18900/21710 movies (87.1%) - Elapsed: 19.60s - Est. remaining: 550.75s
# 2025-04-26 00:40:51,299 : INFO : Processed 19000/21710 movies (87.5%) - Elapsed: 19.73s - Est. remaining: 534.65s
# 2025-04-26 00:40:51,390 : INFO : Processed 19100/21710 movies (88.0%) - Elapsed: 19.82s - Est. remaining: 517.26s
# 2025-04-26 00:40:51,498 : INFO : Processed 19200/21710 movies (88.4%) - Elapsed: 19.93s - Est. remaining: 500.18s
# 2025-04-26 00:40:51,641 : INFO : Processed 19300/21710 movies (88.9%) - Elapsed: 20.07s - Est. remaining: 483.70s
# 2025-04-26 00:40:51,752 : INFO : Processed 19400/21710 movies (89.4%) - Elapsed: 20.18s - Est. remaining: 466.19s
# 2025-04-26 00:40:51,855 : INFO : Processed 19500/21710 movies (89.8%) - Elapsed: 20.28s - Est. remaining: 448.25s
# 2025-04-26 00:40:51,953 : INFO : Processed 19600/21710 movies (90.3%) - Elapsed: 20.38s - Est. remaining: 430.07s
# 2025-04-26 00:40:52,054 : INFO : Processed 19700/21710 movies (90.7%) - Elapsed: 20.48s - Est. remaining: 411.72s
# 2025-04-26 00:40:52,151 : INFO : Processed 19800/21710 movies (91.2%) - Elapsed: 20.58s - Est. remaining: 393.08s
# 2025-04-26 00:40:52,259 : INFO : Processed 19900/21710 movies (91.7%) - Elapsed: 20.69s - Est. remaining: 374.46s
# 2025-04-26 00:40:52,394 : INFO : Processed 20000/21710 movies (92.1%) - Elapsed: 20.82s - Est. remaining: 356.07s
# 2025-04-26 00:40:52,498 : INFO : Processed 20100/21710 movies (92.6%) - Elapsed: 20.93s - Est. remaining: 336.93s
# 2025-04-26 00:40:52,598 : INFO : Processed 20200/21710 movies (93.0%) - Elapsed: 21.03s - Est. remaining: 317.51s
# 2025-04-26 00:40:52,700 : INFO : Processed 20300/21710 movies (93.5%) - Elapsed: 21.13s - Est. remaining: 297.93s
# 2025-04-26 00:40:52,816 : INFO : Processed 20400/21710 movies (94.0%) - Elapsed: 21.25s - Est. remaining: 278.31s
# 2025-04-26 00:40:52,915 : INFO : Processed 20500/21710 movies (94.4%) - Elapsed: 21.34s - Est. remaining: 258.27s
# 2025-04-26 00:40:53,008 : INFO : Processed 20600/21710 movies (94.9%) - Elapsed: 21.44s - Est. remaining: 237.95s
# 2025-04-26 00:40:53,108 : INFO : Processed 20700/21710 movies (95.3%) - Elapsed: 21.54s - Est. remaining: 217.53s
# 2025-04-26 00:40:53,251 : INFO : Processed 20800/21710 movies (95.8%) - Elapsed: 21.68s - Est. remaining: 197.29s
# 2025-04-26 00:40:53,356 : INFO : Processed 20900/21710 movies (96.3%) - Elapsed: 21.79s - Est. remaining: 176.46s
# 2025-04-26 00:40:53,452 : INFO : Processed 21000/21710 movies (96.7%) - Elapsed: 21.88s - Est. remaining: 155.36s
# 2025-04-26 00:40:53,524 : INFO : Processed 21100/21710 movies (97.2%) - Elapsed: 21.95s - Est. remaining: 133.92s
# 2025-04-26 00:40:53,602 : INFO : Processed 21200/21710 movies (97.7%) - Elapsed: 22.03s - Est. remaining: 112.36s
# 2025-04-26 00:40:53,710 : INFO : Processed 21300/21710 movies (98.1%) - Elapsed: 22.14s - Est. remaining: 90.77s
# 2025-04-26 00:40:53,904 : INFO : Processed 21400/21710 movies (98.6%) - Elapsed: 22.33s - Est. remaining: 69.23s
# 2025-04-26 00:40:54,054 : INFO : Processed 21500/21710 movies (99.0%) - Elapsed: 22.48s - Est. remaining: 47.22s
# 2025-04-26 00:40:54,157 : INFO : Processed 21600/21710 movies (99.5%) - Elapsed: 22.59s - Est. remaining: 24.84s
# 2025-04-26 00:40:54,263 : INFO : Processed 21700/21710 movies (100.0%) - Elapsed: 22.69s - Est. remaining: 2.27s
# 2025-04-26 00:40:54,389 : INFO : Processed 21710/21710 movies (100.0%) - Elapsed: 22.82s - Est. remaining: 0.00s
# 2025-04-26 00:40:54,795 : INFO : Calculated LL values for 21708 movies
# 2025-04-26 00:40:54,883 : INFO : After LL calculation: 956.88 MB
# 2025-04-26 00:40:54,884 : INFO : Preparing corpus: 1000/21710 movies (4.6%)
# 2025-04-26 00:40:54,999 : INFO : Preparing corpus: 2000/21710 movies (9.2%)
# 2025-04-26 00:40:55,119 : INFO : Preparing corpus: 3000/21710 movies (13.8%)
# 2025-04-26 00:40:55,216 : INFO : Preparing corpus: 4000/21710 movies (18.4%)
# 2025-04-26 00:40:55,375 : INFO : Preparing corpus: 5000/21710 movies (23.0%)
# 2025-04-26 00:40:55,480 : INFO : Preparing corpus: 6000/21710 movies (27.6%)
# 2025-04-26 00:40:55,581 : INFO : Preparing corpus: 7000/21710 movies (32.2%)
# 2025-04-26 00:40:55,702 : INFO : Preparing corpus: 8000/21710 movies (36.8%)
# 2025-04-26 00:40:55,802 : INFO : Preparing corpus: 9000/21710 movies (41.5%)
# 2025-04-26 00:40:55,904 : INFO : Preparing corpus: 10000/21710 movies (46.1%)
# 2025-04-26 00:40:56,006 : INFO : Preparing corpus: 11000/21710 movies (50.7%)
# 2025-04-26 00:40:56,141 : INFO : Preparing corpus: 12000/21710 movies (55.3%)
# 2025-04-26 00:40:56,234 : INFO : Preparing corpus: 13000/21710 movies (59.9%)
# 2025-04-26 00:40:56,328 : INFO : Preparing corpus: 14000/21710 movies (64.5%)
# 2025-04-26 00:40:56,426 : INFO : Preparing corpus: 15000/21710 movies (69.1%)
# 2025-04-26 00:40:56,535 : INFO : Preparing corpus: 16000/21710 movies (73.7%)
# 2025-04-26 00:40:56,621 : INFO : Preparing corpus: 17000/21710 movies (78.3%)
# 2025-04-26 00:40:56,707 : INFO : Preparing corpus: 18000/21710 movies (82.9%)
# 2025-04-26 00:40:56,781 : INFO : Preparing corpus: 19000/21710 movies (87.5%)
# 2025-04-26 00:40:56,900 : INFO : Preparing corpus: 20000/21710 movies (92.1%)
# 2025-04-26 00:40:56,979 : INFO : Preparing corpus: 21000/21710 movies (96.7%)
# 2025-04-26 00:40:57,047 : INFO : Preparing corpus: 21710/21710 movies (100.0%)
# 2025-04-26 00:40:57,152 : INFO : Training Word2Vec on corpus with 1054595 tokens
# 2025-04-26 00:40:57,153 : INFO : collecting all words and their counts
# 2025-04-26 00:40:57,154 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2025-04-26 00:40:57,220 : INFO : PROGRESS: at sentence #10000, processed 546516 words, keeping 46935 word types
# 2025-04-26 00:40:57,280 : INFO : PROGRESS: at sentence #20000, processed 1000237 words, keeping 74737 word types
# 2025-04-26 00:40:57,287 : INFO : collected 78298 word types from a corpus of 1054595 raw words and 21710 sentences
# 2025-04-26 00:40:57,287 : INFO : Creating a fresh vocabulary
# 2025-04-26 00:40:57,341 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=3 retains 22601 unique words (28.87% of original 78298, drops 55697)', 'datetime': '2025-04-26T00:40:57.341584', 'gensim': '4.3.3', 'python': '3.10.1 (tags/v3.10.1:2cd268a, Dec  6 2021, 19:10:37) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'prepare_vocab'}
# 2025-04-26 00:40:57,342 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=3 leaves 984056 word corpus (93.31% of original 1054595, drops 70539)', 'datetime': '2025-04-26T00:40:57.342747', 'gensim': '4.3.3', 'python': '3.10.1 (tags/v3.10.1:2cd268a, Dec  6 2021, 19:10:37) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'prepare_vocab'}
# 2025-04-26 00:40:57,403 : INFO : deleting the raw counts dictionary of 78298 items
# 2025-04-26 00:40:57,405 : INFO : sample=0.001 downsamples 23 most-common words
# 2025-04-26 00:40:57,406 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 967890.9185478995 word corpus (98.4%% of prior 984056)', 'datetime': '2025-04-26T00:40:57.406060', 'gensim': '4.3.3', 'python': '3.10.1 (tags/v3.10.1:2cd268a, Dec  6 2021, 19:10:37) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'prepare_vocab'}
# 2025-04-26 00:40:57,413 : INFO : constructing a huffman tree from 22601 words
# 2025-04-26 00:40:57,766 : INFO : built huffman tree with maximum node depth 18
# 2025-04-26 00:40:57,866 : INFO : estimated required memory for 22601 words and 100 dimensions: 42941900 bytes
# 2025-04-26 00:40:57,867 : INFO : resetting layer weights
# 2025-04-26 00:40:57,874 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2025-04-26T00:40:57.874678', 'gensim': '4.3.3', 'python': '3.10.1 (tags/v3.10.1:2cd268a, Dec  6 2021, 19:10:37) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'build_vocab'}
# 2025-04-26 00:40:57,875 : WARNING : Both hierarchical softmax and negative sampling are activated. This is probably a mistake. You should set either 'hs=0' or 'negative=0' to disable one of them.
# 2025-04-26 00:40:57,875 : INFO : Word2Vec lifecycle event {'msg': 'training model with 8 workers on 22601 vocabulary and 100 features, using sg=1 hs=1 sample=0.001 negative=15 window=8 shrink_windows=True', 'datetime': '2025-04-26T00:40:57.875678', 'gensim': '4.3.3', 'python': '3.10.1 (tags/v3.10.1:2cd268a, Dec  6 2021, 19:10:37) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'train'}
# 2025-04-26 00:40:59,000 : INFO : EPOCH 0 - PROGRESS: at 16.42% examples, 205364 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:00,048 : INFO : EPOCH 0 - PROGRESS: at 45.97% examples, 231907 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:01,078 : INFO : EPOCH 0 - PROGRESS: at 74.94% examples, 245215 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:01,789 : INFO : EPOCH 0: training on 1054595 raw words (968061 effective words) took 3.9s, 247642 effective words/s
# 2025-04-26 00:41:02,816 : INFO : EPOCH 1 - PROGRESS: at 14.55% examples, 206859 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:03,816 : INFO : EPOCH 1 - PROGRESS: at 38.51% examples, 217188 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:04,897 : INFO : EPOCH 1 - PROGRESS: at 67.36% examples, 232335 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:05,710 : INFO : EPOCH 1: training on 1054595 raw words (967851 effective words) took 3.9s, 246981 effective words/s
# 2025-04-26 00:41:06,719 : INFO : EPOCH 2 - PROGRESS: at 15.51% examples, 220128 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:07,720 : INFO : EPOCH 2 - PROGRESS: at 44.95% examples, 246386 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:08,751 : INFO : EPOCH 2 - PROGRESS: at 68.25% examples, 240479 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:09,607 : INFO : EPOCH 2: training on 1054595 raw words (967850 effective words) took 3.9s, 248684 effective words/s
# 2025-04-26 00:41:10,778 : INFO : EPOCH 3 - PROGRESS: at 16.42% examples, 198076 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:11,786 : INFO : EPOCH 3 - PROGRESS: at 46.81% examples, 235981 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:12,941 : INFO : EPOCH 3 - PROGRESS: at 69.30% examples, 222438 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:13,743 : INFO : EPOCH 3: training on 1054595 raw words (967855 effective words) took 4.1s, 234529 effective words/s
# 2025-04-26 00:41:14,793 : INFO : EPOCH 4 - PROGRESS: at 15.51% examples, 211193 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:15,801 : INFO : EPOCH 4 - PROGRESS: at 39.16% examples, 218550 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:16,815 : INFO : EPOCH 4 - PROGRESS: at 67.36% examples, 235061 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:17,829 : INFO : EPOCH 4 - PROGRESS: at 96.79% examples, 232662 words/s, in_qsize 2, out_qsize 1
# 2025-04-26 00:41:17,845 : INFO : EPOCH 4: training on 1054595 raw words (967665 effective words) took 4.1s, 236126 effective words/s
# 2025-04-26 00:41:19,064 : INFO : EPOCH 5 - PROGRESS: at 16.45% examples, 188680 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:20,235 : INFO : EPOCH 5 - PROGRESS: at 47.63% examples, 218364 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:21,253 : INFO : EPOCH 5 - PROGRESS: at 76.02% examples, 233096 words/s, in_qsize 16, out_qsize 0
# 2025-04-26 00:41:22,015 : INFO : EPOCH 5: training on 1054595 raw words (967949 effective words) took 4.2s, 232400 effective words/s
# 2025-04-26 00:41:23,212 : INFO : EPOCH 6 - PROGRESS: at 16.42% examples, 192973 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:24,363 : INFO : EPOCH 6 - PROGRESS: at 47.67% examples, 222373 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:25,431 : INFO : EPOCH 6 - PROGRESS: at 78.14% examples, 237973 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:25,938 : INFO : EPOCH 6: training on 1054595 raw words (967869 effective words) took 3.9s, 246373 effective words/s
# 2025-04-26 00:41:27,082 : INFO : EPOCH 7 - PROGRESS: at 16.46% examples, 203365 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:28,184 : INFO : EPOCH 7 - PROGRESS: at 46.81% examples, 229402 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:29,331 : INFO : EPOCH 7 - PROGRESS: at 76.02% examples, 234353 words/s, in_qsize 16, out_qsize 0
# 2025-04-26 00:41:30,031 : INFO : EPOCH 7: training on 1054595 raw words (967651 effective words) took 4.1s, 237211 effective words/s
# 2025-04-26 00:41:31,036 : INFO : EPOCH 8 - PROGRESS: at 14.62% examples, 211560 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:32,127 : INFO : EPOCH 8 - PROGRESS: at 31.42% examples, 179663 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:33,125 : INFO : EPOCH 8 - PROGRESS: at 55.98% examples, 198087 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:34,128 : INFO : EPOCH 8 - PROGRESS: at 82.86% examples, 207136 words/s, in_qsize 14, out_qsize 0
# 2025-04-26 00:41:34,558 : INFO : EPOCH 8: training on 1054595 raw words (967928 effective words) took 4.5s, 213741 effective words/s
# 2025-04-26 00:41:35,780 : INFO : EPOCH 9 - PROGRESS: at 16.42% examples, 188314 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:36,792 : INFO : EPOCH 9 - PROGRESS: at 46.81% examples, 230048 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:37,803 : INFO : EPOCH 9 - PROGRESS: at 64.15% examples, 214453 words/s, in_qsize 16, out_qsize 0
# 2025-04-26 00:41:38,823 : INFO : EPOCH 9 - PROGRESS: at 88.77% examples, 209891 words/s, in_qsize 9, out_qsize 0
# 2025-04-26 00:41:39,115 : INFO : EPOCH 9: training on 1054595 raw words (967835 effective words) took 4.5s, 212816 effective words/s
# 2025-04-26 00:41:40,200 : INFO : EPOCH 10 - PROGRESS: at 10.28% examples, 144865 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:41,214 : INFO : EPOCH 10 - PROGRESS: at 30.53% examples, 175250 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:42,233 : INFO : EPOCH 10 - PROGRESS: at 53.64% examples, 188097 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:43,270 : INFO : EPOCH 10 - PROGRESS: at 77.07% examples, 193446 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:43,935 : INFO : EPOCH 10: training on 1054595 raw words (967943 effective words) took 4.8s, 201063 effective words/s
# 2025-04-26 00:41:45,118 : INFO : EPOCH 11 - PROGRESS: at 16.42% examples, 195362 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:46,289 : INFO : EPOCH 11 - PROGRESS: at 47.63% examples, 221811 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:47,297 : INFO : EPOCH 11 - PROGRESS: at 73.72% examples, 230986 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:48,171 : INFO : EPOCH 11: training on 1054595 raw words (967791 effective words) took 4.2s, 228697 effective words/s
# 2025-04-26 00:41:49,178 : INFO : EPOCH 12 - PROGRESS: at 15.51% examples, 220506 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:50,186 : INFO : EPOCH 12 - PROGRESS: at 39.16% examples, 223283 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:51,382 : INFO : EPOCH 12 - PROGRESS: at 60.48% examples, 205271 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:52,410 : INFO : EPOCH 12 - PROGRESS: at 87.59% examples, 208871 words/s, in_qsize 10, out_qsize 0
# 2025-04-26 00:41:52,677 : INFO : EPOCH 12: training on 1054595 raw words (967933 effective words) took 4.5s, 215048 effective words/s
# 2025-04-26 00:41:53,728 : INFO : EPOCH 13 - PROGRESS: at 14.55% examples, 202352 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:54,880 : INFO : EPOCH 13 - PROGRESS: at 37.17% examples, 195849 words/s, in_qsize 16, out_qsize 0
# 2025-04-26 00:41:55,972 : INFO : EPOCH 13 - PROGRESS: at 59.48% examples, 197227 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:57,030 : INFO : EPOCH 13 - PROGRESS: at 83.90% examples, 197093 words/s, in_qsize 13, out_qsize 0
# 2025-04-26 00:41:57,422 : INFO : EPOCH 13: training on 1054595 raw words (967700 effective words) took 4.7s, 204174 effective words/s
# 2025-04-26 00:41:58,424 : INFO : EPOCH 14 - PROGRESS: at 10.95% examples, 165137 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:41:59,620 : INFO : EPOCH 14 - PROGRESS: at 39.17% examples, 204711 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:42:00,624 : INFO : EPOCH 14 - PROGRESS: at 61.38% examples, 208472 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:42:01,707 : INFO : EPOCH 14 - PROGRESS: at 87.59% examples, 206626 words/s, in_qsize 10, out_qsize 0
# 2025-04-26 00:42:02,041 : INFO : EPOCH 14: training on 1054595 raw words (967771 effective words) took 4.6s, 209651 effective words/s
# 2025-04-26 00:42:03,066 : INFO : EPOCH 15 - PROGRESS: at 11.65% examples, 171779 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:42:04,286 : INFO : EPOCH 15 - PROGRESS: at 37.17% examples, 192095 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:42:05,456 : INFO : EPOCH 15 - PROGRESS: at 59.55% examples, 189888 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:42:06,494 : INFO : EPOCH 15 - PROGRESS: at 83.90% examples, 192146 words/s, in_qsize 13, out_qsize 0
# 2025-04-26 00:42:06,949 : INFO : EPOCH 15: training on 1054595 raw words (967720 effective words) took 4.9s, 196906 effective words/s
# 2025-04-26 00:42:07,966 : INFO : EPOCH 16 - PROGRESS: at 14.18% examples, 202299 words/s, in_qsize 16, out_qsize 0
# 2025-04-26 00:42:08,991 : INFO : EPOCH 16 - PROGRESS: at 31.36% examples, 185294 words/s, in_qsize 16, out_qsize 0
# 2025-04-26 00:42:10,081 : INFO : EPOCH 16 - PROGRESS: at 54.31% examples, 190913 words/s, in_qsize 14, out_qsize 1
# 2025-04-26 00:42:11,087 : INFO : EPOCH 16 - PROGRESS: at 81.65% examples, 203667 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:42:11,678 : INFO : EPOCH 16: training on 1054595 raw words (967889 effective words) took 4.7s, 205479 effective words/s
# 2025-04-26 00:42:12,719 : INFO : EPOCH 17 - PROGRESS: at 10.28% examples, 151129 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:42:13,719 : INFO : EPOCH 17 - PROGRESS: at 32.21% examples, 187886 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:42:14,735 : INFO : EPOCH 17 - PROGRESS: at 58.60% examples, 209732 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:42:15,783 : INFO : EPOCH 17 - PROGRESS: at 86.50% examples, 212905 words/s, in_qsize 11, out_qsize 0
# 2025-04-26 00:42:16,423 : INFO : EPOCH 17: training on 1054595 raw words (967770 effective words) took 4.7s, 204299 effective words/s
# 2025-04-26 00:42:17,469 : INFO : EPOCH 18 - PROGRESS: at 10.28% examples, 150419 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:42:18,498 : INFO : EPOCH 18 - PROGRESS: at 30.40% examples, 177432 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:42:19,599 : INFO : EPOCH 18 - PROGRESS: at 52.76% examples, 181711 words/s, in_qsize 16, out_qsize 0
# 2025-04-26 00:42:20,625 : INFO : EPOCH 18 - PROGRESS: at 77.31% examples, 191277 words/s, in_qsize 15, out_qsize 0
# 2025-04-26 00:42:21,182 : INFO : EPOCH 18: training on 1054595 raw words (967886 effective words) took 4.8s, 203622 effective words/s
# 2025-04-26 00:42:22,236 : INFO : EPOCH 19 - PROGRESS: at 10.28% examples, 149007 words/s, in_qsize 16, out_qsize 0
# 2025-04-26 00:42:23,309 : INFO : EPOCH 19 - PROGRESS: at 29.54% examples, 168504 words/s, in_qsize 16, out_qsize 0
# 2025-04-26 00:42:24,362 : INFO : EPOCH 19 - PROGRESS: at 52.76% examples, 181422 words/s, in_qsize 16, out_qsize 0
# 2025-04-26 00:42:25,378 : INFO : EPOCH 19 - PROGRESS: at 80.54% examples, 198027 words/s, in_qsize 16, out_qsize 0
# 2025-04-26 00:42:25,891 : INFO : EPOCH 19: training on 1054595 raw words (968011 effective words) took 4.7s, 205787 effective words/s
# 2025-04-26 00:42:25,891 : INFO : Word2Vec lifecycle event {'msg': 'training on 21091900 raw words (19356928 effective words) took 88.0s, 219927 effective words/s', 'datetime': '2025-04-26T00:42:25.891343', 'gensim': '4.3.3', 'python': '3.10.1 (tags/v3.10.1:2cd268a, Dec  6 2021, 19:10:37) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'train'}
# 2025-04-26 00:42:25,892 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec<vocab=22601, vector_size=100, alpha=0.025>', 'datetime': '2025-04-26T00:42:25.892343', 'gensim': '4.3.3', 'python': '3.10.1 (tags/v3.10.1:2cd268a, Dec  6 2021, 19:10:37) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'created'}
# 2025-04-26 00:42:25,989 : INFO : Word2Vec model training completed in 91.10s
# 2025-04-26 00:42:25,993 : INFO : Word2Vec lifecycle event {'fname_or_handle': './rec/content-recommendations\\word2vec_model', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2025-04-26T00:42:25.993718', 'gensim': '4.3.3', 'python': '3.10.1 (tags/v3.10.1:2cd268a, Dec  6 2021, 19:10:37) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'saving'}
# 2025-04-26 00:42:25,993 : INFO : not storing attribute cum_table
# 2025-04-26 00:42:26,103 : INFO : saved ./rec/content-recommendations\word2vec_model
# 2025-04-26 00:42:26,104 : INFO : Trained Word2Vec model with vector size 100
# 2025-04-26 00:42:26,231 : INFO : After Word2Vec training: 976.47 MB
# 2025-04-26 00:42:26,250 : INFO : Generated vectors: 100/21708 movies (0.5%) - Success: 100
# 2025-04-26 00:42:26,354 : INFO : Generated vectors: 200/21708 movies (0.9%) - Success: 200
# 2025-04-26 00:42:26,500 : INFO : Generated vectors: 300/21708 movies (1.4%) - Success: 300
# 2025-04-26 00:42:26,606 : INFO : Generated vectors: 400/21708 movies (1.8%) - Success: 400
# 2025-04-26 00:42:26,702 : INFO : Generated vectors: 500/21708 movies (2.3%) - Success: 500
# 2025-04-26 00:42:26,802 : INFO : Generated vectors: 600/21708 movies (2.8%) - Success: 600
# 2025-04-26 00:42:26,930 : INFO : Generated vectors: 700/21708 movies (3.2%) - Success: 700
# 2025-04-26 00:42:27,024 : INFO : Generated vectors: 800/21708 movies (3.7%) - Success: 797
# 2025-04-26 00:42:27,126 : INFO : Generated vectors: 900/21708 movies (4.1%) - Success: 894
# 2025-04-26 00:42:27,233 : INFO : Generated vectors: 1000/21708 movies (4.6%) - Success: 994
# 2025-04-26 00:42:27,360 : INFO : Generated vectors: 1100/21708 movies (5.1%) - Success: 1093
# 2025-04-26 00:42:27,583 : INFO : Generated vectors: 1200/21708 movies (5.5%) - Success: 1191
# 2025-04-26 00:42:27,784 : INFO : Generated vectors: 1300/21708 movies (6.0%) - Success: 1291
# 2025-04-26 00:42:28,000 : INFO : Generated vectors: 1400/21708 movies (6.4%) - Success: 1391
# 2025-04-26 00:42:28,144 : INFO : Generated vectors: 1500/21708 movies (6.9%) - Success: 1491
# 2025-04-26 00:42:28,272 : INFO : Generated vectors: 1600/21708 movies (7.4%) - Success: 1591
# 2025-04-26 00:42:28,370 : INFO : Generated vectors: 1700/21708 movies (7.8%) - Success: 1689
# 2025-04-26 00:42:28,474 : INFO : Generated vectors: 1800/21708 movies (8.3%) - Success: 1788
# 2025-04-26 00:42:28,573 : INFO : Generated vectors: 1900/21708 movies (8.8%) - Success: 1888
# 2025-04-26 00:42:28,726 : INFO : Generated vectors: 2000/21708 movies (9.2%) - Success: 1988
# 2025-04-26 00:42:28,822 : INFO : Generated vectors: 2100/21708 movies (9.7%) - Success: 2088
# 2025-04-26 00:42:28,911 : INFO : Generated vectors: 2200/21708 movies (10.1%) - Success: 2187
# 2025-04-26 00:42:29,075 : INFO : Generated vectors: 2300/21708 movies (10.6%) - Success: 2287
# 2025-04-26 00:42:29,235 : INFO : Generated vectors: 2400/21708 movies (11.1%) - Success: 2387
# 2025-04-26 00:42:29,347 : INFO : Generated vectors: 2500/21708 movies (11.5%) - Success: 2487
# 2025-04-26 00:42:29,474 : INFO : Generated vectors: 2600/21708 movies (12.0%) - Success: 2586
# 2025-04-26 00:42:29,602 : INFO : Generated vectors: 2700/21708 movies (12.4%) - Success: 2686
# 2025-04-26 00:42:29,703 : INFO : Generated vectors: 2800/21708 movies (12.9%) - Success: 2786
# 2025-04-26 00:42:29,945 : INFO : Generated vectors: 2900/21708 movies (13.4%) - Success: 2886
# 2025-04-26 00:42:30,066 : INFO : Generated vectors: 3000/21708 movies (13.8%) - Success: 2986
# 2025-04-26 00:42:30,182 : INFO : Generated vectors: 3100/21708 movies (14.3%) - Success: 3086
# 2025-04-26 00:42:30,274 : INFO : Generated vectors: 3200/21708 movies (14.7%) - Success: 3186
# 2025-04-26 00:42:30,382 : INFO : Generated vectors: 3300/21708 movies (15.2%) - Success: 3286
# 2025-04-26 00:42:30,495 : INFO : Generated vectors: 3400/21708 movies (15.7%) - Success: 3386
# 2025-04-26 00:42:30,587 : INFO : Generated vectors: 3500/21708 movies (16.1%) - Success: 3486
# 2025-04-26 00:42:30,716 : INFO : Generated vectors: 3600/21708 movies (16.6%) - Success: 3586
# 2025-04-26 00:42:30,816 : INFO : Generated vectors: 3700/21708 movies (17.0%) - Success: 3686
# 2025-04-26 00:42:30,969 : INFO : Generated vectors: 3800/21708 movies (17.5%) - Success: 3786
# 2025-04-26 00:42:31,090 : INFO : Generated vectors: 3900/21708 movies (18.0%) - Success: 3886
# 2025-04-26 00:42:31,192 : INFO : Generated vectors: 4000/21708 movies (18.4%) - Success: 3986
# 2025-04-26 00:42:31,280 : INFO : Generated vectors: 4100/21708 movies (18.9%) - Success: 4086
# 2025-04-26 00:42:31,376 : INFO : Generated vectors: 4200/21708 movies (19.3%) - Success: 4186
# 2025-04-26 00:42:31,477 : INFO : Generated vectors: 4300/21708 movies (19.8%) - Success: 4286
# 2025-04-26 00:42:31,568 : INFO : Generated vectors: 4400/21708 movies (20.3%) - Success: 4386
# 2025-04-26 00:42:31,660 : INFO : Generated vectors: 4500/21708 movies (20.7%) - Success: 4486
# 2025-04-26 00:42:31,792 : INFO : Generated vectors: 4600/21708 movies (21.2%) - Success: 4586
# 2025-04-26 00:42:31,895 : INFO : Generated vectors: 4700/21708 movies (21.7%) - Success: 4686
# 2025-04-26 00:42:32,014 : INFO : Generated vectors: 4800/21708 movies (22.1%) - Success: 4786
# 2025-04-26 00:42:32,116 : INFO : Generated vectors: 4900/21708 movies (22.6%) - Success: 4886
# 2025-04-26 00:42:32,216 : INFO : Generated vectors: 5000/21708 movies (23.0%) - Success: 4986
# 2025-04-26 00:42:32,305 : INFO : Generated vectors: 5100/21708 movies (23.5%) - Success: 5085
# 2025-04-26 00:42:32,398 : INFO : Generated vectors: 5200/21708 movies (24.0%) - Success: 5184
# 2025-04-26 00:42:32,489 : INFO : Generated vectors: 5300/21708 movies (24.4%) - Success: 5284
# 2025-04-26 00:42:32,612 : INFO : Generated vectors: 5400/21708 movies (24.9%) - Success: 5384
# 2025-04-26 00:42:32,712 : INFO : Generated vectors: 5500/21708 movies (25.3%) - Success: 5483
# 2025-04-26 00:42:32,808 : INFO : Generated vectors: 5600/21708 movies (25.8%) - Success: 5583
# ...
# 2025-04-26 01:37:40,201 : INFO : Batch metrics - RMSE: 1.1179, MAE: 0.8589, Accuracy: 0.5499
# 2025-04-26 01:37:40,216 : INFO : TP: 759, FP: 517, TN: 608, FN: 602
# 2025-04-26 01:37:40,216 : INFO : Processed 6000/9991 users (60.1%) - Elapsed: 1247.55s - Est. remaining: 541.95s
# 2025-04-26 01:37:40,310 : INFO : Evaluating batch 61: users 6001-6100 of 9991
# 2025-04-26 01:37:56,436 : INFO : Batch metrics - RMSE: 1.1422, MAE: 0.8864, Accuracy: 0.5904
# 2025-04-26 01:37:56,436 : INFO : TP: 812, FP: 461, TN: 929, FN: 747
# 2025-04-26 01:37:56,436 : INFO : Processed 6100/9991 users (61.1%) - Elapsed: 1263.78s - Est. remaining: 627.47s
# 2025-04-26 01:37:56,530 : INFO : Evaluating batch 62: users 6101-6200 of 9991
# 2025-04-26 01:38:14,344 : INFO : Batch metrics - RMSE: 1.0575, MAE: 0.8015, Accuracy: 0.6280
# 2025-04-26 01:38:14,344 : INFO : TP: 901, FP: 611, TN: 1147, FN: 602
# 2025-04-26 01:38:14,344 : INFO : Processed 6200/9991 users (62.1%) - Elapsed: 1281.69s - Est. remaining: 675.34s
# 2025-04-26 01:38:14,438 : INFO : Evaluating batch 63: users 6201-6300 of 9991
# 2025-04-26 01:38:30,096 : INFO : Batch metrics - RMSE: 1.0940, MAE: 0.8328, Accuracy: 0.5858
# 2025-04-26 01:38:30,096 : INFO : TP: 804, FP: 474, TN: 882, FN: 718
# 2025-04-26 01:38:30,096 : INFO : Processed 6300/9991 users (63.1%) - Elapsed: 1297.44s - Est. remaining: 577.94s
# 2025-04-26 01:38:30,190 : INFO : Evaluating batch 64: users 6301-6400 of 9991
# 2025-04-26 01:38:45,613 : INFO : Batch metrics - RMSE: 1.0928, MAE: 0.8360, Accuracy: 0.6093
# 2025-04-26 01:38:45,613 : INFO : TP: 983, FP: 545, TN: 748, FN: 565
# 2025-04-26 01:38:45,613 : INFO : Processed 6400/9991 users (64.1%) - Elapsed: 1312.96s - Est. remaining: 553.85s
# 2025-04-26 01:38:45,723 : INFO : Evaluating batch 65: users 6401-6500 of 9991
# 2025-04-26 01:39:04,818 : INFO : Batch metrics - RMSE: 1.0926, MAE: 0.8506, Accuracy: 0.6176
# 2025-04-26 01:39:04,818 : INFO : TP: 1061, FP: 584, TN: 1113, FN: 762
# 2025-04-26 01:39:04,818 : INFO : Processed 6500/9991 users (65.1%) - Elapsed: 1332.17s - Est. remaining: 666.63s
# 2025-04-26 01:39:04,928 : INFO : Evaluating batch 66: users 6501-6600 of 9991
# 2025-04-26 01:39:21,508 : INFO : Batch metrics - RMSE: 1.0693, MAE: 0.7999, Accuracy: 0.6601
# 2025-04-26 01:39:21,508 : INFO : TP: 1099, FP: 559, TN: 888, FN: 464
# 2025-04-26 01:39:21,508 : INFO : Processed 6600/9991 users (66.1%) - Elapsed: 1348.86s - Est. remaining: 562.23s
# 2025-04-26 01:39:21,602 : INFO : Evaluating batch 67: users 6601-6700 of 9991
# 2025-04-26 01:39:37,056 : INFO : Batch metrics - RMSE: 1.0512, MAE: 0.7953, Accuracy: 0.6474
# 2025-04-26 01:39:37,056 : INFO : TP: 1114, FP: 573, TN: 739, FN: 436
# 2025-04-26 01:39:37,056 : INFO : Processed 6700/9991 users (67.1%) - Elapsed: 1364.40s - Est. remaining: 508.61s
# 2025-04-26 01:39:37,150 : INFO : Evaluating batch 68: users 6701-6800 of 9991
# 2025-04-26 01:39:51,370 : INFO : Batch metrics - RMSE: 1.1503, MAE: 0.8918, Accuracy: 0.6381
# 2025-04-26 01:39:51,370 : INFO : TP: 656, FP: 411, TN: 1035, FN: 548
# 2025-04-26 01:39:51,370 : INFO : Processed 6800/9991 users (68.1%) - Elapsed: 1378.72s - Est. remaining: 453.77s
# 2025-04-26 01:39:51,464 : INFO : Evaluating batch 69: users 6801-6900 of 9991
# 2025-04-26 01:40:05,497 : INFO : Batch metrics - RMSE: 1.0604, MAE: 0.8133, Accuracy: 0.6214
# 2025-04-26 01:40:05,497 : INFO : TP: 853, FP: 463, TN: 765, FN: 523
# 2025-04-26 01:40:05,497 : INFO : Processed 6900/9991 users (69.1%) - Elapsed: 1392.84s - Est. remaining: 433.75s
# 2025-04-26 01:40:05,590 : INFO : Evaluating batch 70: users 6901-7000 of 9991
# 2025-04-26 01:40:23,030 : INFO : Batch metrics - RMSE: 1.0116, MAE: 0.7677, Accuracy: 0.5988
# 2025-04-26 01:40:23,030 : INFO : TP: 1163, FP: 747, TN: 758, FN: 540
# 2025-04-26 01:40:23,030 : INFO : Processed 7000/9991 users (70.1%) - Elapsed: 1410.38s - Est. remaining: 521.61s
# 2025-04-26 01:40:23,123 : INFO : Evaluating batch 71: users 7001-7100 of 9991
# 2025-04-26 01:40:37,328 : INFO : Batch metrics - RMSE: 1.1305, MAE: 0.8490, Accuracy: 0.5794
# 2025-04-26 01:40:37,328 : INFO : TP: 865, FP: 592, TN: 671, FN: 523
# 2025-04-26 01:40:37,328 : INFO : Processed 7100/9991 users (71.1%) - Elapsed: 1424.68s - Est. remaining: 410.66s
# 2025-04-26 01:40:37,422 : INFO : Evaluating batch 72: users 7101-7200 of 9991
# 2025-04-26 01:40:59,096 : INFO : Batch metrics - RMSE: 1.0289, MAE: 0.8059, Accuracy: 0.6904
# 2025-04-26 01:40:59,096 : INFO : TP: 1085, FP: 497, TN: 1622, FN: 717
# 2025-04-26 01:40:59,096 : INFO : Processed 7200/9991 users (72.1%) - Elapsed: 1446.44s - Est. remaining: 604.93s
# 2025-04-26 01:40:59,190 : INFO : Evaluating batch 73: users 7201-7300 of 9991
# 2025-04-26 01:41:15,739 : INFO : Batch metrics - RMSE: 1.0328, MAE: 0.7976, Accuracy: 0.6532
# 2025-04-26 01:41:15,739 : INFO : TP: 921, FP: 447, TN: 1064, FN: 607
# 2025-04-26 01:41:15,739 : INFO : Processed 7300/9991 users (73.1%) - Elapsed: 1463.09s - Est. remaining: 445.33s
# 2025-04-26 01:41:15,848 : INFO : Evaluating batch 74: users 7301-7400 of 9991
# 2025-04-26 01:41:33,990 : INFO : Batch metrics - RMSE: 1.0443, MAE: 0.7894, Accuracy: 0.6810
# 2025-04-26 01:41:33,990 : INFO : TP: 1041, FP: 521, TN: 1228, FN: 542
# 2025-04-26 01:41:33,990 : INFO : Processed 7400/9991 users (74.1%) - Elapsed: 1481.34s - Est. remaining: 470.07s
# 2025-04-26 01:41:34,084 : INFO : Evaluating batch 75: users 7401-7500 of 9991
# 2025-04-26 01:41:55,524 : INFO : Batch metrics - RMSE: 1.0390, MAE: 0.7864, Accuracy: 0.5597
# 2025-04-26 01:41:55,524 : INFO : TP: 1191, FP: 1069, TN: 966, FN: 628
# 2025-04-26 01:41:55,539 : INFO : Processed 7500/9991 users (75.1%) - Elapsed: 1502.87s - Est. remaining: 534.06s
# 2025-04-26 01:41:55,633 : INFO : Evaluating batch 76: users 7501-7600 of 9991
# 2025-04-26 01:42:09,744 : INFO : Batch metrics - RMSE: 1.1439, MAE: 0.8711, Accuracy: 0.5814
# 2025-04-26 01:42:09,760 : INFO : TP: 892, FP: 619, TN: 608, FN: 461
# 2025-04-26 01:42:09,760 : INFO : Processed 7600/9991 users (76.1%) - Elapsed: 1517.09s - Est. remaining: 337.40s
# 2025-04-26 01:42:09,854 : INFO : Evaluating batch 77: users 7601-7700 of 9991
# 2025-04-26 01:42:27,887 : INFO : Batch metrics - RMSE: 1.0567, MAE: 0.8115, Accuracy: 0.6189
# 2025-04-26 01:42:27,887 : INFO : TP: 1032, FP: 565, TN: 1034, FN: 707
# 2025-04-26 01:42:27,887 : INFO : Processed 7700/9991 users (77.1%) - Elapsed: 1535.23s - Est. remaining: 413.14s
# 2025-04-26 01:42:27,980 : INFO : Evaluating batch 78: users 7701-7800 of 9991
# 2025-04-26 01:42:42,122 : INFO : Batch metrics - RMSE: 1.0613, MAE: 0.8101, Accuracy: 0.6409
# 2025-04-26 01:42:42,122 : INFO : TP: 832, FP: 468, TN: 833, FN: 465
# 2025-04-26 01:42:42,122 : INFO : Processed 7800/9991 users (78.1%) - Elapsed: 1549.47s - Est. remaining: 309.85s
# 2025-04-26 01:42:42,232 : INFO : Evaluating batch 79: users 7801-7900 of 9991
# 2025-04-26 01:42:56,749 : INFO : Batch metrics - RMSE: 1.0729, MAE: 0.8186, Accuracy: 0.6136
# 2025-04-26 01:42:56,749 : INFO : TP: 966, FP: 558, TN: 657, FN: 464
# 2025-04-26 01:42:56,749 : INFO : Processed 7900/9991 users (79.1%) - Elapsed: 1564.10s - Est. remaining: 303.55s
# 2025-04-26 01:42:56,874 : INFO : Evaluating batch 80: users 7901-8000 of 9991
# 2025-04-26 01:43:12,359 : INFO : Batch metrics - RMSE: 1.0366, MAE: 0.7779, Accuracy: 0.6417
# 2025-04-26 01:43:12,359 : INFO : TP: 1036, FP: 604, TN: 798, FN: 420
# 2025-04-26 01:43:12,359 : INFO : Processed 8000/9991 users (80.1%) - Elapsed: 1579.71s - Est. remaining: 308.32s
# 2025-04-26 01:43:12,453 : INFO : Evaluating batch 81: users 8001-8100 of 9991
# 2025-04-26 01:43:27,924 : INFO : Batch metrics - RMSE: 1.0543, MAE: 0.8052, Accuracy: 0.6671
# 2025-04-26 01:43:27,924 : INFO : TP: 800, FP: 536, TN: 1066, FN: 395
# 2025-04-26 01:43:27,924 : INFO : Processed 8100/9991 users (81.1%) - Elapsed: 1595.27s - Est. remaining: 292.55s
# 2025-04-26 01:43:28,017 : INFO : Evaluating batch 82: users 8101-8200 of 9991
# 2025-04-26 01:43:43,487 : INFO : Batch metrics - RMSE: 1.0967, MAE: 0.8311, Accuracy: 0.5794
# 2025-04-26 01:43:43,487 : INFO : TP: 901, FP: 751, TN: 781, FN: 470
# 2025-04-26 01:43:43,487 : INFO : Processed 8200/9991 users (82.1%) - Elapsed: 1610.83s - Est. remaining: 277.07s
# 2025-04-26 01:43:43,597 : INFO : Evaluating batch 83: users 8201-8300 of 9991
# 2025-04-26 01:44:00,677 : INFO : Batch metrics - RMSE: 0.9856, MAE: 0.7397, Accuracy: 0.6091
# 2025-04-26 01:44:00,677 : INFO : TP: 1283, FP: 788, TN: 582, FN: 409
# 2025-04-26 01:44:00,677 : INFO : Processed 8300/9991 users (83.1%) - Elapsed: 1628.02s - Est. remaining: 288.83s
# 2025-04-26 01:44:00,771 : INFO : Evaluating batch 84: users 8301-8400 of 9991
# 2025-04-26 01:44:16,804 : INFO : Batch metrics - RMSE: 1.0770, MAE: 0.8274, Accuracy: 0.5801
# 2025-04-26 01:44:16,804 : INFO : TP: 814, FP: 489, TN: 924, FN: 769
# 2025-04-26 01:44:16,804 : INFO : Processed 8400/9991 users (84.1%) - Elapsed: 1644.15s - Est. remaining: 255.08s
# 2025-04-26 01:44:16,897 : INFO : Evaluating batch 85: users 8401-8500 of 9991
# 2025-04-26 01:44:38,244 : INFO : Batch metrics - RMSE: 1.0161, MAE: 0.7862, Accuracy: 0.6148
# 2025-04-26 01:44:38,244 : INFO : TP: 891, FP: 605, TN: 1489, FN: 886
# 2025-04-26 01:44:38,244 : INFO : Processed 8500/9991 users (85.1%) - Elapsed: 1665.59s - Est. remaining: 318.27s
# 2025-04-26 01:44:38,337 : INFO : Evaluating batch 86: users 8501-8600 of 9991
# 2025-04-26 01:44:54,948 : INFO : Batch metrics - RMSE: 1.0370, MAE: 0.7832, Accuracy: 0.6456
# 2025-04-26 01:44:54,948 : INFO : TP: 901, FP: 519, TN: 1052, FN: 553
# 2025-04-26 01:44:54,948 : INFO : Processed 8600/9991 users (86.1%) - Elapsed: 1682.30s - Est. remaining: 231.06s
# 2025-04-26 01:44:55,042 : INFO : Evaluating batch 87: users 8601-8700 of 9991
# 2025-04-26 01:45:11,372 : INFO : Batch metrics - RMSE: 1.0035, MAE: 0.7658, Accuracy: 0.6258
# 2025-04-26 01:45:11,372 : INFO : TP: 973, FP: 517, TN: 863, FN: 581
# 2025-04-26 01:45:11,372 : INFO : Processed 8700/9991 users (87.1%) - Elapsed: 1698.72s - Est. remaining: 210.82s
# 2025-04-26 01:45:11,465 : INFO : Evaluating batch 88: users 8701-8800 of 9991
# 2025-04-26 01:45:26,733 : INFO : Batch metrics - RMSE: 1.1021, MAE: 0.8546, Accuracy: 0.5590
# 2025-04-26 01:45:26,733 : INFO : TP: 792, FP: 575, TN: 771, FN: 658
# 2025-04-26 01:45:26,733 : INFO : Processed 8800/9991 users (88.1%) - Elapsed: 1714.08s - Est. remaining: 181.84s
# 2025-04-26 01:45:26,842 : INFO : Evaluating batch 89: users 8801-8900 of 9991
# 2025-04-26 01:45:47,376 : INFO : Batch metrics - RMSE: 1.0097, MAE: 0.7659, Accuracy: 0.6417
# 2025-04-26 01:45:47,376 : INFO : TP: 1269, FP: 833, TN: 1104, FN: 492
# 2025-04-26 01:45:47,376 : INFO : Processed 8900/9991 users (89.1%) - Elapsed: 1734.72s - Est. remaining: 224.02s
# 2025-04-26 01:45:47,470 : INFO : Evaluating batch 90: users 8901-9000 of 9991
# 2025-04-26 01:46:04,924 : INFO : Batch metrics - RMSE: 1.0340, MAE: 0.7842, Accuracy: 0.6611
# 2025-04-26 01:46:04,924 : INFO : TP: 831, FP: 504, TN: 1309, FN: 593
# 2025-04-26 01:46:04,924 : INFO : Processed 9000/9991 users (90.1%) - Elapsed: 1752.27s - Est. remaining: 172.98s
# 2025-04-26 01:46:05,018 : INFO : Evaluating batch 91: users 9001-9100 of 9991
# 2025-04-26 01:46:19,801 : INFO : Batch metrics - RMSE: 1.0556, MAE: 0.8050, Accuracy: 0.6289
# 2025-04-26 01:46:19,801 : INFO : TP: 964, FP: 475, TN: 756, FN: 540
# 2025-04-26 01:46:19,801 : INFO : Processed 9100/9991 users (91.1%) - Elapsed: 1767.15s - Est. remaining: 131.71s
# 2025-04-26 01:46:19,894 : INFO : Evaluating batch 92: users 9101-9200 of 9991
# 2025-04-26 01:46:33,427 : INFO : Batch metrics - RMSE: 1.0298, MAE: 0.7970, Accuracy: 0.6178
# 2025-04-26 01:46:33,427 : INFO : TP: 1117, FP: 599, TN: 399, FN: 339
# 2025-04-26 01:46:33,442 : INFO : Processed 9200/9991 users (92.1%) - Elapsed: 1780.77s - Est. remaining: 107.04s
# 2025-04-26 01:46:33,536 : INFO : Evaluating batch 93: users 9201-9300 of 9991
# 2025-04-26 01:46:49,991 : INFO : Batch metrics - RMSE: 1.1011, MAE: 0.8452, Accuracy: 0.6188
# 2025-04-26 01:46:49,991 : INFO : TP: 910, FP: 399, TN: 937, FN: 739
# 2025-04-26 01:46:49,991 : INFO : Processed 9300/9991 users (93.1%) - Elapsed: 1797.34s - Est. remaining: 113.70s
# 2025-04-26 01:46:50,085 : INFO : Evaluating batch 94: users 9301-9400 of 9991
# 2025-04-26 01:47:06,742 : INFO : Batch metrics - RMSE: 1.0300, MAE: 0.7829, Accuracy: 0.6039
# 2025-04-26 01:47:06,742 : INFO : TP: 1004, FP: 594, TN: 842, FN: 617
# 2025-04-26 01:47:06,742 : INFO : Processed 9400/9991 users (94.1%) - Elapsed: 1814.09s - Est. remaining: 98.45s
# 2025-04-26 01:47:06,852 : INFO : Evaluating batch 95: users 9401-9500 of 9991
# 2025-04-26 01:47:20,165 : INFO : Batch metrics - RMSE: 1.0261, MAE: 0.7785, Accuracy: 0.6787
# 2025-04-26 01:47:20,181 : INFO : TP: 620, FP: 324, TN: 1051, FN: 467
# 2025-04-26 01:47:20,181 : INFO : Processed 9500/9991 users (95.1%) - Elapsed: 1827.51s - Est. remaining: 65.37s
# 2025-04-26 01:47:20,290 : INFO : Evaluating batch 96: users 9501-9600 of 9991
# 2025-04-26 01:47:36,557 : INFO : Batch metrics - RMSE: 1.0922, MAE: 0.8464, Accuracy: 0.5709
# 2025-04-26 01:47:36,557 : INFO : TP: 988, FP: 733, TN: 723, FN: 553
# 2025-04-26 01:47:36,557 : INFO : Processed 9600/9991 users (96.1%) - Elapsed: 1843.90s - Est. remaining: 63.60s
# 2025-04-26 01:47:36,651 : INFO : Evaluating batch 97: users 9601-9700 of 9991
# 2025-04-26 01:47:52,950 : INFO : Batch metrics - RMSE: 1.1654, MAE: 0.8760, Accuracy: 0.5720
# 2025-04-26 01:47:52,950 : INFO : TP: 1022, FP: 758, TN: 718, FN: 544
# 2025-04-26 01:47:52,950 : INFO : Processed 9700/9991 users (97.1%) - Elapsed: 1860.30s - Est. remaining: 47.43s
# 2025-04-26 01:47:53,043 : INFO : Evaluating batch 98: users 9701-9800 of 9991
# 2025-04-26 01:48:07,936 : INFO : Batch metrics - RMSE: 1.0391, MAE: 0.7818, Accuracy: 0.6476
# 2025-04-26 01:48:07,936 : INFO : TP: 875, FP: 561, TN: 893, FN: 401
# 2025-04-26 01:48:07,936 : INFO : Processed 9800/9991 users (98.1%) - Elapsed: 1875.28s - Est. remaining: 28.44s
# 2025-04-26 01:48:08,029 : INFO : Evaluating batch 99: users 9801-9900 of 9991
# 2025-04-26 01:48:27,796 : INFO : Batch metrics - RMSE: 0.9883, MAE: 0.7390, Accuracy: 0.6024
# 2025-04-26 01:48:27,796 : INFO : TP: 1199, FP: 775, TN: 960, FN: 650
# 2025-04-26 01:48:27,796 : INFO : Processed 9900/9991 users (99.1%) - Elapsed: 1895.14s - Est. remaining: 17.99s
# 2025-04-26 01:48:27,890 : INFO : Evaluating batch 100: users 9901-9991 of 9991
# 2025-04-26 01:48:40,470 : INFO : Batch metrics - RMSE: 1.0796, MAE: 0.8230, Accuracy: 0.6235
# 2025-04-26 01:48:40,470 : INFO : TP: 778, FP: 408, TN: 661, FN: 461
# 2025-04-26 01:48:40,470 : INFO : Processed 9991/9991 users (100.0%) - Elapsed: 1907.82s - Est. remaining: 0.00s
# 2025-04-26 01:48:40,564 : INFO :
# Evaluation results:
# 2025-04-26 01:48:40,564 : INFO : Users evaluated: 9991
# 2025-04-26 01:48:40,564 : INFO : Total predictions: 296324
# 2025-04-26 01:48:40,564 : INFO : RMSE: 1.0656
# 2025-04-26 01:48:40,564 : INFO : MAE: 0.8132
# 2025-04-26 01:48:40,564 : INFO : Accuracy: 0.6144
# 2025-04-26 01:48:40,564 : INFO : Precision: 0.6185
# 2025-04-26 01:48:40,564 : INFO : Recall: 0.6324
# 2025-04-26 01:48:40,564 : INFO : F1 Score: 0.6254
# 2025-04-26 01:48:40,564 : INFO : Confusion Matrix: [TP: 95364, FP: 58831, TN: 86705, FN: 55424]
# 2025-04-26 01:48:40,579 : INFO :
# Stored evaluation metrics:
# 2025-04-26 01:48:40,579 : INFO :   rmse: 1.0656255919218725
# 2025-04-26 01:48:40,579 : INFO :   mae: 0.8132155831022727
# 2025-04-26 01:48:40,579 : INFO :   accuracy: 0.6144254262226482
# 2025-04-26 01:48:40,579 : INFO :   precision: 0.6184636337105613
# 2025-04-26 01:48:40,579 : INFO :   recall: 0.6324375945035414
# 2025-04-26 01:48:40,579 : INFO :   f1_score: 0.6253725617493434
# 2025-04-26 01:48:40,579 : INFO :   true_positives: 95364
# 2025-04-26 01:48:40,579 : INFO :   false_positives: 58831
# 2025-04-26 01:48:40,579 : INFO :   true_negatives: 86705
# 2025-04-26 01:48:40,579 : INFO :   false_negatives: 55424
# 2025-04-26 01:48:40,579 : INFO :   num_users_evaluated: 9991
# 2025-04-26 01:48:40,579 : INFO :   num_predictions: 296324
# 2025-04-26 01:48:40,720 : INFO : Created evaluation visualizations
# 2025-04-26 01:48:40,798 : INFO : After evaluation: 1793.88 MB
# 2025-04-26 01:48:40,798 : INFO : Content-based recommendation pipeline completed successfully!

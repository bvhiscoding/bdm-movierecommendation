# %%
import numpy as np
import pandas as pd
import os
import pickle
import logging
import heapq
from datetime import datetime
from collections import Counter, defaultdict
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
import seaborn as sns
import time
import math
from gensim.models import Word2Vec
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import ast  # To safely evaluate string representations of lists
import sys
import gc  # Add garbage collector for memory management

# Set up logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
logger = logging.getLogger(__name__)

print("\n" + "="*80)
print("CONTENT-BASED MOVIE RECOMMENDATION SYSTEM WITH LOG-LIKELIHOOD AND WORD2VEC")
print("="*80)

# Set paths
input_path = "./"  # Current directory where stage1.py saved the files
output_path = "./rec/content-recommendations"
top_n =20

# Create output directory if it doesn't exist
if not os.path.exists(output_path):
    os.makedirs(output_path)

# # Initialize NLTK tools
# nltk.download('punkt', quiet=True)
# nltk.download('stopwords', quiet=True)
# nltk.download('wordnet', quiet=True)
# stop_words = set(stopwords.words('english'))
# lemmatizer = WordNetLemmatizer()

# Model parameters/
similarity_threshold = 0.7  # Minimum similarity to consider
word2vec_dim = 200  # Dimensionality of Word2Vec embeddings

print("\n" + "="*80)
print("STEP 1: DATA LOADING")
print("="*80)

def load_data():
    """Load processed data from stage1.py"""
    print("Loading processed data from stage1.py...")
    
    # Data containers
    data = {}
    
    # Load movie features
    movie_features_path = os.path.join(input_path, './processed/processed_movie_features.csv')
    if os.path.exists(movie_features_path):
        # First, load without the tokens column to save memory
        data['movie_features'] = pd.read_csv(movie_features_path)
        # Convert string representation of tokens and top_keywords back to lists
        data['movie_features']['tokens'] = data['movie_features']['tokens'].apply(
            lambda x: ast.literal_eval(x) if isinstance(x, str) else []
        )
        data['movie_features']['top_keywords'] = data['movie_features']['top_keywords'].apply(
            lambda x: ast.literal_eval(x) if isinstance(x, str) else []
        )
        print(f"Loaded features for {len(data['movie_features'])} movies")
        print("\nSample of movie features data:")
        print(data['movie_features'][['movieId', 'title', 'top_keywords']].head(3))
        
        # Print token statistics
        token_lengths = [len(tokens) for tokens in data['movie_features']['tokens']]
        print(f"\nAverage token count per movie: {np.mean(token_lengths):.2f}")
        print(f"Min token count: {min(token_lengths)}, Max token count: {max(token_lengths)}")
    else:
        print(f"Error: Movie features not found at {movie_features_path}")
        sys.exit(1)
    
    # Load normalized ratings
    ratings_path = os.path.join(input_path, './processed/normalized_ratings.csv')
    if os.path.exists(ratings_path):
        # Read in chunks to save memory
        chunk_size = 100000  # Adjust based on dataset size
        chunks = []
        for chunk in pd.read_csv(ratings_path, chunksize=chunk_size):
            chunks.append(chunk)
        data['ratings'] = pd.concat(chunks)
        print(f"\nLoaded {len(data['ratings'])} normalized ratings")
        print("\nSample of normalized ratings data:")
        print(data['ratings'].head(3))
        
        # Print rating statistics
        print(f"\nNumber of unique users: {data['ratings']['userId'].nunique()}")
        print(f"Number of unique movies: {data['ratings']['movieId'].nunique()}")
        print(f"Rating sparsity: {(1 - len(data['ratings']) / (data['ratings']['userId'].nunique() * data['ratings']['movieId'].nunique())) * 100:.4f}%")
    else:
        print(f"Error: Normalized ratings not found at {ratings_path}")
        sys.exit(1)
    
    # Create training and testing sets with 80-20 split
    # Create training and testing sets with 80-20 split
    if 'ratings' in data:
        print("Splitting ratings into training and testing sets...")
        
        # Import train_test_split if not already imported
        from sklearn.model_selection import train_test_split
        
        # Split ratings into training and testing sets
        train_ratings, test_ratings = train_test_split(
            data['ratings'], 
            test_size=0.2
        )
        
        # Store the split data
        data['train_ratings'] = train_ratings
        data['test_ratings'] = test_ratings
        
        print(f"\nSplit ratings into {len(data['train_ratings'])} training and {len(data['test_ratings'])} testing samples")
        print(f"Training set covers {data['train_ratings']['userId'].nunique()} users and {data['train_ratings']['movieId'].nunique()} movies")
        print(f"Testing set covers {data['test_ratings']['userId'].nunique()} users and {data['test_ratings']['movieId'].nunique()} movies")
    
    return data

# Load the data
data = load_data()

print("\n" + "="*80)
print("STEP 2: CORPUS ANALYSIS")
print("="*80)

# Build corpus word counts from movie features
if 'movie_features' in data:
    print("Building vocabulary and word frequency counts...")
    
    corpus_word_counts = Counter()
    
    # Process in batches to avoid memory spikes
    batch_size = 1000
    total_movies = len(data['movie_features'])
    
    for i in range(0, total_movies, batch_size):
        batch_end = min(i + batch_size, total_movies)
        batch = data['movie_features'].iloc[i:batch_end]
        
        for tokens in batch['tokens']:
            corpus_word_counts.update(tokens)
        
        # Log progress
        print(f"Processed {batch_end}/{total_movies} movies ({batch_end/total_movies*100:.1f}%)")
    
    data['corpus_word_counts'] = corpus_word_counts
    
    # Save corpus word counts
    with open(os.path.join(output_path, 'corpus_word_counts.pkl'), 'wb') as f:
        pickle.dump(corpus_word_counts, f)
    
    print(f"Built vocabulary with {len(corpus_word_counts)} unique words")
    print(f"Total words in corpus: {sum(corpus_word_counts.values())}")
    
    # Display top 20 most common words
    print("\nTop 20 most common words in the corpus:")
    for word, count in corpus_word_counts.most_common(20):
        print(f"'{word}': {count}")

    # Clear memory
    gc.collect()

print("\n" + "="*80)
print("STEP 3: LOG-LIKELIHOOD CALCULATION")
print("="*80)

def calculate_log_likelihood(movie_features, corpus_word_counts, batch_size=100):
    """Calculate Log-Likelihood values for words in each movie in batches"""
    print("Calculating Log-Likelihood values for all movies in batches...")
    start_time = time.time()
    
    # Calculate total corpus size
    total_corpus_size = sum(corpus_word_counts.values())
    print(f"Total corpus size: {total_corpus_size} words")
    
    # Initialize container for movie features
    movie_ll_values = {}
    
    # Process each movie document in batches
    total_movies = len(movie_features)
    
    for batch_start in range(0, total_movies, batch_size):
        batch_end = min(batch_start + batch_size, total_movies)
        print(f"Processing batch {batch_start//batch_size + 1}: movies {batch_start+1}-{batch_end} of {total_movies}")
        
        # Get batch of movies
        batch = movie_features.iloc[batch_start:batch_end]
        
        for _, row in batch.iterrows():
            movie_id = row['movieId']
            tokens = row['tokens']
            
            if not tokens:
                continue
            
            # Count word occurrences in this movie
            movie_word_counts = Counter(tokens)
            movie_size = sum(movie_word_counts.values())
            
            # Calculate Log-Likelihood for each word
            movie_ll_values[movie_id] = {}
            
            for word, count in movie_word_counts.items():
                # Observed frequencies
                a = count  # Occurrences in this movie
                b = corpus_word_counts[word] - count  # Occurrences in other movies
                c = movie_size  # Total words in this movie
                d = total_corpus_size - movie_size  # Total words in other movies
                
                # Expected counts based on corpus distribution
                e1 = c * (a + b) / (c + d)
                e2 = d * (a + b) / (c + d)
                
                # Log-Likelihood calculation
                ll = 0
                if a > 0 and e1 > 0:
                    ll += a * math.log(a / e1)
                if b > 0 and e2 > 0:
                    ll += b * math.log(b / e2)
                
                ll = 2 * ll
                movie_ll_values[movie_id][word] = ll
        
        # Log progress and elapsed time
        elapsed = time.time() - start_time
        progress = batch_end / total_movies * 100
        remaining = elapsed / (batch_end - batch_start) * (total_movies - batch_end) if batch_end < total_movies else 0
        print(f"Progress: {progress:.1f}% - Elapsed: {elapsed:.2f}s - Est. remaining: {remaining:.2f}s")
        
        # Force garbage collection after each batch
        gc.collect()
    
    # Show sample LL values for a movie
    if movie_ll_values:
        sample_movie_id = next(iter(movie_ll_values.keys()))
        sample_movie_title = movie_features[movie_features['movieId'] == sample_movie_id]['title'].values[0]
        print(f"\nSample Log-Likelihood values for movie '{sample_movie_title}' (ID: {sample_movie_id}):")
        
        # Get top 10 words by LL value
        top_ll_words = sorted(movie_ll_values[sample_movie_id].items(), key=lambda x: x[1], reverse=True)[:10]
        for word, ll_value in top_ll_words:
            print(f"Word: '{word}', LL Value: {ll_value:.2f}")
    
    return movie_ll_values

# Calculate Log-Likelihood if movie features are available
if 'movie_features' in data and 'corpus_word_counts' in data:
    movie_ll_values = calculate_log_likelihood(data['movie_features'], data['corpus_word_counts'], batch_size=100)
    data['movie_ll_values'] = movie_ll_values
    
    # Save Log-Likelihood values
    with open(os.path.join(output_path, 'movie_ll_values.pkl'), 'wb') as f:
        pickle.dump(movie_ll_values, f)
    
    print(f"Calculated Log-Likelihood values for {len(movie_ll_values)} movies")
    
    # Calculate average number of words with high LL values
    high_ll_counts = []
    for movie_id, ll_dict in movie_ll_values.items():
        high_ll_words = [word for word, value in ll_dict.items() if value > 10]  # Threshold of 10
        high_ll_counts.append(len(high_ll_words))
    
    print(f"Average number of words with LL > 10 per movie: {np.mean(high_ll_counts):.2f}")
    print(f"Min: {min(high_ll_counts)}, Max: {max(high_ll_counts)}")
    
    # Free memory
    gc.collect()

print("\n" + "="*80)
print("STEP 4: WORD2VEC MODEL TRAINING")
print("="*80)

def train_word2vec(movie_features, vector_size=100, batch_size=1000):
    """Train Word2Vec model on movie tokens with memory optimization"""
    print(f"Training Word2Vec model with {vector_size} dimensions...")
    start_time = time.time()
    
    # Extract token lists from movie features in batches
    tokenized_corpus = []
    total_movies = len(movie_features)
    
    for i in range(0, total_movies, batch_size):
        batch_end = min(i + batch_size, total_movies)
        batch = movie_features.iloc[i:batch_end]
        
        batch_tokens = list(batch['tokens'])
        tokenized_corpus.extend(batch_tokens)
        
        # Log progress
        print(f"Loaded tokens from {batch_end}/{total_movies} movies ({batch_end/total_movies*100:.1f}%)")
    
    # Print corpus statistics
    total_tokens = sum(len(tokens) for tokens in tokenized_corpus)
    print(f"Training corpus size: {total_tokens} tokens from {len(tokenized_corpus)} documents")
    
    # Train Word2Vec model using CBOW approach with memory optimization
    print("Starting Word2Vec training (this may take a few minutes)...")
    word2vec_model = Word2Vec(
        sentences=tokenized_corpus,
        vector_size=vector_size,
        window=10,
        min_count=3,
        workers=8,
        epochs=25,  # Reduced from 50 to save memory
        sg=1,  # CBOW model
        hs=1,
        negative=20
    )
    
    # Free memory - no longer need the full corpus
    del tokenized_corpus
    gc.collect()
    
    elapsed = time.time() - start_time
    print(f"Word2Vec training completed in {elapsed:.2f} seconds")
    
    # Print model statistics
    vocab_size = len(word2vec_model.wv)
    print(f"Word2Vec model vocabulary size: {vocab_size} words")
    
    # Show some example vectors for common words
    print("\nExample word vectors from the trained model:")
    common_words = [word for word, _ in data['corpus_word_counts'].most_common(10)]
    for word in common_words:
        if word in word2vec_model.wv:
            # Show just the first 5 dimensions of the vector
            print(f"'{word}': {word2vec_model.wv[word][:5]}...")
    
    # Show some word similarities
    if len(word2vec_model.wv) > 0:
        print("\nExample word similarities:")
        try:
            # Try some movie-related terms
            for word in ['action', 'love', 'hero', 'villain']:
                if word in word2vec_model.wv:
                    similar_words = word2vec_model.wv.most_similar(word, topn=5)
                    print(f"Words similar to '{word}': {similar_words}")
        except Exception as e:
            print(f"Could not compute word similarities: {str(e)}")
    
    return word2vec_model

# Train Word2Vec if movie features are available
if 'movie_features' in data:
    word2vec_model = train_word2vec(data['movie_features'], word2vec_dim)
    data['word2vec_model'] = word2vec_model
    
    # Save Word2Vec model
    word2vec_path = os.path.join(output_path, 'word2vec_model')
    word2vec_model.save(word2vec_path)
    
    print(f"Trained and saved Word2Vec model with {len(word2vec_model.wv)} words")
    
    # Free memory
    gc.collect()

print("\n" + "="*80)
print("STEP 5: MOVIE VECTOR GENERATION")
print("="*80)

def generate_movie_vectors(movie_ll_values, word2vec_model, movie_features, batch_size=100):
    """Generate movie feature vectors using Log-Likelihood and Word2Vec in batches"""
    print("Generating movie feature vectors using Log-Likelihood + Word2Vec in batches...")
    start_time = time.time()
    
    movie_vectors = {}
    successful_vectors = 0
    no_words_found = 0
    low_ll_sum = 0
    
    # Get movie IDs from LL values
    movie_ids = list(movie_ll_values.keys())
    total_movies = len(movie_ids)
    
    # Process movies in batches
    for batch_start in range(0, total_movies, batch_size):
        batch_end = min(batch_start + batch_size, total_movies)
        batch_movie_ids = movie_ids[batch_start:batch_end]
        total_corpus_size = sum(corpus_word_counts.values())

        print(f"Processing batch {batch_start//batch_size + 1}: movies {batch_start+1}-{batch_end} of {total_movies}")
        
        for movie_id in batch_movie_ids:
            # Sort words by LL value and select top 200
            ll_values = movie_ll_values[movie_id]
    # Tính IDF cho từng từ
            idf = {word: math.log(total_corpus_size/(corpus_word_counts[word]+1)) 
                for word in ll_values.keys()}
            
            # Kết hợp LL và IDF
            combined_scores = {word: ll * idf[word] 
                            for word, ll in ll_values.items()}
            
            # Chọn top words dựa trên combined scores
            top_words = sorted(combined_scores.items(), key=lambda x: x[1], reverse=True)[:500]            
            if not top_words:
                no_words_found += 1
                continue
            
            # Combine Word2Vec vectors weighted by Log-Likelihood values
            weighted_vectors = []
            ll_sum = 0
            words_used = 0
            
            for word, ll_value in top_words:
                if ll_value <= 0:
                    continue
                
                if word in word2vec_model.wv:
                    weighted_vectors.append(word2vec_model.wv[word] * ll_value)
                    ll_sum += ll_value
                    words_used += 1
            
            if weighted_vectors and ll_sum > 0:
                # Calculate the weighted average vector
                movie_vector = np.sum(weighted_vectors, axis=0) / ll_sum
                
                # Normalize to unit length
                norm = np.linalg.norm(movie_vector)
                if norm > 0:
                    movie_vector = movie_vector / norm
                    movie_vectors[movie_id] = movie_vector
                    successful_vectors += 1
            else:
                low_ll_sum += 1
        
        # Log progress and elapsed time
        elapsed = time.time() - start_time
        progress = batch_end / total_movies * 100
        remaining = elapsed / (batch_end - batch_start) * (total_movies - batch_end) if batch_end < total_movies else 0
        print(f"Progress: {progress:.1f}% - Elapsed: {elapsed:.2f}s - Est. remaining: {remaining:.2f}s")
        print(f"Successfully created vectors: {successful_vectors}/{batch_end}")
        
        # Force garbage collection after each batch
        gc.collect()
    
    print(f"\nVector generation complete:")
    print(f"Successfully created vectors: {successful_vectors}/{total_movies} ({successful_vectors/total_movies*100:.1f}%)")
    print(f"Movies with no words found: {no_words_found}")
    print(f"Movies with too low LL sum: {low_ll_sum}")
    
    # Display sample movie vectors
    if movie_vectors:
        print("\nSample movie vectors:")
        for movie_id in list(movie_vectors.keys())[:3]:
            movie_title = movie_features[movie_features['movieId'] == movie_id]['title'].values[0]
            vector = movie_vectors[movie_id]
            print(f"Movie: '{movie_title}' (ID: {movie_id})")
            print(f"Vector shape: {vector.shape}")
            print(f"Vector norm: {np.linalg.norm(vector):.4f}")
            print(f"First 5 dimensions: {vector[:5]}")
            print("---")
    
    return movie_vectors

# Generate movie vectors if Word2Vec and LL values are available
if 'word2vec_model' in data and 'movie_ll_values' in data:
    movie_vectors = generate_movie_vectors(
        data['movie_ll_values'], 
        data['word2vec_model'],
        data['movie_features'],
        batch_size=100
    )
    data['movie_vectors'] = movie_vectors
    
    # Save movie vectors
    with open(os.path.join(output_path, 'movie_vectors.pkl'), 'wb') as f:
        pickle.dump(movie_vectors, f)
    
    # Create movie ID to index mapping
    movie_id_to_idx = {movie_id: i for i, movie_id in enumerate(movie_vectors.keys())}
    data['movie_id_to_idx'] = movie_id_to_idx
    
    # Save the mapping
    with open(os.path.join(output_path, 'movie_id_to_idx.pkl'), 'wb') as f:
        pickle.dump(movie_id_to_idx, f)
    
    print(f"Generated and saved feature vectors for {len(movie_vectors)} movies")
    
    # Calculate and display vector statistics
    vector_norms = [np.linalg.norm(v) for v in movie_vectors.values()]
    print(f"\nVector statistics:")
    print(f"Average vector norm: {np.mean(vector_norms):.4f}")
    print(f"Vector dimensionality: {word2vec_dim}")
    
    # Free memory
    gc.collect()

print("\n" + "="*80)
print("STEP 6: USER VECTOR GENERATION")
print("="*80)

def generate_user_vectors(movie_vectors, train_ratings, batch_size=100):
    """Generate user feature vectors based on rated movies and their content in batches"""
    print("Generating user feature vectors based on movie ratings in batches...")
    start_time = time.time()
    
    user_vectors = {}
    successful_vectors = 0
    no_ratings_found = 0
    no_vectors_for_movies = 0
    low_weight_sum = 0
    
    # Create a rating cache for quick lookups
    # This can be memory intensive for large datasets, but speeds up processing
    user_ratings_dict = {}
    print("Creating user ratings lookup dictionary...")
    
    # Process in chunks to avoid memory issues
    for _, row in train_ratings.iterrows():
        user_id = row['userId']
        movie_id = row['movieId']
        rating = row['rating']
        
        if user_id not in user_ratings_dict:
            user_ratings_dict[user_id] = {}
        
        user_ratings_dict[user_id][movie_id] = rating
    
    # Process each user
    user_ids = list(user_ratings_dict.keys())
    total_users = len(user_ids)
    print(f"Processing {total_users} users in batches...")
    
    # Process users in batches
    for batch_start in range(0, total_users, batch_size):
        batch_end = min(batch_start + batch_size, total_users)
        batch_user_ids = user_ids[batch_start:batch_end]
        
        print(f"Processing batch {batch_start//batch_size + 1}: users {batch_start+1}-{batch_end} of {total_users}")
        
        for user_id in batch_user_ids:
            # Get user ratings
            user_ratings = user_ratings_dict[user_id]
            
            if len(user_ratings) == 0:
                no_ratings_found += 1
                continue
            
            weighted_vectors = []
            weight_sum = 0
            movies_with_vectors = 0
            movies_without_vectors = 0
            
            for movie_id, rating in user_ratings.items():
                # Center rating at 3.0 as described in the papers
                weight = rating - 3.0
                
                # Skip if movie vector is not available
                if movie_id not in movie_vectors:
                    movies_without_vectors += 1
                    continue
                else:
                    movies_with_vectors += 1
                
                if weight != 0:
                    weighted_vectors.append(movie_vectors[movie_id] * weight)
                    weight_sum += abs(weight)
            
            if weighted_vectors and weight_sum > 0:
                # Calculate the weighted average vector
                user_vector = np.sum(weighted_vectors, axis=0) / weight_sum
                
                # Normalize to unit length
                norm = np.linalg.norm(user_vector)
                if norm > 0:
                    user_vector = user_vector / norm
                    user_vectors[user_id] = user_vector
                    successful_vectors += 1
            else:
                low_weight_sum += 1
        
        # Log progress
        elapsed = time.time() - start_time
        progress = batch_end / total_users * 100
        remaining = elapsed / (batch_end - batch_start) * (total_users - batch_end) if batch_end < total_users else 0
        print(f"Progress: {progress:.1f}% - Elapsed: {elapsed:.2f}s - Est. remaining: {remaining:.2f}s")
        print(f"Successfully created vectors: {successful_vectors}")
        
        # Force garbage collection after each batch
        gc.collect()
    
    print(f"\nUser vector generation complete:")
    print(f"Successfully created vectors: {successful_vectors}/{total_users} ({successful_vectors/total_users*100:.1f}%)")
    print(f"Users with no ratings: {no_ratings_found}")
    print(f"Users with no vectorized movies: {no_vectors_for_movies}")
    print(f"Users with too low weight sum: {low_weight_sum}")
    
    # Free memory
    del user_ratings_dict
    gc.collect()
    
    # Display sample user vectors
    if user_vectors:
        print("\nSample user vectors:")
        for user_id in list(user_vectors.keys())[:3]:
            vector = user_vectors[user_id]
            user_rating_count = len([r for r in train_ratings[train_ratings['userId'] == user_id]])
            print(f"User ID: {user_id}")
            print(f"Number of ratings: {user_rating_count}")
            print(f"Vector shape: {vector.shape}")
            print(f"Vector norm: {np.linalg.norm(vector):.4f}")
            print(f"First 5 dimensions: {vector[:5]}")
            print("---")
    
    return user_vectors

# Generate user vectors if movie vectors and training ratings are available
if 'movie_vectors' in data and 'train_ratings' in data:
    user_vectors = generate_user_vectors(data['movie_vectors'], data['train_ratings'], batch_size=100)
    data['user_vectors'] = user_vectors
    
    # Save user vectors
    with open(os.path.join(output_path, 'user_vectors.pkl'), 'wb') as f:
        pickle.dump(user_vectors, f)
    
    # Create user ID to index mapping
    user_id_to_idx = {user_id: i for i, user_id in enumerate(user_vectors.keys())}
    data['user_id_to_idx'] = user_id_to_idx
    
    # Save the mapping
    with open(os.path.join(output_path, 'user_id_to_idx.pkl'), 'wb') as f:
        pickle.dump(user_id_to_idx, f)
    
    print(f"Generated and saved feature vectors for {len(user_vectors)} users")
    
    # Calculate and display vector statistics
    vector_norms = [np.linalg.norm(v) for v in user_vectors.values()]
    print(f"\nVector statistics:")
    print(f"Average vector norm: {np.mean(vector_norms):.4f}")
    print(f"Vector dimensionality: {word2vec_dim}")
    
    # Free memory
    gc.collect()

print("\n" + "="*80)
print("STEP 7: USER-MOVIE SIMILARITY CALCULATION")
print("="*80)

def calculate_user_movie_similarity(user_vectors, movie_vectors, threshold=0.7, batch_size=50):
    """Calculate similarity between users and movies in batches"""
    print(f"Calculating user-movie similarity with threshold {threshold} in batches...")
    start_time = time.time()
    
    # Store similarities in a dictionary of dictionaries
    # {user_id: {movie_id: similarity_score}}
    user_movie_similarities = {}
    
    # Get all user IDs
    user_ids = list(user_vectors.keys())
    total_users = len(user_ids)
    total_movies = len(movie_vectors)
    
    # Process users in batches
    for batch_start in range(0, total_users, batch_size):
        batch_end = min(batch_start + batch_size, total_users)
        batch_user_ids = user_ids[batch_start:batch_end]
        
        print(f"Processing batch {batch_start//batch_size + 1}: users {batch_start+1}-{batch_end} of {total_users}")
        
        for user_id in batch_user_ids:
            user_vector = user_vectors[user_id]
            user_sims = {}
            user_similarities = 0
            user_above_threshold = 0
            
            # Calculate similarity for all movies at once (vectorized)
            # Convert both user and movie vectors to arrays for faster computation
            user_vector_array = np.array(user_vector).reshape(1, -1)
            
            # Process movies in chunks to avoid memory issues
            movie_ids = list(movie_vectors.keys())
            movie_chunk_size = 1000  # Adjust based on memory availability
            
            for movie_chunk_start in range(0, len(movie_ids), movie_chunk_size):
                movie_chunk_end = min(movie_chunk_start + movie_chunk_size, len(movie_ids))
                chunk_movie_ids = movie_ids[movie_chunk_start:movie_chunk_end]
                
                # Create array of movie vectors for this chunk
                movie_vectors_array = np.array([movie_vectors[mid] for mid in chunk_movie_ids])
                
                # Calculate cosine similarity in a vectorized way
                similarities = np.dot(user_vector_array, movie_vectors_array.T)[0]
                
                # Filter by threshold and store
                for i, sim in enumerate(similarities):
                    if sim > threshold:
                        movie_id = chunk_movie_ids[i]
                        user_sims[movie_id] = float(sim)  # Convert to native Python float
                        user_above_threshold += 1
                    user_similarities += 1
            
            user_movie_similarities[user_id] = user_sims
            
            # Log progress for this user
            if len(batch_user_ids) <= 10 or (user_id == batch_user_ids[-1]):
                print(f"User {user_id}: {user_above_threshold}/{total_movies} movies above threshold ({user_above_threshold/total_movies*100:.2f}%)")
        
        # Log progress for this batch
        elapsed = time.time() - start_time
        progress = batch_end / total_users * 100
        remaining = (elapsed / (batch_end - batch_start)) * (total_users - batch_end) if batch_end < total_users else 0
        print(f"Processed {batch_end}/{total_users} users ({progress:.1f}%) - Elapsed: {elapsed:.2f}s - Est. remaining: {remaining:.2f}s")
        
        # Force garbage collection after each batch
        gc.collect()
    
    avg_above_threshold = sum(len(sims) for sims in user_movie_similarities.values()) / len(user_movie_similarities) if user_movie_similarities else 0
    
    print(f"\nSimilarity calculation complete:")
    print(f"Total users processed: {len(user_movie_similarities)}")
    print(f"Total movies per user: {total_movies}")
    print(f"Average movies above threshold per user: {avg_above_threshold:.2f}")
    
    # Display sample user similarities
    if user_movie_similarities:
        print("\nSample user-movie similarities:")
        for user_id in list(user_movie_similarities.keys())[:3]:
            sims = user_movie_similarities[user_id]
            print(f"User ID: {user_id}")
            print(f"Number of movies above threshold: {len(sims)}")
            if sims:
                top_movies = sorted(sims.items(), key=lambda x: x[1], reverse=True)[:5]
                print("Top 5 most similar movies:")
                for movie_id, sim in top_movies:
                    movie_title = data['movie_features'][data['movie_features']['movieId'] == movie_id]['title'].values[0] if 'movie_features' in data else f"Movie {movie_id}"
                    print(f"  '{movie_title}' (ID: {movie_id}): {sim:.4f}")
            print("---")
    
    return user_movie_similarities
# Calculate similarities if user and movie vectors are available
if 'user_vectors' in data and 'movie_vectors' in data:
    user_movie_similarities = calculate_user_movie_similarity(
        data['user_vectors'], 
        data['movie_vectors'], 
        threshold=similarity_threshold,
        batch_size=50
    )
    data['user_movie_similarities'] = user_movie_similarities
    
    # Save the similarities
    with open(os.path.join(output_path, 'user_movie_similarities.pkl'), 'wb') as f:
        pickle.dump(user_movie_similarities, f)
    
    print(f"Calculated and saved similarities for {len(user_movie_similarities)} users")
    
    # Calculate and display similarity statistics
    similarity_counts = [len(sims) for sims in user_movie_similarities.values()]
    print(f"\nSimilarity statistics:")
    print(f"Average number of similar movies per user: {np.mean(similarity_counts):.2f}")
    print(f"Min: {min(similarity_counts)}, Max: {max(similarity_counts)}")
    
    # Free memory
    gc.collect()

print("\n" + "="*80)
print("STEP 8: RECOMMENDATION GENERATION")
print("="*80)

def get_user_rated_movies(user_id, train_ratings, cached_rated_movies=None):
    """Get the set of movies already rated by a user with caching for efficiency"""
    # Initialize cache if not provided
    if cached_rated_movies is None:
        cached_rated_movies = {}
        
    # Return from cache if available
    if user_id in cached_rated_movies:
        return cached_rated_movies[user_id]
    
    # Get from ratings dataframe
    if train_ratings is None:
        return set()
    
    user_data = train_ratings[train_ratings['userId'] == user_id]
    rated_movies = set(user_data['movieId'].values)
    
    # Cache for future use
    cached_rated_movies[user_id] = rated_movies
    
    return rated_movies

def get_top_n_recommendations(user_id, user_movie_similarities, train_ratings, cached_rated_movies=None, n=10):
    """
    Generate top-N recommendations for a specific user
    
    Parameters:
    -----------
    user_id : int
        The user ID to generate recommendations for
    user_movie_similarities : dict
        Dictionary of user-movie similarities
    train_ratings : pd.DataFrame
        DataFrame of user ratings
    cached_rated_movies : dict, optional
        Cache of user rated movies for efficiency
    n : int, optional
        Number of recommendations to generate
        
    Returns:
    --------
    list of tuples
        (movie_id, similarity_score) pairs sorted by similarity in descending order
    """
    if user_id not in user_movie_similarities:
        return []
    
    # Get movies already rated by the user (using cache)
    rated_movies = get_user_rated_movies(user_id, train_ratings, cached_rated_movies)
    
    # Get user's similarities
    user_sims = user_movie_similarities[user_id]
    
    # Filter out already rated movies and sort by similarity
    candidates = [(movie_id, sim) for movie_id, sim in user_sims.items() 
                 if movie_id not in rated_movies]
    
    # Sort by similarity (descending)
    recommendations = sorted(candidates, key=lambda x: x[1], reverse=True)
    
    # Return top N
    return recommendations[:n]

def predict_rating(user_id, movie_id, user_movie_similarities, train_ratings):
    """
    Predict a user's rating for a movie
    
    Parameters:
    -----------
    user_id : int
        The user ID
    movie_id : int
        The movie ID
    user_movie_similarities : dict
        Dictionary of user-movie similarities
    train_ratings : pd.DataFrame
        DataFrame of user ratings
        
    Returns:
    --------
    float
        Predicted rating (0.5-5.0 scale)
    """
    # If user not in similarity matrix, return average rating
    if user_id not in user_movie_similarities:
        return 3.0
    
    # Get user's average rating from training data
    user_train = train_ratings[train_ratings['userId'] == user_id]
    user_avg_rating = user_train['rating'].mean() if len(user_train) > 0 else 3.0
    
    # If movie not in similarity matrix, return user's average rating
    if movie_id not in user_movie_similarities[user_id]:
        return user_avg_rating
    
    # Convert similarity score to rating prediction
    # Similarity is in range [0,1], convert to rating range [0.5,5]
    sim_score = user_movie_similarities[user_id][movie_id]
    predicted_rating = 0.5 + 4.5 * sim_score
    
    return predicted_rating

def generate_recommendations_for_all_users(user_movie_similarities, train_ratings, movie_features, n=10, batch_size=100):
    """Generate recommendations for all users with memory efficiency in mind"""
    print(f"Generating top-{n} recommendations for all users in batches...")
    start_time = time.time()
    
    # Create a shared cache for rated movies
    cached_rated_movies = {}
    
    # Get all user IDs
    user_ids = list(user_movie_similarities.keys())
    total_users = len(user_ids)
    
    all_recommendations = {}
    users_with_recommendations = 0
    
    # Process users in batches
    for batch_start in range(0, total_users, batch_size):
        batch_end = min(batch_start + batch_size, total_users)
        batch_user_ids = user_ids[batch_start:batch_end]
        
        print(f"Processing batch {batch_start//batch_size + 1}: users {batch_start+1}-{batch_end} of {total_users}")
        batch_start_time = time.time()
        
        for user_id in batch_user_ids:
            recommendations = get_top_n_recommendations(
                user_id, 
                user_movie_similarities, 
                train_ratings, 
                cached_rated_movies,
                n
            )
            
            if recommendations:
                all_recommendations[user_id] = recommendations
                users_with_recommendations += 1
        
        # Log progress after each batch
        batch_time = time.time() - batch_start_time
        elapsed = time.time() - start_time
        progress = batch_end / total_users * 100
        remaining = batch_time * ((total_users - batch_end) / len(batch_user_ids)) if batch_end < total_users else 0
        
        print(f"Processed {batch_end}/{total_users} users ({progress:.1f}%) - Elapsed: {elapsed:.2f}s - Est. remaining: {remaining:.2f}s")
        print(f"Users with recommendations so far: {users_with_recommendations}")
        
        # Force garbage collection after each batch
        gc.collect()
    
    # Calculate statistics
    if all_recommendations:
        total_recommendations = sum(len(recs) for recs in all_recommendations.values())
        avg_recommendations = total_recommendations / users_with_recommendations if users_with_recommendations > 0 else 0
        
        print(f"\nRecommendation generation complete:")
        print(f"Users with recommendations: {users_with_recommendations}/{total_users} ({users_with_recommendations/total_users*100:.1f}%)")
        print(f"Total recommendations generated: {total_recommendations}")
        print(f"Average recommendations per user: {avg_recommendations:.2f}")
    
    # Display sample recommendations for a few users
    if all_recommendations:
        print("\nSample recommendations for 3 users:")
        for user_id in list(all_recommendations.keys())[:3]:
            print(f"User ID: {user_id}")
            print("Top 5 recommended movies:")
            
            for rank, (movie_id, score) in enumerate(all_recommendations[user_id][:5], 1):
                movie_title = "Unknown"
                if movie_features is not None:
                    movie_row = movie_features[movie_features['movieId'] == movie_id]
                    if not movie_row.empty and 'title' in movie_row.columns:
                        movie_title = movie_row.iloc[0]['title']
                print(f"  {rank}. '{movie_title}' (ID: {movie_id}): {score:.4f}")
            print("---")
    
    return all_recommendations

# Generate recommendations if similarities are available
if 'user_movie_similarities' in data and 'train_ratings' in data:
    # Get all user IDs and sort them numerically
    all_user_ids = sorted(list(user_movie_similarities.keys()))
    
    # Calculate the number of users to include (first 20%)
    target_users_count = int(len(all_user_ids) * 0.2)
    target_users = all_user_ids[:target_users_count]
    
    print(f"Generating recommendations for first 20% of users ({len(target_users)} out of {len(all_user_ids)} total users)")
    print(f"Target user range: {min(target_users)} to {max(target_users)}")
    
    # Create a filtered version of user_movie_similarities with only the target users
    filtered_similarities = {uid: user_movie_similarities[uid] for uid in target_users}
    
    # Generate recommendations only for the target users
    all_recommendations = generate_recommendations_for_all_users(
        filtered_similarities, 
        data['train_ratings'],
        data['movie_features'],
        n=top_n,
        batch_size=100
    )
    data['all_recommendations'] = all_recommendations
    
    # Save recommendations
    with open(os.path.join(output_path, 'content_based_recommendations.pkl'), 'wb') as f:
        pickle.dump(all_recommendations, f)
    
    # Also save in a more readable CSV format
    recommendations_list = []
    
    # Process in chunks to avoid memory issues
    chunk_size = 1000
    user_ids = list(all_recommendations.keys())
    total_users = len(user_ids)
    
    for chunk_start in range(0, total_users, chunk_size):
        chunk_end = min(chunk_start + chunk_size, total_users)
        user_chunk = user_ids[chunk_start:chunk_end]
        
        chunk_recommendations = []
        for user_id in user_chunk:
            for rank, (movie_id, score) in enumerate(all_recommendations[user_id], 1):
                movie_title = "Unknown"
                if 'movie_features' in data:
                    movie_row = data['movie_features'][data['movie_features']['movieId'] == movie_id]
                    if not movie_row.empty and 'title' in movie_row.columns:
                        movie_title = movie_row.iloc[0]['title']
                        
                chunk_recommendations.append({
                    'userId': user_id,
                    'movieId': movie_id,
                    'title': movie_title,
                    'rank': rank,
                    'similarity_score': score
                })
        
        recommendations_list.extend(chunk_recommendations)
        print(f"Processed recommendation chunk {chunk_start//chunk_size + 1}: users {chunk_start+1}-{chunk_end} of {total_users}")
        gc.collect()
    
    if recommendations_list:
        # Write CSV in chunks to avoid memory issues
        chunk_size = 10000
        total_recs = len(recommendations_list)
        
        for chunk_start in range(0, total_recs, chunk_size):
            chunk_end = min(chunk_start + chunk_size, total_recs)
            chunk = recommendations_list[chunk_start:chunk_end]
            
            chunk_df = pd.DataFrame(chunk)
            
            # For first chunk, write with header
            if chunk_start == 0:
                chunk_df.to_csv(os.path.join(output_path, 'content_based_recommendations.csv'), index=False, mode='w')
            else:
                # For subsequent chunks, append without header
                chunk_df.to_csv(os.path.join(output_path, 'content_based_recommendations.csv'), index=False, mode='a', header=False)
            
            print(f"Saved recommendation chunk {chunk_start//chunk_size + 1}: recommendations {chunk_start+1}-{chunk_end} of {total_recs}")
            
        print(f"Saved recommendations to CSV file with {total_recs} entries")
    
    # Free memory
    del recommendations_list
    gc.collect()
print("\n" + "="*80)
print("STEP 9: MODEL EVALUATION")
print("="*80)

# Thay đổi hàm evaluate_with_rmse_mae như sau:
def evaluate_with_rmse_mae(user_movie_similarities, train_ratings, test_ratings, batch_size=100):
    """
    Evaluate the recommendations using RMSE and MAE with batching for memory efficiency
    
    Parameters:
    -----------
    user_movie_similarities : dict
        Dictionary of user-movie similarities
    train_ratings : pd.DataFrame
        DataFrame of training ratings
    test_ratings : pd.DataFrame
        DataFrame of test ratings
    batch_size : int
        Size of user batches to process
        
    Returns:
    --------
    dict
        Dictionary of evaluation metrics
    """
    print("Evaluating recommendation model using RMSE and MAE with batching...")
    start_time = time.time()
    
    # Lấy common users giữa test_ratings và training users
    test_users = set(test_ratings['userId'].unique())
    train_users = set(train_ratings['userId'].unique())
    users_to_evaluate = test_users.intersection(train_users)
    
    print(f"Users in test set: {len(test_users)}")
    print(f"Users in training set: {len(train_users)}")
    print(f"Users to evaluate (intersection): {len(users_to_evaluate)}")
    
    # Kiểm tra nếu chúng ta đang sử dụng user-based split
    if len(users_to_evaluate) == 0:
        print("Using user-based split - no common users between train and test.")
        print("Evaluating using average rating for all predictions instead.")
        
        # Lấy average rating từ training set
        avg_rating = train_ratings['rating'].mean()
        
        # Đếm số lượng dự đoán
        total_predictions = len(test_ratings)
        
        # Tính MSE và MAE bằng cách dùng average rating làm dự đoán
        squared_errors_sum = ((test_ratings['rating'] - avg_rating) ** 2).sum()
        absolute_errors_sum = (abs(test_ratings['rating'] - avg_rating)).sum()
        
        # Tính RMSE và MAE
        overall_rmse = np.sqrt(squared_errors_sum / total_predictions)
        overall_mae = absolute_errors_sum / total_predictions
        
        print("\nEvaluation results using average rating baseline:")
        print(f"Total predictions: {total_predictions}")
        print(f"RMSE: {overall_rmse:.4f}")
        print(f"MAE: {overall_mae:.4f}")
        
        # Tạo metrics dictionary
        metrics = {
            'rmse': overall_rmse,
            'mae': overall_mae,
            'num_predictions': total_predictions,
            'evaluation_method': 'average_rating_baseline'
        }
        
        return metrics
    
    # Nếu có common users, tiếp tục với cách đánh giá gốc
    # (Phần code gốc của bạn bắt đầu từ đây, giữ nguyên)
    users_with_similarity = set(user_movie_similarities.keys())
    users_in_test_with_similarity = users_to_evaluate.intersection(users_with_similarity)
    
    print(f"Users in test set with similarity data: {len(users_in_test_with_similarity)}/{len(users_to_evaluate)} ({len(users_in_test_with_similarity)/len(users_to_evaluate)*100:.1f}%)")
    
    # Track metrics in chunks instead of storing all predictions
    squared_errors_sum = 0
    absolute_errors_sum = 0
    total_predictions = 0
    users_evaluated = 0
    
    # Process users in batches
    user_list = list(users_in_test_with_similarity)
    for batch_start in range(0, len(user_list), batch_size):
        batch_end = min(batch_start + batch_size, len(user_list))
        batch_users = user_list[batch_start:batch_end]
        
        print(f"Evaluating batch {batch_start//batch_size + 1}: users {batch_start+1}-{batch_end} of {len(user_list)}")
        batch_start_time = time.time()
        
        batch_squared_errors = 0
        batch_absolute_errors = 0
        batch_predictions = 0
        
        for user_id in batch_users:
            # Get user test ratings
            user_test = test_ratings[test_ratings['userId'] == user_id]
            
            if len(user_test) == 0:
                continue
            
            # Get user's average rating from training data
            user_train = train_ratings[train_ratings['userId'] == user_id]
            user_avg_rating = user_train['rating'].mean() if len(user_train) > 0 else 3.0
            
            # Predict ratings for test items
            for _, row in user_test.iterrows():
                movie_id = row['movieId']
                true_rating = row['rating']
                
                # Get similarity-based prediction
                if movie_id in user_movie_similarities.get(user_id, {}):
                    # Convert similarity score to rating prediction
                    sim_score = user_movie_similarities[user_id][movie_id]
                    predicted_rating = 0.5 + 4.5 * sim_score
                else:
                    # Use user's average rating as fallback
                    predicted_rating = user_avg_rating
                
                # Calculate error
                squared_error = (predicted_rating - true_rating) ** 2
                absolute_error = abs(predicted_rating - true_rating)
                
                batch_squared_errors += squared_error
                batch_absolute_errors += absolute_error
                batch_predictions += 1
            
            users_evaluated += 1
        
        # Accumulate batch metrics
        squared_errors_sum += batch_squared_errors
        absolute_errors_sum += batch_absolute_errors
        total_predictions += batch_predictions
        
        # Log progress
        batch_time = time.time() - batch_start_time
        elapsed = time.time() - start_time
        progress = batch_end / len(user_list) * 100
        remaining = batch_time * ((len(user_list) - batch_end) / len(batch_users)) if batch_end < len(user_list) else 0
        
        # Periodically calculate and log intermediate metrics
        if batch_predictions > 0:
            batch_rmse = np.sqrt(batch_squared_errors / batch_predictions)
            batch_mae = batch_absolute_errors / batch_predictions
            print(f"Batch metrics - RMSE: {batch_rmse:.4f}, MAE: {batch_mae:.4f}, Predictions: {batch_predictions}")
        
        print(f"Processed {batch_end}/{len(user_list)} users ({progress:.1f}%) - Elapsed: {elapsed:.2f}s - Est. remaining: {remaining:.2f}s")
        
        # Force garbage collection after each batch
        gc.collect()
    
    # Calculate overall RMSE and MAE
    if total_predictions > 0:
        overall_rmse = np.sqrt(squared_errors_sum / total_predictions)
        overall_mae = absolute_errors_sum / total_predictions
    else:
        overall_rmse = 0.0
        overall_mae = 0.0
    
    print("\nEvaluation results:")
    print(f"Users evaluated: {users_evaluated}")
    print(f"Total predictions: {total_predictions}")
    print(f"RMSE: {overall_rmse:.4f}")
    print(f"MAE: {overall_mae:.4f}")
    
    # Create metrics dictionary
    metrics = {
        'rmse': overall_rmse,
        'mae': overall_mae,
        'num_users_evaluated': users_evaluated,
        'num_predictions': total_predictions
    }
    
    return metrics
# Evaluate recommendations if test ratings are available
if 'user_movie_similarities' in data and 'train_ratings' in data and 'test_ratings' in data:
    # Call the new evaluation function
    print("Running evaluation with RMSE and MAE metrics...")
    evaluation_metrics = evaluate_with_rmse_mae(
        data['user_movie_similarities'],
        data['train_ratings'],
        data['test_ratings'],
        batch_size=100
    )
    
    # Store the metrics in the data dictionary
    data['evaluation_metrics'] = evaluation_metrics
    
    # Print the metrics to confirm they're stored correctly
    print("\nStored evaluation metrics:")
    for key, value in evaluation_metrics.items():
        print(f"  {key}: {value}")
    
    # Save metrics to CSV
    evaluation_results = pd.DataFrame([evaluation_metrics])
    evaluation_results.to_csv(os.path.join(output_path, 'content_based_evaluation.csv'), index=False)
    
    # Also save user metrics
    if 'user_metrics' in data:
        user_metrics_df = pd.DataFrame.from_dict(data['user_metrics'], orient='index')
        user_metrics_df.reset_index(inplace=True)
        user_metrics_df.rename(columns={'index': 'userId'}, inplace=True)
        user_metrics_df.to_csv(os.path.join(output_path, 'user_metrics.csv'), index=False)
    
    print(f"Saved evaluation metrics to CSV files")
    
    # Free memory
    gc.collect()

print("\n" + "="*80)
print("SUMMARY OF CONTENT-BASED RECOMMENDATION SYSTEM")
print("="*80)

# Data information
print("\nData Information:")
if 'movie_features' in data:
    print(f"- Processed {len(data['movie_features'])} movie feature records")
if 'corpus_word_counts' in data:
    print(f"- Vocabulary size: {len(data['corpus_word_counts'])} unique words")
if 'movie_vectors' in data:
    print(f"- Generated feature vectors for {len(data['movie_vectors'])} movies")
if 'user_vectors' in data:
    print(f"- Generated feature vectors for {len(data['user_vectors'])} users")
if 'user_movie_similarities' in data:
    avg_similar_movies = sum(len(sims) for sims in data['user_movie_similarities'].values()) / len(data['user_movie_similarities'])
    print(f"- Average similar movies per user: {avg_similar_movies:.2f}")
if 'all_recommendations' in data:
    avg_recommendations = sum(len(recs) for recs in data['all_recommendations'].values()) / len(data['all_recommendations'])
    print(f"- Average recommendations per user: {avg_recommendations:.2f}")

# Safely display evaluation metrics without assuming specific keys
print("\nPerformance Metrics:")
if 'evaluation_metrics' in data:
    # Safely check for each expected metric
    if 'rmse' in data['evaluation_metrics']:
        print(f"- RMSE: {data['evaluation_metrics']['rmse']:.4f}")
    if 'mae' in data['evaluation_metrics']:
        print(f"- MAE: {data['evaluation_metrics']['mae']:.4f}")
    if 'num_users_evaluated' in data['evaluation_metrics']:
        print(f"- Users evaluated: {data['evaluation_metrics']['num_users_evaluated']}")
    if 'num_predictions' in data['evaluation_metrics']:
        print(f"- Total predictions: {data['evaluation_metrics']['num_predictions']}")
else:
    print("- No evaluation metrics available")

# Model advantages
print("\nAdvantages of this approach:")
print("- Log-Likelihood identifies more meaningful words compared to TF-IDF")
print("- Word2Vec captures semantic relationships between words")
print("- Handles new movies effectively (cold start for items)")
print("- Generates personalized recommendations based on content preferences")
print("- Doesn't require item-item similarity calculations")
print("- Memory-optimized batch processing prevents RAM overflow during long runs")

# Saved files
print("\nSaved Files:")
for file in os.listdir(output_path):
    file_path = os.path.join(output_path, file)
    file_size = os.path.getsize(file_path) / (1024 * 1024)  # Size in MB
    print(f"- {file} ({file_size:.2f} MB)")

# Memory usage information
import psutil 
process = psutil.Process(os.getpid())
memory_usage = process.memory_info().rss / (1024 * 1024)  # MB
print(f"\nFinal memory usage: {memory_usage:.2f} MB")

print("\nContent-Based Filtering Model Successfully Implemented!")
# Out:
# ================================================================================
# CONTENT-BASED MOVIE RECOMMENDATION SYSTEM WITH LOG-LIKELIHOOD AND WORD2VEC
# ================================================================================
#
# ================================================================================
# STEP 1: DATA LOADING
# ================================================================================
# Loading processed data from stage1.py...
# Loaded features for 24378 movies
#
# Sample of movie features data:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                     top_keywords
# 0   [animation, pixar, tom hanks, computer, toy]
# 1  [robin williams, game, time, travel, fantasy]
# 2        [sequel, old, comedinha, de, velhinhos]
#
# Average token count per movie: 64.14
# Min token count: 1, Max token count: 4117
#
# Loaded 14472091 normalized ratings
#
# Sample of normalized ratings data:
#    userId  movieId  rating  normalized_rating
# 0       1        2     3.5           2.058415
# 1       1       29     3.5           2.058415
# 2       1       32     3.5           2.058415
#
# Number of unique users: 100000
# Number of unique movies: 24829
# Rating sparsity: 99.4171%
# Splitting ratings into training and testing sets...
#
# Split ratings into 11577672 training and 2894419 testing samples
# Training set covers 100000 users and 23950 movies
# Testing set covers 99879 users and 18755 movies
#
# ================================================================================
# STEP 2: CORPUS ANALYSIS
# ================================================================================
# Building vocabulary and word frequency counts...
# Processed 1000/24378 movies (4.1%)
# Processed 2000/24378 movies (8.2%)
# Processed 3000/24378 movies (12.3%)
# Processed 4000/24378 movies (16.4%)
# Processed 5000/24378 movies (20.5%)
# Processed 6000/24378 movies (24.6%)
# Processed 7000/24378 movies (28.7%)
# Processed 8000/24378 movies (32.8%)
# Processed 9000/24378 movies (36.9%)
# Processed 10000/24378 movies (41.0%)
# Processed 11000/24378 movies (45.1%)
# Processed 12000/24378 movies (49.2%)
# Processed 13000/24378 movies (53.3%)
# Processed 14000/24378 movies (57.4%)
# Processed 15000/24378 movies (61.5%)
# Processed 16000/24378 movies (65.6%)
# Processed 17000/24378 movies (69.7%)
# Processed 18000/24378 movies (73.8%)
# Processed 19000/24378 movies (77.9%)
# Processed 20000/24378 movies (82.0%)
# Processed 21000/24378 movies (86.1%)
# Processed 22000/24378 movies (90.2%)
# Processed 23000/24378 movies (94.3%)
# Processed 24000/24378 movies (98.4%)
# Processed 24378/24378 movies (100.0%)
# Built vocabulary with 95445 unique words
# Total words in corpus: 1563519
#
# Top 20 most common words in the corpus:
# 'comedy': 11199
# 'book': 9569
# 'based': 9429
# 'nudity': 9006
# 'ending': 7492
# 'story': 7485
# 'life': 6671
# 'topless': 6542
# 'dark': 6004
# 'fi': 5469
# 'sci': 5428
# 'action': 5425
# 'time': 5030
# 'atmospheric': 4655
# 'great': 4584
# 'twist': 4576
# 'family': 4473
# 'love': 4466
# 'true': 4327
# 'funny': 4275
#
# ================================================================================
# STEP 3: LOG-LIKELIHOOD CALCULATION
# ================================================================================
# Calculating Log-Likelihood values for all movies in batches...
# Total corpus size: 1563519 words
# Processing batch 1: movies 1-100 of 24378
# Progress: 0.4% - Elapsed: 0.01s - Est. remaining: 2.91s
# Processing batch 2: movies 101-200 of 24378
# Progress: 0.8% - Elapsed: 0.10s - Est. remaining: 25.09s
# Processing batch 3: movies 201-300 of 24378
# Progress: 1.2% - Elapsed: 0.20s - Est. remaining: 47.06s
# Processing batch 4: movies 301-400 of 24378
# Progress: 1.6% - Elapsed: 0.29s - Est. remaining: 69.22s
# Processing batch 5: movies 401-500 of 24378
# Progress: 2.1% - Elapsed: 0.38s - Est. remaining: 90.77s
# Processing batch 6: movies 501-600 of 24378
# Progress: 2.5% - Elapsed: 0.47s - Est. remaining: 112.79s
# Processing batch 7: movies 601-700 of 24378
# Progress: 2.9% - Elapsed: 0.57s - Est. remaining: 134.29s
# Processing batch 8: movies 701-800 of 24378
# Progress: 3.3% - Elapsed: 0.66s - Est. remaining: 155.57s
# Processing batch 9: movies 801-900 of 24378
# Progress: 3.7% - Elapsed: 0.75s - Est. remaining: 176.92s
# Processing batch 10: movies 901-1000 of 24378
# Progress: 4.1% - Elapsed: 0.85s - Est. remaining: 198.05s
# Processing batch 11: movies 1001-1100 of 24378
# Progress: 4.5% - Elapsed: 0.94s - Est. remaining: 218.85s
# Processing batch 12: movies 1101-1200 of 24378
# Progress: 4.9% - Elapsed: 1.04s - Est. remaining: 240.94s
# Processing batch 13: movies 1201-1300 of 24378
# Progress: 5.3% - Elapsed: 1.16s - Est. remaining: 268.66s
# Processing batch 14: movies 1301-1400 of 24378
# Progress: 5.7% - Elapsed: 1.26s - Est. remaining: 288.89s
# Processing batch 15: movies 1401-1500 of 24378
# Progress: 6.2% - Elapsed: 1.35s - Est. remaining: 308.49s
# Processing batch 16: movies 1501-1600 of 24378
# Progress: 6.6% - Elapsed: 1.44s - Est. remaining: 328.60s
# Processing batch 17: movies 1601-1700 of 24378
# Progress: 7.0% - Elapsed: 1.54s - Est. remaining: 348.30s
# Processing batch 18: movies 1701-1800 of 24378
# Progress: 7.4% - Elapsed: 1.63s - Est. remaining: 367.96s
# Processing batch 19: movies 1801-1900 of 24378
# Progress: 7.8% - Elapsed: 1.72s - Est. remaining: 387.55s
# Processing batch 20: movies 1901-2000 of 24378
# Progress: 8.2% - Elapsed: 1.82s - Est. remaining: 406.47s
# Processing batch 21: movies 2001-2100 of 24378
# Progress: 8.6% - Elapsed: 1.91s - Est. remaining: 425.31s
# Processing batch 22: movies 2101-2200 of 24378
# Progress: 9.0% - Elapsed: 2.00s - Est. remaining: 444.28s
# Processing batch 23: movies 2201-2300 of 24378
# Progress: 9.4% - Elapsed: 2.10s - Est. remaining: 463.74s
# Processing batch 24: movies 2301-2400 of 24378
# Progress: 9.8% - Elapsed: 2.19s - Est. remaining: 481.75s
# Processing batch 25: movies 2401-2500 of 24378
# Progress: 10.3% - Elapsed: 2.29s - Est. remaining: 500.21s
# Processing batch 26: movies 2501-2600 of 24378
# Progress: 10.7% - Elapsed: 2.38s - Est. remaining: 518.54s
# Processing batch 27: movies 2601-2700 of 24378
# Progress: 11.1% - Elapsed: 2.48s - Est. remaining: 536.71s
# Processing batch 28: movies 2701-2800 of 24378
# Progress: 11.5% - Elapsed: 2.57s - Est. remaining: 554.42s
# Processing batch 29: movies 2801-2900 of 24378
# Progress: 11.9% - Elapsed: 2.67s - Est. remaining: 572.63s
# Processing batch 30: movies 2901-3000 of 24378
# Progress: 12.3% - Elapsed: 2.76s - Est. remaining: 589.61s
# Processing batch 31: movies 3001-3100 of 24378
# Progress: 12.7% - Elapsed: 2.85s - Est. remaining: 606.49s
# Processing batch 32: movies 3101-3200 of 24378
# Progress: 13.1% - Elapsed: 2.94s - Est. remaining: 623.12s
# Processing batch 33: movies 3201-3300 of 24378
# Progress: 13.5% - Elapsed: 3.04s - Est. remaining: 639.83s
# Processing batch 34: movies 3301-3400 of 24378
# Progress: 13.9% - Elapsed: 3.13s - Est. remaining: 657.58s
# Processing batch 35: movies 3401-3500 of 24378
# Progress: 14.4% - Elapsed: 3.23s - Est. remaining: 673.37s
# Processing batch 36: movies 3501-3600 of 24378
# Progress: 14.8% - Elapsed: 3.32s - Est. remaining: 689.38s
# Processing batch 37: movies 3601-3700 of 24378
# Progress: 15.2% - Elapsed: 3.41s - Est. remaining: 705.04s
# Processing batch 38: movies 3701-3800 of 24378
# Progress: 15.6% - Elapsed: 3.50s - Est. remaining: 720.79s
# Processing batch 39: movies 3801-3900 of 24378
# Progress: 16.0% - Elapsed: 3.60s - Est. remaining: 736.50s
# Processing batch 40: movies 3901-4000 of 24378
# Progress: 16.4% - Elapsed: 3.69s - Est. remaining: 751.54s
# Processing batch 41: movies 4001-4100 of 24378
# Progress: 16.8% - Elapsed: 3.78s - Est. remaining: 766.49s
# Processing batch 42: movies 4101-4200 of 24378
# Progress: 17.2% - Elapsed: 3.87s - Est. remaining: 781.19s
# Processing batch 43: movies 4201-4300 of 24378
# Progress: 17.6% - Elapsed: 3.96s - Est. remaining: 795.78s
# Processing batch 44: movies 4301-4400 of 24378
# Progress: 18.0% - Elapsed: 4.05s - Est. remaining: 810.08s
# Processing batch 45: movies 4401-4500 of 24378
# Progress: 18.5% - Elapsed: 4.16s - Est. remaining: 826.21s
# Processing batch 46: movies 4501-4600 of 24378
# Progress: 18.9% - Elapsed: 4.25s - Est. remaining: 840.17s
# Processing batch 47: movies 4601-4700 of 24378
# Progress: 19.3% - Elapsed: 4.34s - Est. remaining: 853.97s
# Processing batch 48: movies 4701-4800 of 24378
# Progress: 19.7% - Elapsed: 4.43s - Est. remaining: 867.77s
# Processing batch 49: movies 4801-4900 of 24378
# Progress: 20.1% - Elapsed: 4.52s - Est. remaining: 881.15s
# Processing batch 50: movies 4901-5000 of 24378
# Progress: 20.5% - Elapsed: 4.62s - Est. remaining: 895.25s
# Processing batch 51: movies 5001-5100 of 24378
# Progress: 20.9% - Elapsed: 4.71s - Est. remaining: 908.23s
# Processing batch 52: movies 5101-5200 of 24378
# Progress: 21.3% - Elapsed: 4.80s - Est. remaining: 920.90s
# Processing batch 53: movies 5201-5300 of 24378
# Progress: 21.7% - Elapsed: 4.89s - Est. remaining: 933.69s
# Processing batch 54: movies 5301-5400 of 24378
# Progress: 22.2% - Elapsed: 4.99s - Est. remaining: 946.11s
# Processing batch 55: movies 5401-5500 of 24378
# Progress: 22.6% - Elapsed: 5.08s - Est. remaining: 958.72s
# Processing batch 56: movies 5501-5600 of 24378
# Progress: 23.0% - Elapsed: 5.17s - Est. remaining: 970.86s
# Processing batch 57: movies 5601-5700 of 24378
# Progress: 23.4% - Elapsed: 5.27s - Est. remaining: 983.47s
# Processing batch 58: movies 5701-5800 of 24378
# Progress: 23.8% - Elapsed: 5.36s - Est. remaining: 995.22s
# Processing batch 59: movies 5801-5900 of 24378
# Progress: 24.2% - Elapsed: 5.45s - Est. remaining: 1006.85s
# Processing batch 60: movies 5901-6000 of 24378
# Progress: 24.6% - Elapsed: 5.54s - Est. remaining: 1018.23s
# Processing batch 61: movies 6001-6100 of 24378
# Progress: 25.0% - Elapsed: 5.63s - Est. remaining: 1029.64s
# Processing batch 62: movies 6101-6200 of 24378
# Progress: 25.4% - Elapsed: 5.74s - Est. remaining: 1043.93s
# Processing batch 63: movies 6201-6300 of 24378
# Progress: 25.8% - Elapsed: 5.83s - Est. remaining: 1054.78s
# Processing batch 64: movies 6301-6400 of 24378
# Progress: 26.3% - Elapsed: 5.93s - Est. remaining: 1065.32s
# Processing batch 65: movies 6401-6500 of 24378
# Progress: 26.7% - Elapsed: 6.02s - Est. remaining: 1075.92s
# Processing batch 66: movies 6501-6600 of 24378
# Progress: 27.1% - Elapsed: 6.11s - Est. remaining: 1086.31s
# Processing batch 67: movies 6601-6700 of 24378
# Progress: 27.5% - Elapsed: 6.21s - Est. remaining: 1097.67s
# Processing batch 68: movies 6701-6800 of 24378
# Progress: 27.9% - Elapsed: 6.31s - Est. remaining: 1108.63s
# Processing batch 69: movies 6801-6900 of 24378
# Progress: 28.3% - Elapsed: 6.40s - Est. remaining: 1118.30s
# Processing batch 70: movies 6901-7000 of 24378
# Progress: 28.7% - Elapsed: 6.49s - Est. remaining: 1127.80s
# Processing batch 71: movies 7001-7100 of 24378
# Progress: 29.1% - Elapsed: 6.58s - Est. remaining: 1137.30s
# Processing batch 72: movies 7101-7200 of 24378
# Progress: 29.5% - Elapsed: 6.67s - Est. remaining: 1146.61s
# Processing batch 73: movies 7201-7300 of 24378
# Progress: 29.9% - Elapsed: 6.77s - Est. remaining: 1155.65s
# Processing batch 74: movies 7301-7400 of 24378
# Progress: 30.4% - Elapsed: 6.86s - Est. remaining: 1164.35s
# Processing batch 75: movies 7401-7500 of 24378
# Progress: 30.8% - Elapsed: 6.95s - Est. remaining: 1173.01s
# Processing batch 76: movies 7501-7600 of 24378
# Progress: 31.2% - Elapsed: 7.04s - Est. remaining: 1181.40s
# Processing batch 77: movies 7601-7700 of 24378
# Progress: 31.6% - Elapsed: 7.13s - Est. remaining: 1189.61s
# Processing batch 78: movies 7701-7800 of 24378
# Progress: 32.0% - Elapsed: 7.23s - Est. remaining: 1197.81s
# Processing batch 79: movies 7801-7900 of 24378
# Progress: 32.4% - Elapsed: 7.32s - Est. remaining: 1206.51s
# Processing batch 80: movies 7901-8000 of 24378
# Progress: 32.8% - Elapsed: 7.41s - Est. remaining: 1214.34s
# Processing batch 81: movies 8001-8100 of 24378
# Progress: 33.2% - Elapsed: 7.51s - Est. remaining: 1221.71s
# Processing batch 82: movies 8101-8200 of 24378
# Progress: 33.6% - Elapsed: 7.60s - Est. remaining: 1229.31s
# Processing batch 83: movies 8201-8300 of 24378
# Progress: 34.0% - Elapsed: 7.69s - Est. remaining: 1236.71s
# Processing batch 84: movies 8301-8400 of 24378
# Progress: 34.5% - Elapsed: 7.78s - Est. remaining: 1243.58s
# Processing batch 85: movies 8401-8500 of 24378
# Progress: 34.9% - Elapsed: 7.87s - Est. remaining: 1250.20s
# Processing batch 86: movies 8501-8600 of 24378
# Progress: 35.3% - Elapsed: 7.96s - Est. remaining: 1256.69s
# Processing batch 87: movies 8601-8700 of 24378
# Progress: 35.7% - Elapsed: 8.06s - Est. remaining: 1262.97s
# Processing batch 88: movies 8701-8800 of 24378
# Progress: 36.1% - Elapsed: 8.15s - Est. remaining: 1269.28s
# Processing batch 89: movies 8801-8900 of 24378
# Progress: 36.5% - Elapsed: 8.24s - Est. remaining: 1275.41s
# Processing batch 90: movies 8901-9000 of 24378
# Progress: 36.9% - Elapsed: 8.34s - Est. remaining: 1281.82s
# Processing batch 91: movies 9001-9100 of 24378
# Progress: 37.3% - Elapsed: 8.43s - Est. remaining: 1287.48s
# Processing batch 92: movies 9101-9200 of 24378
# Progress: 37.7% - Elapsed: 8.52s - Est. remaining: 1292.95s
# Processing batch 93: movies 9201-9300 of 24378
# Progress: 38.1% - Elapsed: 8.61s - Est. remaining: 1298.15s
# Processing batch 94: movies 9301-9400 of 24378
# Progress: 38.6% - Elapsed: 8.70s - Est. remaining: 1303.29s
# Processing batch 95: movies 9401-9500 of 24378
# Progress: 39.0% - Elapsed: 8.79s - Est. remaining: 1308.14s
# Processing batch 96: movies 9501-9600 of 24378
# Progress: 39.4% - Elapsed: 8.88s - Est. remaining: 1313.00s
# Processing batch 97: movies 9601-9700 of 24378
# Progress: 39.8% - Elapsed: 8.98s - Est. remaining: 1317.76s
# Processing batch 98: movies 9701-9800 of 24378
# Progress: 40.2% - Elapsed: 9.07s - Est. remaining: 1322.10s
# Processing batch 99: movies 9801-9900 of 24378
# Progress: 40.6% - Elapsed: 9.16s - Est. remaining: 1326.30s
# Processing batch 100: movies 9901-10000 of 24378
# Progress: 41.0% - Elapsed: 9.25s - Est. remaining: 1330.41s
# Processing batch 101: movies 10001-10100 of 24378
# Progress: 41.4% - Elapsed: 9.34s - Est. remaining: 1334.21s
# Processing batch 102: movies 10101-10200 of 24378
# Progress: 41.8% - Elapsed: 9.44s - Est. remaining: 1339.04s
# Processing batch 103: movies 10201-10300 of 24378
# Progress: 42.3% - Elapsed: 9.54s - Est. remaining: 1342.66s
# Processing batch 104: movies 10301-10400 of 24378
# Progress: 42.7% - Elapsed: 9.63s - Est. remaining: 1346.11s
# Processing batch 105: movies 10401-10500 of 24378
# Progress: 43.1% - Elapsed: 9.72s - Est. remaining: 1349.49s
# Processing batch 106: movies 10501-10600 of 24378
# Progress: 43.5% - Elapsed: 9.82s - Est. remaining: 1352.57s
# Processing batch 107: movies 10601-10700 of 24378
# Progress: 43.9% - Elapsed: 9.91s - Est. remaining: 1355.67s
# Processing batch 108: movies 10701-10800 of 24378
# Progress: 44.3% - Elapsed: 10.00s - Est. remaining: 1358.18s
# Processing batch 109: movies 10801-10900 of 24378
# Progress: 44.7% - Elapsed: 10.10s - Est. remaining: 1360.76s
# Processing batch 110: movies 10901-11000 of 24378
# Progress: 45.1% - Elapsed: 10.19s - Est. remaining: 1363.16s
# Processing batch 111: movies 11001-11100 of 24378
# Progress: 45.5% - Elapsed: 10.28s - Est. remaining: 1365.21s
# Processing batch 112: movies 11101-11200 of 24378
# Progress: 45.9% - Elapsed: 10.37s - Est. remaining: 1366.99s
# Processing batch 113: movies 11201-11300 of 24378
# Progress: 46.4% - Elapsed: 10.47s - Est. remaining: 1369.71s
# Processing batch 114: movies 11301-11400 of 24378
# Progress: 46.8% - Elapsed: 10.57s - Est. remaining: 1371.33s
# Processing batch 115: movies 11401-11500 of 24378
# Progress: 47.2% - Elapsed: 10.66s - Est. remaining: 1372.57s
# Processing batch 116: movies 11501-11600 of 24378
# Progress: 47.6% - Elapsed: 10.75s - Est. remaining: 1373.91s
# Processing batch 117: movies 11601-11700 of 24378
# Progress: 48.0% - Elapsed: 10.84s - Est. remaining: 1374.69s
# Processing batch 118: movies 11701-11800 of 24378
# Progress: 48.4% - Elapsed: 10.94s - Est. remaining: 1375.41s
# Processing batch 119: movies 11801-11900 of 24378
# Progress: 48.8% - Elapsed: 11.03s - Est. remaining: 1375.90s
# Processing batch 120: movies 11901-12000 of 24378
# Progress: 49.2% - Elapsed: 11.12s - Est. remaining: 1376.30s
# Processing batch 121: movies 12001-12100 of 24378
# Progress: 49.6% - Elapsed: 11.21s - Est. remaining: 1376.44s
# Processing batch 122: movies 12101-12200 of 24378
# Progress: 50.0% - Elapsed: 11.30s - Est. remaining: 1376.66s
# Processing batch 123: movies 12201-12300 of 24378
# Progress: 50.5% - Elapsed: 11.40s - Est. remaining: 1376.41s
# Processing batch 124: movies 12301-12400 of 24378
# Progress: 50.9% - Elapsed: 11.49s - Est. remaining: 1376.49s
# Processing batch 125: movies 12401-12500 of 24378
# Progress: 51.3% - Elapsed: 11.59s - Est. remaining: 1376.12s
# Processing batch 126: movies 12501-12600 of 24378
# Progress: 51.7% - Elapsed: 11.68s - Est. remaining: 1375.46s
# Processing batch 127: movies 12601-12700 of 24378
# Progress: 52.1% - Elapsed: 11.77s - Est. remaining: 1374.46s
# Processing batch 128: movies 12701-12800 of 24378
# Progress: 52.5% - Elapsed: 11.86s - Est. remaining: 1373.22s
# Processing batch 129: movies 12801-12900 of 24378
# Progress: 52.9% - Elapsed: 11.95s - Est. remaining: 1372.17s
# Processing batch 130: movies 12901-13000 of 24378
# Progress: 53.3% - Elapsed: 12.05s - Est. remaining: 1370.59s
# Processing batch 131: movies 13001-13100 of 24378
# Progress: 53.7% - Elapsed: 12.14s - Est. remaining: 1368.83s
# Processing batch 132: movies 13101-13200 of 24378
# Progress: 54.1% - Elapsed: 12.23s - Est. remaining: 1367.09s
# Processing batch 133: movies 13201-13300 of 24378
# Progress: 54.6% - Elapsed: 12.32s - Est. remaining: 1365.28s
# Processing batch 134: movies 13301-13400 of 24378
# Progress: 55.0% - Elapsed: 12.42s - Est. remaining: 1362.97s
# Processing batch 135: movies 13401-13500 of 24378
# Progress: 55.4% - Elapsed: 12.51s - Est. remaining: 1360.76s
# Processing batch 136: movies 13501-13600 of 24378
# Progress: 55.8% - Elapsed: 12.60s - Est. remaining: 1358.40s
# Processing batch 137: movies 13601-13700 of 24378
# Progress: 56.2% - Elapsed: 12.70s - Est. remaining: 1355.68s
# Processing batch 138: movies 13701-13800 of 24378
# Progress: 56.6% - Elapsed: 12.79s - Est. remaining: 1352.83s
# Processing batch 139: movies 13801-13900 of 24378
# Progress: 57.0% - Elapsed: 12.88s - Est. remaining: 1349.65s
# Processing batch 140: movies 13901-14000 of 24378
# Progress: 57.4% - Elapsed: 12.97s - Est. remaining: 1346.33s
# Processing batch 141: movies 14001-14100 of 24378
# Progress: 57.8% - Elapsed: 13.07s - Est. remaining: 1342.84s
# Processing batch 142: movies 14101-14200 of 24378
# Progress: 58.2% - Elapsed: 13.16s - Est. remaining: 1339.00s
# Processing batch 143: movies 14201-14300 of 24378
# Progress: 58.7% - Elapsed: 13.25s - Est. remaining: 1335.14s
# Processing batch 144: movies 14301-14400 of 24378
# Progress: 59.1% - Elapsed: 13.34s - Est. remaining: 1331.16s
# Processing batch 145: movies 14401-14500 of 24378
# Progress: 59.5% - Elapsed: 13.43s - Est. remaining: 1326.89s
# Processing batch 146: movies 14501-14600 of 24378
# Progress: 59.9% - Elapsed: 13.52s - Est. remaining: 1322.42s
# Processing batch 147: movies 14601-14700 of 24378
# Progress: 60.3% - Elapsed: 13.62s - Est. remaining: 1318.40s
# Processing batch 148: movies 14701-14800 of 24378
# Progress: 60.7% - Elapsed: 13.71s - Est. remaining: 1313.62s
# Processing batch 149: movies 14801-14900 of 24378
# Progress: 61.1% - Elapsed: 13.81s - Est. remaining: 1308.66s
# Processing batch 150: movies 14901-15000 of 24378
# Progress: 61.5% - Elapsed: 13.90s - Est. remaining: 1303.62s
# Processing batch 151: movies 15001-15100 of 24378
# Progress: 61.9% - Elapsed: 13.99s - Est. remaining: 1298.10s
# Processing batch 152: movies 15101-15200 of 24378
# Progress: 62.4% - Elapsed: 14.08s - Est. remaining: 1292.55s
# Processing batch 153: movies 15201-15300 of 24378
# Progress: 62.8% - Elapsed: 14.17s - Est. remaining: 1286.72s
# Processing batch 154: movies 15301-15400 of 24378
# Progress: 63.2% - Elapsed: 14.27s - Est. remaining: 1280.73s
# Processing batch 155: movies 15401-15500 of 24378
# Progress: 63.6% - Elapsed: 14.36s - Est. remaining: 1274.67s
# Processing batch 156: movies 15501-15600 of 24378
# Progress: 64.0% - Elapsed: 14.45s - Est. remaining: 1268.57s
# Processing batch 157: movies 15601-15700 of 24378
# Progress: 64.4% - Elapsed: 14.55s - Est. remaining: 1262.41s
# Processing batch 158: movies 15701-15800 of 24378
# Progress: 64.8% - Elapsed: 14.64s - Est. remaining: 1256.22s
# Processing batch 159: movies 15801-15900 of 24378
# Progress: 65.2% - Elapsed: 14.74s - Est. remaining: 1249.42s
# Processing batch 160: movies 15901-16000 of 24378
# Progress: 65.6% - Elapsed: 14.83s - Est. remaining: 1242.24s
# Processing batch 161: movies 16001-16100 of 24378
# Progress: 66.0% - Elapsed: 14.92s - Est. remaining: 1234.97s
# Processing batch 162: movies 16101-16200 of 24378
# Progress: 66.5% - Elapsed: 15.01s - Est. remaining: 1227.41s
# Processing batch 163: movies 16201-16300 of 24378
# Progress: 66.9% - Elapsed: 15.10s - Est. remaining: 1219.77s
# Processing batch 164: movies 16301-16400 of 24378
# Progress: 67.3% - Elapsed: 15.19s - Est. remaining: 1211.90s
# Processing batch 165: movies 16401-16500 of 24378
# Progress: 67.7% - Elapsed: 15.28s - Est. remaining: 1204.04s
# Processing batch 166: movies 16501-16600 of 24378
# Progress: 68.1% - Elapsed: 15.38s - Est. remaining: 1195.95s
# Processing batch 167: movies 16601-16700 of 24378
# Progress: 68.5% - Elapsed: 15.47s - Est. remaining: 1187.47s
# Processing batch 168: movies 16701-16800 of 24378
# Progress: 68.9% - Elapsed: 15.56s - Est. remaining: 1178.87s
# Processing batch 169: movies 16801-16900 of 24378
# Progress: 69.3% - Elapsed: 15.65s - Est. remaining: 1170.38s
# Processing batch 170: movies 16901-17000 of 24378
# Progress: 69.7% - Elapsed: 15.75s - Est. remaining: 1161.68s
# Processing batch 171: movies 17001-17100 of 24378
# Progress: 70.1% - Elapsed: 15.84s - Est. remaining: 1152.81s
# Processing batch 172: movies 17101-17200 of 24378
# Progress: 70.6% - Elapsed: 15.93s - Est. remaining: 1143.48s
# Processing batch 173: movies 17201-17300 of 24378
# Progress: 71.0% - Elapsed: 16.02s - Est. remaining: 1133.99s
# Processing batch 174: movies 17301-17400 of 24378
# Progress: 71.4% - Elapsed: 16.11s - Est. remaining: 1124.36s
# Processing batch 175: movies 17401-17500 of 24378
# Progress: 71.8% - Elapsed: 16.20s - Est. remaining: 1114.56s
# Processing batch 176: movies 17501-17600 of 24378
# Progress: 72.2% - Elapsed: 16.30s - Est. remaining: 1104.77s
# Processing batch 177: movies 17601-17700 of 24378
# Progress: 72.6% - Elapsed: 16.39s - Est. remaining: 1094.56s
# Processing batch 178: movies 17701-17800 of 24378
# Progress: 73.0% - Elapsed: 16.48s - Est. remaining: 1084.15s
# Processing batch 179: movies 17801-17900 of 24378
# Progress: 73.4% - Elapsed: 16.61s - Est. remaining: 1075.86s
# Processing batch 180: movies 17901-18000 of 24378
# Progress: 73.8% - Elapsed: 16.71s - Est. remaining: 1065.52s
# Processing batch 181: movies 18001-18100 of 24378
# Progress: 74.2% - Elapsed: 16.80s - Est. remaining: 1054.60s
# Processing batch 182: movies 18101-18200 of 24378
# Progress: 74.7% - Elapsed: 16.89s - Est. remaining: 1043.50s
# Processing batch 183: movies 18201-18300 of 24378
# Progress: 75.1% - Elapsed: 16.98s - Est. remaining: 1032.31s
# Processing batch 184: movies 18301-18400 of 24378
# Progress: 75.5% - Elapsed: 17.08s - Est. remaining: 1020.94s
# Processing batch 185: movies 18401-18500 of 24378
# Progress: 75.9% - Elapsed: 17.17s - Est. remaining: 1009.28s
# Processing batch 186: movies 18501-18600 of 24378
# Progress: 76.3% - Elapsed: 17.26s - Est. remaining: 997.40s
# Processing batch 187: movies 18601-18700 of 24378
# Progress: 76.7% - Elapsed: 17.36s - Est. remaining: 985.47s
# Processing batch 188: movies 18701-18800 of 24378
# Progress: 77.1% - Elapsed: 17.45s - Est. remaining: 973.13s
# Processing batch 189: movies 18801-18900 of 24378
# Progress: 77.5% - Elapsed: 17.54s - Est. remaining: 960.70s
# Processing batch 190: movies 18901-19000 of 24378
# Progress: 77.9% - Elapsed: 17.63s - Est. remaining: 948.18s
# Processing batch 191: movies 19001-19100 of 24378
# Progress: 78.3% - Elapsed: 17.73s - Est. remaining: 935.65s
# Processing batch 192: movies 19101-19200 of 24378
# Progress: 78.8% - Elapsed: 17.83s - Est. remaining: 922.98s
# Processing batch 193: movies 19201-19300 of 24378
# Progress: 79.2% - Elapsed: 17.92s - Est. remaining: 909.79s
# Processing batch 194: movies 19301-19400 of 24378
# Progress: 79.6% - Elapsed: 18.01s - Est. remaining: 896.48s
# Processing batch 195: movies 19401-19500 of 24378
# Progress: 80.0% - Elapsed: 18.10s - Est. remaining: 882.93s
# Processing batch 196: movies 19501-19600 of 24378
# Progress: 80.4% - Elapsed: 18.19s - Est. remaining: 869.24s
# Processing batch 197: movies 19601-19700 of 24378
# Progress: 80.8% - Elapsed: 18.28s - Est. remaining: 855.32s
# Processing batch 198: movies 19701-19800 of 24378
# Progress: 81.2% - Elapsed: 18.38s - Est. remaining: 841.22s
# Processing batch 199: movies 19801-19900 of 24378
# Progress: 81.6% - Elapsed: 18.47s - Est. remaining: 826.96s
# Processing batch 200: movies 19901-20000 of 24378
# Progress: 82.0% - Elapsed: 18.56s - Est. remaining: 812.59s
# Processing batch 201: movies 20001-20100 of 24378
# Progress: 82.5% - Elapsed: 18.65s - Est. remaining: 797.94s
# Processing batch 202: movies 20101-20200 of 24378
# Progress: 82.9% - Elapsed: 18.74s - Est. remaining: 783.09s
# Processing batch 203: movies 20201-20300 of 24378
# Progress: 83.3% - Elapsed: 18.84s - Est. remaining: 768.35s
# Processing batch 204: movies 20301-20400 of 24378
# Progress: 83.7% - Elapsed: 18.93s - Est. remaining: 753.12s
# Processing batch 205: movies 20401-20500 of 24378
# Progress: 84.1% - Elapsed: 19.02s - Est. remaining: 737.79s
# Processing batch 206: movies 20501-20600 of 24378
# Progress: 84.5% - Elapsed: 19.12s - Est. remaining: 722.23s
# Processing batch 207: movies 20601-20700 of 24378
# Progress: 84.9% - Elapsed: 19.21s - Est. remaining: 706.44s
# Processing batch 208: movies 20701-20800 of 24378
# Progress: 85.3% - Elapsed: 19.30s - Est. remaining: 690.52s
# Processing batch 209: movies 20801-20900 of 24378
# Progress: 85.7% - Elapsed: 19.39s - Est. remaining: 674.44s
# Processing batch 210: movies 20901-21000 of 24378
# Progress: 86.1% - Elapsed: 19.48s - Est. remaining: 658.12s
# Processing batch 211: movies 21001-21100 of 24378
# Progress: 86.6% - Elapsed: 19.58s - Est. remaining: 641.67s
# Processing batch 212: movies 21101-21200 of 24378
# Progress: 87.0% - Elapsed: 19.67s - Est. remaining: 624.98s
# Processing batch 213: movies 21201-21300 of 24378
# Progress: 87.4% - Elapsed: 19.76s - Est. remaining: 608.11s
# Processing batch 214: movies 21301-21400 of 24378
# Progress: 87.8% - Elapsed: 19.85s - Est. remaining: 591.26s
# Processing batch 215: movies 21401-21500 of 24378
# Progress: 88.2% - Elapsed: 19.95s - Est. remaining: 574.06s
# Processing batch 216: movies 21501-21600 of 24378
# Progress: 88.6% - Elapsed: 20.04s - Est. remaining: 556.64s
# Processing batch 217: movies 21601-21700 of 24378
# Progress: 89.0% - Elapsed: 20.13s - Est. remaining: 539.05s
# Processing batch 218: movies 21701-21800 of 24378
# Progress: 89.4% - Elapsed: 20.22s - Est. remaining: 521.31s
# Processing batch 219: movies 21801-21900 of 24378
# Progress: 89.8% - Elapsed: 20.32s - Est. remaining: 503.42s
# Processing batch 220: movies 21901-22000 of 24378
# Progress: 90.2% - Elapsed: 20.41s - Est. remaining: 485.31s
# Processing batch 221: movies 22001-22100 of 24378
# Progress: 90.7% - Elapsed: 20.50s - Est. remaining: 466.97s
# Processing batch 222: movies 22101-22200 of 24378
# Progress: 91.1% - Elapsed: 20.59s - Est. remaining: 448.49s
# Processing batch 223: movies 22201-22300 of 24378
# Progress: 91.5% - Elapsed: 20.68s - Est. remaining: 429.80s
# Processing batch 224: movies 22301-22400 of 24378
# Progress: 91.9% - Elapsed: 20.78s - Est. remaining: 410.95s
# Processing batch 225: movies 22401-22500 of 24378
# Progress: 92.3% - Elapsed: 20.87s - Est. remaining: 391.97s
# Processing batch 226: movies 22501-22600 of 24378
# Progress: 92.7% - Elapsed: 20.96s - Est. remaining: 372.74s
# Processing batch 227: movies 22601-22700 of 24378
# Progress: 93.1% - Elapsed: 21.05s - Est. remaining: 353.30s
# Processing batch 228: movies 22701-22800 of 24378
# Progress: 93.5% - Elapsed: 21.15s - Est. remaining: 333.68s
# Processing batch 229: movies 22801-22900 of 24378
# Progress: 93.9% - Elapsed: 21.24s - Est. remaining: 313.90s
# Processing batch 230: movies 22901-23000 of 24378
# Progress: 94.3% - Elapsed: 21.33s - Est. remaining: 293.96s
# Processing batch 231: movies 23001-23100 of 24378
# Progress: 94.8% - Elapsed: 21.42s - Est. remaining: 273.78s
# Processing batch 232: movies 23101-23200 of 24378
# Progress: 95.2% - Elapsed: 21.51s - Est. remaining: 253.43s
# Processing batch 233: movies 23201-23300 of 24378
# Progress: 95.6% - Elapsed: 21.61s - Est. remaining: 232.93s
# Processing batch 234: movies 23301-23400 of 24378
# Progress: 96.0% - Elapsed: 21.70s - Est. remaining: 212.21s
# Processing batch 235: movies 23401-23500 of 24378
# Progress: 96.4% - Elapsed: 21.79s - Est. remaining: 191.31s
# Processing batch 236: movies 23501-23600 of 24378
# Progress: 96.8% - Elapsed: 21.88s - Est. remaining: 170.23s
# Processing batch 237: movies 23601-23700 of 24378
# Progress: 97.2% - Elapsed: 21.98s - Est. remaining: 149.00s
# Processing batch 238: movies 23701-23800 of 24378
# Progress: 97.6% - Elapsed: 22.07s - Est. remaining: 127.55s
# Processing batch 239: movies 23801-23900 of 24378
# Progress: 98.0% - Elapsed: 22.16s - Est. remaining: 105.91s
# Processing batch 240: movies 23901-24000 of 24378
# Progress: 98.4% - Elapsed: 22.25s - Est. remaining: 84.10s
# Processing batch 241: movies 24001-24100 of 24378
# Progress: 98.9% - Elapsed: 22.34s - Est. remaining: 62.11s
# Processing batch 242: movies 24101-24200 of 24378
# Progress: 99.3% - Elapsed: 22.43s - Est. remaining: 39.93s
# Processing batch 243: movies 24201-24300 of 24378
# Progress: 99.7% - Elapsed: 22.52s - Est. remaining: 17.57s
# Processing batch 244: movies 24301-24378 of 24378
# Progress: 100.0% - Elapsed: 22.61s - Est. remaining: 0.00s
#
# Sample Log-Likelihood values for movie 'Toy Story (1995)' (ID: 1):
# Word: 'pixar', LL Value: 731.81
# Word: 'animation', LL Value: 623.16
# Word: 'toy', LL Value: 223.11
# Word: 'tom hanks', LL Value: 202.57
# Word: 'computer', LL Value: 168.33
# Word: 'disney', LL Value: 125.83
# Word: 'animated', LL Value: 104.44
# Word: 'child', LL Value: 93.84
# Word: 'disney pixar', LL Value: 86.13
# Word: 'witty', LL Value: 73.97
# 2025-05-01 11:32:07,325 : INFO : collecting all words and their counts
# 2025-05-01 11:32:07,326 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# Calculated Log-Likelihood values for 24378 movies
# Average number of words with LL > 10 per movie: 16.80
# Min: 1, Max: 147
#
# ================================================================================
# STEP 4: WORD2VEC MODEL TRAINING
# ================================================================================
# Training Word2Vec model with 200 dimensions...
# Loaded tokens from 1000/24378 movies (4.1%)
# Loaded tokens from 2000/24378 movies (8.2%)
# Loaded tokens from 3000/24378 movies (12.3%)
# Loaded tokens from 4000/24378 movies (16.4%)
# Loaded tokens from 5000/24378 movies (20.5%)
# Loaded tokens from 6000/24378 movies (24.6%)
# Loaded tokens from 7000/24378 movies (28.7%)
# Loaded tokens from 8000/24378 movies (32.8%)
# Loaded tokens from 9000/24378 movies (36.9%)
# Loaded tokens from 10000/24378 movies (41.0%)
# Loaded tokens from 11000/24378 movies (45.1%)
# Loaded tokens from 12000/24378 movies (49.2%)
# Loaded tokens from 13000/24378 movies (53.3%)
# Loaded tokens from 14000/24378 movies (57.4%)
# Loaded tokens from 15000/24378 movies (61.5%)
# Loaded tokens from 16000/24378 movies (65.6%)
# Loaded tokens from 17000/24378 movies (69.7%)
# Loaded tokens from 18000/24378 movies (73.8%)
# Loaded tokens from 19000/24378 movies (77.9%)
# Loaded tokens from 20000/24378 movies (82.0%)
# Loaded tokens from 21000/24378 movies (86.1%)
# Loaded tokens from 22000/24378 movies (90.2%)
# Loaded tokens from 23000/24378 movies (94.3%)
# Loaded tokens from 24000/24378 movies (98.4%)
# Loaded tokens from 24378/24378 movies (100.0%)
# Training corpus size: 1563519 tokens from 24378 documents
# Starting Word2Vec training (this may take a few minutes)...
# 2025-05-01 11:32:07,441 : INFO : PROGRESS: at sentence #10000, processed 788641 words, keeping 53383 word types
# 2025-05-01 11:32:07,537 : INFO : PROGRESS: at sentence #20000, processed 1396870 words, keeping 84652 word types
# 2025-05-01 11:32:07,576 : INFO : collected 95445 word types from a corpus of 1563519 raw words and 24378 sentences
# 2025-05-01 11:32:07,576 : INFO : Creating a fresh vocabulary
# 2025-05-01 11:32:07,653 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=3 retains 27637 unique words (28.96% of original 95445, drops 67808)', 'datetime': '2025-05-01T11:32:07.653183', 'gensim': '4.3.3', 'python': '3.11.0 (main, Oct 24 2022, 18:26:48) [MSC v.1933 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# 2025-05-01 11:32:07,654 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=3 leaves 1473966 word corpus (94.27% of original 1563519, drops 89553)', 'datetime': '2025-05-01T11:32:07.654375', 'gensim': '4.3.3', 'python': '3.11.0 (main, Oct 24 2022, 18:26:48) [MSC v.1933 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# 2025-05-01 11:32:07,756 : INFO : deleting the raw counts dictionary of 95445 items
# 2025-05-01 11:32:07,759 : INFO : sample=0.001 downsamples 23 most-common words
# 2025-05-01 11:32:07,759 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 1437387.653062624 word corpus (97.5%% of prior 1473966)', 'datetime': '2025-05-01T11:32:07.759704', 'gensim': '4.3.3', 'python': '3.11.0 (main, Oct 24 2022, 18:26:48) [MSC v.1933 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# 2025-05-01 11:32:07,772 : INFO : constructing a huffman tree from 27637 words
# 2025-05-01 11:32:08,355 : INFO : built huffman tree with maximum node depth 19
# 2025-05-01 11:32:08,528 : INFO : estimated required memory for 27637 words and 200 dimensions: 85674700 bytes
# 2025-05-01 11:32:08,529 : INFO : resetting layer weights
# 2025-05-01 11:32:08,551 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2025-05-01T11:32:08.551961', 'gensim': '4.3.3', 'python': '3.11.0 (main, Oct 24 2022, 18:26:48) [MSC v.1933 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'build_vocab'}
# 2025-05-01 11:32:08,552 : WARNING : Both hierarchical softmax and negative sampling are activated. This is probably a mistake. You should set either 'hs=0' or 'negative=0' to disable one of them.
# 2025-05-01 11:32:08,553 : INFO : Word2Vec lifecycle event {'msg': 'training model with 8 workers on 27637 vocabulary and 200 features, using sg=1 hs=1 sample=0.001 negative=20 window=10 shrink_windows=True', 'datetime': '2025-05-01T11:32:08.553977', 'gensim': '4.3.3', 'python': '3.11.0 (main, Oct 24 2022, 18:26:48) [MSC v.1933 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'train'}
# 2025-05-01 11:32:10,132 : INFO : EPOCH 0 - PROGRESS: at 2.74% examples, 50605 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:32:11,141 : INFO : EPOCH 0 - PROGRESS: at 5.52% examples, 66466 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:32:12,151 : INFO : EPOCH 0 - PROGRESS: at 9.69% examples, 73016 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:32:13,166 : INFO : EPOCH 0 - PROGRESS: at 15.03% examples, 78858 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:32:14,251 : INFO : EPOCH 0 - PROGRESS: at 19.49% examples, 76754 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:32:15,252 : INFO : EPOCH 0 - PROGRESS: at 25.19% examples, 77439 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:32:16,446 : INFO : EPOCH 0 - PROGRESS: at 30.22% examples, 76156 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:32:17,781 : INFO : EPOCH 0 - PROGRESS: at 39.36% examples, 76881 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:32:18,845 : INFO : EPOCH 0 - PROGRESS: at 45.17% examples, 77681 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:32:19,885 : INFO : EPOCH 0 - PROGRESS: at 50.39% examples, 78474 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:32:21,008 : INFO : EPOCH 0 - PROGRESS: at 56.37% examples, 79447 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:32:22,192 : INFO : EPOCH 0 - PROGRESS: at 62.37% examples, 78543 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:32:23,237 : INFO : EPOCH 0 - PROGRESS: at 70.49% examples, 79129 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:32:24,249 : INFO : EPOCH 0 - PROGRESS: at 77.75% examples, 79251 words/s, in_qsize 16, out_qsize 0
# 2025-05-01 11:32:25,304 : INFO : EPOCH 0 - PROGRESS: at 86.78% examples, 79668 words/s, in_qsize 12, out_qsize 0
# 2025-05-01 11:32:26,353 : INFO : EPOCH 0 - PROGRESS: at 100.00% examples, 80785 words/s, in_qsize 0, out_qsize 1
# 2025-05-01 11:32:26,354 : INFO : EPOCH 0: training on 1563519 raw words (1437630 effective words) took 17.8s, 80781 effective words/s
# 2025-05-01 11:32:28,049 : INFO : EPOCH 1 - PROGRESS: at 2.80% examples, 46980 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:32:29,060 : INFO : EPOCH 1 - PROGRESS: at 6.76% examples, 73513 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:32:30,083 : INFO : EPOCH 1 - PROGRESS: at 10.96% examples, 77863 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:32:31,540 : INFO : EPOCH 1 - PROGRESS: at 15.66% examples, 71848 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:32:32,600 : INFO : EPOCH 1 - PROGRESS: at 21.84% examples, 75693 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:32:33,623 : INFO : EPOCH 1 - PROGRESS: at 28.67% examples, 78880 words/s, in_qsize 16, out_qsize 0
# 2025-05-01 11:32:34,880 : INFO : EPOCH 1 - PROGRESS: at 34.28% examples, 76852 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:32:35,901 : INFO : EPOCH 1 - PROGRESS: at 42.00% examples, 78086 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:32:37,031 : INFO : EPOCH 1 - PROGRESS: at 47.16% examples, 78187 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:32:38,135 : INFO : EPOCH 1 - PROGRESS: at 52.44% examples, 78585 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:32:39,314 : INFO : EPOCH 1 - PROGRESS: at 58.28% examples, 78447 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:32:40,482 : INFO : EPOCH 1 - PROGRESS: at 66.33% examples, 79011 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:32:41,530 : INFO : EPOCH 1 - PROGRESS: at 74.51% examples, 79568 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:32:42,560 : INFO : EPOCH 1 - PROGRESS: at 82.14% examples, 79538 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:32:43,618 : INFO : EPOCH 1 - PROGRESS: at 90.81% examples, 79376 words/s, in_qsize 8, out_qsize 0
# 2025-05-01 11:32:44,086 : INFO : EPOCH 1: training on 1563519 raw words (1437528 effective words) took 17.7s, 81086 effective words/s
# 2025-05-01 11:32:45,126 : INFO : EPOCH 2 - PROGRESS: at 2.14% examples, 59181 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:32:46,671 : INFO : EPOCH 2 - PROGRESS: at 5.00% examples, 59355 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:32:47,719 : INFO : EPOCH 2 - PROGRESS: at 9.69% examples, 72272 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:32:49,280 : INFO : EPOCH 2 - PROGRESS: at 15.66% examples, 71747 words/s, in_qsize 16, out_qsize 0
# 2025-05-01 11:32:50,434 : INFO : EPOCH 2 - PROGRESS: at 22.47% examples, 75907 words/s, in_qsize 16, out_qsize 0
# 2025-05-01 11:32:51,468 : INFO : EPOCH 2 - PROGRESS: at 29.16% examples, 78910 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:32:52,661 : INFO : EPOCH 2 - PROGRESS: at 35.35% examples, 77448 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:32:53,682 : INFO : EPOCH 2 - PROGRESS: at 42.93% examples, 79520 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:32:54,928 : INFO : EPOCH 2 - PROGRESS: at 47.72% examples, 77811 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:32:55,941 : INFO : EPOCH 2 - PROGRESS: at 53.49% examples, 79620 words/s, in_qsize 16, out_qsize 0
# 2025-05-01 11:32:57,029 : INFO : EPOCH 2 - PROGRESS: at 58.90% examples, 79264 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:32:58,049 : INFO : EPOCH 2 - PROGRESS: at 67.15% examples, 80609 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:32:59,458 : INFO : EPOCH 2 - PROGRESS: at 74.51% examples, 78555 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:00,460 : INFO : EPOCH 2 - PROGRESS: at 84.02% examples, 79837 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:01,615 : INFO : EPOCH 2 - PROGRESS: at 97.35% examples, 81001 words/s, in_qsize 2, out_qsize 1
# 2025-05-01 11:33:01,874 : INFO : EPOCH 2: training on 1563519 raw words (1437449 effective words) took 17.8s, 80834 effective words/s
# 2025-05-01 11:33:03,454 : INFO : EPOCH 3 - PROGRESS: at 2.74% examples, 50398 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:04,531 : INFO : EPOCH 3 - PROGRESS: at 5.72% examples, 64708 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:05,567 : INFO : EPOCH 3 - PROGRESS: at 10.96% examples, 78609 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:06,950 : INFO : EPOCH 3 - PROGRESS: at 15.66% examples, 73400 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:07,980 : INFO : EPOCH 3 - PROGRESS: at 20.48% examples, 74487 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:09,019 : INFO : EPOCH 3 - PROGRESS: at 27.59% examples, 77713 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:10,116 : INFO : EPOCH 3 - PROGRESS: at 33.67% examples, 78387 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:11,185 : INFO : EPOCH 3 - PROGRESS: at 40.81% examples, 78145 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:12,248 : INFO : EPOCH 3 - PROGRESS: at 46.09% examples, 78764 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:13,282 : INFO : EPOCH 3 - PROGRESS: at 51.24% examples, 79559 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:14,406 : INFO : EPOCH 3 - PROGRESS: at 56.37% examples, 78945 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:15,412 : INFO : EPOCH 3 - PROGRESS: at 62.37% examples, 79112 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:16,496 : INFO : EPOCH 3 - PROGRESS: at 69.54% examples, 78834 words/s, in_qsize 16, out_qsize 0
# 2025-05-01 11:33:17,524 : INFO : EPOCH 3 - PROGRESS: at 76.90% examples, 78901 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:18,888 : INFO : EPOCH 3 - PROGRESS: at 85.75% examples, 77908 words/s, in_qsize 13, out_qsize 0
# 2025-05-01 11:33:19,844 : INFO : EPOCH 3: training on 1563519 raw words (1437667 effective words) took 18.0s, 80025 effective words/s
# 2025-05-01 11:33:20,868 : INFO : EPOCH 4 - PROGRESS: at 1.05% examples, 33006 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:22,485 : INFO : EPOCH 4 - PROGRESS: at 5.00% examples, 58138 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:23,571 : INFO : EPOCH 4 - PROGRESS: at 9.69% examples, 70491 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:24,587 : INFO : EPOCH 4 - PROGRESS: at 13.83% examples, 72830 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:25,920 : INFO : EPOCH 4 - PROGRESS: at 19.93% examples, 73358 words/s, in_qsize 16, out_qsize 0
# 2025-05-01 11:33:26,933 : INFO : EPOCH 4 - PROGRESS: at 25.70% examples, 74396 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:28,093 : INFO : EPOCH 4 - PROGRESS: at 32.42% examples, 76132 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:29,097 : INFO : EPOCH 4 - PROGRESS: at 40.21% examples, 77656 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:30,218 : INFO : EPOCH 4 - PROGRESS: at 45.74% examples, 77885 words/s, in_qsize 16, out_qsize 0
# 2025-05-01 11:33:31,229 : INFO : EPOCH 4 - PROGRESS: at 50.16% examples, 78130 words/s, in_qsize 16, out_qsize 0
# 2025-05-01 11:33:32,250 : INFO : EPOCH 4 - PROGRESS: at 55.79% examples, 79048 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:33,474 : INFO : EPOCH 4 - PROGRESS: at 61.87% examples, 77907 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:34,556 : INFO : EPOCH 4 - PROGRESS: at 70.49% examples, 78969 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:35,633 : INFO : EPOCH 4 - PROGRESS: at 76.02% examples, 77627 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:36,747 : INFO : EPOCH 4 - PROGRESS: at 81.48% examples, 75739 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:37,763 : INFO : EPOCH 4 - PROGRESS: at 90.81% examples, 76467 words/s, in_qsize 8, out_qsize 0
# 2025-05-01 11:33:38,521 : INFO : EPOCH 4: training on 1563519 raw words (1437203 effective words) took 18.7s, 76982 effective words/s
# 2025-05-01 11:33:39,530 : INFO : EPOCH 5 - PROGRESS: at 1.84% examples, 51970 words/s, in_qsize 14, out_qsize 1
# 2025-05-01 11:33:40,554 : INFO : EPOCH 5 - PROGRESS: at 4.12% examples, 57230 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:41,574 : INFO : EPOCH 5 - PROGRESS: at 7.10% examples, 68135 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:43,161 : INFO : EPOCH 5 - PROGRESS: at 11.44% examples, 64573 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:44,233 : INFO : EPOCH 5 - PROGRESS: at 17.09% examples, 70081 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:45,267 : INFO : EPOCH 5 - PROGRESS: at 22.64% examples, 71483 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:46,355 : INFO : EPOCH 5 - PROGRESS: at 27.59% examples, 70872 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:47,524 : INFO : EPOCH 5 - PROGRESS: at 33.11% examples, 70756 words/s, in_qsize 16, out_qsize 0
# 2025-05-01 11:33:48,589 : INFO : EPOCH 5 - PROGRESS: at 41.40% examples, 73139 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:49,609 : INFO : EPOCH 5 - PROGRESS: at 46.09% examples, 73678 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:50,678 : INFO : EPOCH 5 - PROGRESS: at 49.63% examples, 72430 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:51,717 : INFO : EPOCH 5 - PROGRESS: at 54.82% examples, 72913 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:52,886 : INFO : EPOCH 5 - PROGRESS: at 60.41% examples, 72655 words/s, in_qsize 16, out_qsize 0
# 2025-05-01 11:33:54,005 : INFO : EPOCH 5 - PROGRESS: at 67.04% examples, 72680 words/s, in_qsize 16, out_qsize 0
# 2025-05-01 11:33:55,009 : INFO : EPOCH 5 - PROGRESS: at 74.46% examples, 73225 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:56,316 : INFO : EPOCH 5 - PROGRESS: at 79.53% examples, 70897 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:33:57,431 : INFO : EPOCH 5 - PROGRESS: at 86.78% examples, 70564 words/s, in_qsize 12, out_qsize 0
# 2025-05-01 11:33:58,529 : INFO : EPOCH 5 - PROGRESS: at 94.68% examples, 70060 words/s, in_qsize 4, out_qsize 1
# 2025-05-01 11:33:58,700 : INFO : EPOCH 5: training on 1563519 raw words (1437483 effective words) took 20.2s, 71255 effective words/s
# 2025-05-01 11:33:59,899 : INFO : EPOCH 6 - PROGRESS: at 1.48% examples, 35794 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:34:00,923 : INFO : EPOCH 6 - PROGRESS: at 4.03% examples, 48210 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:34:01,941 : INFO : EPOCH 6 - PROGRESS: at 6.09% examples, 55873 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:34:03,036 : INFO : EPOCH 6 - PROGRESS: at 9.81% examples, 60600 words/s, in_qsize 16, out_qsize 0
# 2025-05-01 11:34:04,048 : INFO : EPOCH 6 - PROGRESS: at 13.84% examples, 64555 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:34:05,113 : INFO : EPOCH 6 - PROGRESS: at 18.49% examples, 65271 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:34:06,336 : INFO : EPOCH 6 - PROGRESS: at 23.84% examples, 65526 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:34:07,342 : INFO : EPOCH 6 - PROGRESS: at 29.16% examples, 67391 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:34:08,696 : INFO : EPOCH 6 - PROGRESS: at 36.35% examples, 67323 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:34:09,752 : INFO : EPOCH 6 - PROGRESS: at 42.93% examples, 69021 words/s, in_qsize 16, out_qsize 0
# 2025-05-01 11:34:10,780 : INFO : EPOCH 6 - PROGRESS: at 48.27% examples, 70588 words/s, in_qsize 16, out_qsize 0
# 2025-05-01 11:34:11,850 : INFO : EPOCH 6 - PROGRESS: at 51.93% examples, 69707 words/s, in_qsize 15, out_qsize 0
# 2025-05-01 11:34:12,949 : INFO : EPOCH 6 - PROGRESS: at 56.42% examples, 69456 words/s, in_qsize 15, out_qsize 0
# ...
# Processed 92500/99872 users (92.6%) - Elapsed: 1753.78s - Est. remaining: 124.33s
# Evaluating batch 926: users 92501-92600 of 99872
# Batch metrics - RMSE: 1.0047, MAE: 0.7884, Predictions: 3323
# Processed 92600/99872 users (92.7%) - Elapsed: 1755.63s - Est. remaining: 124.99s
# Evaluating batch 927: users 92601-92700 of 99872
# Batch metrics - RMSE: 0.9809, MAE: 0.7672, Predictions: 3121
# Processed 92700/99872 users (92.8%) - Elapsed: 1757.43s - Est. remaining: 120.99s
# Evaluating batch 928: users 92701-92800 of 99872
# Batch metrics - RMSE: 0.9634, MAE: 0.7562, Predictions: 2793
# Processed 92800/99872 users (92.9%) - Elapsed: 1759.26s - Est. remaining: 120.69s
# Evaluating batch 929: users 92801-92900 of 99872
# Batch metrics - RMSE: 0.9701, MAE: 0.7744, Predictions: 3458
# Processed 92900/99872 users (93.0%) - Elapsed: 1761.11s - Est. remaining: 120.07s
# Evaluating batch 930: users 92901-93000 of 99872
# Batch metrics - RMSE: 1.0677, MAE: 0.8525, Predictions: 2640
# Processed 93000/99872 users (93.1%) - Elapsed: 1762.91s - Est. remaining: 114.48s
# Evaluating batch 931: users 93001-93100 of 99872
# Batch metrics - RMSE: 0.9525, MAE: 0.7558, Predictions: 2863
# Processed 93100/99872 users (93.2%) - Elapsed: 1764.70s - Est. remaining: 112.60s
# Evaluating batch 932: users 93101-93200 of 99872
# Batch metrics - RMSE: 1.0245, MAE: 0.8019, Predictions: 3318
# Processed 93200/99872 users (93.3%) - Elapsed: 1766.50s - Est. remaining: 112.31s
# Evaluating batch 933: users 93201-93300 of 99872
# Batch metrics - RMSE: 0.9857, MAE: 0.7750, Predictions: 3263
# Processed 93300/99872 users (93.4%) - Elapsed: 1768.30s - Est. remaining: 109.97s
# Evaluating batch 934: users 93301-93400 of 99872
# Batch metrics - RMSE: 0.9373, MAE: 0.7273, Predictions: 2287
# Processed 93400/99872 users (93.5%) - Elapsed: 1770.08s - Est. remaining: 107.12s
# Evaluating batch 935: users 93401-93500 of 99872
# Batch metrics - RMSE: 0.9328, MAE: 0.7373, Predictions: 3132
# Processed 93500/99872 users (93.6%) - Elapsed: 1771.91s - Est. remaining: 109.05s
# Evaluating batch 936: users 93501-93600 of 99872
# Batch metrics - RMSE: 0.9793, MAE: 0.7566, Predictions: 3600
# Processed 93600/99872 users (93.7%) - Elapsed: 1773.73s - Est. remaining: 106.35s
# Evaluating batch 937: users 93601-93700 of 99872
# Batch metrics - RMSE: 0.9468, MAE: 0.7286, Predictions: 3085
# Processed 93700/99872 users (93.8%) - Elapsed: 1775.62s - Est. remaining: 109.14s
# Evaluating batch 938: users 93701-93800 of 99872
# Batch metrics - RMSE: 1.0068, MAE: 0.7837, Predictions: 2204
# Processed 93800/99872 users (93.9%) - Elapsed: 1777.42s - Est. remaining: 100.84s
# Evaluating batch 939: users 93801-93900 of 99872
# Batch metrics - RMSE: 0.9749, MAE: 0.7668, Predictions: 3334
# Processed 93900/99872 users (94.0%) - Elapsed: 1779.23s - Est. remaining: 100.72s
# Evaluating batch 940: users 93901-94000 of 99872
# Batch metrics - RMSE: 0.9870, MAE: 0.7708, Predictions: 3337
# Processed 94000/99872 users (94.1%) - Elapsed: 1781.08s - Est. remaining: 101.81s
# Evaluating batch 941: users 94001-94100 of 99872
# Batch metrics - RMSE: 1.0022, MAE: 0.7808, Predictions: 2131
# Processed 94100/99872 users (94.2%) - Elapsed: 1782.88s - Est. remaining: 96.49s
# Evaluating batch 942: users 94101-94200 of 99872
# Batch metrics - RMSE: 0.9416, MAE: 0.7354, Predictions: 2715
# Processed 94200/99872 users (94.3%) - Elapsed: 1784.71s - Est. remaining: 96.98s
# Evaluating batch 943: users 94201-94300 of 99872
# Batch metrics - RMSE: 0.9760, MAE: 0.7678, Predictions: 3250
# Processed 94300/99872 users (94.4%) - Elapsed: 1786.50s - Est. remaining: 93.05s
# Evaluating batch 944: users 94301-94400 of 99872
# Batch metrics - RMSE: 0.9847, MAE: 0.7836, Predictions: 2560
# Processed 94400/99872 users (94.5%) - Elapsed: 1788.32s - Est. remaining: 92.98s
# Evaluating batch 945: users 94401-94500 of 99872
# Batch metrics - RMSE: 1.0085, MAE: 0.7949, Predictions: 2622
# Processed 94500/99872 users (94.6%) - Elapsed: 1790.12s - Est. remaining: 90.01s
# Evaluating batch 946: users 94501-94600 of 99872
# Batch metrics - RMSE: 0.8890, MAE: 0.6828, Predictions: 2745
# Processed 94600/99872 users (94.7%) - Elapsed: 1791.92s - Est. remaining: 88.20s
# Evaluating batch 947: users 94601-94700 of 99872
# Batch metrics - RMSE: 0.9906, MAE: 0.7789, Predictions: 3020
# Processed 94700/99872 users (94.8%) - Elapsed: 1793.80s - Est. remaining: 90.94s
# Evaluating batch 948: users 94701-94800 of 99872
# Batch metrics - RMSE: 0.9386, MAE: 0.7273, Predictions: 3145
# Processed 94800/99872 users (94.9%) - Elapsed: 1795.92s - Est. remaining: 100.62s
# Evaluating batch 949: users 94801-94900 of 99872
# Batch metrics - RMSE: 1.0198, MAE: 0.8043, Predictions: 3267
# Processed 94900/99872 users (95.0%) - Elapsed: 1797.76s - Est. remaining: 85.06s
# Evaluating batch 950: users 94901-95000 of 99872
# Batch metrics - RMSE: 0.9935, MAE: 0.7925, Predictions: 2326
# Processed 95000/99872 users (95.1%) - Elapsed: 1799.54s - Est. remaining: 80.69s
# Evaluating batch 951: users 95001-95100 of 99872
# Batch metrics - RMSE: 0.9278, MAE: 0.7149, Predictions: 2331
# Processed 95100/99872 users (95.2%) - Elapsed: 1801.33s - Est. remaining: 79.31s
# Evaluating batch 952: users 95101-95200 of 99872
# Batch metrics - RMSE: 0.9195, MAE: 0.7039, Predictions: 3660
# Processed 95200/99872 users (95.3%) - Elapsed: 1803.17s - Est. remaining: 80.17s
# Evaluating batch 953: users 95201-95300 of 99872
# Batch metrics - RMSE: 0.9697, MAE: 0.7663, Predictions: 3138
# Processed 95300/99872 users (95.4%) - Elapsed: 1804.98s - Est. remaining: 77.13s
# Evaluating batch 954: users 95301-95400 of 99872
# Batch metrics - RMSE: 0.9634, MAE: 0.7500, Predictions: 2915
# Processed 95400/99872 users (95.5%) - Elapsed: 1806.80s - Est. remaining: 75.57s
# Evaluating batch 955: users 95401-95500 of 99872
# Batch metrics - RMSE: 0.9280, MAE: 0.7258, Predictions: 2913
# Processed 95500/99872 users (95.6%) - Elapsed: 1808.62s - Est. remaining: 73.69s
# Evaluating batch 956: users 95501-95600 of 99872
# Batch metrics - RMSE: 0.9734, MAE: 0.7624, Predictions: 2679
# Processed 95600/99872 users (95.7%) - Elapsed: 1810.44s - Est. remaining: 72.66s
# Evaluating batch 957: users 95601-95700 of 99872
# Batch metrics - RMSE: 0.9856, MAE: 0.7740, Predictions: 2576
# Processed 95700/99872 users (95.8%) - Elapsed: 1812.21s - Est. remaining: 68.91s
# Evaluating batch 958: users 95701-95800 of 99872
# Batch metrics - RMSE: 0.9299, MAE: 0.7102, Predictions: 2644
# Processed 95800/99872 users (95.9%) - Elapsed: 1814.02s - Est. remaining: 68.73s
# Evaluating batch 959: users 95801-95900 of 99872
# Batch metrics - RMSE: 0.9657, MAE: 0.7588, Predictions: 4219
# Processed 95900/99872 users (96.0%) - Elapsed: 1815.87s - Est. remaining: 68.64s
# Evaluating batch 960: users 95901-96000 of 99872
# Batch metrics - RMSE: 0.9684, MAE: 0.7442, Predictions: 2684
# Processed 96000/99872 users (96.1%) - Elapsed: 1817.66s - Est. remaining: 64.62s
# Evaluating batch 961: users 96001-96100 of 99872
# Batch metrics - RMSE: 0.9504, MAE: 0.7367, Predictions: 2803
# Processed 96100/99872 users (96.2%) - Elapsed: 1819.45s - Est. remaining: 62.69s
# Evaluating batch 962: users 96101-96200 of 99872
# Batch metrics - RMSE: 0.9991, MAE: 0.7822, Predictions: 2841
# Processed 96200/99872 users (96.3%) - Elapsed: 1821.26s - Est. remaining: 61.98s
# Evaluating batch 963: users 96201-96300 of 99872
# Batch metrics - RMSE: 0.9424, MAE: 0.7312, Predictions: 2794
# Processed 96300/99872 users (96.4%) - Elapsed: 1823.09s - Est. remaining: 60.93s
# Evaluating batch 964: users 96301-96400 of 99872
# Batch metrics - RMSE: 0.9766, MAE: 0.7691, Predictions: 2469
# Processed 96400/99872 users (96.5%) - Elapsed: 1824.87s - Est. remaining: 57.36s
# Evaluating batch 965: users 96401-96500 of 99872
# Batch metrics - RMSE: 0.9006, MAE: 0.7006, Predictions: 4002
# Processed 96500/99872 users (96.6%) - Elapsed: 1826.70s - Est. remaining: 57.84s
# Evaluating batch 966: users 96501-96600 of 99872
# Batch metrics - RMSE: 0.9584, MAE: 0.7463, Predictions: 3016
# Processed 96600/99872 users (96.7%) - Elapsed: 1828.50s - Est. remaining: 54.83s
# Evaluating batch 967: users 96601-96700 of 99872
# Batch metrics - RMSE: 0.9894, MAE: 0.7755, Predictions: 2994
# Processed 96700/99872 users (96.8%) - Elapsed: 1830.30s - Est. remaining: 53.24s
# Evaluating batch 968: users 96701-96800 of 99872
# Batch metrics - RMSE: 0.9002, MAE: 0.6953, Predictions: 2868
# Processed 96800/99872 users (96.9%) - Elapsed: 1832.18s - Est. remaining: 54.11s
# Evaluating batch 969: users 96801-96900 of 99872
# Batch metrics - RMSE: 0.9698, MAE: 0.7519, Predictions: 2831
# Processed 96900/99872 users (97.0%) - Elapsed: 1834.31s - Est. remaining: 59.45s
# Evaluating batch 970: users 96901-97000 of 99872
# Batch metrics - RMSE: 0.9399, MAE: 0.7141, Predictions: 2165
# Processed 97000/99872 users (97.1%) - Elapsed: 1836.09s - Est. remaining: 47.46s
# Evaluating batch 971: users 97001-97100 of 99872
# Batch metrics - RMSE: 1.0092, MAE: 0.7956, Predictions: 3745
# Processed 97100/99872 users (97.2%) - Elapsed: 1837.97s - Est. remaining: 48.77s
# Evaluating batch 972: users 97101-97200 of 99872
# Batch metrics - RMSE: 0.9619, MAE: 0.7527, Predictions: 3218
# Processed 97200/99872 users (97.3%) - Elapsed: 1839.80s - Est. remaining: 45.45s
# Evaluating batch 973: users 97201-97300 of 99872
# Batch metrics - RMSE: 1.0009, MAE: 0.7848, Predictions: 2417
# Processed 97300/99872 users (97.4%) - Elapsed: 1841.64s - Est. remaining: 44.16s
# Evaluating batch 974: users 97301-97400 of 99872
# Batch metrics - RMSE: 0.8997, MAE: 0.6985, Predictions: 2928
# Processed 97400/99872 users (97.5%) - Elapsed: 1843.49s - Est. remaining: 42.78s
# Evaluating batch 975: users 97401-97500 of 99872
# Batch metrics - RMSE: 1.0036, MAE: 0.7860, Predictions: 3158
# Processed 97500/99872 users (97.6%) - Elapsed: 1845.37s - Est. remaining: 41.50s
# Evaluating batch 976: users 97501-97600 of 99872
# Batch metrics - RMSE: 0.9073, MAE: 0.6965, Predictions: 2798
# Processed 97600/99872 users (97.7%) - Elapsed: 1847.17s - Est. remaining: 38.18s
# Evaluating batch 977: users 97601-97700 of 99872
# Batch metrics - RMSE: 0.9594, MAE: 0.7482, Predictions: 3344
# Processed 97700/99872 users (97.8%) - Elapsed: 1848.98s - Est. remaining: 36.60s
# Evaluating batch 978: users 97701-97800 of 99872
# Batch metrics - RMSE: 0.8873, MAE: 0.6868, Predictions: 3524
# Processed 97800/99872 users (97.9%) - Elapsed: 1850.78s - Est. remaining: 34.75s
# Evaluating batch 979: users 97801-97900 of 99872
# Batch metrics - RMSE: 0.9454, MAE: 0.7461, Predictions: 2685
# Processed 97900/99872 users (98.0%) - Elapsed: 1852.73s - Est. remaining: 35.93s
# Evaluating batch 980: users 97901-98000 of 99872
# Batch metrics - RMSE: 0.9875, MAE: 0.7777, Predictions: 2642
# Processed 98000/99872 users (98.1%) - Elapsed: 1854.65s - Est. remaining: 33.30s
# Evaluating batch 981: users 98001-98100 of 99872
# Batch metrics - RMSE: 1.0632, MAE: 0.8478, Predictions: 3085
# Processed 98100/99872 users (98.2%) - Elapsed: 1856.76s - Est. remaining: 35.09s
# Evaluating batch 982: users 98101-98200 of 99872
# Batch metrics - RMSE: 1.0153, MAE: 0.8017, Predictions: 2388
# Processed 98200/99872 users (98.3%) - Elapsed: 1858.70s - Est. remaining: 30.07s
# Evaluating batch 983: users 98201-98300 of 99872
# Batch metrics - RMSE: 0.9842, MAE: 0.7775, Predictions: 2800
# Processed 98300/99872 users (98.4%) - Elapsed: 1860.55s - Est. remaining: 27.00s
# Evaluating batch 984: users 98301-98400 of 99872
# Batch metrics - RMSE: 0.9348, MAE: 0.7339, Predictions: 3241
# Processed 98400/99872 users (98.5%) - Elapsed: 1862.37s - Est. remaining: 25.07s
# Evaluating batch 985: users 98401-98500 of 99872
# Batch metrics - RMSE: 0.9857, MAE: 0.7799, Predictions: 2672
# Processed 98500/99872 users (98.6%) - Elapsed: 1864.17s - Est. remaining: 23.04s
# Evaluating batch 986: users 98501-98600 of 99872
# Batch metrics - RMSE: 0.9718, MAE: 0.7474, Predictions: 2489
# Processed 98600/99872 users (98.7%) - Elapsed: 1866.01s - Est. remaining: 21.75s
# Evaluating batch 987: users 98601-98700 of 99872
# Batch metrics - RMSE: 1.0094, MAE: 0.7919, Predictions: 2777
# Processed 98700/99872 users (98.8%) - Elapsed: 1867.85s - Est. remaining: 20.04s
# Evaluating batch 988: users 98701-98800 of 99872
# Batch metrics - RMSE: 0.9576, MAE: 0.7552, Predictions: 3181
# Processed 98800/99872 users (98.9%) - Elapsed: 1869.67s - Est. remaining: 18.21s
# Evaluating batch 989: users 98801-98900 of 99872
# Batch metrics - RMSE: 0.9544, MAE: 0.7547, Predictions: 2561
# Processed 98900/99872 users (99.0%) - Elapsed: 1871.46s - Est. remaining: 16.24s
# Evaluating batch 990: users 98901-99000 of 99872
# Batch metrics - RMSE: 0.9700, MAE: 0.7572, Predictions: 2283
# Processed 99000/99872 users (99.1%) - Elapsed: 1873.23s - Est. remaining: 14.37s
# Evaluating batch 991: users 99001-99100 of 99872
# Batch metrics - RMSE: 0.9526, MAE: 0.7401, Predictions: 3284
# Processed 99100/99872 users (99.2%) - Elapsed: 1875.08s - Est. remaining: 13.33s
# Evaluating batch 992: users 99101-99200 of 99872
# Batch metrics - RMSE: 0.9929, MAE: 0.7818, Predictions: 2238
# Processed 99200/99872 users (99.3%) - Elapsed: 1876.90s - Est. remaining: 11.35s
# Evaluating batch 993: users 99201-99300 of 99872
# Batch metrics - RMSE: 0.9157, MAE: 0.7174, Predictions: 3036
# Processed 99300/99872 users (99.4%) - Elapsed: 1878.70s - Est. remaining: 9.57s
# Evaluating batch 994: users 99301-99400 of 99872
# Batch metrics - RMSE: 0.9368, MAE: 0.7338, Predictions: 4249
# Processed 99400/99872 users (99.5%) - Elapsed: 1880.55s - Est. remaining: 8.13s
# Evaluating batch 995: users 99401-99500 of 99872
# Batch metrics - RMSE: 0.9730, MAE: 0.7541, Predictions: 2532
# Processed 99500/99872 users (99.6%) - Elapsed: 1882.35s - Est. remaining: 6.22s
# Evaluating batch 996: users 99501-99600 of 99872
# Batch metrics - RMSE: 1.0235, MAE: 0.8047, Predictions: 1996
# Processed 99600/99872 users (99.7%) - Elapsed: 1884.13s - Est. remaining: 4.48s
# Evaluating batch 997: users 99601-99700 of 99872
# Batch metrics - RMSE: 0.9085, MAE: 0.6905, Predictions: 3416
# Processed 99700/99872 users (99.8%) - Elapsed: 1885.95s - Est. remaining: 2.93s
# Evaluating batch 998: users 99701-99800 of 99872
# Batch metrics - RMSE: 1.0163, MAE: 0.7955, Predictions: 2391
# Processed 99800/99872 users (99.9%) - Elapsed: 1887.75s - Est. remaining: 1.21s
# Evaluating batch 999: users 99801-99872 of 99872
# Batch metrics - RMSE: 0.9546, MAE: 0.7527, Predictions: 2084
# Processed 99872/99872 users (100.0%) - Elapsed: 1889.07s - Est. remaining: 0.00s
#
# Evaluation results:
# Users evaluated: 99872
# Total predictions: 2894341
# RMSE: 0.9647
# MAE: 0.7525
#
# Stored evaluation metrics:
#   rmse: 0.9646807940936123
#   mae: 0.7524811763493512
#   num_users_evaluated: 99872
#   num_predictions: 2894341
# Saved evaluation metrics to CSV files
#
# ================================================================================
# SUMMARY OF CONTENT-BASED RECOMMENDATION SYSTEM
# ================================================================================
#
# Data Information:
# - Processed 24378 movie feature records
# - Vocabulary size: 95445 unique words
# - Generated feature vectors for 24367 movies
# - Generated feature vectors for 99992 users
# - Average similar movies per user: 274.14
# - Average recommendations per user: 17.33
#
# Performance Metrics:
# - RMSE: 0.9647
# - MAE: 0.7525
# - Users evaluated: 99872
# - Total predictions: 2894341
#
# Advantages of this approach:
# - Log-Likelihood identifies more meaningful words compared to TF-IDF
# - Word2Vec captures semantic relationships between words
# - Handles new movies effectively (cold start for items)
# - Generates personalized recommendations based on content preferences
# - Doesn't require item-item similarity calculations
# - Memory-optimized batch processing prevents RAM overflow during long runs
#
# Saved Files:
# - content_based_evaluation.csv (0.00 MB)
# - content_based_recommendations.csv (16.56 MB)
# - content_based_recommendations.pkl (4.24 MB)
# - corpus_word_counts.pkl (1.61 MB)
# - movie_id_to_idx.pkl (0.16 MB)
# - movie_ll_values.pkl (15.27 MB)
# - movie_vectors.pkl (19.45 MB)
# - user_id_to_idx.pkl (2.16 MB)
# - user_movie_similarities.pkl (339.32 MB)
# - user_vectors.pkl (81.26 MB)
# - word2vec_model (67.02 MB)
#
# Final memory usage: 2277.77 MB
#
# Content-Based Filtering Model Successfully Implemented!

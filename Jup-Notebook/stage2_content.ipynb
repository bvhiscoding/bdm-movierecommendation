# %%
import numpy as np
import pandas as pd
import os
import pickle
import logging
import heapq
from datetime import datetime
from collections import Counter, defaultdict
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
import seaborn as sns
import time
import math
from gensim.models import Word2Vec
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import ast  # To safely evaluate string representations of lists
import sys
import gc  # Add garbage collector for memory management

# Set up logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
logger = logging.getLogger(__name__)

print("\n" + "="*80)
print("CONTENT-BASED MOVIE RECOMMENDATION SYSTEM WITH LOG-LIKELIHOOD AND WORD2VEC")
print("="*80)

# Set paths
input_path = "./"  # Current directory where stage1.py saved the files
output_path = "./rec/content-recommendations"
top_n =20
similarity_threshold = 0.7  # Minimum similarity to consider
word2vec_dim = 200  # Dimensionality of Word2Vec embeddings
# Create output directory if it doesn't exist
if not os.path.exists(output_path):
    os.makedirs(output_path)
# Out:
# ================================================================================
# CONTENT-BASED MOVIE RECOMMENDATION SYSTEM WITH LOG-LIKELIHOOD AND WORD2VEC
# ================================================================================

# %%
print("\n" + "="*80)
print("STEP 1: DATA LOADING")
print("="*80)

def load_data():
    """Load processed data from stage1.py"""
    print("Loading processed data from stage1.py...")
    
    # Data containers
    data = {}
    
    # Load movie features
    movie_features_path = os.path.join(input_path, './processed/processed_movie_features.csv')
    if os.path.exists(movie_features_path):
        # First, load without the tokens column to save memory
        data['movie_features'] = pd.read_csv(movie_features_path)
        # Convert string representation of tokens and top_keywords back to lists
        data['movie_features']['tokens'] = data['movie_features']['tokens'].apply(
            lambda x: ast.literal_eval(x) if isinstance(x, str) else []
        )
        data['movie_features']['top_keywords'] = data['movie_features']['top_keywords'].apply(
            lambda x: ast.literal_eval(x) if isinstance(x, str) else []
        )
        print(f"Loaded features for {len(data['movie_features'])} movies")
        print("\nSample of movie features data:")
        print(data['movie_features'][['movieId', 'title', 'top_keywords']].head(3))
        
        # Print token statistics
        token_lengths = [len(tokens) for tokens in data['movie_features']['tokens']]
        print(f"\nAverage token count per movie: {np.mean(token_lengths):.2f}")
        print(f"Min token count: {min(token_lengths)}, Max token count: {max(token_lengths)}")
    else:
        print(f"Error: Movie features not found at {movie_features_path}")
        sys.exit(1)
    
    # Load normalized ratings
    ratings_path = os.path.join(input_path, './processed/normalized_ratings.csv')
    if os.path.exists(ratings_path):
        # Read in chunks to save memory
        chunk_size = 100000  # Adjust based on dataset size
        chunks = []
        for chunk in pd.read_csv(ratings_path, chunksize=chunk_size):
            chunks.append(chunk)
        data['ratings'] = pd.concat(chunks)
        print(f"\nLoaded {len(data['ratings'])} normalized ratings")
        print("\nSample of normalized ratings data:")
        print(data['ratings'].head(3))
        
        # Print rating statistics
        print(f"\nNumber of unique users: {data['ratings']['userId'].nunique()}")
        print(f"Number of unique movies: {data['ratings']['movieId'].nunique()}")
        print(f"Rating sparsity: {(1 - len(data['ratings']) / (data['ratings']['userId'].nunique() * data['ratings']['movieId'].nunique())) * 100:.4f}%")
    else:
        print(f"Error: Normalized ratings not found at {ratings_path}")
        sys.exit(1)
    
    # Create training and testing sets with 80-20 split
    # Create training and testing sets with 80-20 split
    if 'ratings' in data:
        print("Splitting ratings into training and testing sets...")
        
        # Import train_test_split if not already imported
        from sklearn.model_selection import train_test_split
        
        # Split ratings into training and testing sets
        train_ratings, test_ratings = train_test_split(
            data['ratings'], 
            test_size=0.2
        )
        
        # Store the split data
        data['train_ratings'] = train_ratings
        data['test_ratings'] = test_ratings
        
        print(f"\nSplit ratings into {len(data['train_ratings'])} training and {len(data['test_ratings'])} testing samples")
        print(f"Training set covers {data['train_ratings']['userId'].nunique()} users and {data['train_ratings']['movieId'].nunique()} movies")
        print(f"Testing set covers {data['test_ratings']['userId'].nunique()} users and {data['test_ratings']['movieId'].nunique()} movies")
    
    return data

# Load the data
data = load_data()
# Out:
# ================================================================================
# STEP 1: DATA LOADING
# ================================================================================
# Loading processed data from stage1.py...
# Loaded features for 24378 movies
#
# Sample of movie features data:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                     top_keywords
# 0   [animation, pixar, tom hanks, computer, toy]
# 1  [robin williams, game, time, travel, fantasy]
# 2        [sequel, old, comedinha, de, velhinhos]
#
# Average token count per movie: 64.14
# Min token count: 1, Max token count: 4117
#
# Loaded 14472091 normalized ratings
#
# Sample of normalized ratings data:
#    userId  movieId  rating  normalized_rating
# 0       1        2     3.5           2.058415
# 1       1       29     3.5           2.058415
# 2       1       32     3.5           2.058415
#
# Number of unique users: 100000
# Number of unique movies: 24829
# Rating sparsity: 99.4171%
# Splitting ratings into training and testing sets...
#
# Split ratings into 11577672 training and 2894419 testing samples
# Training set covers 100000 users and 23952 movies
# Testing set covers 99887 users and 18611 movies

# %%
print("\n" + "="*80)
print("STEP 2: CORPUS ANALYSIS")
print("="*80)

# Build corpus word counts from movie features
if 'movie_features' in data:
    print("Building vocabulary and word frequency counts...")
    
    corpus_word_counts = Counter()
    
    # Process in batches to avoid memory spikes
    batch_size = 1000
    total_movies = len(data['movie_features'])
    
    for i in range(0, total_movies, batch_size):
        batch_end = min(i + batch_size, total_movies)
        batch = data['movie_features'].iloc[i:batch_end]
        
        for tokens in batch['tokens']:
            corpus_word_counts.update(tokens)
        
        # Log progress
        print(f"Processed {batch_end}/{total_movies} movies ({batch_end/total_movies*100:.1f}%)")
    
    data['corpus_word_counts'] = corpus_word_counts
    
    # Save corpus word counts
    with open(os.path.join(output_path, 'corpus_word_counts.pkl'), 'wb') as f:
        pickle.dump(corpus_word_counts, f)
    
    print(f"Built vocabulary with {len(corpus_word_counts)} unique words")
    print(f"Total words in corpus: {sum(corpus_word_counts.values())}")
    
    # Display top 20 most common words
    print("\nTop 20 most common words in the corpus:")
    for word, count in corpus_word_counts.most_common(20):
        print(f"'{word}': {count}")

    # Clear memory
    gc.collect()
# Out:
# ================================================================================
# STEP 2: CORPUS ANALYSIS
# ================================================================================
# Building vocabulary and word frequency counts...
# Processed 1000/24378 movies (4.1%)
# Processed 2000/24378 movies (8.2%)
# Processed 3000/24378 movies (12.3%)
# Processed 4000/24378 movies (16.4%)
# Processed 5000/24378 movies (20.5%)
# Processed 6000/24378 movies (24.6%)
# Processed 7000/24378 movies (28.7%)
# Processed 8000/24378 movies (32.8%)
# Processed 9000/24378 movies (36.9%)
# Processed 10000/24378 movies (41.0%)
# Processed 11000/24378 movies (45.1%)
# Processed 12000/24378 movies (49.2%)
# Processed 13000/24378 movies (53.3%)
# Processed 14000/24378 movies (57.4%)
# Processed 15000/24378 movies (61.5%)
# Processed 16000/24378 movies (65.6%)
# Processed 17000/24378 movies (69.7%)
# Processed 18000/24378 movies (73.8%)
# Processed 19000/24378 movies (77.9%)
# Processed 20000/24378 movies (82.0%)
# Processed 21000/24378 movies (86.1%)
# Processed 22000/24378 movies (90.2%)
# Processed 23000/24378 movies (94.3%)
# Processed 24000/24378 movies (98.4%)
# Processed 24378/24378 movies (100.0%)
# Built vocabulary with 95445 unique words
# Total words in corpus: 1563519
#
# Top 20 most common words in the corpus:
# 'comedy': 11199
# 'book': 9569
# 'based': 9429
# 'nudity': 9006
# 'ending': 7492
# 'story': 7485
# 'life': 6671
# 'topless': 6542
# 'dark': 6004
# 'fi': 5469
# 'sci': 5428
# 'action': 5425
# 'time': 5030
# 'atmospheric': 4655
# 'great': 4584
# 'twist': 4576
# 'family': 4473
# 'love': 4466
# 'true': 4327
# 'funny': 4275

# %%
print("\n" + "="*80)
print("STEP 3: LOG-LIKELIHOOD CALCULATION")
print("="*80)

def calculate_log_likelihood(movie_features, corpus_word_counts, batch_size=100):
    """Calculate Log-Likelihood values for words in each movie in batches"""
    print("Calculating Log-Likelihood values for all movies in batches...")
    start_time = time.time()
    
    # Calculate total corpus size
    total_corpus_size = sum(corpus_word_counts.values())
    print(f"Total corpus size: {total_corpus_size} words")
    
    # Initialize container for movie features
    movie_ll_values = {}
    
    # Process each movie document in batches
    total_movies = len(movie_features)
    
    for batch_start in range(0, total_movies, batch_size):
        batch_end = min(batch_start + batch_size, total_movies)
        print(f"Processing batch {batch_start//batch_size + 1}: movies {batch_start+1}-{batch_end} of {total_movies}")
        
        # Get batch of movies
        batch = movie_features.iloc[batch_start:batch_end]
        
        for _, row in batch.iterrows():
            movie_id = row['movieId']
            tokens = row['tokens']
            
            if not tokens:
                continue
            
            # Count word occurrences in this movie
            movie_word_counts = Counter(tokens)
            movie_size = sum(movie_word_counts.values())
            
            # Calculate Log-Likelihood for each word
            movie_ll_values[movie_id] = {}
            
            for word, count in movie_word_counts.items():
                # Observed frequencies
                a = count  # Occurrences in this movie
                b = corpus_word_counts[word] - count  # Occurrences in other movies
                c = movie_size  # Total words in this movie
                d = total_corpus_size - movie_size  # Total words in other movies
                
                # Expected counts based on corpus distribution
                e1 = c * (a + b) / (c + d)
                e2 = d * (a + b) / (c + d)
                
                # Log-Likelihood calculation
                ll = 0
                if a > 0 and e1 > 0:
                    ll += a * math.log(a / e1)
                if b > 0 and e2 > 0:
                    ll += b * math.log(b / e2)
                
                ll = 2 * ll
                movie_ll_values[movie_id][word] = ll
        
        # Log progress and elapsed time
        elapsed = time.time() - start_time
        progress = batch_end / total_movies * 100
        remaining = elapsed / (batch_end - batch_start) * (total_movies - batch_end) if batch_end < total_movies else 0
        print(f"Progress: {progress:.1f}% - Elapsed: {elapsed:.2f}s - Est. remaining: {remaining:.2f}s")
        
        # Force garbage collection after each batch
        gc.collect()
    
    # Show sample LL values for a movie
    if movie_ll_values:
        sample_movie_id = next(iter(movie_ll_values.keys()))
        sample_movie_title = movie_features[movie_features['movieId'] == sample_movie_id]['title'].values[0]
        print(f"\nSample Log-Likelihood values for movie '{sample_movie_title}' (ID: {sample_movie_id}):")
        
        # Get top 10 words by LL value
        top_ll_words = sorted(movie_ll_values[sample_movie_id].items(), key=lambda x: x[1], reverse=True)[:10]
        for word, ll_value in top_ll_words:
            print(f"Word: '{word}', LL Value: {ll_value:.2f}")
    
    return movie_ll_values

# Calculate Log-Likelihood if movie features are available
if 'movie_features' in data and 'corpus_word_counts' in data:
    movie_ll_values = calculate_log_likelihood(data['movie_features'], data['corpus_word_counts'], batch_size=100)
    data['movie_ll_values'] = movie_ll_values
    
    # Save Log-Likelihood values
    with open(os.path.join(output_path, 'movie_ll_values.pkl'), 'wb') as f:
        pickle.dump(movie_ll_values, f)
    
    print(f"Calculated Log-Likelihood values for {len(movie_ll_values)} movies")
    
    # Calculate average number of words with high LL values
    high_ll_counts = []
    for movie_id, ll_dict in movie_ll_values.items():
        high_ll_words = [word for word, value in ll_dict.items() if value > 10]  # Threshold of 10
        high_ll_counts.append(len(high_ll_words))
    
    print(f"Average number of words with LL > 10 per movie: {np.mean(high_ll_counts):.2f}")
    print(f"Min: {min(high_ll_counts)}, Max: {max(high_ll_counts)}")
    
    # Free memory
    gc.collect()
# Out:
# ================================================================================
# STEP 3: LOG-LIKELIHOOD CALCULATION
# ================================================================================
# Calculating Log-Likelihood values for all movies in batches...
# Total corpus size: 1563519 words
# Processing batch 1: movies 1-100 of 24378
# Progress: 0.4% - Elapsed: 0.01s - Est. remaining: 2.43s
# Processing batch 2: movies 101-200 of 24378
# Progress: 0.8% - Elapsed: 0.16s - Est. remaining: 38.33s
# Processing batch 3: movies 201-300 of 24378
# Progress: 1.2% - Elapsed: 0.31s - Est. remaining: 75.15s
# Processing batch 4: movies 301-400 of 24378
# Progress: 1.6% - Elapsed: 0.44s - Est. remaining: 105.62s
# Processing batch 5: movies 401-500 of 24378
# Progress: 2.1% - Elapsed: 0.57s - Est. remaining: 137.12s
# Processing batch 6: movies 501-600 of 24378
# Progress: 2.5% - Elapsed: 0.69s - Est. remaining: 164.12s
# Processing batch 7: movies 601-700 of 24378
# Progress: 2.9% - Elapsed: 0.85s - Est. remaining: 201.42s
# Processing batch 8: movies 701-800 of 24378
# Progress: 3.3% - Elapsed: 0.97s - Est. remaining: 229.55s
# Processing batch 9: movies 801-900 of 24378
# Progress: 3.7% - Elapsed: 1.12s - Est. remaining: 262.91s
# Processing batch 10: movies 901-1000 of 24378
# Progress: 4.1% - Elapsed: 1.25s - Est. remaining: 292.30s
# Processing batch 11: movies 1001-1100 of 24378
# Progress: 4.5% - Elapsed: 1.39s - Est. remaining: 322.57s
# Processing batch 243: movies 24201-24300 of 24378
# Progress: 99.7% - Elapsed: 31.74s - Est. remaining: 24.76s
# Processing batch 244: movies 24301-24378 of 24378
# Progress: 100.0% - Elapsed: 31.87s - Est. remaining: 0.00s
#
# Sample Log-Likelihood values for movie 'Toy Story (1995)' (ID: 1):
# Word: 'pixar', LL Value: 731.81
# Word: 'animation', LL Value: 623.16
# Word: 'toy', LL Value: 223.11
# Word: 'tom hanks', LL Value: 202.57
# Word: 'computer', LL Value: 168.33
# Word: 'disney', LL Value: 125.83
# Word: 'animated', LL Value: 104.44
# Word: 'child', LL Value: 93.84
# Word: 'disney pixar', LL Value: 86.13
# Word: 'witty', LL Value: 73.97
# Calculated Log-Likelihood values for 24378 movies
# Average number of words with LL > 10 per movie: 16.80
# Min: 1, Max: 147

# %%
print("\n" + "="*80)
print("STEP 4: WORD2VEC MODEL TRAINING")
print("="*80)

def train_word2vec(movie_features, vector_size=100, batch_size=1000):
    """Train Word2Vec model on movie tokens with memory optimization"""
    print(f"Training Word2Vec model with {vector_size} dimensions...")
    start_time = time.time()
    
    # Extract token lists from movie features in batches
    tokenized_corpus = []
    total_movies = len(movie_features)
    
    for i in range(0, total_movies, batch_size):
        batch_end = min(i + batch_size, total_movies)
        batch = movie_features.iloc[i:batch_end]
        
        batch_tokens = list(batch['tokens'])
        tokenized_corpus.extend(batch_tokens)
        
        # Log progress
        print(f"Loaded tokens from {batch_end}/{total_movies} movies ({batch_end/total_movies*100:.1f}%)")
    
    # Print corpus statistics
    total_tokens = sum(len(tokens) for tokens in tokenized_corpus)
    print(f"Training corpus size: {total_tokens} tokens from {len(tokenized_corpus)} documents")
    
    # Train Word2Vec model using CBOW approach with memory optimization
    print("Starting Word2Vec training (this may take a few minutes)...")
    word2vec_model = Word2Vec(
        sentences=tokenized_corpus,
        vector_size=vector_size,
        window=10,
        min_count=3,
        workers=8,
        epochs=25,  # Reduced from 50 to save memory
        sg=1,  # CBOW model
        hs=1,
        negative=20
    )
    
    # Free memory - no longer need the full corpus
    del tokenized_corpus
    gc.collect()
    
    elapsed = time.time() - start_time
    print(f"Word2Vec training completed in {elapsed:.2f} seconds")
    
    # Print model statistics
    vocab_size = len(word2vec_model.wv)
    print(f"Word2Vec model vocabulary size: {vocab_size} words")
    
    # Show some example vectors for common words
    print("\nExample word vectors from the trained model:")
    common_words = [word for word, _ in data['corpus_word_counts'].most_common(10)]
    for word in common_words:
        if word in word2vec_model.wv:
            # Show just the first 5 dimensions of the vector
            print(f"'{word}': {word2vec_model.wv[word][:5]}...")
    
    # Show some word similarities
    if len(word2vec_model.wv) > 0:
        print("\nExample word similarities:")
        try:
            # Try some movie-related terms
            for word in ['action', 'love', 'hero', 'villain']:
                if word in word2vec_model.wv:
                    similar_words = word2vec_model.wv.most_similar(word, topn=5)
                    print(f"Words similar to '{word}': {similar_words}")
        except Exception as e:
            print(f"Could not compute word similarities: {str(e)}")
    
    return word2vec_model

# Train Word2Vec if movie features are available
if 'movie_features' in data:
    word2vec_model = train_word2vec(data['movie_features'], word2vec_dim)
    data['word2vec_model'] = word2vec_model
    
    # Save Word2Vec model
    word2vec_path = os.path.join(output_path, 'word2vec_model')
    word2vec_model.save(word2vec_path)
    
    print(f"Trained and saved Word2Vec model with {len(word2vec_model.wv)} words")
    
    # Free memory
    gc.collect()
# Out:
# 2025-05-05 19:47:45,711 : INFO : collecting all words and their counts
# 2025-05-05 19:47:45,713 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2025-05-05 19:47:45,812 : INFO : PROGRESS: at sentence #10000, processed 788641 words, keeping 53383 word types
# 2025-05-05 19:47:45,897 : INFO : PROGRESS: at sentence #20000, processed 1396870 words, keeping 84652 word types
# ================================================================================
# STEP 4: WORD2VEC MODEL TRAINING
# ================================================================================
# Training Word2Vec model with 200 dimensions...
# Loaded tokens from 1000/24378 movies (4.1%)
# Loaded tokens from 2000/24378 movies (8.2%)
# Loaded tokens from 3000/24378 movies (12.3%)
# Loaded tokens from 4000/24378 movies (16.4%)
# Loaded tokens from 5000/24378 movies (20.5%)
# Loaded tokens from 6000/24378 movies (24.6%)
# Loaded tokens from 7000/24378 movies (28.7%)
# Loaded tokens from 8000/24378 movies (32.8%)
# Loaded tokens from 9000/24378 movies (36.9%)
# Loaded tokens from 10000/24378 movies (41.0%)
# Loaded tokens from 11000/24378 movies (45.1%)
# Loaded tokens from 12000/24378 movies (49.2%)
# Loaded tokens from 13000/24378 movies (53.3%)
# Loaded tokens from 14000/24378 movies (57.4%)
# Loaded tokens from 15000/24378 movies (61.5%)
# Loaded tokens from 16000/24378 movies (65.6%)
# Loaded tokens from 17000/24378 movies (69.7%)
# Loaded tokens from 18000/24378 movies (73.8%)
# Loaded tokens from 19000/24378 movies (77.9%)
# Loaded tokens from 20000/24378 movies (82.0%)
# Loaded tokens from 21000/24378 movies (86.1%)
# Loaded tokens from 22000/24378 movies (90.2%)
# Loaded tokens from 23000/24378 movies (94.3%)
# Loaded tokens from 24000/24378 movies (98.4%)
# Loaded tokens from 24378/24378 movies (100.0%)
# Training corpus size: 1563519 tokens from 24378 documents
# Starting Word2Vec training (this may take a few minutes)...
# 2025-05-05 19:47:45,927 : INFO : collected 95445 word types from a corpus of 1563519 raw words and 24378 sentences
# 2025-05-05 19:47:45,927 : INFO : Creating a fresh vocabulary
# 2025-05-05 19:47:46,008 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=3 retains 27637 unique words (28.96% of original 95445, drops 67808)', 'datetime': '2025-05-05T19:47:46.007022', 'gensim': '4.3.3', 'python': '3.10.1 (tags/v3.10.1:2cd268a, Dec  6 2021, 19:10:37) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'prepare_vocab'}
# 2025-05-05 19:47:46,008 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=3 leaves 1473966 word corpus (94.27% of original 1563519, drops 89553)', 'datetime': '2025-05-05T19:47:46.008022', 'gensim': '4.3.3', 'python': '3.10.1 (tags/v3.10.1:2cd268a, Dec  6 2021, 19:10:37) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'prepare_vocab'}
# 2025-05-05 19:47:46,095 : INFO : deleting the raw counts dictionary of 95445 items
# 2025-05-05 19:47:46,098 : INFO : sample=0.001 downsamples 23 most-common words
# 2025-05-05 19:47:46,099 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 
words/s, in_qsize 15, out_qsize 0
# 2025-05-05 19:53:07,751 : INFO : EPOCH 24 - PROGRESS: at 7.61% examples, 94666 words/s, in_qsize 15, out_qsize 0
# 2025-05-05 19:53:08,761 : INFO : EPOCH 24 - PROGRESS: at 11.44% examples, 90828 words/s, in_qsize 15, out_qsize 0
# 2025-05-05 19:53:09,782 : INFO : EPOCH 24 - PROGRESS: at 19.09% examples, 99015 words/s, in_qsize 15, out_qsize 0
# 2025-05-05 19:53:11,137 : INFO : EPOCH 24 - PROGRESS: at 28.60% examples, 101088 words/s, in_qsize 15, out_qsize 0
# 2025-05-05 19:53:12,322 : INFO : EPOCH 24 - PROGRESS: at 40.21% examples, 104743 words/s, in_qsize 15, out_qsize 0
# 2025-05-05 19:53:13,375 : INFO : EPOCH 24 - PROGRESS: at 47.72% examples, 106624 words/s, in_qsize 15, out_qsize 0
# 2025-05-05 19:53:14,621 : INFO : EPOCH 24 - PROGRESS: at 55.80% examples, 107013 words/s, in_qsize 15, out_qsize 0
# 2025-05-05 19:53:15,880 : INFO : EPOCH 24 - PROGRESS: at 67.15% examples, 108035 words/s, in_qsize 15, out_qsize 0
# 2025-05-05 19:53:16,925 : INFO : EPOCH 24 - PROGRESS: at 79.49% examples, 110093 words/s, in_qsize 15, out_qsize 0
# 2025-05-05 19:53:17,995 : INFO : EPOCH 24 - PROGRESS: at 94.06% examples, 111507 words/s, in_qsize 5, out_qsize 1
# 2025-05-05 19:53:18,316 : INFO : EPOCH 24: training on 1563519 raw words (1437516 effective words) took 12.9s, 111867 effective words/s
# 2025-05-05 19:53:18,317 : INFO : Word2Vec lifecycle event {'msg': 'training on 39087975 raw words (35935097 effective words) took 331.6s, 108379 effective words/s', 'datetime': '2025-05-05T19:53:18.316542', 'gensim': '4.3.3', 'python': '3.10.1 (tags/v3.10.1:2cd268a, Dec  6 2021, 19:10:37) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'train'}
# 2025-05-05 19:53:18,317 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec<vocab=27637, vector_size=200, alpha=0.025>', 'datetime': '2025-05-05T19:53:18.317541', 'gensim': '4.3.3', 'python': '3.10.1 (tags/v3.10.1:2cd268a, Dec  6 2021, 19:10:37) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'created'}
# 2025-05-05 19:53:18,482 : INFO : Word2Vec lifecycle event {'fname_or_handle': './rec/content-recommendations\\word2vec_model', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2025-05-05T19:53:18.482728', 'gensim': '4.3.3', 'python': '3.10.1 (tags/v3.10.1:2cd268a, Dec  6 2021, 19:10:37) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'saving'}
# 2025-05-05 19:53:18,483 : INFO : not storing attribute cum_table
# Word2Vec training completed in 332.75 seconds
# Word2Vec model vocabulary size: 27637 words
#
# Example word vectors from the trained model:
# 'comedy': [-0.15025814 -0.1020118   0.0373003   0.25695944  0.3894567 ]...
# 'book': [ 0.17781025 -0.14538182  0.02569692  0.11944461  0.13530536]...
# 'based': [ 0.12031919 -0.03863497  0.17956974  0.17622623  0.06918911]...
# 'nudity': [ 0.19918957 -0.40024012 -0.00356248  0.24387117  0.26830912]...
# 'ending': [-0.35906926 -0.35513058  0.15552406  0.44691464  0.21652234]...
# 'story': [-0.01104084  0.08566553  0.25276715  0.34146658 -0.01041591]...
# 'life': [ 0.0538758   0.10635457 -0.08681938  0.25011736  0.08946192]...
# 'topless': [ 0.18052258 -0.4517695  -0.0586437   0.22744034  0.27388245]...
# 'dark': [-0.20339346 -0.04174857 -0.2226869   0.46942824 -0.02440552]...
# 'fi': [-0.39503503 -0.13318823  0.05080197  0.22003216  0.24952173]...
#
# Example word similarities:
# Words similar to 'action': [('plot', 0.6143385171890259), ('bad', 0.5715851783752441), ('comic', 0.5618346333503723), ('fi', 0.5572066307067871), ('violence', 0.5504598021507263)]
# Words similar to 'love': [('fall', 0.7526370882987976), ('meet', 0.6720481514930725), ('life', 0.6445057988166809), ('woman', 0.6395397186279297), ('young', 0.6306421756744385)]
# Words similar to 'hero': [('super', 0.729734480381012), ('superheroes', 0.6500062346458435), ('superhero', 0.620000958442688), ('comic', 0.5925536155700684), ('anti', 0.5856203436851501)]
# Words similar to 'villain': [('nonexistent', 0.6492549777030945), ('needed', 0.6224390864372253), ('the joker', 0.5200120210647583), ('kevin conroy', 0.4669175446033478), ('twohy', 0.4615583121776581)]
# 2025-05-05 19:53:18,654 : INFO : saved ./rec/content-recommendations\word2vec_model
# Trained and saved Word2Vec model with 27637 words

# %%
print("\n" + "="*80)
print("STEP 5: MOVIE VECTOR GENERATION")
print("="*80)

def generate_movie_vectors(movie_ll_values, word2vec_model, movie_features, batch_size=100):
    """Generate movie feature vectors using Log-Likelihood and Word2Vec in batches"""
    print("Generating movie feature vectors using Log-Likelihood + Word2Vec in batches...")
    start_time = time.time()
    
    movie_vectors = {}
    successful_vectors = 0
    no_words_found = 0
    low_ll_sum = 0
    
    # Get movie IDs from LL values
    movie_ids = list(movie_ll_values.keys())
    total_movies = len(movie_ids)
    
    # Process movies in batches
    for batch_start in range(0, total_movies, batch_size):
        batch_end = min(batch_start + batch_size, total_movies)
        batch_movie_ids = movie_ids[batch_start:batch_end]
        total_corpus_size = sum(corpus_word_counts.values())

        print(f"Processing batch {batch_start//batch_size + 1}: movies {batch_start+1}-{batch_end} of {total_movies}")
        
        for movie_id in batch_movie_ids:
            # Sort words by LL value and select top 200
            ll_values = movie_ll_values[movie_id]
    # Tính IDF cho từng từ
            idf = {word: math.log(total_corpus_size/(corpus_word_counts[word]+1)) 
                for word in ll_values.keys()}
            
            # Kết hợp LL và IDF
            combined_scores = {word: ll * idf[word] 
                            for word, ll in ll_values.items()}
            
            # Chọn top words dựa trên combined scores
            top_words = sorted(combined_scores.items(), key=lambda x: x[1], reverse=True)[:500]            
            if not top_words:
                no_words_found += 1
                continue
            
            # Combine Word2Vec vectors weighted by Log-Likelihood values
            weighted_vectors = []
            ll_sum = 0
            words_used = 0
            
            for word, ll_value in top_words:
                if ll_value <= 0:
                    continue
                
                if word in word2vec_model.wv:
                    weighted_vectors.append(word2vec_model.wv[word] * ll_value)
                    ll_sum += ll_value
                    words_used += 1
            
            if weighted_vectors and ll_sum > 0:
                # Calculate the weighted average vector
                movie_vector = np.sum(weighted_vectors, axis=0) / ll_sum
                
                # Normalize to unit length
                norm = np.linalg.norm(movie_vector)
                if norm > 0:
                    movie_vector = movie_vector / norm
                    movie_vectors[movie_id] = movie_vector
                    successful_vectors += 1
            else:
                low_ll_sum += 1
        
        # Log progress and elapsed time
        elapsed = time.time() - start_time
        progress = batch_end / total_movies * 100
        remaining = elapsed / (batch_end - batch_start) * (total_movies - batch_end) if batch_end < total_movies else 0
        print(f"Progress: {progress:.1f}% - Elapsed: {elapsed:.2f}s - Est. remaining: {remaining:.2f}s")
        print(f"Successfully created vectors: {successful_vectors}/{batch_end}")
        
        # Force garbage collection after each batch
        gc.collect()
    
    print(f"\nVector generation complete:")
    print(f"Successfully created vectors: {successful_vectors}/{total_movies} ({successful_vectors/total_movies*100:.1f}%)")
    print(f"Movies with no words found: {no_words_found}")
    print(f"Movies with too low LL sum: {low_ll_sum}")
    
    # Display sample movie vectors
    if movie_vectors:
        print("\nSample movie vectors:")
        for movie_id in list(movie_vectors.keys())[:3]:
            movie_title = movie_features[movie_features['movieId'] == movie_id]['title'].values[0]
            vector = movie_vectors[movie_id]
            print(f"Movie: '{movie_title}' (ID: {movie_id})")
            print(f"Vector shape: {vector.shape}")
            print(f"Vector norm: {np.linalg.norm(vector):.4f}")
            print(f"First 5 dimensions: {vector[:5]}")
            print("---")
    
    return movie_vectors

# Generate movie vectors if Word2Vec and LL values are available
if 'word2vec_model' in data and 'movie_ll_values' in data:
    movie_vectors = generate_movie_vectors(
        data['movie_ll_values'], 
        data['word2vec_model'],
        data['movie_features'],
        batch_size=100
    )
    data['movie_vectors'] = movie_vectors
    
    # Save movie vectors
    with open(os.path.join(output_path, 'movie_vectors.pkl'), 'wb') as f:
        pickle.dump(movie_vectors, f)
    
    # Create movie ID to index mapping
    movie_id_to_idx = {movie_id: i for i, movie_id in enumerate(movie_vectors.keys())}
    data['movie_id_to_idx'] = movie_id_to_idx
    
    # Save the mapping
    with open(os.path.join(output_path, 'movie_id_to_idx.pkl'), 'wb') as f:
        pickle.dump(movie_id_to_idx, f)
    
    print(f"Generated and saved feature vectors for {len(movie_vectors)} movies")
    
    # Calculate and display vector statistics
    vector_norms = [np.linalg.norm(v) for v in movie_vectors.values()]
    print(f"\nVector statistics:")
    print(f"Average vector norm: {np.mean(vector_norms):.4f}")
    print(f"Vector dimensionality: {word2vec_dim}")
    
    # Free memory
    gc.collect()
# Out:
# ================================================================================
# STEP 5: MOVIE VECTOR GENERATION
# ================================================================================
# Generating movie feature vectors using Log-Likelihood + Word2Vec in batches...
# Processing batch 1: movies 1-100 of 24378
# Progress: 0.4% - Elapsed: 0.02s - Est. remaining: 5.38s
# Successfully created vectors: 100/100
# Processing batch 2: movies 101-200 of 24378
# Progress: 0.8% - Elapsed: 0.17s - Est. remaining: 41.64s
# Successfully created vectors: 200/200
# Processing batch 3: movies 201-300 of 24378
# Progress: 1.2% - Elapsed: 0.31s - Est. remaining: 75.21s
# Successfully created vectors: 300/300
# Processing batch 4: movies 301-400 of 24378
# Progress: 1.6% - Elapsed: 0.43s - Est. remaining: 103.44s
# Successfully created vectors: 400/400
# Processing batch 5: movies 401-500 of 24378
# Progress: 2.1% - Elapsed: 0.56s - Est. remaining: 132.79s
# Successfully created vectors: 500/500
# Processing batch 6: movies 501-600 of 24378
# Progress: 2.5% - Elapsed: 0.68s - Est. remaining: 162.47s
# Successfully created vectors: 600/600
# Processing batch 7: movies 601-700 of 24378
# Progress: 2.9% - Elapsed: 0.80s - Est. remaining: 189.16s
# Successfully created vectors: 700/700
# Processing batch 8: movies 701-800 of 24378
# ---
# Movie: 'Grumpier Old Men (1995)' (ID: 3)
# Vector shape: (200,)
# Vector norm: 1.0000
# First 5 dimensions: [ 0.0688308  -0.04035268 -0.07584827  0.14726801 -0.04436317]
# ---
# Generated and saved feature vectors for 24367 movies
#
# Vector statistics:
# Average vector norm: 1.0000
# Vector dimensionality: 200

# %%
print("\n" + "="*80)
print("STEP 6: USER VECTOR GENERATION")
print("="*80)

def generate_user_vectors(movie_vectors, train_ratings, batch_size=100):
    """Generate user feature vectors based on rated movies and their content in batches"""
    print("Generating user feature vectors based on movie ratings in batches...")
    start_time = time.time()
    
    user_vectors = {}
    successful_vectors = 0
    no_ratings_found = 0
    no_vectors_for_movies = 0
    low_weight_sum = 0
    
    # Create a rating cache for quick lookups
    # This can be memory intensive for large datasets, but speeds up processing
    user_ratings_dict = {}
    print("Creating user ratings lookup dictionary...")
    
    # Process in chunks to avoid memory issues
    for _, row in train_ratings.iterrows():
        user_id = row['userId']
        movie_id = row['movieId']
        rating = row['rating']
        
        if user_id not in user_ratings_dict:
            user_ratings_dict[user_id] = {}
        
        user_ratings_dict[user_id][movie_id] = rating
    
    # Process each user
    user_ids = list(user_ratings_dict.keys())
    total_users = len(user_ids)
    print(f"Processing {total_users} users in batches...")
    
    # Process users in batches
    for batch_start in range(0, total_users, batch_size):
        batch_end = min(batch_start + batch_size, total_users)
        batch_user_ids = user_ids[batch_start:batch_end]
        
        print(f"Processing batch {batch_start//batch_size + 1}: users {batch_start+1}-{batch_end} of {total_users}")
        
        for user_id in batch_user_ids:
            # Get user ratings
            user_ratings = user_ratings_dict[user_id]
            
            if len(user_ratings) == 0:
                no_ratings_found += 1
                continue
            
            weighted_vectors = []
            weight_sum = 0
            movies_with_vectors = 0
            movies_without_vectors = 0
            
            for movie_id, rating in user_ratings.items():
                # Center rating at 3.0 as described in the papers
                weight = rating - 3.0
                
                # Skip if movie vector is not available
                if movie_id not in movie_vectors:
                    movies_without_vectors += 1
                    continue
                else:
                    movies_with_vectors += 1
                
                if weight != 0:
                    weighted_vectors.append(movie_vectors[movie_id] * weight)
                    weight_sum += abs(weight)
            
            if weighted_vectors and weight_sum > 0:
                # Calculate the weighted average vector
                user_vector = np.sum(weighted_vectors, axis=0) / weight_sum
                
                # Normalize to unit length
                norm = np.linalg.norm(user_vector)
                if norm > 0:
                    user_vector = user_vector / norm
                    user_vectors[user_id] = user_vector
                    successful_vectors += 1
            else:
                low_weight_sum += 1
        
        # Log progress
        elapsed = time.time() - start_time
        progress = batch_end / total_users * 100
        remaining = elapsed / (batch_end - batch_start) * (total_users - batch_end) if batch_end < total_users else 0
        print(f"Progress: {progress:.1f}% - Elapsed: {elapsed:.2f}s - Est. remaining: {remaining:.2f}s")
        print(f"Successfully created vectors: {successful_vectors}")
        
        # Force garbage collection after each batch
        gc.collect()
    
    print(f"\nUser vector generation complete:")
    print(f"Successfully created vectors: {successful_vectors}/{total_users} ({successful_vectors/total_users*100:.1f}%)")
    print(f"Users with no ratings: {no_ratings_found}")
    print(f"Users with no vectorized movies: {no_vectors_for_movies}")
    print(f"Users with too low weight sum: {low_weight_sum}")
    
    # Free memory
    del user_ratings_dict
    gc.collect()
    
    # Display sample user vectors
    if user_vectors:
        print("\nSample user vectors:")
        for user_id in list(user_vectors.keys())[:3]:
            vector = user_vectors[user_id]
            user_rating_count = len([r for r in train_ratings[train_ratings['userId'] == user_id]])
            print(f"User ID: {user_id}")
            print(f"Number of ratings: {user_rating_count}")
            print(f"Vector shape: {vector.shape}")
            print(f"Vector norm: {np.linalg.norm(vector):.4f}")
            print(f"First 5 dimensions: {vector[:5]}")
            print("---")
    
    return user_vectors

# Generate user vectors if movie vectors and training ratings are available
if 'movie_vectors' in data and 'train_ratings' in data:
    user_vectors = generate_user_vectors(data['movie_vectors'], data['train_ratings'], batch_size=100)
    data['user_vectors'] = user_vectors
    
    # Save user vectors
    with open(os.path.join(output_path, 'user_vectors.pkl'), 'wb') as f:
        pickle.dump(user_vectors, f)
    
    # Create user ID to index mapping
    user_id_to_idx = {user_id: i for i, user_id in enumerate(user_vectors.keys())}
    data['user_id_to_idx'] = user_id_to_idx
    
    # Save the mapping
    with open(os.path.join(output_path, 'user_id_to_idx.pkl'), 'wb') as f:
        pickle.dump(user_id_to_idx, f)
    
    print(f"Generated and saved feature vectors for {len(user_vectors)} users")
    
    # Calculate and display vector statistics
    vector_norms = [np.linalg.norm(v) for v in user_vectors.values()]
    print(f"\nVector statistics:")
    print(f"Average vector norm: {np.mean(vector_norms):.4f}")
    print(f"Vector dimensionality: {word2vec_dim}")
    
    # Free memory
    gc.collect()
# Out:
# ================================================================================
# STEP 6: USER VECTOR GENERATION
# ================================================================================
# Generating user feature vectors based on movie ratings in batches...
# Creating user ratings lookup dictionary...
# Processing 100000 users in batches...
# Processing batch 1: users 1-100 of 100000
# Progress: 0.1% - Elapsed: 201.31s - Est. remaining: 201105.69s
# Successfully created vectors: 100
# Processing batch 2: users 101-200 of 100000
# Progress: 0.2% - Elapsed: 201.51s - Est. remaining: 201104.09s
# Successfully created vectors: 200
# Processing batch 3: users 201-300 of 100000
# Progress: 0.3% - Elapsed: 201.67s - Est. remaining: 201067.99s
# Successfully created vectors: 300
# Processing batch 4: users 301-400 of 100000
# Progress: 0.4% - Elapsed: 201.87s - Est. remaining: 201060.48s
# Successfully created vectors: 400
# Processing batch 5: users 401-500 of 100000
# Progress: 0.5% - Elapsed: 202.09s - Est. remaining: 201076.52s
# Successfully created vectors: 500
# Processing batch 6: users 501-600 of 100000
# Progress: 0.6% - Elapsed: 202.27s - Est. remaining: 201053.35s
# Successfully created vectors: 600
# Processing batch 7: users 601-700 of 100000
# Progress: 0.7% - Elapsed: 202.44s - Est. remaining: 201023.86s
# Successfully created vectors: 700
# Processing batch 8: users 701-800 of 100000
# Progress: 0.8% - Elapsed: 202.62s - Est. remaining: 200998.99s
# Successfully created vectors: 800
# Processing batch 9: users 801-900 of 100000
# Progress: 0.9% - Elapsed: 202.81s - Est. remaining: 200983.67s
# Successfully created vectors: 900
# Processing batch 10: users 901-1000 of 100000
# Progress: 1.0% - Elapsed: 202.99s - Est. remaining: 200962.03s
# Successfully created vectors: 1000
# Processing batch 11: users 1001-1100 of 100000
# Progress: 1.1% - Elapsed: 203.18s - Est. remaining: 200942.00s
# Successfully created vectors: 1100
# Processing batch 12: users 1101-1200 of 100000
# Progress: 1.2% - Elapsed: 203.34s - Est. remaining: 200896.91s
# Successfully created vectors: 1200
# Processing batch 13: users 1201-1300 of 100000
# Progress: 1.3% - Elapsed: 203.51s - Est. remaining: 200865.31s
# Successfully created vectors: 1300
# Processing batch 14: users 1301-1400 of 100000
# Progress: 1.4% - Elapsed: 203.67s - Est. remaining: 200822.51s
# Successfully created vectors: 1400
# Processing batch 15: users 1401-1500 of 100000
# Progress: 1.5% - Elapsed: 203.88s - Est. remaining: 200819.78s
# Successfully created vectors: 1500
# Processing batch 16: users 1501-1600 of 100000
# Progress: 1.6% - Elapsed: 204.06s - Est. remaining: 200794.00s
# Successfully created vectors: 1600
# Processing batch 17: users 1601-1700 of 100000
# Progress: 1.7% - Elapsed: 204.24s - Est. remaining: 200769.83s
# Successfully created vectors: 1700
# Processing batch 18: users 1701-1800 of 100000
# Progress: 1.8% - Elapsed: 204.44s - Est. remaining: 200758.06s
# Successfully created vectors: 1800
# Processing batch 19: users 1801-1900 of 100000
# Progress: 1.9% - Elapsed: 204.61s - Est. remaining: 200723.34s
# Successfully created vectors: 1900
# Processing batch 20: users 1901-2000 of 100000
# Progress: 2.0% - Elapsed: 204.80s - Est. remaining: 200700.03s
# Successfully created vectors: 2000
# Processing batch 21: users 2001-2100 of 100000
# Progress: 2.1% - Elapsed: 204.99s - Est. remaining: 200689.07s
# Successfully created vectors: 2100
# Processing batch 22: users 2101-2200 of 100000
# Progress: 2.2% - Elapsed: 205.19s - Est. remaining: 200674.79s
# Successfully created vectors: 2200
# Processing batch 23: users 2201-2300 of 100000
# Progress: 2.3% - Elapsed: 205.38s - Est. remaining: 200652.30s
# Successfully created vectors: 2300
# Processing batch 24: users 2301-2400 of 100000
# Progress: 2.4% - Elapsed: 205.55s - Est. remaining: 200620.65s
# Successfully created vectors: 2400
# Processing batch 25: users 2401-2500 of 100000
# Progress: 2.5% - Elapsed: 205.75s - Est. remaining: 200604.25s
# Successfully created vectors: 2500
# Processing batch 26: users 2501-2600 of 100000
# Progress: 2.6% - Elapsed: 205.92s - Est. remaining: 200566.03s
# Successfully created vectors: 2600
# Processing batch 27: users 2601-2700 of 100000
# Progress: 2.7% - Elapsed: 206.13s - Est. remaining: 200565.41s
# Successfully created vectors: 2700
# Processing batch 28: users 2701-2800 of 100000
# Progress: 2.8% - Elapsed: 206.33s - Est. remaining: 200554.65s
# Successfully created vectors: 2800
# Processing batch 29: users 2801-2900 of 100000
# Progress: 2.9% - Elapsed: 206.51s - Est. remaining: 200519.21s
# Successfully created vectors: 2900
# Processing batch 30: users 2901-3000 of 100000
# Progress: 3.0% - Elapsed: 206.66s - Est. remaining: 200460.14s
# Successfully created vectors: 3000
# Processing batch 31: users 3001-3100 of 100000
# Progress: 3.1% - Elapsed: 206.85s - Est. remaining: 200436.63s
# Successfully created vectors: 3100
# Processing batch 32: users 3101-3200 of 100000
# Progress: 3.2% - Elapsed: 207.02s - Est. remaining: 200393.37s
# Successfully created vectors: 3200
# Processing batch 33: users 3201-3300 of 100000
# Progress: 3.3% - Elapsed: 207.20s - Est. remaining: 200364.39s
# Successfully created vectors: 3300
# Processing batch 34: users 3301-3400 of 100000
# Progress: 3.4% - Elapsed: 207.38s - Est. remaining: 200327.13s
# Successfully created vectors: 3400
# Processing batch 35: users 3401-3500 of 100000
# Progress: 3.5% - Elapsed: 207.57s - Est. remaining: 200307.33s
# Successfully created vectors: 3500
# Processing batch 36: users 3501-3600 of 100000
# Progress: 3.6% - Elapsed: 207.74s - Est. remaining: 200263.78s
# Successfully created vectors: 3600
# Processing batch 37: users 3601-3700 of 100000
# Progress: 3.7% - Elapsed: 207.89s - Est. remaining: 200194.46s
# Successfully created vectors: 3700
# Processing batch 38: users 3701-3800 of 100000
# Progress: 3.8% - Elapsed: 208.06s - Est. remaining: 200156.34s
# Successfully created vectors: 3800
# Processing batch 39: users 3801-3900 of 100000
# Progress: 3.9% - Elapsed: 208.25s - Est. remaining: 200123.52s
# Successfully created vectors: 3900
# Processing batch 40: users 3901-4000 of 100000
# Progress: 4.0% - Elapsed: 208.42s - Est. remaining: 200078.66s
# Successfully created vectors: 4000
# Processing batch 41: users 4001-4100 of 100000
# Progress: 4.1% - Elapsed: 208.58s - Est. remaining: 200023.83s
# Successfully created vectors: 4100
# Processing batch 42: users 4101-4200 of 100000
# Progress: 4.2% - Elapsed: 208.74s - Est. remaining: 199970.13s
# Successfully created vectors: 4200
# Processing batch 43: users 4201-4300 of 100000
# Progress: 4.3% - Elapsed: 208.90s - Est. remaining: 199921.23s
# Successfully created vectors: 4300
# Processing batch 44: users 4301-4400 of 100000
# Progress: 4.4% - Elapsed: 209.07s - Est. remaining: 199874.10s
# Successfully created vectors: 4400
# Processing batch 45: users 4401-4500 of 100000
# Progress: 4.5% - Elapsed: 209.27s - Est. remaining: 199853.32s
# Successfully created vectors: 4500
# Processing batch 46: users 4501-4600 of 100000
# Progress: 4.6% - Elapsed: 209.45s - Est. remaining: 199812.40s
# Successfully created vectors: 4600
# Processing batch 47: users 4601-4700 of 100000
# Progress: 4.7% - Elapsed: 209.62s - Est. remaining: 199764.18s
# Successfully created vectors: 4700
# Processing batch 48: users 4701-4800 of 100000
# Progress: 4.8% - Elapsed: 209.77s - Est. remaining: 199703.10s
# Successfully created vectors: 4800
# Processing batch 49: users 4801-4900 of 100000
# Progress: 4.9% - Elapsed: 209.94s - Est. remaining: 199650.50s
# Successfully created vectors: 4900
# Processing batch 50: users 4901-5000 of 100000
# Progress: 5.0% - Elapsed: 210.10s - Est. remaining: 199598.50s
# Successfully created vectors: 5000
# Processing batch 51: users 5001-5100 of 100000
# Progress: 5.1% - Elapsed: 210.26s - Est. remaining: 199535.42s
# Successfully created vectors: 5100
# Processing batch 52: users 5101-5200 of 100000
# Progress: 5.2% - Elapsed: 210.44s - Est. remaining: 199499.53s
# Successfully created vectors: 5200
# Processing batch 53: users 5201-5300 of 100000
# Progress: 5.3% - Elapsed: 210.63s - Est. remaining: 199471.12s
# Successfully created vectors: 5300
# Processing batch 54: users 5301-5400 of 100000
# Progress: 5.4% - Elapsed: 210.80s - Est. remaining: 199413.16s
# Successfully created vectors: 5400
# Processing batch 55: users 5401-5500 of 100000
# Progress: 5.5% - Elapsed: 210.96s - Est. remaining: 199354.80s
# Successfully created vectors: 5500
# Processing batch 56: users 5501-5600 of 100000
# Progress: 5.6% - Elapsed: 211.11s - Est. remaining: 199291.56s
# Successfully created vectors: 5600
# Processing batch 57: users 5601-5700 of 100000
# Progress: 5.7% - Elapsed: 211.26s - Est. remaining: 199221.95s
# Successfully created vectors: 5700
# Processing batch 58: users 5701-5800 of 100000
# Progress: 5.8% - Elapsed: 211.44s - Est. remaining: 199172.79s
# Successfully created vectors: 5800
# Processing batch 59: users 5801-5900 of 100000
# Progress: 5.9% - Elapsed: 211.63s - Est. remaining: 199145.61s
# Successfully created vectors: 5900
# Processing batch 60: users 5901-6000 of 100000
# Progress: 6.0% - Elapsed: 211.81s - Est. remaining: 199099.70s
# Successfully created vectors: 6000
# Processing batch 61: users 6001-6100 of 100000
# Progress: 6.1% - Elapsed: 211.96s - Est. remaining: 199033.87s
# Successfully created vectors: 6100
# Processing batch 62: users 6101-6200 of 100000
# Progress: 6.2% - Elapsed: 212.14s - Est. remaining: 198990.06s
# Successfully created vectors: 6200
# Processing batch 63: users 6201-6300 of 100000
# Progress: 6.3% - Elapsed: 212.35s - Est. remaining: 198969.14s
# Successfully created vectors: 6300
# Processing batch 64: users 6301-6400 of 100000
# Progress: 6.4% - Elapsed: 212.51s - Est. remaining: 198914.00s
# Successfully created vectors: 6400
# Processing batch 65: users 6401-6500 of 100000
# Progress: 6.5% - Elapsed: 212.68s - Est. remaining: 198853.55s
# Successfully created vectors: 6500
# Processing batch 66: users 6501-6600 of 100000
# Progress: 6.6% - Elapsed: 212.83s - Est. remaining: 198783.51s
# Successfully created vectors: 6600
# Processing batch 67: users 6601-6700 of 100000
# Progress: 6.7% - Elapsed: 212.99s - Est. remaining: 198718.18s
# Successfully created vectors: 6700
# Processing batch 68: users 6701-6800 of 100000
# Progress: 6.8% - Elapsed: 213.15s - Est. remaining: 198652.28s
# Successfully created vectors: 6800
# Processing batch 69: users 6801-6900 of 100000
# Progress: 6.9% - Elapsed: 213.32s - Est. remaining: 198601.36s
# Successfully created vectors: 6900
# Processing batch 70: users 6901-7000 of 100000
# Progress: 7.0% - Elapsed: 213.50s - Est. remaining: 198558.32s
# Successfully created vectors: 7000
# Processing batch 71: users 7001-7100 of 100000
# Progress: 7.1% - Elapsed: 213.68s - Est. remaining: 198512.25s
# Successfully created vectors: 7100
# Processing batch 72: users 7101-7200 of 100000
# Progress: 7.2% - Elapsed: 213.87s - Est. remaining: 198466.94s
# Successfully created vectors: 7200
# Processing batch 73: users 7201-7300 of 100000
# Progress: 7.3% - Elapsed: 214.04s - Est. remaining: 198418.15s
# Successfully created vectors: 7300
# Processing batch 74: users 7301-7400 of 100000
# Progress: 7.4% - Elapsed: 214.21s - Est. remaining: 198361.53s
# Successfully created vectors: 7400
# Processing batch 75: users 7401-7500 of 100000
# Progress: 7.5% - Elapsed: 214.37s - Est. remaining: 198292.86s
# Successfully created vectors: 7500
# Processing batch 76: users 7501-7600 of 100000
# Progress: 7.6% - Elapsed: 214.55s - Est. remaining: 198240.61s
# Successfully created vectors: 7600
# Processing batch 77: users 7601-7700 of 100000
# Progress: 7.7% - Elapsed: 214.75s - Est. remaining: 198214.36s
# Successfully created vectors: 7700
# Processing batch 78: users 7701-7800 of 100000
# Progress: 7.8% - Elapsed: 214.92s - Est. remaining: 198158.34s
# Successfully created vectors: 7800
# Processing batch 79: users 7801-7900 of 100000
# Progress: 7.9% - Elapsed: 215.12s - Est. remaining: 198123.18s
# Successfully created vectors: 7900
# Processing batch 80: users 7901-8000 of 100000
# Progress: 8.0% - Elapsed: 215.28s - Est. remaining: 198061.39s
# Successfully created vectors: 8000
# Processing batch 81: users 8001-8100 of 100000
# Progress: 8.1% - Elapsed: 215.50s - Est. remaining: 198042.91s
# Successfully created vectors: 8100
# Processing batch 82: users 8101-8200 of 100000
# Progress: 8.2% - Elapsed: 215.70s - Est. remaining: 198017.13s
# Successfully created vectors: 8200
# Processing batch 83: users 8201-8300 of 100000
# Progress: 8.3% - Elapsed: 215.91s - Est. remaining: 197988.65s
# Successfully created vectors: 8300
# Processing batch 84: users 8301-8400 of 100000
# Progress: 8.4% - Elapsed: 216.08s - Est. remaining: 197925.89s
# Successfully created vectors: 8400
# Processing batch 85: users 8401-8500 of 100000
# Progress: 8.5% - Elapsed: 216.25s - Est. remaining: 197869.94s
# Successfully created vectors: 8500
# Processing batch 86: users 8501-8600 of 100000
# Progress: 8.6% - Elapsed: 216.41s - Est. remaining: 197801.81s
# Successfully created vectors: 8600
# Processing batch 87: users 8601-8700 of 100000
# Progress: 8.7% - Elapsed: 216.57s - Est. remaining: 197728.73s
# Successfully created vectors: 8700
# Processing batch 88: users 8701-8800 of 100000
# Progress: 8.8% - Elapsed: 216.75s - Est. remaining: 197677.23s
# Successfully created vectors: 8800
# Processing batch 89: users 8801-8900 of 100000
# Progress: 8.9% - Elapsed: 216.93s - Est. remaining: 197622.10s
# Successfully created vectors: 8900
# Processing batch 90: users 8901-9000 of 100000
# Progress: 9.0% - Elapsed: 217.09s - Est. remaining: 197553.76s
# Successfully created vectors: 9000
# Processing batch 91: users 9001-9100 of 100000
# Progress: 9.1% - Elapsed: 217.25s - Est. remaining: 197479.83s
# Successfully created vectors: 9100
# Processing batch 92: users 9101-9200 of 100000
# Progress: 9.2% - Elapsed: 217.43s - Est. remaining: 197426.75s
# Successfully created vectors: 9200
# Processing batch 93: users 9201-9300 of 100000
# Progress: 9.3% - Elapsed: 217.59s - Est. remaining: 197357.35s
# Successfully created vectors: 9300
# Processing batch 94: users 9301-9400 of 100000
# Progress: 24.1% - Elapsed: 244.97s - Est. remaining: 185933.33s
# Successfully created vectors: 24099
# Processing batch 242: users 24101-24200 of 100000
# Progress: 24.2% - Elapsed: 245.14s - Est. remaining: 185818.74s
# Successfully created vectors: 24199
# Processing batch 243: users 24201-24300 of 100000
# Progress: 24.3% - Elapsed: 245.31s - Est. remaining: 185696.23s
# Successfully created vectors: 24299
# Processing batch 244: users 24301-24400 of 100000
# Progress: 24.4% - Elapsed: 245.47s - Est. remaining: 185578.69s
# Successfully created vectors: 24399
# Processing batch 245: users 24401-24500 of 100000
# Progress: 24.5% - Elapsed: 245.65s - Est. remaining: 185465.45s
# Successfully created vectors: 24499
# Processing batch 246: users 24501-24600 of 100000
# Progress: 24.6% - Elapsed: 245.80s - Est. remaining: 185334.41s
# Successfully created vectors: 24599
# Processing batch 247: users 24601-24700 of 100000
# Progress: 24.7% - Elapsed: 245.96s - Est. remaining: 185208.02s
# Successfully created vectors: 24699
# Processing batch 248: users 24701-24800 of 100000
# Progress: 24.8% - Elapsed: 246.22s - Est. remaining: 185157.04s
# Successfully created vectors: 24799
# Processing batch 249: users 24801-24900 of 100000
# Progress: 24.9% - Elapsed: 246.37s - Est. remaining: 185021.03s
# Successfully created vectors: 24899
# Processing batch 250: users 24901-25000 of 100000
# Progress: 25.0% - Elapsed: 246.52s - Est. remaining: 184892.57s
# Successfully created vectors: 24999
# Processing batch 251: users 25001-25100 of 100000
# Progress: 25.1% - Elapsed: 246.67s - Est. remaining: 184757.83s
# Successfully created vectors: 25099
# Processing batch 252: users 25101-25200 of 100000
# Progress: 25.2% - Elapsed: 246.88s - Est. remaining: 184664.76s
# Successfully created vectors: 25199
# Processing batch 253: users 25201-25300 of 100000
# Progress: 25.3% - Elapsed: 247.06s - Est. remaining: 184554.79s
# Successfully created vectors: 25299
# Processing batch 254: users 25301-25400 of 100000
# Progress: 25.4% - Elapsed: 247.31s - Est. remaining: 184490.70s
# Successfully created vectors: 25399
# Processing batch 255: users 25401-25500 of 100000
# Progress: 25.5% - Elapsed: 247.45s - Est. remaining: 184352.91s
# Successfully created vectors: 25499
# Processing batch 256: users 25501-25600 of 100000
# Progress: 25.6% - Elapsed: 247.59s - Est. remaining: 184209.98s
# Successfully created vectors: 25599
# Processing batch 257: users 25601-25700 of 100000
# Progress: 25.7% - Elapsed: 247.74s - Est. remaining: 184073.45s
# Successfully created vectors: 25699
# Processing batch 258: users 25701-25800 of 100000
# Progress: 25.8% - Elapsed: 247.91s - Est. remaining: 183949.20s
# Successfully created vectors: 25799
# Processing batch 259: users 25801-25900 of 100000
# Progress: 25.9% - Elapsed: 248.07s - Est. remaining: 183818.37s
# Successfully created vectors: 25899
# Processing batch 260: users 25901-26000 of 100000
# Progress: 26.0% - Elapsed: 248.23s - Est. remaining: 183692.48s
# Successfully created vectors: 25999
# Processing batch 261: users 26001-26100 of 100000
# Progress: 26.1% - Elapsed: 248.43s - Est. remaining: 183591.38s
# Successfully created vectors: 26099
# Processing batch 262: users 26101-26200 of 100000
# Progress: 90.2% - Elapsed: 330.84s - Est. remaining: 32422.45s
# Successfully created vectors: 90193
# Processing batch 903: users 90201-90300 of 100000
# Progress: 90.3% - Elapsed: 330.97s - Est. remaining: 32103.73s
# Successfully created vectors: 90293
# Processing batch 904: users 90301-90400 of 100000
# Progress: 90.4% - Elapsed: 331.07s - Est. remaining: 31782.84s
# Successfully created vectors: 90393
# Processing batch 905: users 90401-90500 of 100000
# Progress: 90.5% - Elapsed: 331.19s - Est. remaining: 31462.60s
# Successfully created vectors: 90493
# Processing batch 906: users 90501-90600 of 100000
# Progress: 90.6% - Elapsed: 331.29s - Est. remaining: 31141.47s
# Successfully created vectors: 90593
# Processing batch 907: users 90601-90700 of 100000
# Progress: 90.7% - Elapsed: 331.43s - Est. remaining: 30822.62s
# Successfully created vectors: 90693
# Processing batch 908: users 90701-90800 of 100000
# Progress: 90.8% - Elapsed: 331.53s - Est. remaining: 30500.62s
# Successfully created vectors: 90793
# Processing batch 909: users 90801-90900 of 100000
# Progress: 90.9% - Elapsed: 331.63s - Est. remaining: 30178.65s
# Successfully created vectors: 90893
# Processing batch 910: users 90901-91000 of 100000
# Progress: 91.0% - Elapsed: 331.74s - Est. remaining: 29857.01s
# Successfully created vectors: 90993
# Processing batch 911: users 91001-91100 of 100000
# Progress: 91.1% - Elapsed: 331.85s - Est. remaining: 29534.42s
# Successfully created vectors: 91093
# Processing batch 912: users 91101-91200 of 100000
# Progress: 91.2% - Elapsed: 331.96s - Est. remaining: 29212.92s
# Successfully created vectors: 91193
# Processing batch 913: users 91201-91300 of 100000
# Progress: 91.3% - Elapsed: 332.10s - Est. remaining: 28892.27s
# Successfully created vectors: 91293
# Processing batch 914: users 91301-91400 of 100000
# Progress: 91.4% - Elapsed: 332.20s - Est. remaining: 28569.55s
# Successfully created vectors: 91393
# Processing batch 915: users 91401-91500 of 100000
# Progress: 91.5% - Elapsed: 332.34s - Est. remaining: 28248.65s
# Successfully created vectors: 91493
# Processing batch 916: users 91501-91600 of 100000
# Progress: 91.6% - Elapsed: 332.45s - Est. remaining: 27925.64s
# Successfully created vectors: 91593
# Processing batch 917: users 91601-91700 of 100000
# Progress: 91.7% - Elapsed: 332.56s - Est. remaining: 27602.40s
# Successfully created vectors: 91693
# Processing batch 918: users 91701-91800 of 100000
# Progress: 91.8% - Elapsed: 332.66s - Est. remaining: 27278.29s
# Successfully created vectors: 91793
# Processing batch 919: users 91801-91900 of 100000
# Progress: 91.9% - Elapsed: 332.77s - Est. remaining: 26954.54s
# Successfully created vectors: 91893
# Processing batch 920: users 91901-92000 of 100000
# Progress: 92.0% - Elapsed: 332.88s - Est. remaining: 26630.24s
# Successfully created vectors: 91992
# Processing batch 921: users 92001-92100 of 100000
# Progress: 92.1% - Elapsed: 333.02s - Est. remaining: 26308.88s
# Successfully created vectors: 92092
# Processing batch 922: users 92101-92200 of 100000
# Progress: 92.2% - Elapsed: 333.14s - Est. remaining: 25985.27s
# Successfully created vectors: 92192
# Processing batch 923: users 92201-92300 of 100000
# Progress: 96.5% - Elapsed: 338.23s - Est. remaining: 11838.00s
# Successfully created vectors: 96492
# Processing batch 966: users 96501-96600 of 100000
# Progress: 96.6% - Elapsed: 338.35s - Est. remaining: 11503.85s
# Successfully created vectors: 96592
# Processing batch 967: users 96601-96700 of 100000
# Progress: 96.7% - Elapsed: 338.50s - Est. remaining: 11170.45s
# Successfully created vectors: 96692
# Processing batch 968: users 96701-96800 of 100000
# Progress: 96.8% - Elapsed: 338.60s - Est. remaining: 10835.22s
# Successfully created vectors: 96792
# Processing batch 969: users 96801-96900 of 100000
# Progress: 96.9% - Elapsed: 338.72s - Est. remaining: 10500.18s
# Successfully created vectors: 96892
# Processing batch 970: users 96901-97000 of 100000
# Progress: 97.0% - Elapsed: 338.82s - Est. remaining: 10164.56s
# Successfully created vectors: 96992
# Processing batch 971: users 97001-97100 of 100000
# Progress: 97.1% - Elapsed: 338.93s - Est. remaining: 9828.90s
# Successfully created vectors: 97092
# Processing batch 972: users 97101-97200 of 100000
# Progress: 97.2% - Elapsed: 339.03s - Est. remaining: 9492.94s
# Successfully created vectors: 97192
# Processing batch 973: users 97201-97300 of 100000
# Progress: 97.3% - Elapsed: 339.17s - Est. remaining: 9157.58s
# Successfully created vectors: 97292
# Processing batch 974: users 97301-97400 of 100000
# Progress: 97.4% - Elapsed: 339.27s - Est. remaining: 8821.11s
# Successfully created vectors: 97392
# Processing batch 975: users 97401-97500 of 100000
# Progress: 97.5% - Elapsed: 339.40s - Est. remaining: 8484.89s
# Successfully created vectors: 97492
# Processing batch 976: users 97501-97600 of 100000
# Progress: 97.6% - Elapsed: 339.51s - Est. remaining: 8148.30s
# Successfully created vectors: 97592
# Processing batch 977: users 97601-97700 of 100000
# Progress: 97.7% - Elapsed: 339.62s - Est. remaining: 7811.36s
# Successfully created vectors: 97692
# Processing batch 978: users 97701-97800 of 100000
# Progress: 97.8% - Elapsed: 339.73s - Est. remaining: 7474.03s
# Successfully created vectors: 97792
# Processing batch 979: users 97801-97900 of 100000
# Progress: 97.9% - Elapsed: 339.86s - Est. remaining: 7137.11s
# Successfully created vectors: 97892
# Processing batch 980: users 97901-98000 of 100000
# Progress: 98.0% - Elapsed: 339.97s - Est. remaining: 6799.33s
# Successfully created vectors: 97992
# Processing batch 981: users 98001-98100 of 100000
# Progress: 98.1% - Elapsed: 340.08s - Est. remaining: 6461.45s
# Successfully created vectors: 98092
# Processing batch 982: users 98101-98200 of 100000
# Progress: 98.2% - Elapsed: 340.18s - Est. remaining: 6123.25s
# Successfully created vectors: 98192
# Processing batch 983: users 98201-98300 of 100000
# Progress: 98.3% - Elapsed: 340.29s - Est. remaining: 5784.97s
# Successfully created vectors: 98292
# Processing batch 984: users 98301-98400 of 100000
# Progress: 98.4% - Elapsed: 340.39s - Est. remaining: 5446.31s
# Successfully created vectors: 98392
# Processing batch 985: users 98401-98500 of 100000
# Progress: 98.5% - Elapsed: 340.54s - Est. remaining: 5108.11s
# Successfully created vectors: 98492
# Processing batch 986: users 98501-98600 of 100000
# Progress: 98.6% - Elapsed: 340.66s - Est. remaining: 4769.26s
# Successfully created vectors: 98592
# Processing batch 987: users 98601-98700 of 100000
# Progress: 98.7% - Elapsed: 340.77s - Est. remaining: 4430.00s
# Successfully created vectors: 98692
# Processing batch 988: users 98701-98800 of 100000
# Progress: 98.8% - Elapsed: 340.87s - Est. remaining: 4090.47s
# Successfully created vectors: 98792
# Processing batch 989: users 98801-98900 of 100000
# Progress: 98.9% - Elapsed: 341.00s - Est. remaining: 3750.95s
# Successfully created vectors: 98892
# Processing batch 990: users 98901-99000 of 100000
# Progress: 99.0% - Elapsed: 341.11s - Est. remaining: 3411.13s
# Successfully created vectors: 98992
# Processing batch 991: users 99001-99100 of 100000
# Progress: 99.1% - Elapsed: 341.24s - Est. remaining: 3071.19s
# Successfully created vectors: 99092
# Processing batch 992: users 99101-99200 of 100000
# Progress: 99.2% - Elapsed: 341.35s - Est. remaining: 2730.78s
# Successfully created vectors: 99192
# Processing batch 993: users 99201-99300 of 100000
# Progress: 99.3% - Elapsed: 341.46s - Est. remaining: 2390.23s
# Successfully created vectors: 99292
# Processing batch 994: users 99301-99400 of 100000
# Progress: 99.4% - Elapsed: 341.60s - Est. remaining: 2049.62s
# Successfully created vectors: 99392
# Processing batch 995: users 99401-99500 of 100000
# Progress: 99.5% - Elapsed: 341.73s - Est. remaining: 1708.63s
# Successfully created vectors: 99492
# Processing batch 996: users 99501-99600 of 100000
# Progress: 99.6% - Elapsed: 341.84s - Est. remaining: 1367.35s
# Successfully created vectors: 99592
# Processing batch 997: users 99601-99700 of 100000
# Progress: 99.7% - Elapsed: 341.97s - Est. remaining: 1025.91s
# Successfully created vectors: 99692
# Processing batch 998: users 99701-99800 of 100000
# Progress: 99.8% - Elapsed: 342.08s - Est. remaining: 684.16s
# Successfully created vectors: 99792
# Processing batch 999: users 99801-99900 of 100000
# Progress: 99.9% - Elapsed: 342.19s - Est. remaining: 342.19s
# Successfully created vectors: 99892
# Processing batch 1000: users 99901-100000 of 100000
# Progress: 100.0% - Elapsed: 342.29s - Est. remaining: 0.00s
# Successfully created vectors: 99992
#
# User vector generation complete:
# Successfully created vectors: 99992/100000 (100.0%)
# Users with no ratings: 0
# Users with no vectorized movies: 0
# Users with too low weight sum: 8
#
# Sample user vectors:
# User ID: 969.0
# Number of ratings: 4
# Vector shape: (200,)
# Vector norm: 1.0000
# First 5 dimensions: [ 0.07677932 -0.01703884 -0.07186358  0.16195491  0.02876103]
# ---
# User ID: 10393.0
# Number of ratings: 4
# Vector shape: (200,)
# Vector norm: 1.0000
# First 5 dimensions: [ 0.01955729 -0.01106779  0.01202809 -0.10323088 -0.05746099]
# ---
# User ID: 62515.0
# Number of ratings: 4
# Vector shape: (200,)
# Vector norm: 1.0000
# First 5 dimensions: [ 0.11521376  0.00402851 -0.05543931  0.14295486  0.0185784 ]
# ---
# Generated and saved feature vectors for 99992 users
#
# Vector statistics:
# Average vector norm: 1.0000
# Vector dimensionality: 200

# %%
print("\n" + "="*80)
print("STEP 7: USER-MOVIE SIMILARITY CALCULATION")
print("="*80)

def calculate_user_movie_similarity(user_vectors, movie_vectors, threshold=0.7, batch_size=50):
    """Calculate similarity between users and movies in batches"""
    print(f"Calculating user-movie similarity with threshold {threshold} in batches...")
    start_time = time.time()
    
    # Store similarities in a dictionary of dictionaries
    # {user_id: {movie_id: similarity_score}}
    user_movie_similarities = {}
    
    # Get all user IDs
    user_ids = list(user_vectors.keys())
    total_users = len(user_ids)
    total_movies = len(movie_vectors)
    
    # Process users in batches
    for batch_start in range(0, total_users, batch_size):
        batch_end = min(batch_start + batch_size, total_users)
        batch_user_ids = user_ids[batch_start:batch_end]
        
        print(f"Processing batch {batch_start//batch_size + 1}: users {batch_start+1}-{batch_end} of {total_users}")
        
        for user_id in batch_user_ids:
            user_vector = user_vectors[user_id]
            user_sims = {}
            user_similarities = 0
            user_above_threshold = 0
            
            # Calculate similarity for all movies at once (vectorized)
            # Convert both user and movie vectors to arrays for faster computation
            user_vector_array = np.array(user_vector).reshape(1, -1)
            
            # Process movies in chunks to avoid memory issues
            movie_ids = list(movie_vectors.keys())
            movie_chunk_size = 1000  # Adjust based on memory availability
            
            for movie_chunk_start in range(0, len(movie_ids), movie_chunk_size):
                movie_chunk_end = min(movie_chunk_start + movie_chunk_size, len(movie_ids))
                chunk_movie_ids = movie_ids[movie_chunk_start:movie_chunk_end]
                
                # Create array of movie vectors for this chunk
                movie_vectors_array = np.array([movie_vectors[mid] for mid in chunk_movie_ids])
                
                # Calculate cosine similarity in a vectorized way
                similarities = np.dot(user_vector_array, movie_vectors_array.T)[0]
                
                # Filter by threshold and store
                for i, sim in enumerate(similarities):
                    if sim > threshold:
                        movie_id = chunk_movie_ids[i]
                        user_sims[movie_id] = float(sim)  # Convert to native Python float
                        user_above_threshold += 1
                    user_similarities += 1
            
            user_movie_similarities[user_id] = user_sims
            
            # Log progress for this user
            if len(batch_user_ids) <= 10 or (user_id == batch_user_ids[-1]):
                print(f"User {user_id}: {user_above_threshold}/{total_movies} movies above threshold ({user_above_threshold/total_movies*100:.2f}%)")
        
        # Log progress for this batch
        elapsed = time.time() - start_time
        progress = batch_end / total_users * 100
        remaining = (elapsed / (batch_end - batch_start)) * (total_users - batch_end) if batch_end < total_users else 0
        print(f"Processed {batch_end}/{total_users} users ({progress:.1f}%) - Elapsed: {elapsed:.2f}s - Est. remaining: {remaining:.2f}s")
        
        # Force garbage collection after each batch
        gc.collect()
    
    avg_above_threshold = sum(len(sims) for sims in user_movie_similarities.values()) / len(user_movie_similarities) if user_movie_similarities else 0
    
    print(f"\nSimilarity calculation complete:")
    print(f"Total users processed: {len(user_movie_similarities)}")
    print(f"Total movies per user: {total_movies}")
    print(f"Average movies above threshold per user: {avg_above_threshold:.2f}")
    
    # Display sample user similarities
    if user_movie_similarities:
        print("\nSample user-movie similarities:")
        for user_id in list(user_movie_similarities.keys())[:3]:
            sims = user_movie_similarities[user_id]
            print(f"User ID: {user_id}")
            print(f"Number of movies above threshold: {len(sims)}")
            if sims:
                top_movies = sorted(sims.items(), key=lambda x: x[1], reverse=True)[:5]
                print("Top 5 most similar movies:")
                for movie_id, sim in top_movies:
                    movie_title = data['movie_features'][data['movie_features']['movieId'] == movie_id]['title'].values[0] if 'movie_features' in data else f"Movie {movie_id}"
                    print(f"  '{movie_title}' (ID: {movie_id}): {sim:.4f}")
            print("---")
    
    return user_movie_similarities
# Calculate similarities if user and movie vectors are available
if 'user_vectors' in data and 'movie_vectors' in data:
    user_movie_similarities = calculate_user_movie_similarity(
        data['user_vectors'], 
        data['movie_vectors'], 
        threshold=similarity_threshold,
        batch_size=50
    )
    data['user_movie_similarities'] = user_movie_similarities
    
    # Save the similarities
    with open(os.path.join(output_path, 'user_movie_similarities.pkl'), 'wb') as f:
        pickle.dump(user_movie_similarities, f)
    
    print(f"Calculated and saved similarities for {len(user_movie_similarities)} users")
    
    # Calculate and display similarity statistics
    similarity_counts = [len(sims) for sims in user_movie_similarities.values()]
    print(f"\nSimilarity statistics:")
    print(f"Average number of similar movies per user: {np.mean(similarity_counts):.2f}")
    print(f"Min: {min(similarity_counts)}, Max: {max(similarity_counts)}")
    
    # Free memory
    gc.collect()
# Out:
# ================================================================================
# STEP 7: USER-MOVIE SIMILARITY CALCULATION
# ================================================================================
# Calculating user-movie similarity with threshold 0.7 in batches...
# Processing batch 1: users 1-50 of 99992
# User 52927.0: 137/24367 movies above threshold (0.56%)
# Processed 50/99992 users (0.1%) - Elapsed: 1.90s - Est. remaining: 3791.79s
# Processing batch 2: users 51-100 of 99992
# User 14231.0: 5/24367 movies above threshold (0.02%)
# Processed 100/99992 users (0.1%) - Elapsed: 3.88s - Est. remaining: 7755.60s
# Processing batch 3: users 101-150 of 99992
# User 13757.0: 462/24367 movies above threshold (1.90%)
# Processed 150/99992 users (0.2%) - Elapsed: 5.87s - Est. remaining: 11727.42s
# Processing batch 4: users 151-200 of 99992
# User 33497.0: 79/24367 movies above threshold (0.32%)
# Processed 200/99992 users (0.2%) - Elapsed: 7.83s - Est. remaining: 15635.13s
# Processing batch 5: users 201-250 of 99992
# User 66088.0: 14/24367 movies above threshold (0.06%)
# Processed 250/99992 users (0.3%) - Elapsed: 9.74s - Est. remaining: 19425.47s
# Processing batch 6: users 251-300 of 99992
# User 37964.0: 0/24367 movies above threshold (0.00%)
# Processed 300/99992 users (0.3%) - Elapsed: 11.58s - Est. remaining: 23092.37s
# Processing batch 7: users 301-350 of 99992
# User 73289.0: 95/24367 movies above threshold (0.39%)
# Processed 350/99992 users (0.4%) - Elapsed: 13.47s - Est. remaining: 26839.27s
# Processing batch 8: users 351-400 of 99992
# User 20436.0: 20/24367 movies above threshold (0.08%)
# Processed 400/99992 users (0.4%) - Elapsed: 15.31s - Est. remaining: 30504.73s
# Processing batch 9: users 401-450 of 99992
# User 16238.0: 3265/24367 movies above threshold (13.40%)
# Processed 450/99992 users (0.5%) - Elapsed: 17.19s - Est. remaining: 34216.26s
# Processing batch 10: users 451-500 of 99992
# User 78491.0: 256/24367 movies above threshold (1.05%)
# Processed 500/99992 users (0.5%) - Elapsed: 19.10s - Est. remaining: 38013.59s
# Processing batch 11: users 501-550 of 99992
# User 50847.0: 0/24367 movies above threshold (0.00%)
# Processed 550/99992 users (0.6%) - Elapsed: 20.94s - Est. remaining: 41653.95s
# Processing batch 12: users 551-600 of 99992
# User 29879.0: 0/24367 movies above threshold (0.00%)
# Processed 600/99992 users (0.6%) - Elapsed: 22.80s - Est. remaining: 45329.79s
# Processing batch 13: users 601-650 of 99992
# User 27242.0: 1/24367 movies above threshold (0.00%)
# Processed 650/99992 users (0.7%) - Elapsed: 24.68s - Est. remaining: 49030.32s
# Processing batch 14: users 651-700 of 99992
# User 21955.0: 28/24367 movies above threshold (0.11%)
# Processed 700/99992 users (0.7%) - Elapsed: 26.73s - Est. remaining: 53078.60s
# Processing batch 15: users 701-750 of 99992
# User 9801.0: 3143/24367 movies above threshold (12.90%)
# Processed 750/99992 users (0.8%) - Elapsed: 28.67s - Est. remaining: 56896.50s
# Processing batch 16: users 751-800 of 99992
# User 8060.0: 0/24367 movies above threshold (0.00%)
# Processed 800/99992 users (0.8%) - Elapsed: 30.54s - Est. remaining: 60585.54s
# Processing batch 17: users 801-850 of 99992
# User 91193.0: 95/24367 movies above threshold (0.39%)
# Processed 850/99992 users (0.9%) - Elapsed: 32.38s - Est. remaining: 64197.47s
# Processing batch 18: users 851-900 of 99992
# User 47863.0: 67/24367 movies above threshold (0.27%)
# Processed 900/99992 users (0.9%) - Elapsed: 34.32s - Est. remaining: 68026.25s
# Processing batch 19: users 901-950 of 99992
# User 50896.0: 0/24367 movies above threshold (0.00%)
# Processed 950/99992 users (1.0%) - Elapsed: 36.21s - Est. remaining: 71735.70s
# Processing batch 20: users 951-1000 of 99992
# User 65189.0: 413/24367 movies above threshold (1.69%)
# Processed 1000/99992 users (1.0%) - Elapsed: 38.09s - Est. remaining: 75419.60s
# Processing batch 21: users 1001-1050 of 99992
# User 43988.0: 451/24367 movies above threshold (1.85%)
# Processed 1050/99992 users (1.1%) - Elapsed: 39.98s - Est. remaining: 79121.66s
# Processing batch 22: users 1051-1100 of 99992
# User 41215.0: 1276/24367 movies above threshold (5.24%)
# Processed 1100/99992 users (1.1%) - Elapsed: 41.85s - Est. remaining: 82776.28s
# Processing batch 23: users 1101-1150 of 99992
# User 94309.0: 244/24367 movies above threshold (1.00%)
# Processed 1150/99992 users (1.2%) - Elapsed: 43.79s - Est. remaining: 86561.59s
# Processing batch 24: users 1151-1200 of 99992
# User 4340.0: 234/24367 movies above threshold (0.96%)
# Processed 1200/99992 users (1.2%) - Elapsed: 45.70s - Est. remaining: 90287.69s
# Processing batch 25: users 1201-1250 of 99992
# User 54656.0: 1095/24367 movies above threshold (4.49%)
# Processed 1250/99992 users (1.3%) - Elapsed: 47.54s - Est. remaining: 93883.60s
# Processing batch 26: users 1251-1300 of 99992
# User 32632.0: 2422/24367 movies above threshold (9.94%)
# Processed 1300/99992 users (1.3%) - Elapsed: 49.44s - Est. remaining: 97594.24s
# Processing batch 27: users 1301-1350 of 99992
# User 20659.0: 370/24367 movies above threshold (1.52%)
# Processed 1350/99992 users (1.4%) - Elapsed: 51.30s - Est. remaining: 101198.49s
# Processing batch 28: users 1351-1400 of 99992
# User 65919.0: 1925/24367 movies above threshold (7.90%)
# Processed 1400/99992 users (1.4%) - Elapsed: 53.24s - Est. remaining: 104974.53s
# Processing batch 29: users 1401-1450 of 99992
# User 90080.0: 87/24367 movies above threshold (0.36%)
# Processed 1450/99992 users (1.5%) - Elapsed: 55.17s - Est. remaining: 108736.84s
# Processing batch 30: users 1451-1500 of 99992
# User 52810.0: 550/24367 movies above threshold (2.26%)
# Processed 1500/99992 users (1.5%) - Elapsed: 57.06s - Est. remaining: 112404.66s
# Processing batch 31: users 1501-1550 of 99992
# User 70502.0: 0/24367 movies above threshold (0.00%)
# Processed 1550/99992 users (1.6%) - Elapsed: 58.99s - Est. remaining: 116145.48s
# Processing batch 32: users 1551-1600 of 99992
# User 32758.0: 0/24367 movies above threshold (0.00%)
# Processed 1600/99992 users (1.6%) - Elapsed: 60.93s - Est. remaining: 119904.09s
# Processing batch 33: users 1601-1650 of 99992
# User 42722.0: 0/24367 movies above threshold (0.00%)
# Processed 1650/99992 users (1.7%) - Elapsed: 63.11s - Est. remaining: 124123.00s
# Processing batch 34: users 1651-1700 of 99992
# User 20246.0: 27/24367 movies above threshold (0.11%)
# Processed 1700/99992 users (1.7%) - Elapsed: 65.13s - Est. remaining: 128035.24s
# Processing batch 35: users 1701-1750 of 99992
# User 4877.0: 140/24367 movies above threshold (0.57%)
# Processed 1750/99992 users (1.8%) - Elapsed: 67.02s - Est. remaining: 131691.51s
# Processing batch 36: users 1751-1800 of 99992
# User 39625.0: 39/24367 movies above threshold (0.16%)
# Processed 1800/99992 users (1.8%) - Elapsed: 68.90s - Est. remaining: 135310.61s
# Processing batch 37: users 1801-1850 of 99992
# User 45669.0: 0/24367 movies above threshold (0.00%)
# Processed 1850/99992 users (1.9%) - Elapsed: 70.78s - Est. remaining: 138922.03s
# Processing batch 38: users 1851-1900 of 99992
# User 80612.0: 0/24367 movies above threshold (0.00%)
# Processed 1900/99992 users (1.9%) - Elapsed: 72.85s - Est. remaining: 142920.10s
# Processing batch 39: users 1901-1950 of 99992
# User 80942.0: 10/24367 movies above threshold (0.04%)
# Processed 1950/99992 users (2.0%) - Elapsed: 74.77s - Est. remaining: 146617.94s
# Processing batch 40: users 1951-2000 of 99992
# User 36112.0: 11/24367 movies above threshold (0.05%)
# Processed 2000/99992 users (2.0%) - Elapsed: 76.68s - Est. remaining: 150270.78s
# Processing batch 41: users 2001-2050 of 99992
# User 86952.0: 43/24367 movies above threshold (0.18%)
# Processed 2050/99992 users (2.1%) - Elapsed: 78.60s - Est. remaining: 153958.99s
# Processing batch 42: users 2051-2100 of 99992
# User 40266.0: 53/24367 movies above threshold (0.22%)
# Processed 2100/99992 users (2.1%) - Elapsed: 80.47s - Est. remaining: 157537.63s
# Processing batch 43: users 2101-2150 of 99992
# User 58650.0: 0/24367 movies above threshold (0.00%)
# Processed 2150/99992 users (2.2%) - Elapsed: 82.45s - Est. remaining: 161331.70s
# Processing batch 44: users 2151-2200 of 99992
# User 60373.0: 1289/24367 movies above threshold (5.29%)
# Processed 2200/99992 users (2.2%) - Elapsed: 84.32s - Est. remaining: 164920.36s
# Processing batch 45: users 2201-2250 of 99992
# User 68471.0: 236/24367 movies above threshold (0.97%)
# Processed 2250/99992 users (2.3%) - Elapsed: 86.22s - Est. remaining: 168542.41s
# Processing batch 46: users 2251-2300 of 99992
# User 22779.0: 139/24367 movies above threshold (0.57%)
# Processed 2300/99992 users (2.3%) - Elapsed: 88.22s - Est. remaining: 172365.83s
# Processing batch 47: users 2301-2350 of 99992
# User 68400.0: 53/24367 movies above threshold (0.22%)
# Processed 2350/99992 users (2.4%) - Elapsed: 90.16s - Est. remaining: 176058.30s
# Processing batch 48: users 2351-2400 of 99992
# User 51584.0: 16/24367 movies above threshold (0.07%)
# Processed 2400/99992 users (2.4%) - Elapsed: 92.03s - Est. remaining: 179633.69s
# Processing batch 49: users 2401-2450 of 99992
# User 16251.0: 140/24367 movies above threshold (0.57%)
# Processed 2450/99992 users (2.5%) - Elapsed: 93.89s - Est. remaining: 183170.22s
# Processing batch 50: users 2451-2500 of 99992
# User 73364.0: 869/24367 movies above threshold (3.57%)
# Processed 2500/99992 users (2.5%) - Elapsed: 95.77s - Est. remaining: 186732.27s
# Processing batch 51: users 2501-2550 of 99992
# User 67415.0: 35/24367 movies above threshold (0.14%)
# Processed 2550/99992 users (2.6%) - Elapsed: 97.69s - Est. remaining: 190391.91s
# Processing batch 52: users 2551-2600 of 99992
# User 43739.0: 0/24367 movies above threshold (0.00%)
# Processed 2600/99992 users (2.6%) - Elapsed: 99.59s - Est. remaining: 193981.48s
# Processing batch 53: users 2601-2650 of 99992
# User 33296.0: 104/24367 movies above threshold (0.43%)
# Processed 2650/99992 users (2.7%) - Elapsed: 101.50s - Est. remaining: 197595.38s
# Processing batch 54: users 2651-2700 of 99992
# User 94910.0: 0/24367 movies above threshold (0.00%)
# Processed 2700/99992 users (2.7%) - Elapsed: 103.42s - Est. remaining: 201237.68s
# Processing batch 55: users 2701-2750 of 99992
# User 92165.0: 1938/24367 movies above threshold (7.95%)
# Processed 2750/99992 users (2.8%) - Elapsed: 105.30s - Est. remaining: 204792.50s
# Processing batch 56: users 2751-2800 of 99992
# User 92142.0: 264/24367 movies above threshold (1.08%)
# Processed 2800/99992 users (2.8%) - Elapsed: 107.22s - Est. remaining: 208409.64s
# Processing batch 57: users 2801-2850 of 99992
# User 96208.0: 112/24367 movies above threshold (0.46%)
# Processed 2850/99992 users (2.9%) - Elapsed: 109.16s - Est. remaining: 212079.30s
# Processing batch 58: users 2851-2900 of 99992
# User 94628.0: 2990/24367 movies above threshold (12.27%)
# Processed 2900/99992 users (2.9%) - Elapsed: 111.03s - Est. remaining: 215607.21s
# Processing batch 59: users 2901-2950 of 99992
# User 17536.0: 1434/24367 movies above threshold (5.89%)
# Processed 2950/99992 users (3.0%) - Elapsed: 112.96s - Est. remaining: 219234.23s
# Processing batch 60: users 2951-3000 of 99992
# User 35460.0: 19/24367 movies above threshold (0.08%)
# Processed 3000/99992 users (3.0%) - Elapsed: 114.86s - Est. remaining: 222818.65s
# Processing batch 61: users 3001-3050 of 99992
# User 78825.0: 1548/24367 movies above threshold (6.35%)
# Processed 3050/99992 users (3.1%) - Elapsed: 116.82s - Est. remaining: 226494.21s
# Processing batch 62: users 3051-3100 of 99992
# User 63631.0: 13/24367 movies above threshold (0.05%)
# Processed 3100/99992 users (3.1%) - Elapsed: 118.70s - Est. remaining: 230018.59s
# Processing batch 63: users 3101-3150 of 99992
# User 78586.0: 535/24367 movies above threshold (2.20%)
# Processed 3150/99992 users (3.2%) - Elapsed: 120.56s - Est. remaining: 233508.21s
# Processing batch 64: users 3151-3200 of 99992
# User 88828.0: 2185/24367 movies above threshold (8.97%)
# Processed 3200/99992 users (3.2%) - Elapsed: 122.46s - Est. remaining: 237058.00s
# Processing batch 65: users 3201-3250 of 99992
# User 67845.0: 0/24367 movies above threshold (0.00%)
# Processed 3250/99992 users (3.3%) - Elapsed: 124.42s - Est. remaining: 240727.82s
# Processing batch 66: users 3251-3300 of 99992
# User 95339.0: 0/24367 movies above threshold (0.00%)
# Processed 3300/99992 users (3.3%) - Elapsed: 126.43s - Est. remaining: 244496.54s
# Processing batch 67: users 3301-3350 of 99992
# User 2138.0: 208/24367 movies above threshold (0.85%)
# Processed 3350/99992 users (3.4%) - Elapsed: 128.39s - Est. remaining: 248154.61s
# Processing batch 68: users 3351-3400 of 99992
# User 17540.0: 1359/24367 movies above threshold (5.58%)
# Processed 3400/99992 users (3.4%) - Elapsed: 130.37s - Est. remaining: 251857.05s
# Processing batch 69: users 3401-3450 of 99992
# User 97491.0: 0/24367 movies above threshold (0.00%)
# Processed 3450/99992 users (3.5%) - Elapsed: 132.31s - Est. remaining: 255478.30s
# Processing batch 70: users 3451-3500 of 99992
# User 39836.0: 48/24367 movies above threshold (0.20%)
# Processed 3500/99992 users (3.5%) - Elapsed: 134.21s - Est. remaining: 259006.88s
# Processing batch 71: users 3501-3550 of 99992
# User 87802.0: 191/24367 movies above threshold (0.78%)
# Processed 3550/99992 users (3.6%) - Elapsed: 136.14s - Est. remaining: 262597.26s
# Processing batch 72: users 3551-3600 of 99992
# User 99142.0: 137/24367 movies above threshold (0.56%)
# Processed 3600/99992 users (3.6%) - Elapsed: 138.01s - Est. remaining: 266056.53s
# Processing batch 73: users 3601-3650 of 99992
# User 51241.0: 159/24367 movies above threshold (0.65%)
# Processed 3650/99992 users (3.7%) - Elapsed: 140.10s - Est. remaining: 269955.25s
# Processing batch 74: users 3651-3700 of 99992
# User 88898.0: 221/24367 movies above threshold (0.91%)
# Processed 3700/99992 users (3.7%) - Elapsed: 142.16s - Est. remaining: 273786.22s
# Processing batch 75: users 3701-3750 of 99992
# User 14870.0: 47/24367 movies above threshold (0.19%)
# Processed 3750/99992 users (3.8%) - Elapsed: 144.30s - Est. remaining: 277761.28s
# Processing batch 76: users 3751-3800 of 99992
# User 33378.0: 0/24367 movies above threshold (0.00%)
# Processed 3800/99992 users (3.8%) - Elapsed: 146.35s - Est. remaining: 281551.23s
# Processing batch 77: users 3801-3850 of 99992
# User 6468.0: 202/24367 movies above threshold (0.83%)
# Processed 3850/99992 users (3.9%) - Elapsed: 148.32s - Est. remaining: 285190.94s
# Processing batch 78: users 3851-3900 of 99992
# User 11566.0: 46/24367 movies above threshold (0.19%)
# Processed 3900/99992 users (3.9%) - Elapsed: 150.24s - Est. remaining: 288744.08s
# Processing batch 79: users 3901-3950 of 99992
# User 46821.0: 116/24367 movies above threshold (0.48%)
# Processed 3950/99992 users (4.0%) - Elapsed: 152.25s - Est. remaining: 292455.06s
# Processing batch 80: users 3951-4000 of 99992
# User 93297.0: 382/24367 movies above threshold (1.57%)
# Processed 4000/99992 users (4.0%) - Elapsed: 154.63s - Est. remaining: 296860.12s
# Processing batch 81: users 4001-4050 of 99992
# User 89874.0: 10/24367 movies above threshold (0.04%)
# Processed 4050/99992 users (4.1%) - Elapsed: 156.59s - Est. remaining: 300472.17s
# Processing batch 82: users 4051-4100 of 99992
# User 43499.0: 468/24367 movies above threshold (1.92%)
# Processed 4100/99992 users (4.1%) - Elapsed: 158.48s - Est. remaining: 303938.37s
# Processing batch 83: users 4101-4150 of 99992
# User 39959.0: 0/24367 movies above threshold (0.00%)
# Processed 4150/99992 users (4.2%) - Elapsed: 160.45s - Est. remaining: 307554.14s
# Processing batch 84: users 4151-4200 of 99992
# User 46363.0: 45/24367 movies above threshold (0.18%)
# Processed 4200/99992 users (4.2%) - Elapsed: 162.56s - Est. remaining: 311440.13s
# Processing batch 85: users 4201-4250 of 99992
# User 76023.0: 998/24367 movies above threshold (4.10%)
# Processed 4250/99992 users (4.3%) - Elapsed: 164.47s - Est. remaining: 314936.82s
# Processing batch 86: users 4251-4300 of 99992
# User 2568.0: 0/24367 movies above threshold (0.00%)
# Processed 4300/99992 users (4.3%) - Elapsed: 166.33s - Est. remaining: 318322.52s
# Processing batch 87: users 4301-4350 of 99992
# User 36258.0: 24/24367 movies above threshold (0.10%)
# Processed 4350/99992 users (4.4%) - Elapsed: 168.27s - Est. remaining: 321872.83s
# Processing batch 88: users 4351-4400 of 99992
# User 6978.0: 36/24367 movies above threshold (0.15%)
# Processed 4400/99992 users (4.4%) - Elapsed: 170.28s - Est. remaining: 325545.67s
# Processing batch 89: users 4401-4450 of 99992
# User 94011.0: 8/24367 movies above threshold (0.03%)
# Processed 4450/99992 users (4.5%) - Elapsed: 172.18s - Est. remaining: 329013.63s
# Processing batch 90: users 4451-4500 of 99992
# User 2099.0: 1350/24367 movies above threshold (5.54%)
# Processed 4500/99992 users (4.5%) - Elapsed: 174.08s - Est. remaining: 332470.14s
# Processing batch 91: users 4501-4550 of 99992
# User 59917.0: 1174/24367 movies above threshold (4.82%)
# Processed 4550/99992 users (4.6%) - Elapsed: 175.96s - Est. remaining: 335884.67s
# Processing batch 92: users 4551-4600 of 99992
# User 56.0: 134/24367 movies above threshold (0.55%)
# Processed 4600/99992 users (4.6%) - Elapsed: 177.88s - Est. remaining: 339366.03s
# Processing batch 93: users 4601-4650 of 99992
# User 29132.0: 0/24367 movies above threshold (0.00%)
# Processed 4650/99992 users (4.7%) - Elapsed: 179.73s - Est. remaining: 342717.71s
# Processing batch 94: users 4651-4700 of 99992
# User 74449.0: 352/24367 movies above threshold (1.44%)
# Processed 4700/99992 users (4.7%) - Elapsed: 181.67s - Est. remaining: 346237.21s
# Processing batch 95: users 4701-4750 of 99992
# User 74206.0: 16/24367 movies above threshold (0.07%)
# Processed 4750/99992 users (4.8%) - Elapsed: 183.64s - Est. remaining: 349813.78s
# Processing batch 96: users 4751-4800 of 99992
# User 57451.0: 25/24367 movies above threshold (0.10%)
# Processed 4800/99992 users (4.8%) - Elapsed: 185.55s - Est. remaining: 353253.14s
# Processing batch 97: users 4801-4850 of 99992
# User 26316.0: 1835/24367 movies above threshold (7.53%)
# Processed 4850/99992 users (4.9%) - Elapsed: 187.46s - Est. remaining: 356707.72s
# Processing batch 98: users 4851-4900 of 99992
# User 60179.0: 13/24367 movies above threshold (0.05%)
# Processed 4900/99992 users (4.9%) - Elapsed: 189.40s - Est. remaining: 360213.62s
# Processing batch 99: users 4901-4950 of 99992
# User 29646.0: 95/24367 movies above threshold (0.39%)
# Processed 4950/99992 users (5.0%) - Elapsed: 191.25s - Est. remaining: 363542.67s
# Processing batch 100: users 4951-5000 of 99992
# User 92816.0: 25/24367 movies above threshold (0.10%)
# Processed 5000/99992 users (5.0%) - Elapsed: 193.13s - Est. remaining: 366911.71s
# Processing batch 101: users 5001-5050 of 99992
# User 35781.0: 2151/24367 movies above threshold (8.83%)
# Processed 5050/99992 users (5.1%) - Elapsed: 195.02s - Est. remaining: 370309.28s
# Processing batch 102: users 5051-5100 of 99992
# User 45241.0: 0/24367 movies above threshold (0.00%)
# Processed 5100/99992 users (5.1%) - Elapsed: 196.96s - Est. remaining: 373801.76s
# Processing batch 103: users 5101-5150 of 99992
# User 96447.0: 9/24367 movies above threshold (0.04%)
# Processed 5150/99992 users (5.2%) - Elapsed: 198.92s - Est. remaining: 377320.70s
# Processing batch 104: users 5151-5200 of 99992
# User 30600.0: 127/24367 movies above threshold (0.52%)
# Processed 5200/99992 users (5.2%) - Elapsed: 200.74s - Est. remaining: 380577.90s
# Processing batch 105: users 5201-5250 of 99992
# User 62419.0: 0/24367 movies above threshold (0.00%)
# Processed 5250/99992 users (5.3%) - Elapsed: 202.68s - Est. remaining: 384041.22s
# Processing batch 106: users 5251-5300 of 99992
# User 55035.0: 22/24367 movies above threshold (0.09%)
# Processed 5300/99992 users (5.3%) - Elapsed: 204.66s - Est. remaining: 387597.80s
# Processing batch 107: users 5301-5350 of 99992
# User 59806.0: 18/24367 movies above threshold (0.07%)
# Processed 5350/99992 users (5.4%) - Elapsed: 206.54s - Est. remaining: 390950.37s
# Processing batch 108: users 5351-5400 of 99992
# User 30124.0: 123/24367 movies above threshold (0.50%)
# Processed 5400/99992 users (5.4%) - Elapsed: 208.46s - Est. remaining: 394364.81s
# Processing batch 109: users 5401-5450 of 99992
# User 94854.0: 2/24367 movies above threshold (0.01%)
# Processed 5450/99992 users (5.5%) - Elapsed: 210.32s - Est. remaining: 397682.77s
# Processing batch 110: users 5451-5500 of 99992
# User 36471.0: 0/24367 movies above threshold (0.00%)
# Processed 5500/99992 users (5.5%) - Elapsed: 212.30s - Est. remaining: 401216.22s
# Processing batch 111: users 5501-5550 of 99992
# User 81538.0: 18/24367 movies above threshold (0.07%)
# Processed 5550/99992 users (5.6%) - Elapsed: 214.16s - Est. remaining: 404519.04s
# Processing batch 112: users 5551-5600 of 99992
# User 75469.0: 0/24367 movies above threshold (0.00%)
# Processed 5600/99992 users (5.6%) - Elapsed: 216.06s - Est. remaining: 407886.10s
# Processing batch 113: users 5601-5650 of 99992
# User 3091.0: 99/24367 movies above threshold (0.41%)
# Processed 5650/99992 users (5.7%) - Elapsed: 217.95s - Est. remaining: 411230.51s
# Processing batch 114: users 5651-5700 of 99992
# User 39558.0: 77/24367 movies above threshold (0.32%)
# Processed 5700/99992 users (5.7%) - Elapsed: 219.90s - Est. remaining: 414688.06s
# Processing batch 115: users 5701-5750 of 99992
# User 29595.0: 2/24367 movies above threshold (0.01%)
# Processed 5750/99992 users (5.8%) - Elapsed: 221.82s - Est. remaining: 418090.82s
# Processing batch 116: users 5751-5800 of 99992
# User 37762.0: 13/24367 movies above threshold (0.05%)
# Processed 5800/99992 users (5.8%) - Elapsed: 223.70s - Est. remaining: 421421.92s
# Processing batch 117: users 5801-5850 of 99992
# User 51616.0: 71/24367 movies above threshold (0.29%)
# Processed 5850/99992 users (5.9%) - Elapsed: 225.59s - Est. remaining: 424754.89s
# Processing batch 118: users 5851-5900 of 99992
# User 88633.0: 1156/24367 movies above threshold (4.74%)
# Processed 5900/99992 users (5.9%) - Elapsed: 227.63s - Est. remaining: 428366.37s
# Processing batch 119: users 5901-5950 of 99992
# User 7764.0: 244/24367 movies above threshold (1.00%)
# Processed 5950/99992 users (6.0%) - Elapsed: 229.59s - Est. remaining: 431813.89s
# Processing batch 120: users 5951-6000 of 99992
# User 93450.0: 855/24367 movies above threshold (3.51%)
# Processed 6000/99992 users (6.0%) - Elapsed: 231.52s - Est. remaining: 435225.55s
# Processing batch 121: users 6001-6050 of 99992
# User 28130.0: 0/24367 movies above threshold (0.00%)
# Processed 6050/99992 users (6.1%) - Elapsed: 233.44s - Est. remaining: 438597.64s
# Processing batch 122: users 6051-6100 of 99992
# User 17510.0: 18/24367 movies above threshold (0.07%)
# Processed 6100/99992 users (6.1%) - Elapsed: 235.39s - Est. remaining: 442029.74s
# Processing batch 123: users 6101-6150 of 99992
# User 70615.0: 203/24367 movies above threshold (0.83%)
# Processed 6150/99992 users (6.2%) - Elapsed: 237.32s - Est. remaining: 445416.64s
# Processing batch 124: users 6151-6200 of 99992
# User 65421.0: 232/24367 movies above threshold (0.95%)
# Processed 6200/99992 users (6.2%) - Elapsed: 239.25s - Est. remaining: 448795.93s
# Processing batch 125: users 6201-6250 of 99992
# User 15453.0: 75/24367 movies above threshold (0.31%)
# Processed 6250/99992 users (6.3%) - Elapsed: 241.17s - Est. remaining: 452161.99s
# Processing batch 126: users 6251-6300 of 99992
# User 20656.0: 0/24367 movies above threshold (0.00%)
# Processed 6300/99992 users (6.3%) - Elapsed: 243.03s - Est. remaining: 455393.04s
# Processing batch 127: users 6301-6350 of 99992
# User 77746.0: 0/24367 movies above threshold (0.00%)
# Processed 6350/99992 users (6.4%) - Elapsed: 244.91s - Est. remaining: 458674.69s
# Processing batch 128: users 6351-6400 of 99992
# User 43702.0: 154/24367 movies above threshold (0.63%)
# Processed 6400/99992 users (6.4%) - Elapsed: 246.86s - Est. remaining: 462089.23s
# Processing batch 129: users 6401-6450 of 99992
# User 49817.0: 1348/24367 movies above threshold (5.53%)
# Processed 6450/99992 users (6.5%) - Elapsed: 248.75s - Est. remaining: 465372.63s
# Processing batch 130: users 6451-6500 of 99992
# User 591.0: 114/24367 movies above threshold (0.47%)
# Processed 6500/99992 users (6.5%) - Elapsed: 250.62s - Est. remaining: 468622.35s
# Processing batch 131: users 6501-6550 of 99992
# User 73770.0: 6/24367 movies above threshold (0.02%)
# Processed 6550/99992 users (6.6%) - Elapsed: 252.54s - Est. remaining: 471955.70s
# Processing batch 132: users 6551-6600 of 99992
# User 35538.0: 1040/24367 movies above threshold (4.27%)
# Processed 6600/99992 users (6.6%) - Elapsed: 254.46s - Est. remaining: 475285.67s
# Processing batch 133: users 6601-6650 of 99992
# User 94204.0: 83/24367 movies above threshold (0.34%)
# Processed 6650/99992 users (6.7%) - Elapsed: 256.35s - Est. remaining: 478568.87s
# Processing batch 134: users 6651-6700 of 99992
# User 96647.0: 145/24367 movies above threshold (0.60%)
# Processed 6700/99992 users (6.7%) - Elapsed: 258.23s - Est. remaining: 481824.02s
# Processing batch 135: users 6701-6750 of 99992
# User 74730.0: 1771/24367 movies above threshold (7.27%)
# Processed 6750/99992 users (6.8%) - Elapsed: 260.18s - Est. remaining: 485191.03s
# Processing batch 136: users 6751-6800 of 99992
# User 64313.0: 0/24367 movies above threshold (0.00%)
# Processed 6800/99992 users (6.8%) - Elapsed: 262.12s - Est. remaining: 488541.11s
# Processing batch 137: users 6801-6850 of 99992
# User 1283.0: 572/24367 movies above threshold (2.35%)
# Processed 6850/99992 users (6.9%) - Elapsed: 264.02s - Est. remaining: 491833.28s
# Processing batch 138: users 6851-6900 of 99992
# User 42069.0: 69/24367 movies above threshold (0.28%)
# Processed 6900/99992 users (6.9%) - Elapsed: 265.93s - Est. remaining: 495115.23s
# Processing batch 139: users 6901-6950 of 99992
# User 7321.0: 0/24367 movies above threshold (0.00%)
# Processed 6950/99992 users (7.0%) - Elapsed: 267.86s - Est. remaining: 498441.81s
# Processing batch 140: users 6951-7000 of 99992
# User 39492.0: 2/24367 movies above threshold (0.01%)
# Processed 7000/99992 users (7.0%) - Elapsed: 269.76s - Est. remaining: 501716.94s
# Processing batch 141: users 7001-7050 of 99992
# User 13782.0: 61/24367 movies above threshold (0.25%)
# Processed 7050/99992 users (7.1%) - Elapsed: 271.71s - Est. remaining: 505071.91s
# Processing batch 142: users 7051-7100 of 99992
# User 92472.0: 222/24367 movies above threshold (0.91%)
# Processed 7100/99992 users (7.1%) - Elapsed: 273.59s - Est. remaining: 508285.50s
# Processing batch 143: users 7101-7150 of 99992
# User 94278.0: 1024/24367 movies above threshold (4.20%)
# Processed 7150/99992 users (7.2%) - Elapsed: 275.51s - Est. remaining: 511577.03s
# Processing batch 144: users 7151-7200 of 99992
# User 492.0: 18/24367 movies above threshold (0.07%)
# Processed 7200/99992 users (7.2%) - Elapsed: 277.48s - Est. remaining: 514960.16s
# Processing batch 145: users 7201-7250 of 99992
# User 83950.0: 325/24367 movies above threshold (1.33%)
# Processed 7250/99992 users (7.3%) - Elapsed: 279.45s - Est. remaining: 518338.66s
# Processing batch 146: users 7251-7300 of 99992
# User 55606.0: 1841/24367 movies above threshold (7.56%)
# Processed 7300/99992 users (7.3%) - Elapsed: 281.43s - Est. remaining: 521722.39s
# Processing batch 147: users 7301-7350 of 99992
# User 74688.0: 470/24367 movies above threshold (1.93%)
# Processed 7350/99992 users (7.4%) - Elapsed: 283.32s - Est. remaining: 524939.12s
# Processing batch 148: users 7351-7400 of 99992
# User 33087.0: 19/24367 movies above threshold (0.08%)
# Processed 7400/99992 users (7.4%) - Elapsed: 285.24s - Est. remaining: 528213.18s
# Processing batch 149: users 7401-7450 of 99992
# User 25205.0: 3/24367 movies above threshold (0.01%)
# Processed 7450/99992 users (7.5%) - Elapsed: 287.15s - Est. remaining: 531472.30s
# Processing batch 150: users 7451-7500 of 99992
# User 52931.0: 25/24367 movies above threshold (0.10%)
# Processed 7500/99992 users (7.5%) - Elapsed: 289.15s - Est. remaining: 534888.52s
# Processing batch 151: users 7501-7550 of 99992
# User 8083.0: 1429/24367 movies above threshold (5.86%)
# Processed 7550/99992 users (7.6%) - Elapsed: 291.03s - Est. remaining: 538075.18s
# Processing batch 152: users 7551-7600 of 99992
# User 67628.0: 2/24367 movies above threshold (0.01%)
# Processed 7600/99992 users (7.6%) - Elapsed: 292.92s - Est. remaining: 541269.17s
# Processing batch 153: users 7601-7650 of 99992
# User 2183.0: 14/24367 movies above threshold (0.06%)
# Processed 7650/99992 users (7.7%) - Elapsed: 294.84s - Est. remaining: 544520.33s
# Processing batch 154: users 7651-7700 of 99992
# User 11391.0: 262/24367 movies above threshold (1.08%)
# Processed 7700/99992 users (7.7%) - Elapsed: 296.75s - Est. remaining: 547758.42s
# Processing batch 155: users 7701-7750 of 99992
# User 98909.0: 1745/24367 movies above threshold (7.16%)
# Processed 7750/99992 users (7.8%) - Elapsed: 298.77s - Est. remaining: 551182.70s
# Processing batch 156: users 7751-7800 of 99992
# User 87899.0: 656/24367 movies above threshold (2.69%)
# Processed 7800/99992 users (7.8%) - Elapsed: 300.62s - Est. remaining: 554304.25s
# Processing batch 157: users 7801-7850 of 99992
# User 7469.0: 261/24367 movies above threshold (1.07%)
# Processed 7850/99992 users (7.9%) - Elapsed: 302.50s - Est. remaining: 557453.42s
# Processing batch 158: users 7851-7900 of 99992
# User 15343.0: 775/24367 movies above threshold (3.18%)
# Processed 7900/99992 users (7.9%) - Elapsed: 304.40s - Est. remaining: 560663.30s
# Processing batch 159: users 7901-7950 of 99992
# User 54994.0: 1686/24367 movies above threshold (6.92%)
# Processed 7950/99992 users (8.0%) - Elapsed: 306.33s - Est. remaining: 563909.87s
# Processing batch 160: users 7951-8000 of 99992
# User 77867.0: 31/24367 movies above threshold (0.13%)
# Processed 8000/99992 users (8.0%) - Elapsed: 308.21s - Est. remaining: 567051.40s
# Processing batch 161: users 8001-8050 of 99992
# User 37348.0: 146/24367 movies above threshold (0.60%)
# Processed 8050/99992 users (8.1%) - Elapsed: 310.28s - Est. remaining: 570564.29s
# Processing batch 162: users 8051-8100 of 99992
# User 69165.0: 3/24367 movies above threshold (0.01%)
# Processed 8100/99992 users (8.1%) - Elapsed: 312.50s - Est. remaining: 574329.50s
# Processing batch 163: users 8101-8150 of 99992
# User 15947.0: 71/24367 movies above threshold (0.29%)
# Processed 8150/99992 users (8.2%) - Elapsed: 314.41s - Est. remaining: 577512.50s
# Processing batch 164: users 8151-8200 of 99992
# User 69304.0: 2393/24367 movies above threshold (9.82%)
# Processed 8200/99992 users (8.2%) - Elapsed: 316.36s - Est. remaining: 580778.42s
# Processing batch 165: users 8201-8250 of 99992
# User 53830.0: 0/24367 movies above threshold (0.00%)
# Processed 8250/99992 users (8.3%) - Elapsed: 318.34s - Est. remaining: 584100.55s
# Processing batch 166: users 8251-8300 of 99992
# User 85509.0: 96/24367 movies above threshold (0.39%)
# Processed 8300/99992 users (8.3%) - Elapsed: 320.24s - Est. remaining: 587261.00s
# Processing batch 167: users 8301-8350 of 99992
# User 53602.0: 6/24367 movies above threshold (0.02%)
# Processed 8350/99992 users (8.4%) - Elapsed: 322.12s - Est. remaining: 590399.33s
# Processing batch 168: users 8351-8400 of 99992
# User 55034.0: 181/24367 movies above threshold (0.74%)
# Processed 8400/99992 users (8.4%) - Elapsed: 324.01s - Est. remaining: 593530.22s
# Processing batch 169: users 8401-8450 of 99992
# User 30628.0: 1293/24367 movies above threshold (5.31%)
# Processed 8450/99992 users (8.5%) - Elapsed: 325.88s - Est. remaining: 596626.21s
# Processing batch 170: users 8451-8500 of 99992
# User 72102.0: 1117/24367 movies above threshold (4.58%)
# Processed 8500/99992 users (8.5%) - Elapsed: 327.75s - Est. remaining: 599729.45s
# Processing batch 171: users 8501-8550 of 99992
# User 98019.0: 1032/24367 movies above threshold (4.24%)
# Processed 8550/99992 users (8.6%) - Elapsed: 329.63s - Est. remaining: 602843.58s
# Processing batch 172: users 8551-8600 of 99992
# User 4070.0: 47/24367 movies above threshold (0.19%)
# Processed 8600/99992 users (8.6%) - Elapsed: 331.56s - Est. remaining: 606036.19s
# Processing batch 173: users 8601-8650 of 99992
# User 5532.0: 11/24367 movies above threshold (0.05%)
# Processed 8650/99992 users (8.7%) - Elapsed: 333.37s - Est. remaining: 609020.34s
# Processing batch 174: users 8651-8700 of 99992
# User 70213.0: 0/24367 movies above threshold (0.00%)
# Processed 8700/99992 users (8.7%) - Elapsed: 335.27s - Est. remaining: 612154.23s
# Processing batch 175: users 8701-8750 of 99992
# User 80746.0: 0/24367 movies above threshold (0.00%)
# Processed 8750/99992 users (8.8%) - Elapsed: 337.16s - Est. remaining: 615255.89s
# Processing batch 176: users 8751-8800 of 99992
# User 64773.0: 0/24367 movies above threshold (0.00%)
# Processed 8800/99992 users (8.8%) - Elapsed: 339.05s - Est. remaining: 618367.61s
# Processing batch 177: users 8801-8850 of 99992
# User 58855.0: 67/24367 movies above threshold (0.27%)
# Processed 8850/99992 users (8.9%) - Elapsed: 340.88s - Est. remaining: 621369.82s
# Processing batch 178: users 8851-8900 of 99992
# User 69860.0: 65/24367 movies above threshold (0.27%)
# Processed 8900/99992 users (8.9%) - Elapsed: 342.73s - Est. remaining: 624395.70s
# Processing batch 179: users 8901-8950 of 99992
# User 18537.0: 667/24367 movies above threshold (2.74%)
# Processed 8950/99992 users (9.0%) - Elapsed: 344.61s - Est. remaining: 627470.68s
# Processing batch 180: users 8951-9000 of 99992
# User 64497.0: 3/24367 movies above threshold (0.01%)
# Processed 9000/99992 users (9.0%) - Elapsed: 346.61s - Est. remaining: 630770.06s
# Processing batch 181: users 9001-9050 of 99992
# User 2439.0: 36/24367 movies above threshold (0.15%)
# Processed 9050/99992 users (9.1%) - Elapsed: 348.84s - Est. remaining: 634479.46s
# Processing batch 182: users 9051-9100 of 99992
# User 59447.0: 245/24367 movies above threshold (1.01%)
# Processed 9100/99992 users (9.1%) - Elapsed: 350.75s - Est. remaining: 637609.97s
# Processing batch 183: users 9101-9150 of 99992
# User 62154.0: 56/24367 movies above threshold (0.23%)
# Processed 9150/99992 users (9.2%) - Elapsed: 352.60s - Est. remaining: 640622.18s
# Processing batch 184: users 9151-9200 of 99992
# User 33939.0: 166/24367 movies above threshold (0.68%)
# Processed 9200/99992 users (9.2%) - Elapsed: 354.46s - Est. remaining: 643647.03s
# Processing batch 185: users 9201-9250 of 99992
# User 89341.0: 499/24367 movies above threshold (2.05%)
# Processed 9250/99992 users (9.3%) - Elapsed: 356.29s - Est. remaining: 646611.91s
# Processing batch 186: users 9251-9300 of 99992
# User 70911.0: 7/24367 movies above threshold (0.03%)
# Processed 9300/99992 users (9.3%) - Elapsed: 358.22s - Est. remaining: 649756.32s
# Processing batch 187: users 9301-9350 of 99992
# User 51362.0: 103/24367 movies above threshold (0.42%)
# Processed 9350/99992 users (9.4%) - Elapsed: 360.07s - Est. remaining: 652746.41s
# Processing batch 188: users 9351-9400 of 99992
# User 40797.0: 73/24367 movies above threshold (0.30%)
# Processed 9400/99992 users (9.4%) - Elapsed: 361.93s - Est. remaining: 655752.74s
# Processing batch 189: users 9401-9450 of 99992
# User 75618.0: 1260/24367 movies above threshold (5.17%)
# Processed 9450/99992 users (9.5%) - Elapsed: 363.76s - Est. remaining: 658710.08s
# Processing batch 190: users 9451-9500 of 99992
# User 79340.0: 45/24367 movies above threshold (0.18%)
# Processed 9500/99992 users (9.5%) - Elapsed: 365.68s - Est. remaining: 661817.58s
# Processing batch 191: users 9501-9550 of 99992
# User 17030.0: 902/24367 movies above threshold (3.70%)
# Processed 9550/99992 users (9.6%) - Elapsed: 367.51s - Est. remaining: 664765.70s
# Processing batch 192: users 9551-9600 of 99992
# User 65313.0: 179/24367 movies above threshold (0.73%)
# Processed 9600/99992 users (9.6%) - Elapsed: 369.40s - Est. remaining: 667818.62s
# Processing batch 193: users 9601-9650 of 99992
# User 59500.0: 19/24367 movies above threshold (0.08%)
# Processed 9650/99992 users (9.7%) - Elapsed: 371.29s - Est. remaining: 670853.30s
# Processing batch 194: users 9651-9700 of 99992
# User 66901.0: 2461/24367 movies above threshold (10.10%)
# Processed 9700/99992 users (9.7%) - Elapsed: 373.19s - Est. remaining: 673927.55s
# Processing batch 195: users 9701-9750 of 99992
# User 24573.0: 995/24367 movies above threshold (4.08%)
# Processed 9750/99992 users (9.8%) - Elapsed: 375.03s - Est. remaining: 676864.43s
# Processing batch 196: users 9751-9800 of 99992
# User 89891.0: 496/24367 movies above threshold (2.04%)
# Processed 9800/99992 users (9.8%) - Elapsed: 376.95s - Est. remaining: 679965.39s
# Processing batch 197: users 9801-9850 of 99992
# User 15578.0: 0/24367 movies above threshold (0.00%)
# Processed 9850/99992 users (9.9%) - Elapsed: 378.78s - Est. remaining: 682875.01s
# Processing batch 198: users 9851-9900 of 99992
# User 26028.0: 471/24367 movies above threshold (1.93%)
# Processed 9900/99992 users (9.9%) - Elapsed: 380.62s - Est. remaining: 685809.81s
# Processing batch 199: users 9901-9950 of 99992
# User 76214.0: 0/24367 movies above threshold (0.00%)
# Processed 9950/99992 users (10.0%) - Elapsed: 382.46s - Est. remaining: 688755.42s
# Processing batch 200: users 9951-10000 of 99992
# User 50538.0: 107/24367 movies above threshold (0.44%)
# Processed 10000/99992 users (10.0%) - Elapsed: 384.35s - Est. remaining: 691767.37s
# Processing batch 201: users 10001-10050 of 99992
# User 1963.0: 561/24367 movies above threshold (2.30%)
# Processed 10050/99992 users (10.1%) - Elapsed: 386.37s - Est. remaining: 695023.87s
# Processing batch 202: users 10051-10100 of 99992
# User 33645.0: 282/24367 movies above threshold (1.16%)
# Processed 10100/99992 users (10.1%) - Elapsed: 388.47s - Est. remaining: 698405.76s
# Processing batch 203: users 10101-10150 of 99992
# User 1918.0: 38/24367 movies above threshold (0.16%)
# Processed 10150/99992 users (10.2%) - Elapsed: 390.64s - Est. remaining: 701911.19s
# Processing batch 204: users 10151-10200 of 99992
# User 82091.0: 637/24367 movies above threshold (2.61%)
# Processed 10200/99992 users (10.2%) - Elapsed: 392.59s - Est. remaining: 705029.62s
# Processing batch 205: users 10201-10250 of 99992
# User 39531.0: 952/24367 movies above threshold (3.91%)
# Processed 10250/99992 users (10.3%) - Elapsed: 394.46s - Est. remaining: 707988.00s
# Processing batch 206: users 10251-10300 of 99992
# User 29635.0: 0/24367 movies above threshold (0.00%)
# Processed 10300/99992 users (10.3%) - Elapsed: 396.29s - Est. remaining: 710872.67s
# Processing batch 207: users 10301-10350 of 99992
# User 55690.0: 3/24367 movies above threshold (0.01%)
# Processed 10350/99992 users (10.4%) - Elapsed: 398.18s - Est. remaining: 713873.81s
# Processing batch 208: users 10351-10400 of 99992
# User 16372.0: 10/24367 movies above threshold (0.04%)
# Processed 10400/99992 users (10.4%) - Elapsed: 400.04s - Est. remaining: 716810.24s
# Processing batch 209: users 10401-10450 of 99992
# User 58882.0: 2946/24367 movies above threshold (12.09%)
# Processed 10450/99992 users (10.5%) - Elapsed: 402.17s - Est. remaining: 720222.92s
# Processing batch 210: users 10451-10500 of 99992
# User 51822.0: 360/24367 movies above threshold (1.48%)
# Processed 10500/99992 users (10.5%) - Elapsed: 404.36s - Est. remaining: 723731.65s
# Processing batch 211: users 10501-10550 of 99992
# User 3870.0: 1288/24367 movies above threshold (5.29%)
# Processed 10550/99992 users (10.6%) - Elapsed: 406.21s - Est. remaining: 726642.01s
# Processing batch 212: users 10551-10600 of 99992
# User 24519.0: 0/24367 movies above threshold (0.00%)
# Processed 10600/99992 users (10.6%) - Elapsed: 408.11s - Est. remaining: 729641.63s
# Processing batch 213: users 10601-10650 of 99992
# User 96523.0: 936/24367 movies above threshold (3.84%)
# Processed 10650/99992 users (10.7%) - Elapsed: 410.02s - Est. remaining: 732632.08s
# Processing batch 214: users 10651-10700 of 99992
# User 79165.0: 642/24367 movies above threshold (2.63%)
# Processed 10700/99992 users (10.7%) - Elapsed: 411.96s - Est. remaining: 735690.16s
# Processing batch 215: users 10701-10750 of 99992
# User 51978.0: 3870/24367 movies above threshold (15.88%)
# Processed 10750/99992 users (10.8%) - Elapsed: 413.87s - Est. remaining: 738694.38s
# Processing batch 216: users 10751-10800 of 99992
# User 79397.0: 95/24367 movies above threshold (0.39%)
# Processed 10800/99992 users (10.8%) - Elapsed: 415.78s - Est. remaining: 741685.86s
# Processing batch 217: users 10801-10850 of 99992
# User 91899.0: 6/24367 movies above threshold (0.02%)
# Processed 10850/99992 users (10.9%) - Elapsed: 417.70s - Est. remaining: 744684.21s
# Processing batch 218: users 10851-10900 of 99992
# User 4318.0: 0/24367 movies above threshold (0.00%)
# Processed 10900/99992 users (10.9%) - Elapsed: 419.61s - Est. remaining: 747675.17s
# Processing batch 219: users 10901-10950 of 99992
# User 49632.0: 416/24367 movies above threshold (1.71%)
# Processed 10950/99992 users (11.0%) - Elapsed: 421.49s - Est. remaining: 750599.31s
# Processing batch 220: users 10951-11000 of 99992
# User 58406.0: 6/24367 movies above threshold (0.02%)
# Processed 11000/99992 users (11.0%) - Elapsed: 423.35s - Est. remaining: 753500.78s
# Processing batch 221: users 11001-11050 of 99992
# User 79873.0: 55/24367 movies above threshold (0.23%)
# Processed 11050/99992 users (11.1%) - Elapsed: 425.22s - Est. remaining: 756389.63s
# Processing batch 222: users 11051-11100 of 99992
# User 26650.0: 426/24367 movies above threshold (1.75%)
# Processed 11100/99992 users (11.1%) - Elapsed: 427.08s - Est. remaining: 759276.52s
# Processing batch 223: users 11101-11150 of 99992
# User 49307.0: 204/24367 movies above threshold (0.84%)
# Processed 11150/99992 users (11.2%) - Elapsed: 429.05s - Est. remaining: 762351.59s
# Processing batch 224: users 11151-11200 of 99992
# User 955.0: 0/24367 movies above threshold (0.00%)
# Processed 11200/99992 users (11.2%) - Elapsed: 430.88s - Est. remaining: 765165.22s
# Processing batch 225: users 11201-11250 of 99992
# User 38856.0: 41/24367 movies above threshold (0.17%)
# Processed 11250/99992 users (11.3%) - Elapsed: 432.75s - Est. remaining: 768062.17s
# Processing batch 226: users 11251-11300 of 99992
# User 51221.0: 12/24367 movies above threshold (0.05%)
# Processed 11300/99992 users (11.3%) - Elapsed: 434.63s - Est. remaining: 770971.27s
# Processing batch 227: users 11301-11350 of 99992
# User 21206.0: 353/24367 movies above threshold (1.45%)
# Processed 11350/99992 users (11.4%) - Elapsed: 436.56s - Est. remaining: 773947.58s
# Processing batch 228: users 11351-11400 of 99992
# User 52573.0: 78/24367 movies above threshold (0.32%)
# Processed 11400/99992 users (11.4%) - Elapsed: 438.54s - Est. remaining: 777019.26s
# Processing batch 229: users 11401-11450 of 99992
# User 6912.0: 660/24367 movies above threshold (2.71%)
# Processed 11450/99992 users (11.5%) - Elapsed: 440.38s - Est. remaining: 779846.58s
# Processing batch 230: users 11451-11500 of 99992
# User 65097.0: 12/24367 movies above threshold (0.05%)
# Processed 11500/99992 users (11.5%) - Elapsed: 442.22s - Est. remaining: 782655.61s
# Processing batch 231: users 11501-11550 of 99992
# User 33889.0: 3227/24367 movies above threshold (13.24%)
# Processed 11550/99992 users (11.6%) - Elapsed: 444.16s - Est. remaining: 785648.48s
# Processing batch 232: users 11551-11600 of 99992
# User 14812.0: 332/24367 movies above threshold (1.36%)
# Processed 11600/99992 users (11.6%) - Elapsed: 446.03s - Est. remaining: 788501.33s
# Processing batch 233: users 11601-11650 of 99992
# User 48633.0: 75/24367 movies above threshold (0.31%)
# Processed 11650/99992 users (11.7%) - Elapsed: 447.94s - Est. remaining: 791431.74s
# Processing batch 234: users 11651-11700 of 99992
# User 72005.0: 143/24367 movies above threshold (0.59%)
# Processed 11700/99992 users (11.7%) - Elapsed: 449.85s - Est. remaining: 794354.78s
# Processing batch 235: users 11701-11750 of 99992
# User 78839.0: 0/24367 movies above threshold (0.00%)
# Processed 11750/99992 users (11.8%) - Elapsed: 451.74s - Est. remaining: 797251.07s
# Processing batch 236: users 11751-11800 of 99992
# User 79389.0: 28/24367 movies above threshold (0.11%)
# Processed 11800/99992 users (11.8%) - Elapsed: 453.56s - Est. remaining: 799998.93s
# Processing batch 237: users 11801-11850 of 99992
# User 9964.0: 170/24367 movies above threshold (0.70%)
# Processed 11850/99992 users (11.9%) - Elapsed: 455.43s - Est. remaining: 802841.88s
# Processing batch 238: users 11851-11900 of 99992
# User 72992.0: 276/24367 movies above threshold (1.13%)
# Processed 11900/99992 users (11.9%) - Elapsed: 457.34s - Est. remaining: 805751.57s
# Processing batch 239: users 11901-11950 of 99992
# User 27544.0: 300/24367 movies above threshold (1.23%)
# Processed 11950/99992 users (12.0%) - Elapsed: 459.17s - Est. remaining: 808528.89s
# Processing batch 240: users 11951-12000 of 99992
# User 93018.0: 269/24367 movies above threshold (1.10%)
# Processed 12000/99992 users (12.0%) - Elapsed: 461.08s - Est. remaining: 811426.19s
# Processing batch 241: users 12001-12050 of 99992
# User 61647.0: 0/24367 movies above threshold (0.00%)
# Processed 12050/99992 users (12.1%) - Elapsed: 462.95s - Est. remaining: 814247.10s
# Processing batch 242: users 12051-12100 of 99992
# User 77018.0: 2055/24367 movies above threshold (8.43%)
# Processed 12100/99992 users (12.1%) - Elapsed: 464.82s - Est. remaining: 817074.83s
# Processing batch 243: users 12101-12150 of 99992
# User 89626.0: 0/24367 movies above threshold (0.00%)
# Processed 12150/99992 users (12.2%) - Elapsed: 466.66s - Est. remaining: 819847.86s
# Processing batch 244: users 12151-12200 of 99992
# User 63298.0: 0/24367 movies above threshold (0.00%)
# Processed 12200/99992 users (12.2%) - Elapsed: 468.56s - Est. remaining: 822724.31s
# Processing batch 245: users 12201-12250 of 99992
# User 22803.0: 106/24367 movies above threshold (0.44%)
# Processed 12250/99992 users (12.3%) - Elapsed: 470.48s - Est. remaining: 825614.51s
# Processing batch 246: users 12251-12300 of 99992
# User 4072.0: 317/24367 movies above threshold (1.30%)
# Processed 12300/99992 users (12.3%) - Elapsed: 472.32s - Est. remaining: 828372.84s
# Processing batch 247: users 12301-12350 of 99992
# User 10822.0: 52/24367 movies above threshold (0.21%)
# Processed 12350/99992 users (12.4%) - Elapsed: 474.48s - Est. remaining: 831695.42s
# Processing batch 248: users 12351-12400 of 99992
# User 91185.0: 0/24367 movies above threshold (0.00%)
# Processed 12400/99992 users (12.4%) - Elapsed: 476.40s - Est. remaining: 834582.71s
# Processing batch 249: users 12401-12450 of 99992
# User 44229.0: 279/24367 movies above threshold (1.14%)
# Processed 12450/99992 users (12.5%) - Elapsed: 478.63s - Est. remaining: 838005.42s
# Processing batch 250: users 12451-12500 of 99992
# User 21672.0: 0/24367 movies above threshold (0.00%)
# Processed 12500/99992 users (12.5%) - Elapsed: 480.74s - Est. remaining: 841217.20s
# Processing batch 251: users 12501-12550 of 99992
# User 48930.0: 92/24367 movies above threshold (0.38%)
# Processed 12550/99992 users (12.6%) - Elapsed: 482.75s - Est. remaining: 844255.12s
# Processing batch 252: users 12551-12600 of 99992
# User 96778.0: 30/24367 movies above threshold (0.12%)
# Processed 12600/99992 users (12.6%) - Elapsed: 484.89s - Est. remaining: 847509.24s
# Processing batch 253: users 12601-12650 of 99992
# User 5995.0: 122/24367 movies above threshold (0.50%)
# Processed 12650/99992 users (12.7%) - Elapsed: 486.82s - Est. remaining: 850395.75s
# Processing batch 254: users 12651-12700 of 99992
# User 3.0: 392/24367 movies above threshold (1.61%)
# Processed 12700/99992 users (12.7%) - Elapsed: 488.67s - Est. remaining: 853135.24s
# Processing batch 255: users 12701-12750 of 99992
# User 19092.0: 295/24367 movies above threshold (1.21%)
# Processed 12750/99992 users (12.8%) - Elapsed: 490.53s - Est. remaining: 855904.18s
# Processing batch 256: users 12751-12800 of 99992
# User 79433.0: 154/24367 movies above threshold (0.63%)
# Processed 12800/99992 users (12.8%) - Elapsed: 492.37s - Est. remaining: 858618.82s
# Processing batch 257: users 12801-12850 of 99992
# User 43294.0: 239/24367 movies above threshold (0.98%)
# Processed 12850/99992 users (12.9%) - Elapsed: 494.23s - Est. remaining: 861369.87s
# Processing batch 258: users 12851-12900 of 99992
# User 63154.0: 0/24367 movies above threshold (0.00%)
# Processed 12900/99992 users (12.9%) - Elapsed: 496.08s - Est. remaining: 864096.29s
# Processing batch 259: users 12901-12950 of 99992
# User 99620.0: 701/24367 movies above threshold (2.88%)
# Processed 12950/99992 users (13.0%) - Elapsed: 497.96s - Est. remaining: 866864.28s
# Processing batch 260: users 12951-13000 of 99992
# User 3927.0: 439/24367 movies above threshold (1.80%)
# Processed 13000/99992 users (13.0%) - Elapsed: 499.76s - Est. remaining: 869506.73s
# Processing batch 261: users 13001-13050 of 99992
# ...
# Processing batch 1922: users 96051-96100 of 99992
# User 83644.0: 29/24367 movies above threshold (0.12%)
# Processed 96100/99992 users (96.1%) - Elapsed: 3807.90s - Est. remaining: 296406.72s
# Processing batch 1923: users 96101-96150 of 99992
# User 57664.0: 9/24367 movies above threshold (0.04%)
# Processed 96150/99992 users (96.2%) - Elapsed: 3810.05s - Est. remaining: 292764.19s
# Processing batch 1924: users 96151-96200 of 99992
# User 13919.0: 37/24367 movies above threshold (0.15%)
# Processed 96200/99992 users (96.2%) - Elapsed: 3812.11s - Est. remaining: 289110.14s
# Processing batch 1925: users 96201-96250 of 99992
# User 92245.0: 42/24367 movies above threshold (0.17%)
# Processed 96250/99992 users (96.3%) - Elapsed: 3814.46s - Est. remaining: 285474.28s
# Processing batch 1926: users 96251-96300 of 99992
# User 15828.0: 273/24367 movies above threshold (1.12%)
# Processed 96300/99992 users (96.3%) - Elapsed: 3816.51s - Est. remaining: 281810.75s
# Processing batch 1927: users 96301-96350 of 99992
# User 22394.0: 34/24367 movies above threshold (0.14%)
# Processed 96350/99992 users (96.4%) - Elapsed: 3818.71s - Est. remaining: 278154.93s
# Processing batch 1928: users 96351-96400 of 99992
# User 22020.0: 28/24367 movies above threshold (0.11%)
# Processed 96400/99992 users (96.4%) - Elapsed: 3820.78s - Est. remaining: 274484.71s
# Processing batch 1929: users 96401-96450 of 99992
# User 14548.0: 931/24367 movies above threshold (3.82%)
# Processed 96450/99992 users (96.5%) - Elapsed: 3822.83s - Est. remaining: 270808.94s
# Processing batch 1930: users 96451-96500 of 99992
# User 2674.0: 2/24367 movies above threshold (0.01%)
# Processed 96500/99992 users (96.5%) - Elapsed: 3824.84s - Est. remaining: 267126.70s
# Processing batch 1931: users 96501-96550 of 99992
# User 66269.0: 261/24367 movies above threshold (1.07%)
# Processed 96550/99992 users (96.6%) - Elapsed: 3826.84s - Est. remaining: 263439.76s
# Processing batch 1932: users 96551-96600 of 99992
# User 31168.0: 25/24367 movies above threshold (0.10%)
# Processed 96600/99992 users (96.6%) - Elapsed: 3828.82s - Est. remaining: 259747.45s
# Processing batch 1933: users 96601-96650 of 99992
# User 55062.0: 15/24367 movies above threshold (0.06%)
# Processed 96650/99992 users (96.7%) - Elapsed: 3830.86s - Est. remaining: 256054.98s
# Processing batch 1934: users 96651-96700 of 99992
# User 74883.0: 0/24367 movies above threshold (0.00%)
# Processed 96700/99992 users (96.7%) - Elapsed: 3832.89s - Est. remaining: 252357.37s
# Processing batch 1935: users 96701-96750 of 99992
# User 57115.0: 8/24367 movies above threshold (0.03%)
# Processed 96750/99992 users (96.8%) - Elapsed: 3835.04s - Est. remaining: 248664.22s
# Processing batch 1936: users 96751-96800 of 99992
# User 37480.0: 9/24367 movies above threshold (0.04%)
# Processed 96800/99992 users (96.8%) - Elapsed: 3837.23s - Est. remaining: 244968.59s
# Processing batch 1937: users 96801-96850 of 99992
# User 42316.0: 60/24367 movies above threshold (0.25%)
# Processed 96850/99992 users (96.9%) - Elapsed: 3839.51s - Est. remaining: 241274.76s
# Processing batch 1938: users 96851-96900 of 99992
# User 54482.0: 0/24367 movies above threshold (0.00%)
# Processed 96900/99992 users (96.9%) - Elapsed: 3841.80s - Est. remaining: 237576.87s
# Processing batch 1939: users 96901-96950 of 99992
# User 96595.0: 47/24367 movies above threshold (0.19%)
# Processed 96950/99992 users (97.0%) - Elapsed: 3844.00s - Est. remaining: 233868.73s
# Processing batch 1940: users 96951-97000 of 99992
# User 16727.0: 1/24367 movies above threshold (0.00%)
# Processed 97000/99992 users (97.0%) - Elapsed: 3846.55s - Est. remaining: 230177.51s
# Processing batch 1941: users 97001-97050 of 99992
# User 68327.0: 42/24367 movies above threshold (0.17%)
# Processed 97050/99992 users (97.1%) - Elapsed: 3849.04s - Est. remaining: 226477.53s
# Processing batch 1942: users 97051-97100 of 99992
# User 14894.0: 0/24367 movies above threshold (0.00%)
# Processed 97100/99992 users (97.1%) - Elapsed: 3851.38s - Est. remaining: 222763.66s
# Processing batch 1943: users 97101-97150 of 99992
# User 84076.0: 15/24367 movies above threshold (0.06%)
# Processed 97150/99992 users (97.2%) - Elapsed: 3853.42s - Est. remaining: 219028.58s
# Processing batch 1944: users 97151-97200 of 99992
# User 16327.0: 20/24367 movies above threshold (0.08%)
# Processed 97200/99992 users (97.2%) - Elapsed: 3855.43s - Est. remaining: 215287.00s
# Processing batch 1945: users 97201-97250 of 99992
# User 67940.0: 15/24367 movies above threshold (0.06%)
# Processed 97250/99992 users (97.3%) - Elapsed: 3857.40s - Est. remaining: 211540.05s
# Processing batch 1946: users 97251-97300 of 99992
# User 22098.0: 4/24367 movies above threshold (0.02%)
# Processed 97300/99992 users (97.3%) - Elapsed: 3859.39s - Est. remaining: 207789.30s
# Processing batch 1947: users 97301-97350 of 99992
# User 7385.0: 58/24367 movies above threshold (0.24%)
# Processed 97350/99992 users (97.4%) - Elapsed: 3861.41s - Est. remaining: 204036.76s
# Processing batch 1948: users 97351-97400 of 99992
# User 29442.0: 1/24367 movies above threshold (0.00%)
# Processed 97400/99992 users (97.4%) - Elapsed: 3863.43s - Est. remaining: 200280.43s
# Processing batch 1949: users 97401-97450 of 99992
# User 8766.0: 73/24367 movies above threshold (0.30%)
# Processed 97450/99992 users (97.5%) - Elapsed: 3865.36s - Est. remaining: 196514.77s
# Processing batch 1950: users 97451-97500 of 99992
# User 50344.0: 0/24367 movies above threshold (0.00%)
# Processed 97500/99992 users (97.5%) - Elapsed: 3867.34s - Est. remaining: 192748.29s
# Processing batch 1951: users 97501-97550 of 99992
# User 83763.0: 11/24367 movies above threshold (0.05%)
# Processed 97550/99992 users (97.6%) - Elapsed: 3869.33s - Est. remaining: 188978.05s
# Processing batch 1952: users 97551-97600 of 99992
# User 83865.0: 1/24367 movies above threshold (0.00%)
# Processed 97600/99992 users (97.6%) - Elapsed: 3871.39s - Est. remaining: 185207.08s
# Processing batch 1953: users 97601-97650 of 99992
# User 31779.0: 1164/24367 movies above threshold (4.78%)
# Processed 97650/99992 users (97.7%) - Elapsed: 3873.37s - Est. remaining: 181428.48s
# Processing batch 1954: users 97651-97700 of 99992
# User 76174.0: 42/24367 movies above threshold (0.17%)
# Processed 97700/99992 users (97.7%) - Elapsed: 3875.31s - Est. remaining: 177644.41s
# Processing batch 1955: users 97701-97750 of 99992
# User 17033.0: 2631/24367 movies above threshold (10.80%)
# Processed 97750/99992 users (97.8%) - Elapsed: 3877.32s - Est. remaining: 173858.82s
# Processing batch 1956: users 97751-97800 of 99992
# User 51112.0: 67/24367 movies above threshold (0.27%)
# Processed 97800/99992 users (97.8%) - Elapsed: 3879.51s - Est. remaining: 170077.86s
# Processing batch 1957: users 97801-97850 of 99992
# User 54372.0: 313/24367 movies above threshold (1.28%)
# Processed 97850/99992 users (97.9%) - Elapsed: 3881.70s - Est. remaining: 166292.04s
# Processing batch 1958: users 97851-97900 of 99992
# User 87777.0: 1/24367 movies above threshold (0.00%)
# Processed 97900/99992 users (97.9%) - Elapsed: 3883.76s - Est. remaining: 162496.41s
# Processing batch 1959: users 97901-97950 of 99992
# User 3627.0: 148/24367 movies above threshold (0.61%)
# Processed 97950/99992 users (98.0%) - Elapsed: 3886.09s - Est. remaining: 158707.85s
# Processing batch 1960: users 97951-98000 of 99992
# User 94917.0: 64/24367 movies above threshold (0.26%)
# Processed 98000/99992 users (98.0%) - Elapsed: 3888.55s - Est. remaining: 154919.84s
# Processing batch 1961: users 98001-98050 of 99992
# User 80050.0: 4/24367 movies above threshold (0.02%)
# Processed 98050/99992 users (98.1%) - Elapsed: 3890.93s - Est. remaining: 151123.73s
# Processing batch 1962: users 98051-98100 of 99992
# User 87339.0: 4/24367 movies above threshold (0.02%)
# Processed 98100/99992 users (98.1%) - Elapsed: 3893.26s - Est. remaining: 147321.15s
# Processing batch 1963: users 98101-98150 of 99992
# User 67049.0: 0/24367 movies above threshold (0.00%)
# Processed 98150/99992 users (98.2%) - Elapsed: 3895.64s - Est. remaining: 143515.49s
# Processing batch 1964: users 98151-98200 of 99992
# User 16758.0: 2/24367 movies above threshold (0.01%)
# Processed 98200/99992 users (98.2%) - Elapsed: 3897.97s - Est. remaining: 139703.14s
# Processing batch 1965: users 98201-98250 of 99992
# User 68316.0: 18/24367 movies above threshold (0.07%)
# Processed 98250/99992 users (98.3%) - Elapsed: 3900.45s - Est. remaining: 135891.82s
# Processing batch 1966: users 98251-98300 of 99992
# User 58631.0: 0/24367 movies above threshold (0.00%)
# Processed 98300/99992 users (98.3%) - Elapsed: 3902.56s - Est. remaining: 132062.56s
# Processing batch 1967: users 98301-98350 of 99992
# User 93888.0: 2878/24367 movies above threshold (11.81%)
# Processed 98350/99992 users (98.4%) - Elapsed: 3904.55s - Est. remaining: 128225.32s
# Processing batch 1968: users 98351-98400 of 99992
# User 31816.0: 24/24367 movies above threshold (0.10%)
# Processed 98400/99992 users (98.4%) - Elapsed: 3906.58s - Est. remaining: 124385.47s
# Processing batch 1969: users 98401-98450 of 99992
# User 9915.0: 29/24367 movies above threshold (0.12%)
# Processed 98450/99992 users (98.5%) - Elapsed: 3908.89s - Est. remaining: 120550.15s
# Processing batch 1970: users 98451-98500 of 99992
# User 47906.0: 0/24367 movies above threshold (0.00%)
# Processed 98500/99992 users (98.5%) - Elapsed: 3911.47s - Est. remaining: 116718.13s
# Processing batch 1971: users 98501-98550 of 99992
# User 8348.0: 60/24367 movies above threshold (0.25%)
# Processed 98550/99992 users (98.6%) - Elapsed: 3913.91s - Est. remaining: 112877.10s
# Processing batch 1972: users 98551-98600 of 99992
# User 95838.0: 0/24367 movies above threshold (0.00%)
# Processed 98600/99992 users (98.6%) - Elapsed: 3916.30s - Est. remaining: 109029.68s
# Processing batch 1973: users 98601-98650 of 99992
# User 32799.0: 12/24367 movies above threshold (0.05%)
# Processed 98650/99992 users (98.7%) - Elapsed: 3918.69s - Est. remaining: 105177.53s
# Processing batch 1974: users 98651-98700 of 99992
# User 1156.0: 31/24367 movies above threshold (0.13%)
# Processed 98700/99992 users (98.7%) - Elapsed: 3921.12s - Est. remaining: 101321.77s
# Processing batch 1975: users 98701-98750 of 99992
# User 67316.0: 41/24367 movies above threshold (0.17%)
# Processed 98750/99992 users (98.8%) - Elapsed: 3923.26s - Est. remaining: 97453.80s
# Processing batch 1976: users 98751-98800 of 99992
# User 27711.0: 46/24367 movies above threshold (0.19%)
# Processed 98800/99992 users (98.8%) - Elapsed: 3925.32s - Est. remaining: 93579.56s
# Processing batch 1977: users 98801-98850 of 99992
# User 18106.0: 13/24367 movies above threshold (0.05%)
# Processed 98850/99992 users (98.9%) - Elapsed: 3927.27s - Est. remaining: 89698.82s
# Processing batch 1978: users 98851-98900 of 99992
# User 43593.0: 30/24367 movies above threshold (0.12%)
# Processed 98900/99992 users (98.9%) - Elapsed: 3929.29s - Est. remaining: 85815.63s
# Processing batch 1979: users 98901-98950 of 99992
# User 73724.0: 4/24367 movies above threshold (0.02%)
# Processed 98950/99992 users (99.0%) - Elapsed: 3931.29s - Est. remaining: 81928.00s
# Processing batch 1980: users 98951-99000 of 99992
# User 44158.0: 13/24367 movies above threshold (0.05%)
# Processed 99000/99992 users (99.0%) - Elapsed: 3933.33s - Est. remaining: 78037.25s
# Processing batch 1981: users 99001-99050 of 99992
# User 51938.0: 294/24367 movies above threshold (1.21%)
# Processed 99050/99992 users (99.1%) - Elapsed: 3935.32s - Est. remaining: 74141.34s
# Processing batch 1982: users 99051-99100 of 99992
# User 30433.0: 102/24367 movies above threshold (0.42%)
# Processed 99100/99992 users (99.1%) - Elapsed: 3937.21s - Est. remaining: 70239.76s
# Processing batch 1983: users 99101-99150 of 99992
# User 78510.0: 382/24367 movies above threshold (1.57%)
# Processed 99150/99992 users (99.2%) - Elapsed: 3939.12s - Est. remaining: 66334.73s
# Processing batch 1984: users 99151-99200 of 99992
# User 19340.0: 0/24367 movies above threshold (0.00%)
# Processed 99200/99992 users (99.2%) - Elapsed: 3941.26s - Est. remaining: 62429.57s
# Processing batch 1985: users 99201-99250 of 99992
# User 15340.0: 0/24367 movies above threshold (0.00%)
# Processed 99250/99992 users (99.3%) - Elapsed: 3943.66s - Est. remaining: 58523.93s
# Processing batch 1986: users 99251-99300 of 99992
# User 60443.0: 48/24367 movies above threshold (0.20%)
# Processed 99300/99992 users (99.3%) - Elapsed: 3946.40s - Est. remaining: 54618.16s
# Processing batch 1987: users 99301-99350 of 99992
# User 83220.0: 0/24367 movies above threshold (0.00%)
# Processed 99350/99992 users (99.4%) - Elapsed: 3948.82s - Est. remaining: 50702.86s
# Processing batch 1988: users 99351-99400 of 99992
# User 93927.0: 6/24367 movies above threshold (0.02%)
# Processed 99400/99992 users (99.4%) - Elapsed: 3951.24s - Est. remaining: 46782.74s
# Processing batch 1989: users 99401-99450 of 99992
# User 15834.0: 0/24367 movies above threshold (0.00%)
# Processed 99450/99992 users (99.5%) - Elapsed: 3953.66s - Est. remaining: 42857.64s
# Processing batch 1990: users 99451-99500 of 99992
# User 56045.0: 17/24367 movies above threshold (0.07%)
# Processed 99500/99992 users (99.5%) - Elapsed: 3955.83s - Est. remaining: 38925.34s
# Processing batch 1991: users 99501-99550 of 99992
# User 58979.0: 0/24367 movies above threshold (0.00%)
# Processed 99550/99992 users (99.6%) - Elapsed: 3958.30s - Est. remaining: 34991.37s
# Processing batch 1992: users 99551-99600 of 99992
# User 34522.0: 447/24367 movies above threshold (1.83%)
# Processed 99600/99992 users (99.6%) - Elapsed: 3960.67s - Est. remaining: 31051.66s
# Processing batch 1993: users 99601-99650 of 99992
# User 22049.0: 0/24367 movies above threshold (0.00%)
# Processed 99650/99992 users (99.7%) - Elapsed: 3962.56s - Est. remaining: 27103.92s
# Processing batch 1994: users 99651-99700 of 99992
# User 74141.0: 16/24367 movies above threshold (0.07%)
# Processed 99700/99992 users (99.7%) - Elapsed: 3964.43s - Est. remaining: 23152.24s
# Processing batch 1995: users 99701-99750 of 99992
# User 11667.0: 47/24367 movies above threshold (0.19%)
# Processed 99750/99992 users (99.8%) - Elapsed: 3966.62s - Est. remaining: 19198.43s
# Processing batch 1996: users 99751-99800 of 99992
# User 86098.0: 721/24367 movies above threshold (2.96%)
# Processed 99800/99992 users (99.8%) - Elapsed: 3969.17s - Est. remaining: 15241.62s
# Processing batch 1997: users 99801-99850 of 99992
# User 71094.0: 39/24367 movies above threshold (0.16%)
# Processed 99850/99992 users (99.9%) - Elapsed: 3971.30s - Est. remaining: 11278.50s
# Processing batch 1998: users 99851-99900 of 99992
# User 36878.0: 473/24367 movies above threshold (1.94%)
# Processed 99900/99992 users (99.9%) - Elapsed: 3973.73s - Est. remaining: 7311.66s
# Processing batch 1999: users 99901-99950 of 99992
# User 58112.0: 14/24367 movies above threshold (0.06%)
# Processed 99950/99992 users (100.0%) - Elapsed: 3976.00s - Est. remaining: 3339.84s
# Processing batch 2000: users 99951-99992 of 99992
# User 22349.0: 10/24367 movies above threshold (0.04%)
# Processed 99992/99992 users (100.0%) - Elapsed: 3977.95s - Est. remaining: 0.00s
#
# Similarity calculation complete:
# Total users processed: 99992
# Total movies per user: 24367
# Average movies above threshold per user: 268.26
#
# Sample user-movie similarities:
# User ID: 969.0
# Number of movies above threshold: 480
# Top 5 most similar movies:
#   'Snow Falling on Cedars (1999)' (ID: 3185): 0.7786
#   'Cube Zero (2004)' (ID: 32213): 0.7774
#   'Children of the Corn II: The Final Sacrifice (1993)' (ID: 2515): 0.7761
#   'Reflecting Skin, The (1990)' (ID: 26702): 0.7725
#   'Very Bad Things (1998)' (ID: 2387): 0.7691
# ---
# User ID: 10393.0
# Number of movies above threshold: 0
# ---
# User ID: 62515.0
# Number of movies above threshold: 2133
# Top 5 most similar movies:
#   'Sex and the City 2 (2010)' (ID: 78174): 0.8004
#   'Witches, The (Le streghe) (1967)' (ID: 89620): 0.7903
#   'A Year Along the Abandoned Road' (ID: 127005): 0.7892
#   'Chain Reaction (2006)' (ID: 69339): 0.7885
#   'Splitting Heirs (1993)' (ID: 26841): 0.7881
# ---
# Calculated and saved similarities for 99992 users
#
# Similarity statistics:
# Average number of similar movies per user: 268.26
# Min: 0, Max: 8587

# %%
print("\n" + "="*80)
print("STEP 8: RECOMMENDATION GENERATION")
print("="*80)

def get_user_rated_movies(user_id, train_ratings, cached_rated_movies=None):
    """Get the set of movies already rated by a user with caching for efficiency"""
    # Initialize cache if not provided
    if cached_rated_movies is None:
        cached_rated_movies = {}
        
    # Return from cache if available
    if user_id in cached_rated_movies:
        return cached_rated_movies[user_id]
    
    # Get from ratings dataframe
    if train_ratings is None:
        return set()
    
    user_data = train_ratings[train_ratings['userId'] == user_id]
    rated_movies = set(user_data['movieId'].values)
    
    # Cache for future use
    cached_rated_movies[user_id] = rated_movies
    
    return rated_movies

def get_top_n_recommendations(user_id, user_movie_similarities, train_ratings, cached_rated_movies=None, n=10):
    """
    Generate top-N recommendations for a specific user
    
    Parameters:
    -----------
    user_id : int
        The user ID to generate recommendations for
    user_movie_similarities : dict
        Dictionary of user-movie similarities
    train_ratings : pd.DataFrame
        DataFrame of user ratings
    cached_rated_movies : dict, optional
        Cache of user rated movies for efficiency
    n : int, optional
        Number of recommendations to generate
        
    Returns:
    --------
    list of tuples
        (movie_id, similarity_score) pairs sorted by similarity in descending order
    """
    if user_id not in user_movie_similarities:
        return []
    
    # Get movies already rated by the user (using cache)
    rated_movies = get_user_rated_movies(user_id, train_ratings, cached_rated_movies)
    
    # Get user's similarities
    user_sims = user_movie_similarities[user_id]
    
    # Filter out already rated movies and sort by similarity
    candidates = [(movie_id, sim) for movie_id, sim in user_sims.items() 
                 if movie_id not in rated_movies]
    
    # Sort by similarity (descending)
    recommendations = sorted(candidates, key=lambda x: x[1], reverse=True)
    
    # Return top N
    return recommendations[:n]

def predict_rating(user_id, movie_id, user_movie_similarities, train_ratings):
    """
    Predict a user's rating for a movie
    
    Parameters:
    -----------
    user_id : int
        The user ID
    movie_id : int
        The movie ID
    user_movie_similarities : dict
        Dictionary of user-movie similarities
    train_ratings : pd.DataFrame
        DataFrame of user ratings
        
    Returns:
    --------
    float
        Predicted rating (0.5-5.0 scale)
    """
    # If user not in similarity matrix, return average rating
    if user_id not in user_movie_similarities:
        return 3.0
    
    # Get user's average rating from training data
    user_train = train_ratings[train_ratings['userId'] == user_id]
    user_avg_rating = user_train['rating'].mean() if len(user_train) > 0 else 3.0
    
    # If movie not in similarity matrix, return user's average rating
    if movie_id not in user_movie_similarities[user_id]:
        return user_avg_rating
    
    # Convert similarity score to rating prediction
    # Similarity is in range [0,1], convert to rating range [0.5,5]
    sim_score = user_movie_similarities[user_id][movie_id]
    predicted_rating = 0.5 + 4.5 * sim_score
    
    return predicted_rating

def generate_recommendations_for_all_users(user_movie_similarities, train_ratings, movie_features, n=10, batch_size=100):
    """Generate recommendations for all users with memory efficiency in mind"""
    print(f"Generating top-{n} recommendations for all users in batches...")
    start_time = time.time()
    
    # Create a shared cache for rated movies
    cached_rated_movies = {}
    
    # Get all user IDs
    user_ids = list(user_movie_similarities.keys())
    total_users = len(user_ids)
    
    all_recommendations = {}
    users_with_recommendations = 0
    
    # Process users in batches
    for batch_start in range(0, total_users, batch_size):
        batch_end = min(batch_start + batch_size, total_users)
        batch_user_ids = user_ids[batch_start:batch_end]
        
        print(f"Processing batch {batch_start//batch_size + 1}: users {batch_start+1}-{batch_end} of {total_users}")
        batch_start_time = time.time()
        
        for user_id in batch_user_ids:
            recommendations = get_top_n_recommendations(
                user_id, 
                user_movie_similarities, 
                train_ratings, 
                cached_rated_movies,
                n
            )
            
            if recommendations:
                all_recommendations[user_id] = recommendations
                users_with_recommendations += 1
        
        # Log progress after each batch
        batch_time = time.time() - batch_start_time
        elapsed = time.time() - start_time
        progress = batch_end / total_users * 100
        remaining = batch_time * ((total_users - batch_end) / len(batch_user_ids)) if batch_end < total_users else 0
        
        print(f"Processed {batch_end}/{total_users} users ({progress:.1f}%) - Elapsed: {elapsed:.2f}s - Est. remaining: {remaining:.2f}s")
        print(f"Users with recommendations so far: {users_with_recommendations}")
        
        # Force garbage collection after each batch
        gc.collect()
    
    # Calculate statistics
    if all_recommendations:
        total_recommendations = sum(len(recs) for recs in all_recommendations.values())
        avg_recommendations = total_recommendations / users_with_recommendations if users_with_recommendations > 0 else 0
        
        print(f"\nRecommendation generation complete:")
        print(f"Users with recommendations: {users_with_recommendations}/{total_users} ({users_with_recommendations/total_users*100:.1f}%)")
        print(f"Total recommendations generated: {total_recommendations}")
        print(f"Average recommendations per user: {avg_recommendations:.2f}")
    
    # Display sample recommendations for a few users
    if all_recommendations:
        print("\nSample recommendations for 3 users:")
        for user_id in list(all_recommendations.keys())[:3]:
            print(f"User ID: {user_id}")
            print("Top 5 recommended movies:")
            
            for rank, (movie_id, score) in enumerate(all_recommendations[user_id][:5], 1):
                movie_title = "Unknown"
                if movie_features is not None:
                    movie_row = movie_features[movie_features['movieId'] == movie_id]
                    if not movie_row.empty and 'title' in movie_row.columns:
                        movie_title = movie_row.iloc[0]['title']
                print(f"  {rank}. '{movie_title}' (ID: {movie_id}): {score:.4f}")
            print("---")
    
    return all_recommendations

# Generate recommendations if similarities are available
if 'user_movie_similarities' in data and 'train_ratings' in data:
    # Get all user IDs and sort them numerically
    all_user_ids = sorted(list(user_movie_similarities.keys()))
    
    # Calculate the number of users to include (first 20%)
    target_users_count = int(len(all_user_ids) * 0.2)
    target_users = all_user_ids[:target_users_count]
    
    print(f"Generating recommendations for first 20% of users ({len(target_users)} out of {len(all_user_ids)} total users)")
    print(f"Target user range: {min(target_users)} to {max(target_users)}")
    
    # Create a filtered version of user_movie_similarities with only the target users
    filtered_similarities = {uid: user_movie_similarities[uid] for uid in target_users}
    
    # Generate recommendations only for the target users
    all_recommendations = generate_recommendations_for_all_users(
        filtered_similarities, 
        data['train_ratings'],
        data['movie_features'],
        n=top_n,
        batch_size=100
    )
    data['all_recommendations'] = all_recommendations
    
    # Save recommendations
    with open(os.path.join(output_path, 'content_based_recommendations.pkl'), 'wb') as f:
        pickle.dump(all_recommendations, f)
    
    # Also save in a more readable CSV format
    recommendations_list = []
    
    # Process in chunks to avoid memory issues
    chunk_size = 1000
    user_ids = list(all_recommendations.keys())
    total_users = len(user_ids)
    
    for chunk_start in range(0, total_users, chunk_size):
        chunk_end = min(chunk_start + chunk_size, total_users)
        user_chunk = user_ids[chunk_start:chunk_end]
        
        chunk_recommendations = []
        for user_id in user_chunk:
            for rank, (movie_id, score) in enumerate(all_recommendations[user_id], 1):
                movie_title = "Unknown"
                if 'movie_features' in data:
                    movie_row = data['movie_features'][data['movie_features']['movieId'] == movie_id]
                    if not movie_row.empty and 'title' in movie_row.columns:
                        movie_title = movie_row.iloc[0]['title']
                        
                chunk_recommendations.append({
                    'userId': user_id,
                    'movieId': movie_id,
                    'title': movie_title,
                    'rank': rank,
                    'similarity_score': score
                })
        
        recommendations_list.extend(chunk_recommendations)
        print(f"Processed recommendation chunk {chunk_start//chunk_size + 1}: users {chunk_start+1}-{chunk_end} of {total_users}")
        gc.collect()
    
    if recommendations_list:
        # Write CSV in chunks to avoid memory issues
        chunk_size = 10000
        total_recs = len(recommendations_list)
        
        for chunk_start in range(0, total_recs, chunk_size):
            chunk_end = min(chunk_start + chunk_size, total_recs)
            chunk = recommendations_list[chunk_start:chunk_end]
            
            chunk_df = pd.DataFrame(chunk)
            
            # For first chunk, write with header
            if chunk_start == 0:
                chunk_df.to_csv(os.path.join(output_path, 'content_based_recommendations.csv'), index=False, mode='w')
            else:
                # For subsequent chunks, append without header
                chunk_df.to_csv(os.path.join(output_path, 'content_based_recommendations.csv'), index=False, mode='a', header=False)
            
            print(f"Saved recommendation chunk {chunk_start//chunk_size + 1}: recommendations {chunk_start+1}-{chunk_end} of {total_recs}")
            
        print(f"Saved recommendations to CSV file with {total_recs} entries")
    
    # Free memory
    del recommendations_list
    gc.collect()
# Out:
# ================================================================================
# STEP 8: RECOMMENDATION GENERATION
# ================================================================================
# Generating recommendations for first 20% of users (19998 out of 99992 total users)
# Target user range: 1.0 to 20000.0
# Generating top-20 recommendations for all users in batches...
# Processing batch 1: users 1-100 of 19998
# Processed 100/19998 users (0.5%) - Elapsed: 2.20s - Est. remaining: 437.77s
# Users with recommendations so far: 86
# Processing batch 2: users 101-200 of 19998
# Processed 200/19998 users (1.0%) - Elapsed: 4.41s - Est. remaining: 410.79s
# Users with recommendations so far: 163
# Processing batch 3: users 201-300 of 19998
# Processed 300/19998 users (1.5%) - Elapsed: 6.29s - Est. remaining: 338.83s
# Users with recommendations so far: 248
# Processing batch 4: users 301-400 of 19998
# Processed 400/19998 users (2.0%) - Elapsed: 8.29s - Est. remaining: 368.12s
# Users with recommendations so far: 327
# Processing batch 5: users 401-500 of 19998
# Processed 500/19998 users (2.5%) - Elapsed: 10.14s - Est. remaining: 334.96s
# Users with recommendations so far: 403
# Processing batch 6: users 501-600 of 19998
# Processed 600/19998 users (3.0%) - Elapsed: 12.09s - Est. remaining: 351.97s
# Users with recommendations so far: 484
# Processing batch 7: users 601-700 of 19998
# Processed 700/19998 users (3.5%) - Elapsed: 13.92s - Est. remaining: 325.82s
# Users with recommendations so far: 564
# Processing batch 8: users 701-800 of 19998
# Processed 800/19998 users (4.0%) - Elapsed: 15.80s - Est. remaining: 328.67s
# Users with recommendations so far: 643
# Processing batch 9: users 801-900 of 19998
# Processed 900/19998 users (4.5%) - Elapsed: 17.51s - Est. remaining: 297.74s
# Users with recommendations so far: 722
# Processing batch 10: users 901-1000 of 19998
# Processed 1000/19998 users (5.0%) - Elapsed: 19.35s - Est. remaining: 323.52s
# Users with recommendations so far: 791
# Processing batch 11: users 1001-1100 of 19998
# Processed 1100/19998 users (5.5%) - Elapsed: 21.14s - Est. remaining: 315.19s
# Users with recommendations so far: 872
# Processing batch 12: users 1101-1200 of 19998
# Processed 1200/19998 users (6.0%) - Elapsed: 23.21s - Est. remaining: 365.17s
# Users with recommendations so far: 958
# Processing batch 13: users 1201-1300 of 19998
# Processed 1300/19998 users (6.5%) - Elapsed: 25.09s - Est. remaining: 328.30s
# Users with recommendations so far: 1044
# Processing batch 14: users 1301-1400 of 19998
# Processed 1400/19998 users (7.0%) - Elapsed: 26.90s - Est. remaining: 310.18s
# Users with recommendations so far: 1131
# Processing batch 15: users 1401-1500 of 19998
# Processed 1500/19998 users (7.5%) - Elapsed: 28.49s - Est. remaining: 274.68s
# Users with recommendations so far: 1205
# Processing batch 16: users 1501-1600 of 19998
# Processed 1600/19998 users (8.0%) - Elapsed: 30.33s - Est. remaining: 311.30s
# Users with recommendations so far: 1286
# Processing batch 17: users 1601-1700 of 19998
# Processed 1700/19998 users (8.5%) - Elapsed: 32.27s - Est. remaining: 331.78s
# Users with recommendations so far: 1365
# Processing batch 18: users 1701-1800 of 19998
# Processed 1800/19998 users (9.0%) - Elapsed: 34.06s - Est. remaining: 299.07s
# Users with recommendations so far: 1444
# Processing batch 19: users 1801-1900 of 19998
# Processed 1900/19998 users (9.5%) - Elapsed: 35.62s - Est. remaining: 257.21s
# Users with recommendations so far: 1526
# Processing batch 20: users 1901-2000 of 19998
# Processed 2000/19998 users (10.0%) - Elapsed: 37.12s - Est. remaining: 252.27s
# Users with recommendations so far: 1608
# Processing batch 21: users 2001-2100 of 19998
# Processed 2100/19998 users (10.5%) - Elapsed: 38.73s - Est. remaining: 262.31s
# Users with recommendations so far: 1690
# Processing batch 22: users 2101-2200 of 19998
# Processed 2200/19998 users (11.0%) - Elapsed: 40.49s - Est. remaining: 286.67s
# Users with recommendations so far: 1769
# Processing batch 23: users 2201-2300 of 19998
# Processed 2300/19998 users (11.5%) - Elapsed: 41.98s - Est. remaining: 246.31s
# Users with recommendations so far: 1846
# Processing batch 24: users 2301-2400 of 19998
# Processed 2400/19998 users (12.0%) - Elapsed: 43.77s - Est. remaining: 286.43s
# Users with recommendations so far: 1930
# Processing batch 25: users 2401-2500 of 19998
# Processed 2500/19998 users (12.5%) - Elapsed: 45.30s - Est. remaining: 250.52s
# Users with recommendations so far: 2007
# Processing batch 26: users 2501-2600 of 19998
# Processed 2600/19998 users (13.0%) - Elapsed: 47.23s - Est. remaining: 309.67s
# Users with recommendations so far: 2085
# Processing batch 27: users 2601-2700 of 19998
# Processed 2700/19998 users (13.5%) - Elapsed: 48.90s - Est. remaining: 260.23s
# Users with recommendations so far: 2162
# Processing batch 28: users 2701-2800 of 19998
# Processed 2800/19998 users (14.0%) - Elapsed: 50.73s - Est. remaining: 296.15s
# Users with recommendations so far: 2238
# Processing batch 29: users 2801-2900 of 19998
# Processed 2900/19998 users (14.5%) - Elapsed: 52.79s - Est. remaining: 314.26s
# Users with recommendations so far: 2321
# Processing batch 30: users 2901-3000 of 19998
# Processed 3000/19998 users (15.0%) - Elapsed: 54.63s - Est. remaining: 289.82s
# Users with recommendations so far: 2399
# Processing batch 31: users 3001-3100 of 19998
# Processed 3100/19998 users (15.5%) - Elapsed: 56.06s - Est. remaining: 218.66s
# Users with recommendations so far: 2480
# Processing batch 32: users 3101-3200 of 19998
# Processed 3200/19998 users (16.0%) - Elapsed: 57.49s - Est. remaining: 223.08s
# Users with recommendations so far: 2551
# Processing batch 33: users 3201-3300 of 19998
# Processed 3300/19998 users (16.5%) - Elapsed: 59.19s - Est. remaining: 265.50s
# Users with recommendations so far: 2640
# Processing batch 34: users 3301-3400 of 19998
# Processed 3400/19998 users (17.0%) - Elapsed: 61.31s - Est. remaining: 328.31s
# Users with recommendations so far: 2723
# Processing batch 35: users 3401-3500 of 19998
# Processed 3500/19998 users (17.5%) - Elapsed: 62.92s - Est. remaining: 236.25s
# Users with recommendations so far: 2804
# Processing batch 36: users 3501-3600 of 19998
# Processed 3600/19998 users (18.0%) - Elapsed: 64.30s - Est. remaining: 208.58s
# Users with recommendations so far: 2886
# Processing batch 37: users 3601-3700 of 19998
# Processed 3700/19998 users (18.5%) - Elapsed: 65.94s - Est. remaining: 250.99s
# Users with recommendations so far: 2964
# Processing batch 38: users 3701-3800 of 19998
# Processed 3800/19998 users (19.0%) - Elapsed: 67.46s - Est. remaining: 226.12s
# Users with recommendations so far: 3036
# Processing batch 39: users 3801-3900 of 19998
# Processed 3900/19998 users (19.5%) - Elapsed: 68.87s - Est. remaining: 208.95s
# Users with recommendations so far: 3113
# Processing batch 40: users 3901-4000 of 19998
# Processed 4000/19998 users (20.0%) - Elapsed: 70.31s - Est. remaining: 213.89s
# Users with recommendations so far: 3193
# Processing batch 41: users 4001-4100 of 19998
# Processed 4100/19998 users (20.5%) - Elapsed: 71.71s - Est. remaining: 204.77s
# Users with recommendations so far: 3278
# Processing batch 42: users 4101-4200 of 19998
# Processed 4200/19998 users (21.0%) - Elapsed: 73.28s - Est. remaining: 227.33s
# Users with recommendations so far: 3359
# Processing batch 43: users 4201-4300 of 19998
# Processed 4300/19998 users (21.5%) - Elapsed: 74.73s - Est. remaining: 208.94s
# Users with recommendations so far: 3437
# Processing batch 44: users 4301-4400 of 19998
# Processed 4400/19998 users (22.0%) - Elapsed: 76.13s - Est. remaining: 198.25s
# Users with recommendations so far: 3515
# Processing batch 45: users 4401-4500 of 19998
# Processed 4500/19998 users (22.5%) - Elapsed: 77.52s - Est. remaining: 198.37s
# Users with recommendations so far: 3595
# Processing batch 46: users 4501-4600 of 19998
# Processed 4600/19998 users (23.0%) - Elapsed: 79.12s - Est. remaining: 229.58s
# Users with recommendations so far: 3687
# Processing batch 47: users 4601-4700 of 19998
# Processed 4700/19998 users (23.5%) - Elapsed: 80.77s - Est. remaining: 233.14s
# Users with recommendations so far: 3762
# Processing batch 48: users 4701-4800 of 19998
# Processed 4800/19998 users (24.0%) - Elapsed: 82.41s - Est. remaining: 232.38s
# Users with recommendations so far: 3843
# Processing batch 49: users 4801-4900 of 19998
# Processed 4900/19998 users (24.5%) - Elapsed: 83.99s - Est. remaining: 219.68s
# Users with recommendations so far: 3924
# Processing batch 50: users 4901-5000 of 19998
# Processed 5000/19998 users (25.0%) - Elapsed: 85.41s - Est. remaining: 196.32s
# Users with recommendations so far: 4006
# Processing batch 51: users 5001-5100 of 19998
# Processed 5100/19998 users (25.5%) - Elapsed: 86.98s - Est. remaining: 214.53s
# Users with recommendations so far: 4083
# Processing batch 52: users 5101-5200 of 19998
# Processed 5200/19998 users (26.0%) - Elapsed: 88.89s - Est. remaining: 258.82s
# Users with recommendations so far: 4171
# Processing batch 53: users 5201-5300 of 19998
# Processed 5300/19998 users (26.5%) - Elapsed: 90.33s - Est. remaining: 189.02s
# Users with recommendations so far: 4252
# Processing batch 54: users 5301-5400 of 19998
# Processed 5400/19998 users (27.0%) - Elapsed: 91.81s - Est. remaining: 199.44s
# Users with recommendations so far: 4330
# Processing batch 55: users 5401-5500 of 19998
# Processed 5500/19998 users (27.5%) - Elapsed: 93.38s - Est. remaining: 209.52s
# Users with recommendations so far: 4416
# Processing batch 56: users 5501-5600 of 19998
# Processed 5600/19998 users (28.0%) - Elapsed: 95.27s - Est. remaining: 236.99s
# Users with recommendations so far: 4503
# Processing batch 57: users 5601-5700 of 19998
# Processed 5700/19998 users (28.5%) - Elapsed: 96.64s - Est. remaining: 176.44s
# Users with recommendations so far: 4581
# Processing batch 58: users 5701-5800 of 19998
# Processed 5800/19998 users (29.0%) - Elapsed: 97.99s - Est. remaining: 176.34s
# Users with recommendations so far: 4660
# Processing batch 59: users 5801-5900 of 19998
# Processed 5900/19998 users (29.5%) - Elapsed: 99.33s - Est. remaining: 173.12s
# Users with recommendations so far: 4743
# Processing batch 60: users 5901-6000 of 19998
# Processed 6000/19998 users (30.0%) - Elapsed: 100.89s - Est. remaining: 192.05s
# Users with recommendations so far: 4821
# Processing batch 61: users 6001-6100 of 19998
# Processed 6100/19998 users (30.5%) - Elapsed: 102.37s - Est. remaining: 189.71s
# Users with recommendations so far: 4904
# Processing batch 62: users 6101-6200 of 19998
# Processed 6200/19998 users (31.0%) - Elapsed: 103.79s - Est. remaining: 177.22s
# Users with recommendations so far: 4986
# Processing batch 63: users 6201-6300 of 19998
# Processed 6300/19998 users (31.5%) - Elapsed: 105.37s - Est. remaining: 196.70s
# Users with recommendations so far: 5064
# Processing batch 64: users 6301-6400 of 19998
# Processed 6400/19998 users (32.0%) - Elapsed: 107.44s - Est. remaining: 253.47s
# Users with recommendations so far: 5146
# Processing batch 65: users 6401-6500 of 19998
# Processed 6500/19998 users (32.5%) - Elapsed: 109.37s - Est. remaining: 239.18s
# Users with recommendations so far: 5229
# Processing batch 66: users 6501-6600 of 19998
# Processed 6600/19998 users (33.0%) - Elapsed: 111.00s - Est. remaining: 197.22s
# Users with recommendations so far: 5306
# Processing batch 67: users 6601-6700 of 19998
# Processed 6700/19998 users (33.5%) - Elapsed: 112.89s - Est. remaining: 233.11s
# Users with recommendations so far: 5386
# Processing batch 68: users 6701-6800 of 19998
# Processed 6800/19998 users (34.0%) - Elapsed: 114.78s - Est. remaining: 234.40s
# Users with recommendations so far: 5468
# Processing batch 69: users 6801-6900 of 19998
# Processed 6900/19998 users (34.5%) - Elapsed: 116.46s - Est. remaining: 198.30s
# Users with recommendations so far: 5550
# Processing batch 70: users 6901-7000 of 19998
# Processed 7000/19998 users (35.0%) - Elapsed: 118.19s - Est. remaining: 209.27s
# Users with recommendations so far: 5626
# Processing batch 71: users 7001-7100 of 19998
# Processed 7100/19998 users (35.5%) - Elapsed: 119.97s - Est. remaining: 210.53s
# Users with recommendations so far: 5709
# Processing batch 72: users 7101-7200 of 19998
# Processed 7200/19998 users (36.0%) - Elapsed: 122.00s - Est. remaining: 237.02s
# Users with recommendations so far: 5794
# Processing batch 73: users 7201-7300 of 19998
# Processed 7300/19998 users (36.5%) - Elapsed: 123.80s - Est. remaining: 213.20s
# Users with recommendations so far: 5868
# Processing batch 74: users 7301-7400 of 19998
# Processed 7400/19998 users (37.0%) - Elapsed: 125.44s - Est. remaining: 190.99s
# Users with recommendations so far: 5947
# Processing batch 75: users 7401-7500 of 19998
# Processed 7500/19998 users (37.5%) - Elapsed: 127.24s - Est. remaining: 203.22s
# Users with recommendations so far: 6029
# Processing batch 76: users 7501-7600 of 19998
# Processed 7600/19998 users (38.0%) - Elapsed: 128.88s - Est. remaining: 186.59s
# Users with recommendations so far: 6113
# Processing batch 77: users 7601-7700 of 19998
# Processed 7700/19998 users (38.5%) - Elapsed: 130.59s - Est. remaining: 193.57s
# Users with recommendations so far: 6199
# Processing batch 78: users 7701-7800 of 19998
# Processed 7800/19998 users (39.0%) - Elapsed: 132.22s - Est. remaining: 182.48s
# Users with recommendations so far: 6275
# Processing batch 79: users 7801-7900 of 19998
# Processed 7900/19998 users (39.5%) - Elapsed: 134.08s - Est. remaining: 208.57s
# Users with recommendations so far: 6356
# Processing batch 80: users 7901-8000 of 19998
# Processed 8000/19998 users (40.0%) - Elapsed: 135.89s - Est. remaining: 201.33s
# Users with recommendations so far: 6435
# Processing batch 81: users 8001-8100 of 19998
# Processed 8100/19998 users (40.5%) - Elapsed: 137.33s - Est. remaining: 157.41s
# Users with recommendations so far: 6518
# Processing batch 82: users 8101-8200 of 19998
# Processed 8200/19998 users (41.0%) - Elapsed: 139.14s - Est. remaining: 193.37s
# Users with recommendations so far: 6607
# Processing batch 83: users 8201-8300 of 19998
# Processed 8300/19998 users (41.5%) - Elapsed: 140.90s - Est. remaining: 185.88s
# Users with recommendations so far: 6688
# Processing batch 84: users 8301-8400 of 19998
# Processed 8400/19998 users (42.0%) - Elapsed: 142.62s - Est. remaining: 184.76s
# Users with recommendations so far: 6762
# Processing batch 85: users 8401-8500 of 19998
# Processed 8500/19998 users (42.5%) - Elapsed: 144.04s - Est. remaining: 149.13s
# Users with recommendations so far: 6842
# Processing batch 86: users 8501-8600 of 19998
# Processed 8600/19998 users (43.0%) - Elapsed: 145.65s - Est. remaining: 170.29s
# Users with recommendations so far: 6915
# Processing batch 87: users 8601-8700 of 19998
# Processed 8700/19998 users (43.5%) - Elapsed: 147.03s - Est. remaining: 141.45s
# Users with recommendations so far: 6993
# Processing batch 88: users 8701-8800 of 19998
# Processed 8800/19998 users (44.0%) - Elapsed: 148.53s - Est. remaining: 154.42s
# Users with recommendations so far: 7079
# Processing batch 89: users 8801-8900 of 19998
# Processed 8900/19998 users (44.5%) - Elapsed: 149.92s - Est. remaining: 139.95s
# Users with recommendations so far: 7161
# Processing batch 90: users 8901-9000 of 19998
# Processed 9000/19998 users (45.0%) - Elapsed: 151.36s - Est. remaining: 144.29s
# Users with recommendations so far: 7245
# Processing batch 91: users 9001-9100 of 19998
# Processed 9100/19998 users (45.5%) - Elapsed: 152.81s - Est. remaining: 144.62s
# Users with recommendations so far: 7327
# Processing batch 92: users 9101-9200 of 19998
# Processed 9200/19998 users (46.0%) - Elapsed: 154.43s - Est. remaining: 157.76s
# Users with recommendations so far: 7404
# Processing batch 93: users 9201-9300 of 19998
# Processed 9300/19998 users (46.5%) - Elapsed: 155.85s - Est. remaining: 139.29s
# Users with recommendations so far: 7486
# Processing batch 94: users 9301-9400 of 19998
# Processed 9400/19998 users (47.0%) - Elapsed: 157.26s - Est. remaining: 136.08s
# Users with recommendations so far: 7572
# Processing batch 95: users 9401-9500 of 19998
# Processed 9500/19998 users (47.5%) - Elapsed: 158.71s - Est. remaining: 135.74s
# Users with recommendations so far: 7652
# Processing batch 96: users 9501-9600 of 19998
# Processed 9600/19998 users (48.0%) - Elapsed: 160.26s - Est. remaining: 147.86s
# Users with recommendations so far: 7725
# Processing batch 97: users 9601-9700 of 19998
# Processed 9700/19998 users (48.5%) - Elapsed: 161.93s - Est. remaining: 156.12s
# Users with recommendations so far: 7803
# Processing batch 98: users 9701-9800 of 19998
# Processed 9800/19998 users (49.0%) - Elapsed: 163.71s - Est. remaining: 157.46s
# Users with recommendations so far: 7880
# Processing batch 99: users 9801-9900 of 19998
# Processed 9900/19998 users (49.5%) - Elapsed: 165.05s - Est. remaining: 121.98s
# Users with recommendations so far: 7961
# Processing batch 100: users 9901-10000 of 19998
# Processed 10000/19998 users (50.0%) - Elapsed: 166.47s - Est. remaining: 129.87s
# Users with recommendations so far: 8045
# Processing batch 101: users 10001-10100 of 19998
# Processed 10100/19998 users (50.5%) - Elapsed: 167.79s - Est. remaining: 118.38s
# Users with recommendations so far: 8125
# Processing batch 102: users 10101-10200 of 19998
# Processed 10200/19998 users (51.0%) - Elapsed: 169.17s - Est. remaining: 121.89s
# Users with recommendations so far: 8205
# Processing batch 103: users 10201-10300 of 19998
# Processed 10300/19998 users (51.5%) - Elapsed: 170.40s - Est. remaining: 106.97s
# Users with recommendations so far: 8281
# Processing batch 104: users 10301-10400 of 19998
# Processed 10400/19998 users (52.0%) - Elapsed: 171.59s - Est. remaining: 102.41s
# Users with recommendations so far: 8366
# Processing batch 105: users 10401-10500 of 19998
# Processed 10500/19998 users (52.5%) - Elapsed: 172.90s - Est. remaining: 112.46s
# Users with recommendations so far: 8445
# Processing batch 106: users 10501-10600 of 19998
# Processed 10600/19998 users (53.0%) - Elapsed: 174.14s - Est. remaining: 104.88s
# Users with recommendations so far: 8521
# Processing batch 107: users 10601-10700 of 19998
# Processed 10700/19998 users (53.5%) - Elapsed: 175.36s - Est. remaining: 100.60s
# Users with recommendations so far: 8597
# Processing batch 108: users 10701-10800 of 19998
# Processed 10800/19998 users (54.0%) - Elapsed: 176.54s - Est. remaining: 98.23s
# Users with recommendations so far: 8678
# Processing batch 109: users 10801-10900 of 19998
# Processed 10900/19998 users (54.5%) - Elapsed: 177.91s - Est. remaining: 113.09s
# Users with recommendations so far: 8762
# Processing batch 110: users 10901-11000 of 19998
# Processed 11000/19998 users (55.0%) - Elapsed: 179.22s - Est. remaining: 103.63s
# Users with recommendations so far: 8847
# Processing batch 111: users 11001-11100 of 19998
# Processed 11100/19998 users (55.5%) - Elapsed: 180.40s - Est. remaining: 93.78s
# Users with recommendations so far: 8927
# Processing batch 112: users 11101-11200 of 19998
# Processed 11200/19998 users (56.0%) - Elapsed: 181.64s - Est. remaining: 97.22s
# Users with recommendations so far: 9012
# Processing batch 113: users 11201-11300 of 19998
# Processed 11300/19998 users (56.5%) - Elapsed: 182.86s - Est. remaining: 94.46s
# Users with recommendations so far: 9093
# Processing batch 114: users 11301-11400 of 19998
# Processed 11400/19998 users (57.0%) - Elapsed: 184.15s - Est. remaining: 100.85s
# Users with recommendations so far: 9171
# Processing batch 115: users 11401-11500 of 19998
# Processed 11500/19998 users (57.5%) - Elapsed: 185.37s - Est. remaining: 92.19s
# Users with recommendations so far: 9242
# Processing batch 116: users 11501-11600 of 19998
# Processed 11600/19998 users (58.0%) - Elapsed: 186.60s - Est. remaining: 93.55s
# Users with recommendations so far: 9325
# Processing batch 117: users 11601-11700 of 19998
# Processed 11700/19998 users (58.5%) - Elapsed: 187.81s - Est. remaining: 90.45s
# Users with recommendations so far: 9403
# Processing batch 118: users 11701-11800 of 19998
# Processed 11800/19998 users (59.0%) - Elapsed: 189.04s - Est. remaining: 89.60s
# Users with recommendations so far: 9484
# Processing batch 119: users 11801-11900 of 19998
# Processed 11900/19998 users (59.5%) - Elapsed: 190.37s - Est. remaining: 96.37s
# Users with recommendations so far: 9562
# Processing batch 120: users 11901-12000 of 19998
# Processed 12000/19998 users (60.0%) - Elapsed: 191.66s - Est. remaining: 92.94s
# Users with recommendations so far: 9644
# Processing batch 121: users 12001-12100 of 19998
# Processed 12100/19998 users (60.5%) - Elapsed: 192.91s - Est. remaining: 89.01s
# Users with recommendations so far: 9724
# Processing batch 122: users 12101-12200 of 19998
# Processed 12200/19998 users (61.0%) - Elapsed: 194.18s - Est. remaining: 88.74s
# Users with recommendations so far: 9798
# Processing batch 123: users 12201-12300 of 19998
# Processed 12300/19998 users (61.5%) - Elapsed: 195.51s - Est. remaining: 92.68s
# Users with recommendations so far: 9872
# Processing batch 124: users 12301-12400 of 19998
# Processed 12400/19998 users (62.0%) - Elapsed: 196.86s - Est. remaining: 89.04s
# Users with recommendations so far: 9952
# Processing batch 125: users 12401-12500 of 19998
# Processed 12500/19998 users (62.5%) - Elapsed: 198.10s - Est. remaining: 83.83s
# Users with recommendations so far: 10031
# Processing batch 126: users 12501-12600 of 19998
# Processed 12600/19998 users (63.0%) - Elapsed: 199.37s - Est. remaining: 84.93s
# Users with recommendations so far: 10114
# Processing batch 127: users 12601-12700 of 19998
# Processed 12700/19998 users (63.5%) - Elapsed: 200.65s - Est. remaining: 83.94s
# Users with recommendations so far: 10192
# Processing batch 128: users 12701-12800 of 19998
# Processed 12800/19998 users (64.0%) - Elapsed: 202.04s - Est. remaining: 90.77s
# Users with recommendations so far: 10276
# Processing batch 129: users 12801-12900 of 19998
# Processed 12900/19998 users (64.5%) - Elapsed: 203.32s - Est. remaining: 82.41s
# Users with recommendations so far: 10358
# Processing batch 130: users 12901-13000 of 19998
# Processed 13000/19998 users (65.0%) - Elapsed: 204.59s - Est. remaining: 79.71s
# Users with recommendations so far: 10439
# Processing batch 131: users 13001-13100 of 19998
# Processed 13100/19998 users (65.5%) - Elapsed: 205.83s - Est. remaining: 77.19s
# Users with recommendations so far: 10520
# Processing batch 132: users 13101-13200 of 19998
# Processed 13200/19998 users (66.0%) - Elapsed: 207.23s - Est. remaining: 84.67s
# Users with recommendations so far: 10603
# Processing batch 133: users 13201-13300 of 19998
# Processed 13300/19998 users (66.5%) - Elapsed: 208.60s - Est. remaining: 77.76s
# Users with recommendations so far: 10683
# Processing batch 134: users 13301-13400 of 19998
# Processed 13400/19998 users (67.0%) - Elapsed: 209.88s - Est. remaining: 76.47s
# Users with recommendations so far: 10763
# Processing batch 135: users 13401-13500 of 19998
# Processed 13500/19998 users (67.5%) - Elapsed: 211.14s - Est. remaining: 73.36s
# Users with recommendations so far: 10839
# Processing batch 136: users 13501-13600 of 19998
# Processed 13600/19998 users (68.0%) - Elapsed: 212.40s - Est. remaining: 71.66s
# Users with recommendations so far: 10926
# Processing batch 137: users 13601-13700 of 19998
# Processed 13700/19998 users (68.5%) - Elapsed: 213.79s - Est. remaining: 77.31s
# Users with recommendations so far: 11003
# Processing batch 138: users 13701-13800 of 19998
# Processed 13800/19998 users (69.0%) - Elapsed: 215.09s - Est. remaining: 72.27s
# Users with recommendations so far: 11082
# Processing batch 139: users 13801-13900 of 19998
# Processed 13900/19998 users (69.5%) - Elapsed: 216.33s - Est. remaining: 67.50s
# Users with recommendations so far: 11163
# Processing batch 140: users 13901-14000 of 19998
# Processed 14000/19998 users (70.0%) - Elapsed: 217.61s - Est. remaining: 68.92s
# Users with recommendations so far: 11245
# Processing batch 141: users 14001-14100 of 19998
# Processed 14100/19998 users (70.5%) - Elapsed: 218.99s - Est. remaining: 72.90s
# Users with recommendations so far: 11328
# Processing batch 142: users 14101-14200 of 19998
# Processed 14200/19998 users (71.0%) - Elapsed: 220.25s - Est. remaining: 64.47s
# Users with recommendations so far: 11402
# Processing batch 143: users 14201-14300 of 19998
# Processed 14300/19998 users (71.5%) - Elapsed: 221.51s - Est. remaining: 63.87s
# Users with recommendations so far: 11489
# Processing batch 144: users 14301-14400 of 19998
# Processed 14400/19998 users (72.0%) - Elapsed: 222.75s - Est. remaining: 62.31s
# Users with recommendations so far: 11568
# Processing batch 145: users 14401-14500 of 19998
# Processed 14500/19998 users (72.5%) - Elapsed: 224.03s - Est. remaining: 63.34s
# Users with recommendations so far: 11646
# Processing batch 146: users 14501-14600 of 19998
# Processed 14600/19998 users (73.0%) - Elapsed: 225.41s - Est. remaining: 66.88s
# Users with recommendations so far: 11722
# Processing batch 147: users 14601-14700 of 19998
# Processed 14700/19998 users (73.5%) - Elapsed: 226.71s - Est. remaining: 61.78s
# Users with recommendations so far: 11799
# Processing batch 148: users 14701-14800 of 19998
# Processed 14800/19998 users (74.0%) - Elapsed: 228.02s - Est. remaining: 61.20s
# Users with recommendations so far: 11884
# Processing batch 149: users 14801-14900 of 19998
# Processed 14900/19998 users (74.5%) - Elapsed: 229.28s - Est. remaining: 57.20s
# Users with recommendations so far: 11968
# Processing batch 150: users 14901-15000 of 19998
# Processed 15000/19998 users (75.0%) - Elapsed: 230.71s - Est. remaining: 64.43s
# Users with recommendations so far: 12048
# Processing batch 151: users 15001-15100 of 19998
# Processed 15100/19998 users (75.5%) - Elapsed: 232.02s - Est. remaining: 57.89s
# Users with recommendations so far: 12131
# Processing batch 152: users 15101-15200 of 19998
# Processed 15200/19998 users (76.0%) - Elapsed: 233.25s - Est. remaining: 52.69s
# Users with recommendations so far: 12217
# Processing batch 153: users 15201-15300 of 19998
# Processed 15300/19998 users (76.5%) - Elapsed: 234.49s - Est. remaining: 51.87s
# Users with recommendations so far: 12289
# Processing batch 154: users 15301-15400 of 19998
# Processed 15400/19998 users (77.0%) - Elapsed: 235.77s - Est. remaining: 50.72s
# Users with recommendations so far: 12367
# Processing batch 155: users 15401-15500 of 19998
# Processed 15500/19998 users (77.5%) - Elapsed: 237.15s - Est. remaining: 55.74s
# Users with recommendations so far: 12443
# Processing batch 156: users 15501-15600 of 19998
# Processed 15600/19998 users (78.0%) - Elapsed: 238.45s - Est. remaining: 51.25s
# Users with recommendations so far: 12521
# Processing batch 157: users 15601-15700 of 19998
# Processed 15700/19998 users (78.5%) - Elapsed: 239.76s - Est. remaining: 50.03s
# Users with recommendations so far: 12598
# Processing batch 158: users 15701-15800 of 19998
# Processed 15800/19998 users (79.0%) - Elapsed: 241.01s - Est. remaining: 46.81s
# Users with recommendations so far: 12677
# Processing batch 159: users 15801-15900 of 19998
# Processed 15900/19998 users (79.5%) - Elapsed: 242.42s - Est. remaining: 51.97s
# Users with recommendations so far: 12753
# Processing batch 160: users 15901-16000 of 19998
# Processed 16000/19998 users (80.0%) - Elapsed: 243.70s - Est. remaining: 45.46s
# Users with recommendations so far: 12828
# Processing batch 161: users 16001-16100 of 19998
# Processed 16100/19998 users (80.5%) - Elapsed: 244.96s - Est. remaining: 43.93s
# Users with recommendations so far: 12907
# Processing batch 162: users 16101-16200 of 19998
# Processed 16200/19998 users (81.0%) - Elapsed: 246.23s - Est. remaining: 43.11s
# Users with recommendations so far: 12988
# Processing batch 163: users 16201-16300 of 19998
# Processed 16300/19998 users (81.5%) - Elapsed: 247.53s - Est. remaining: 42.73s
# Users with recommendations so far: 13068
# Processing batch 164: users 16301-16400 of 19998
# Processed 16400/19998 users (82.0%) - Elapsed: 248.95s - Est. remaining: 45.12s
# Users with recommendations so far: 13143
# Processing batch 165: users 16401-16500 of 19998
# Processed 16500/19998 users (82.5%) - Elapsed: 250.21s - Est. remaining: 39.07s
# Users with recommendations so far: 13225
# Processing batch 166: users 16501-16600 of 19998
# Processed 16600/19998 users (83.0%) - Elapsed: 251.49s - Est. remaining: 38.70s
# Users with recommendations so far: 13309
# Processing batch 167: users 16601-16700 of 19998
# Processed 16700/19998 users (83.5%) - Elapsed: 252.78s - Est. remaining: 37.66s
# Users with recommendations so far: 13388
# Processing batch 168: users 16701-16800 of 19998
# Processed 16800/19998 users (84.0%) - Elapsed: 254.15s - Est. remaining: 39.14s
# Users with recommendations so far: 13465
# Processing batch 169: users 16801-16900 of 19998
# Processed 16900/19998 users (84.5%) - Elapsed: 255.47s - Est. remaining: 36.56s
# Users with recommendations so far: 13544
# Processing batch 170: users 16901-17000 of 19998
# Processed 17000/19998 users (85.0%) - Elapsed: 256.73s - Est. remaining: 33.40s
# Users with recommendations so far: 13621
# Processing batch 171: users 17001-17100 of 19998
# Processed 17100/19998 users (85.5%) - Elapsed: 258.03s - Est. remaining: 33.76s
# Users with recommendations so far: 13705
# Processing batch 172: users 17101-17200 of 19998
# Processed 17200/19998 users (86.0%) - Elapsed: 259.30s - Est. remaining: 31.23s
# Users with recommendations so far: 13790
# Processing batch 173: users 17201-17300 of 19998
# Processed 17300/19998 users (86.5%) - Elapsed: 260.73s - Est. remaining: 33.38s
# Users with recommendations so far: 13874
# Processing batch 174: users 17301-17400 of 19998
# Processed 17400/19998 users (87.0%) - Elapsed: 261.98s - Est. remaining: 28.81s
# Users with recommendations so far: 13954
# Processing batch 175: users 17401-17500 of 19998
# Processed 17500/19998 users (87.5%) - Elapsed: 263.30s - Est. remaining: 29.53s
# Users with recommendations so far: 14038
# Processing batch 176: users 17501-17600 of 19998
# Processed 17600/19998 users (88.0%) - Elapsed: 264.60s - Est. remaining: 27.32s
# Users with recommendations so far: 14118
# Processing batch 177: users 17601-17700 of 19998
# Processed 17700/19998 users (88.5%) - Elapsed: 265.98s - Est. remaining: 28.38s
# Users with recommendations so far: 14199
# Processing batch 178: users 17701-17800 of 19998
# Processed 17800/19998 users (89.0%) - Elapsed: 267.26s - Est. remaining: 25.08s
# Users with recommendations so far: 14283
# Processing batch 179: users 17801-17900 of 19998
# Processed 17900/19998 users (89.5%) - Elapsed: 268.53s - Est. remaining: 23.52s
# Users with recommendations so far: 14366
# Processing batch 180: users 17901-18000 of 19998
# Processed 18000/19998 users (90.0%) - Elapsed: 269.82s - Est. remaining: 22.54s
# Users with recommendations so far: 14451
# Processing batch 181: users 18001-18100 of 19998
# Processed 18100/19998 users (90.5%) - Elapsed: 271.14s - Est. remaining: 22.32s
# Users with recommendations so far: 14532
# Processing batch 182: users 18101-18200 of 19998
# Processed 18200/19998 users (91.0%) - Elapsed: 272.43s - Est. remaining: 19.98s
# Users with recommendations so far: 14608
# Processing batch 183: users 18201-18300 of 19998
# Processed 18300/19998 users (91.5%) - Elapsed: 273.74s - Est. remaining: 19.20s
# Users with recommendations so far: 14694
# Processing batch 184: users 18301-18400 of 19998
# Processed 18400/19998 users (92.0%) - Elapsed: 275.02s - Est. remaining: 18.22s
# Users with recommendations so far: 14773
# Processing batch 185: users 18401-18500 of 19998
# Processed 18500/19998 users (92.5%) - Elapsed: 276.36s - Est. remaining: 17.69s
# Users with recommendations so far: 14849
# Processing batch 186: users 18501-18600 of 19998
# Processed 18600/19998 users (93.0%) - Elapsed: 277.83s - Est. remaining: 18.20s
# Users with recommendations so far: 14928
# Processing batch 187: users 18601-18700 of 19998
# Processed 18700/19998 users (93.5%) - Elapsed: 279.12s - Est. remaining: 14.84s
# Users with recommendations so far: 15008
# Processing batch 188: users 18701-18800 of 19998
# Processed 18800/19998 users (94.0%) - Elapsed: 280.38s - Est. remaining: 13.24s
# Users with recommendations so far: 15090
# Processing batch 189: users 18801-18900 of 19998
# Processed 18900/19998 users (94.5%) - Elapsed: 281.68s - Est. remaining: 12.65s
# Users with recommendations so far: 15166
# Processing batch 190: users 18901-19000 of 19998
# Processed 19000/19998 users (95.0%) - Elapsed: 283.04s - Est. remaining: 12.11s
# Users with recommendations so far: 15247
# Processing batch 191: users 19001-19100 of 19998
# Processed 19100/19998 users (95.5%) - Elapsed: 284.43s - Est. remaining: 11.16s
# Users with recommendations so far: 15334
# Processing batch 192: users 19101-19200 of 19998
# Processed 19200/19998 users (96.0%) - Elapsed: 285.73s - Est. remaining: 9.07s
# Users with recommendations so far: 15419
# Processing batch 193: users 19201-19300 of 19998
# Processed 19300/19998 users (96.5%) - Elapsed: 287.05s - Est. remaining: 8.05s
# Users with recommendations so far: 15500
# Processing batch 194: users 19301-19400 of 19998
# Processed 19400/19998 users (97.0%) - Elapsed: 288.32s - Est. remaining: 6.70s
# Users with recommendations so far: 15581
# Processing batch 195: users 19401-19500 of 19998
# Processed 19500/19998 users (97.5%) - Elapsed: 289.74s - Est. remaining: 6.34s
# Users with recommendations so far: 15663
# Processing batch 196: users 19501-19600 of 19998
# Processed 19600/19998 users (98.0%) - Elapsed: 291.02s - Est. remaining: 4.48s
# Users with recommendations so far: 15742
# Processing batch 197: users 19601-19700 of 19998
# Processed 19700/19998 users (98.5%) - Elapsed: 292.34s - Est. remaining: 3.45s
# Users with recommendations so far: 15817
# Processing batch 198: users 19701-19800 of 19998
# Processed 19800/19998 users (99.0%) - Elapsed: 293.63s - Est. remaining: 2.26s
# Users with recommendations so far: 15894
# Processing batch 199: users 19801-19900 of 19998
# Processed 19900/19998 users (99.5%) - Elapsed: 295.05s - Est. remaining: 1.25s
# Users with recommendations so far: 15980
# Processing batch 200: users 19901-19998 of 19998
# Processed 19998/19998 users (100.0%) - Elapsed: 296.38s - Est. remaining: 0.00s
# Users with recommendations so far: 16064
#
# Recommendation generation complete:
# Users with recommendations: 16064/19998 (80.3%)
# Total recommendations generated: 278842
# Average recommendations per user: 17.36
#
# Sample recommendations for 3 users:
# User ID: 1.0
# Top 5 recommended movies:
#   1. 'Black Sunday (La maschera del demonio) (1960)' (ID: 3205): 0.7821
#   2. 'Casshern (2004)' (ID: 27905): 0.7779
#   3. 'Paradox (2010)' (ID: 119167): 0.7693
#   4. 'Cube Zero (2004)' (ID: 32213): 0.7664
#   5. 'Jack the Giant Slayer (2013)' (ID: 101025): 0.7637
# ---
# User ID: 2.0
# Top 5 recommended movies:
#   1. 'Black Hole, The (1979)' (ID: 2034): 0.8000
#   2. 'Casshern (2004)' (ID: 27905): 0.7842
#   3. 'Lifeforce (1985)' (ID: 2377): 0.7739
#   4. 'Outland (1981)' (ID: 4443): 0.7664
#   5. 'Alien: Resurrection (1997)' (ID: 1690): 0.7645
# ---
# User ID: 3.0
# Top 5 recommended movies:
#   1. 'Alien: Resurrection (1997)' (ID: 1690): 0.7900
#   2. 'Cube Zero (2004)' (ID: 32213): 0.7815
#   3. 'Casshern (2004)' (ID: 27905): 0.7775
#   4. 'Children of the Corn II: The Final Sacrifice (1993)' (ID: 2515): 0.7742
#   5. 'Outland (1981)' (ID: 4443): 0.7708
# ---
# Processed recommendation chunk 1: users 1-1000 of 16064
# Processed recommendation chunk 2: users 1001-2000 of 16064
# Processed recommendation chunk 3: users 2001-3000 of 16064
# Processed recommendation chunk 4: users 3001-4000 of 16064
# Processed recommendation chunk 5: users 4001-5000 of 16064
# Processed recommendation chunk 6: users 5001-6000 of 16064
# Processed recommendation chunk 7: users 6001-7000 of 16064
# Processed recommendation chunk 8: users 7001-8000 of 16064
# Processed recommendation chunk 9: users 8001-9000 of 16064
# Processed recommendation chunk 10: users 9001-10000 of 16064
# Processed recommendation chunk 11: users 10001-11000 of 16064
# Processed recommendation chunk 12: users 11001-12000 of 16064
# Processed recommendation chunk 13: users 12001-13000 of 16064
# Processed recommendation chunk 14: users 13001-14000 of 16064
# Processed recommendation chunk 15: users 14001-15000 of 16064
# Processed recommendation chunk 16: users 15001-16000 of 16064
# Processed recommendation chunk 17: users 16001-16064 of 16064
# Saved recommendation chunk 1: recommendations 1-10000 of 278842
# Saved recommendation chunk 2: recommendations 10001-20000 of 278842
# Saved recommendation chunk 3: recommendations 20001-30000 of 278842
# Saved recommendation chunk 4: recommendations 30001-40000 of 278842
# Saved recommendation chunk 5: recommendations 40001-50000 of 278842
# Saved recommendation chunk 6: recommendations 50001-60000 of 278842
# Saved recommendation chunk 7: recommendations 60001-70000 of 278842
# Saved recommendation chunk 8: recommendations 70001-80000 of 278842
# Saved recommendation chunk 9: recommendations 80001-90000 of 278842
# Saved recommendation chunk 10: recommendations 90001-100000 of 278842
# Saved recommendation chunk 11: recommendations 100001-110000 of 278842
# Saved recommendation chunk 12: recommendations 110001-120000 of 278842
# Saved recommendation chunk 13: recommendations 120001-130000 of 278842
# Saved recommendation chunk 14: recommendations 130001-140000 of 278842
# Saved recommendation chunk 15: recommendations 140001-150000 of 278842
# Saved recommendation chunk 16: recommendations 150001-160000 of 278842
# Saved recommendation chunk 17: recommendations 160001-170000 of 278842
# Saved recommendation chunk 18: recommendations 170001-180000 of 278842
# Saved recommendation chunk 19: recommendations 180001-190000 of 278842
# Saved recommendation chunk 20: recommendations 190001-200000 of 278842
# Saved recommendation chunk 21: recommendations 200001-210000 of 278842
# Saved recommendation chunk 22: recommendations 210001-220000 of 278842
# Saved recommendation chunk 23: recommendations 220001-230000 of 278842
# Saved recommendation chunk 24: recommendations 230001-240000 of 278842
# Saved recommendation chunk 25: recommendations 240001-250000 of 278842
# Saved recommendation chunk 26: recommendations 250001-260000 of 278842
# Saved recommendation chunk 27: recommendations 260001-270000 of 278842
# Saved recommendation chunk 28: recommendations 270001-278842 of 278842
# Saved recommendations to CSV file with 278842 entries

# %%
print("\n" + "="*80)
print("STEP 9: MODEL EVALUATION")
print("="*80)

# Thay đổi hàm evaluate_with_rmse_mae như sau:
def evaluate_with_rmse_mae(user_movie_similarities, train_ratings, test_ratings, batch_size=100):
    """
    Evaluate the recommendations using RMSE and MAE with batching for memory efficiency
    
    Parameters:
    -----------
    user_movie_similarities : dict
        Dictionary of user-movie similarities
    train_ratings : pd.DataFrame
        DataFrame of training ratings
    test_ratings : pd.DataFrame
        DataFrame of test ratings
    batch_size : int
        Size of user batches to process
        
    Returns:
    --------
    dict
        Dictionary of evaluation metrics
    """
    print("Evaluating recommendation model using RMSE and MAE with batching...")
    start_time = time.time()
    
    # Lấy common users giữa test_ratings và training users
    test_users = set(test_ratings['userId'].unique())
    train_users = set(train_ratings['userId'].unique())
    users_to_evaluate = test_users.intersection(train_users)
    
    print(f"Users in test set: {len(test_users)}")
    print(f"Users in training set: {len(train_users)}")
    print(f"Users to evaluate (intersection): {len(users_to_evaluate)}")
    
    # Kiểm tra nếu chúng ta đang sử dụng user-based split
    if len(users_to_evaluate) == 0:
        print("Using user-based split - no common users between train and test.")
        print("Evaluating using average rating for all predictions instead.")
        
        # Lấy average rating từ training set
        avg_rating = train_ratings['rating'].mean()
        
        # Đếm số lượng dự đoán
        total_predictions = len(test_ratings)
        
        # Tính MSE và MAE bằng cách dùng average rating làm dự đoán
        squared_errors_sum = ((test_ratings['rating'] - avg_rating) ** 2).sum()
        absolute_errors_sum = (abs(test_ratings['rating'] - avg_rating)).sum()
        
        # Tính RMSE và MAE
        overall_rmse = np.sqrt(squared_errors_sum / total_predictions)
        overall_mae = absolute_errors_sum / total_predictions
        
        print("\nEvaluation results using average rating baseline:")
        print(f"Total predictions: {total_predictions}")
        print(f"RMSE: {overall_rmse:.4f}")
        print(f"MAE: {overall_mae:.4f}")
        
        # Tạo metrics dictionary
        metrics = {
            'rmse': overall_rmse,
            'mae': overall_mae,
            'num_predictions': total_predictions,
            'evaluation_method': 'average_rating_baseline'
        }
        
        return metrics
    
    # Nếu có common users, tiếp tục với cách đánh giá gốc
    # (Phần code gốc của bạn bắt đầu từ đây, giữ nguyên)
    users_with_similarity = set(user_movie_similarities.keys())
    users_in_test_with_similarity = users_to_evaluate.intersection(users_with_similarity)
    
    print(f"Users in test set with similarity data: {len(users_in_test_with_similarity)}/{len(users_to_evaluate)} ({len(users_in_test_with_similarity)/len(users_to_evaluate)*100:.1f}%)")
    
    # Track metrics in chunks instead of storing all predictions
    squared_errors_sum = 0
    absolute_errors_sum = 0
    total_predictions = 0
    users_evaluated = 0
    
    # Process users in batches
    user_list = list(users_in_test_with_similarity)
    for batch_start in range(0, len(user_list), batch_size):
        batch_end = min(batch_start + batch_size, len(user_list))
        batch_users = user_list[batch_start:batch_end]
        
        print(f"Evaluating batch {batch_start//batch_size + 1}: users {batch_start+1}-{batch_end} of {len(user_list)}")
        batch_start_time = time.time()
        
        batch_squared_errors = 0
        batch_absolute_errors = 0
        batch_predictions = 0
        
        for user_id in batch_users:
            # Get user test ratings
            user_test = test_ratings[test_ratings['userId'] == user_id]
            
            if len(user_test) == 0:
                continue
            
            # Get user's average rating from training data
            user_train = train_ratings[train_ratings['userId'] == user_id]
            user_avg_rating = user_train['rating'].mean() if len(user_train) > 0 else 3.0
            
            # Predict ratings for test items
            for _, row in user_test.iterrows():
                movie_id = row['movieId']
                true_rating = row['rating']
                
                # Get similarity-based prediction
                if movie_id in user_movie_similarities.get(user_id, {}):
                    # Convert similarity score to rating prediction
                    sim_score = user_movie_similarities[user_id][movie_id]
                    predicted_rating = 0.5 + 4.5 * sim_score
                else:
                    # Use user's average rating as fallback
                    predicted_rating = user_avg_rating
                
                # Calculate error
                squared_error = (predicted_rating - true_rating) ** 2
                absolute_error = abs(predicted_rating - true_rating)
                
                batch_squared_errors += squared_error
                batch_absolute_errors += absolute_error
                batch_predictions += 1
            
            users_evaluated += 1
        
        # Accumulate batch metrics
        squared_errors_sum += batch_squared_errors
        absolute_errors_sum += batch_absolute_errors
        total_predictions += batch_predictions
        
        # Log progress
        batch_time = time.time() - batch_start_time
        elapsed = time.time() - start_time
        progress = batch_end / len(user_list) * 100
        remaining = batch_time * ((len(user_list) - batch_end) / len(batch_users)) if batch_end < len(user_list) else 0
        
        # Periodically calculate and log intermediate metrics
        if batch_predictions > 0:
            batch_rmse = np.sqrt(batch_squared_errors / batch_predictions)
            batch_mae = batch_absolute_errors / batch_predictions
            print(f"Batch metrics - RMSE: {batch_rmse:.4f}, MAE: {batch_mae:.4f}, Predictions: {batch_predictions}")
        
        print(f"Processed {batch_end}/{len(user_list)} users ({progress:.1f}%) - Elapsed: {elapsed:.2f}s - Est. remaining: {remaining:.2f}s")
        
        # Force garbage collection after each batch
        gc.collect()
    
    # Calculate overall RMSE and MAE
    if total_predictions > 0:
        overall_rmse = np.sqrt(squared_errors_sum / total_predictions)
        overall_mae = absolute_errors_sum / total_predictions
    else:
        overall_rmse = 0.0
        overall_mae = 0.0
    
    print("\nEvaluation results:")
    print(f"Users evaluated: {users_evaluated}")
    print(f"Total predictions: {total_predictions}")
    print(f"RMSE: {overall_rmse:.4f}")
    print(f"MAE: {overall_mae:.4f}")
    
    # Create metrics dictionary
    metrics = {
        'rmse': overall_rmse,
        'mae': overall_mae,
        'num_users_evaluated': users_evaluated,
        'num_predictions': total_predictions
    }
    
    return metrics
# Evaluate recommendations if test ratings are available
if 'user_movie_similarities' in data and 'train_ratings' in data and 'test_ratings' in data:
    # Call the new evaluation function
    print("Running evaluation with RMSE and MAE metrics...")
    evaluation_metrics = evaluate_with_rmse_mae(
        data['user_movie_similarities'],
        data['train_ratings'],
        data['test_ratings'],
        batch_size=100
    )
    
    # Store the metrics in the data dictionary
    data['evaluation_metrics'] = evaluation_metrics
    
    # Print the metrics to confirm they're stored correctly
    print("\nStored evaluation metrics:")
    for key, value in evaluation_metrics.items():
        print(f"  {key}: {value}")
    
    # Save metrics to CSV
    evaluation_results = pd.DataFrame([evaluation_metrics])
    evaluation_results.to_csv(os.path.join(output_path, 'content_based_evaluation.csv'), index=False)
    
    # Also save user metrics
    if 'user_metrics' in data:
        user_metrics_df = pd.DataFrame.from_dict(data['user_metrics'], orient='index')
        user_metrics_df.reset_index(inplace=True)
        user_metrics_df.rename(columns={'index': 'userId'}, inplace=True)
        user_metrics_df.to_csv(os.path.join(output_path, 'user_metrics.csv'), index=False)
    
    print(f"Saved evaluation metrics to CSV files")
    
    # Free memory
    gc.collect()
# Out:
# ================================================================================
# STEP 9: MODEL EVALUATION
# ================================================================================
# Running evaluation with RMSE and MAE metrics...
# Evaluating recommendation model using RMSE and MAE with batching...
# Users in test set: 99887
# Users in training set: 100000
# Users to evaluate (intersection): 99887
# Users in test set with similarity data: 99879/99887 (100.0%)
# Evaluating batch 1: users 1-100 of 99879
# Batch metrics - RMSE: 0.9626, MAE: 0.7536, Predictions: 2254
# Processed 100/99879 users (0.1%) - Elapsed: 2.23s - Est. remaining: 1964.37s
# Evaluating batch 2: users 101-200 of 99879
# Batch metrics - RMSE: 0.9591, MAE: 0.7622, Predictions: 2810
# Processed 200/99879 users (0.2%) - Elapsed: 4.26s - Est. remaining: 1778.28s
# Evaluating batch 3: users 201-300 of 99879
# Batch metrics - RMSE: 0.9147, MAE: 0.7079, Predictions: 2934
# Processed 300/99879 users (0.3%) - Elapsed: 6.12s - Est. remaining: 1701.80s
# Evaluating batch 4: users 301-400 of 99879
# Batch metrics - RMSE: 0.9922, MAE: 0.7697, Predictions: 3167
# Processed 400/99879 users (0.4%) - Elapsed: 8.42s - Est. remaining: 2094.03s
# Evaluating batch 5: users 401-500 of 99879
# Batch metrics - RMSE: 0.9919, MAE: 0.7782, Predictions: 3100
# Processed 500/99879 users (0.5%) - Elapsed: 10.40s - Est. remaining: 1803.73s
# Evaluating batch 6: users 501-600 of 99879
# Batch metrics - RMSE: 0.9611, MAE: 0.7537, Predictions: 2638
# Processed 600/99879 users (0.6%) - Elapsed: 12.51s - Est. remaining: 1940.90s
# Evaluating batch 7: users 601-700 of 99879
# Batch metrics - RMSE: 0.9517, MAE: 0.7486, Predictions: 2954
# Processed 700/99879 users (0.7%) - Elapsed: 14.45s - Est. remaining: 1775.30s
# Evaluating batch 8: users 701-800 of 99879
# Batch metrics - RMSE: 1.1336, MAE: 0.8838, Predictions: 3874
# Processed 800/99879 users (0.8%) - Elapsed: 16.35s - Est. remaining: 1733.88s
# Evaluating batch 9: users 801-900 of 99879
# Batch metrics - RMSE: 1.0117, MAE: 0.7813, Predictions: 2554
# Processed 900/99879 users (0.9%) - Elapsed: 18.45s - Est. remaining: 1903.37s
# Evaluating batch 10: users 901-1000 of 99879
# Batch metrics - RMSE: 0.9614, MAE: 0.7591, Predictions: 3821
# Processed 1000/99879 users (1.0%) - Elapsed: 20.40s - Est. remaining: 1745.21s
# Evaluating batch 11: users 1001-1100 of 99879
# Batch metrics - RMSE: 0.9942, MAE: 0.7829, Predictions: 2400
# Processed 1100/99879 users (1.1%) - Elapsed: 22.40s - Est. remaining: 1796.79s
# Evaluating batch 12: users 1101-1200 of 99879
# Batch metrics - RMSE: 0.9267, MAE: 0.7306, Predictions: 3030
# Processed 1200/99879 users (1.2%) - Elapsed: 24.71s - Est. remaining: 2110.74s
# Evaluating batch 13: users 1201-1300 of 99879
# Batch metrics - RMSE: 0.9004, MAE: 0.6928, Predictions: 2685
# Processed 1300/99879 users (1.3%) - Elapsed: 26.80s - Est. remaining: 1897.64s
# Evaluating batch 14: users 1301-1400 of 99879
# Batch metrics - RMSE: 0.9105, MAE: 0.7096, Predictions: 2556
# Processed 1400/99879 users (1.4%) - Elapsed: 29.10s - Est. remaining: 2045.41s
# Evaluating batch 15: users 1401-1500 of 99879
# Batch metrics - RMSE: 0.9712, MAE: 0.7590, Predictions: 2525
# Processed 1500/99879 users (1.5%) - Elapsed: 31.64s - Est. remaining: 2267.63s
# Evaluating batch 16: users 1501-1600 of 99879
# Batch metrics - RMSE: 0.9892, MAE: 0.7735, Predictions: 3177
# Processed 1600/99879 users (1.6%) - Elapsed: 35.92s - Est. remaining: 3795.53s
# Evaluating batch 17: users 1601-1700 of 99879
# Batch metrics - RMSE: 0.9777, MAE: 0.7674, Predictions: 2524
# Processed 1700/99879 users (1.7%) - Elapsed: 39.41s - Est. remaining: 3088.71s
# Evaluating batch 18: users 1701-1800 of 99879
# Batch metrics - RMSE: 1.0603, MAE: 0.8241, Predictions: 2972
# Processed 1800/99879 users (1.8%) - Elapsed: 42.41s - Est. remaining: 2524.55s
# Evaluating batch 19: users 1801-1900 of 99879
# Batch metrics - RMSE: 0.9132, MAE: 0.7108, Predictions: 3306
# Processed 1900/99879 users (1.9%) - Elapsed: 45.08s - Est. remaining: 2466.13s
# Evaluating batch 20: users 1901-2000 of 99879
# Batch metrics - RMSE: 0.9334, MAE: 0.7287, Predictions: 3015
# Processed 2000/99879 users (2.0%) - Elapsed: 47.61s - Est. remaining: 2279.60s
# Evaluating batch 21: users 2001-2100 of 99879
# Batch metrics - RMSE: 0.9631, MAE: 0.7437, Predictions: 3276
# Processed 2100/99879 users (2.1%) - Elapsed: 49.56s - Est. remaining: 1722.86s
# Evaluating batch 22: users 2101-2200 of 99879
# Batch metrics - RMSE: 0.9863, MAE: 0.7611, Predictions: 2776
# Processed 2200/99879 users (2.2%) - Elapsed: 51.55s - Est. remaining: 1801.20s
# Evaluating batch 23: users 2201-2300 of 99879
# Batch metrics - RMSE: 0.9096, MAE: 0.6977, Predictions: 3632
# Processed 2300/99879 users (2.3%) - Elapsed: 53.40s - Est. remaining: 1670.55s
# Evaluating batch 24: users 2301-2400 of 99879
# Batch metrics - RMSE: 0.9489, MAE: 0.7335, Predictions: 3496
# Processed 2400/99879 users (2.4%) - Elapsed: 55.10s - Est. remaining: 1495.33s
# Evaluating batch 25: users 2401-2500 of 99879
# Batch metrics - RMSE: 0.9934, MAE: 0.7852, Predictions: 2184
# Processed 2500/99879 users (2.5%) - Elapsed: 56.85s - Est. remaining: 1577.54s
# Evaluating batch 26: users 2501-2600 of 99879
# Batch metrics - RMSE: 0.9002, MAE: 0.6899, Predictions: 2669
# Processed 2600/99879 users (2.6%) - Elapsed: 58.60s - Est. remaining: 1563.27s
# Evaluating batch 27: users 2601-2700 of 99879
# Batch metrics - RMSE: 0.9229, MAE: 0.7000, Predictions: 2654
# Processed 2700/99879 users (2.7%) - Elapsed: 60.39s - Est. remaining: 1585.96s
# Evaluating batch 28: users 2701-2800 of 99879
# Batch metrics - RMSE: 1.0125, MAE: 0.7916, Predictions: 3209
# Processed 2800/99879 users (2.8%) - Elapsed: 62.13s - Est. remaining: 1556.17s
# Evaluating batch 29: users 2801-2900 of 99879
# Batch metrics - RMSE: 0.9816, MAE: 0.7696, Predictions: 3054
# Processed 2900/99879 users (2.9%) - Elapsed: 64.01s - Est. remaining: 1639.91s
# Evaluating batch 30: users 2901-3000 of 99879
# Batch metrics - RMSE: 0.9188, MAE: 0.7106, Predictions: 3010
# Processed 3000/99879 users (3.0%) - Elapsed: 65.97s - Est. remaining: 1739.94s
# Evaluating batch 31: users 3001-3100 of 99879
# Batch metrics - RMSE: 0.9024, MAE: 0.7006, Predictions: 2890
# Processed 3100/99879 users (3.1%) - Elapsed: 67.84s - Est. remaining: 1665.57s
# Evaluating batch 32: users 3101-3200 of 99879
# Batch metrics - RMSE: 0.9771, MAE: 0.7606, Predictions: 3134
# Processed 3200/99879 users (3.2%) - Elapsed: 69.76s - Est. remaining: 1691.88s
# Evaluating batch 33: users 3201-3300 of 99879
# Batch metrics - RMSE: 0.9661, MAE: 0.7535, Predictions: 3988
# Processed 3300/99879 users (3.3%) - Elapsed: 71.68s - Est. remaining: 1683.37s
# Evaluating batch 34: users 3301-3400 of 99879
# Batch metrics - RMSE: 0.9824, MAE: 0.7612, Predictions: 2871
# Processed 3400/99879 users (3.4%) - Elapsed: 73.50s - Est. remaining: 1619.88s
# Evaluating batch 35: users 3401-3500 of 99879
# Batch metrics - RMSE: 0.9183, MAE: 0.7158, Predictions: 2501
# Processed 3500/99879 users (3.5%) - Elapsed: 75.26s - Est. remaining: 1547.84s
# Evaluating batch 36: users 3501-3600 of 99879
# Batch metrics - RMSE: 1.0184, MAE: 0.8091, Predictions: 3308
# Processed 3600/99879 users (3.6%) - Elapsed: 77.08s - Est. remaining: 1606.89s
# Evaluating batch 37: users 3601-3700 of 99879
# Batch metrics - RMSE: 0.9459, MAE: 0.7282, Predictions: 3938
# Processed 3700/99879 users (3.7%) - Elapsed: 78.95s - Est. remaining: 1651.39s
# Evaluating batch 38: users 3701-3800 of 99879
# Batch metrics - RMSE: 0.9988, MAE: 0.7788, Predictions: 3005
# Processed 3800/99879 users (3.8%) - Elapsed: 81.08s - Est. remaining: 1890.83s
# Evaluating batch 39: users 3801-3900 of 99879
# Batch metrics - RMSE: 1.0390, MAE: 0.8288, Predictions: 2521
# Processed 3900/99879 users (3.9%) - Elapsed: 83.55s - Est. remaining: 2145.13s
# Evaluating batch 40: users 3901-4000 of 99879
# Batch metrics - RMSE: 0.9181, MAE: 0.7087, Predictions: 3475
# Processed 4000/99879 users (4.0%) - Elapsed: 85.51s - Est. remaining: 1730.62s
# Evaluating batch 41: users 4001-4100 of 99879
# Batch metrics - RMSE: 0.9290, MAE: 0.7190, Predictions: 3200
# Processed 4100/99879 users (4.1%) - Elapsed: 87.71s - Est. remaining: 1963.47s
# Evaluating batch 42: users 4101-4200 of 99879
# Batch metrics - RMSE: 0.9834, MAE: 0.7781, Predictions: 2908
# Processed 4200/99879 users (4.2%) - Elapsed: 90.26s - Est. remaining: 2200.62s
# Evaluating batch 43: users 4201-4300 of 99879
# Batch metrics - RMSE: 0.9243, MAE: 0.7224, Predictions: 3380
# Processed 4300/99879 users (4.3%) - Elapsed: 92.87s - Est. remaining: 2309.19s
# Evaluating batch 44: users 4301-4400 of 99879
# Batch metrics - RMSE: 0.9762, MAE: 0.7602, Predictions: 3753
# Processed 4400/99879 users (4.4%) - Elapsed: 95.38s - Est. remaining: 2118.68s
# Evaluating batch 45: users 4401-4500 of 99879
# Batch metrics - RMSE: 0.9505, MAE: 0.7409, Predictions: 2865
# Processed 4500/99879 users (4.5%) - Elapsed: 97.74s - Est. remaining: 2086.89s
# Evaluating batch 46: users 4501-4600 of 99879
# Batch metrics - RMSE: 0.9710, MAE: 0.7764, Predictions: 3656
# Processed 4600/99879 users (4.6%) - Elapsed: 99.89s - Est. remaining: 1891.29s
# Evaluating batch 47: users 4601-4700 of 99879
# Batch metrics - RMSE: 0.9512, MAE: 0.7367, Predictions: 2656
# Processed 4700/99879 users (4.7%) - Elapsed: 102.17s - Est. remaining: 2000.66s
# Evaluating batch 48: users 4701-4800 of 99879
# Batch metrics - RMSE: 0.9330, MAE: 0.7313, Predictions: 2581
# Processed 4800/99879 users (4.8%) - Elapsed: 104.13s - Est. remaining: 1664.83s
# Evaluating batch 49: users 4801-4900 of 99879
# Batch metrics - RMSE: 0.9668, MAE: 0.7553, Predictions: 2649
# Processed 4900/99879 users (4.9%) - Elapsed: 106.43s - Est. remaining: 2038.25s
# Evaluating batch 50: users 4901-5000 of 99879
# Batch metrics - RMSE: 0.9081, MAE: 0.7039, Predictions: 3241
# Processed 5000/99879 users (5.0%) - Elapsed: 110.02s - Est. remaining: 3262.88s
# Evaluating batch 51: users 5001-5100 of 99879
# Batch metrics - RMSE: 0.9995, MAE: 0.7841, Predictions: 3277
# Processed 5100/99879 users (5.1%) - Elapsed: 111.83s - Est. remaining: 1582.81s
# Evaluating batch 52: users 5101-5200 of 99879
# Batch metrics - RMSE: 0.9052, MAE: 0.6998, Predictions: 3053
# Processed 5200/99879 users (5.2%) - Elapsed: 113.70s - Est. remaining: 1622.80s
# Evaluating batch 53: users 5201-5300 of 99879
# Batch metrics - RMSE: 0.9599, MAE: 0.7461, Predictions: 2643
# Processed 5300/99879 users (5.3%) - Elapsed: 115.44s - Est. remaining: 1512.32s
# Evaluating batch 54: users 5301-5400 of 99879
# Batch metrics - RMSE: 0.9647, MAE: 0.7639, Predictions: 3175
# Processed 5400/99879 users (5.4%) - Elapsed: 117.31s - Est. remaining: 1613.70s
# Evaluating batch 55: users 5401-5500 of 99879
# Batch metrics - RMSE: 0.9411, MAE: 0.7444, Predictions: 2993
# Processed 5500/99879 users (5.5%) - Elapsed: 119.22s - Est. remaining: 1664.84s
# Evaluating batch 56: users 5501-5600 of 99879
# Batch metrics - RMSE: 0.9754, MAE: 0.7687, Predictions: 2905
# Processed 5600/99879 users (5.6%) - Elapsed: 121.04s - Est. remaining: 1586.71s
# Evaluating batch 57: users 5601-5700 of 99879
# Batch metrics - RMSE: 0.9865, MAE: 0.7625, Predictions: 2260
# Processed 5700/99879 users (5.7%) - Elapsed: 122.84s - Est. remaining: 1562.43s
# Evaluating batch 58: users 5701-5800 of 99879
# Batch metrics - RMSE: 0.9316, MAE: 0.7438, Predictions: 3322
# Processed 5800/99879 users (5.8%) - Elapsed: 124.87s - Est. remaining: 1725.41s
# Evaluating batch 59: users 5801-5900 of 99879
# Batch metrics - RMSE: 0.9835, MAE: 0.7712, Predictions: 2965
# Processed 5900/99879 users (5.9%) - Elapsed: 126.79s - Est. remaining: 1665.31s
# Evaluating batch 60: users 5901-6000 of 99879
# Batch metrics - RMSE: 0.9568, MAE: 0.7379, Predictions: 2434
# Processed 6000/99879 users (6.0%) - Elapsed: 128.75s - Est. remaining: 1704.84s
# Evaluating batch 61: users 6001-6100 of 99879
# Batch metrics - RMSE: 0.9450, MAE: 0.7351, Predictions: 3386
# Processed 6100/99879 users (6.1%) - Elapsed: 130.54s - Est. remaining: 1542.66s
# Evaluating batch 62: users 6101-6200 of 99879
# Batch metrics - RMSE: 0.9670, MAE: 0.7594, Predictions: 3096
# Processed 6200/99879 users (6.2%) - Elapsed: 132.39s - Est. remaining: 1599.10s
# Evaluating batch 63: users 6201-6300 of 99879
# Batch metrics - RMSE: 0.9327, MAE: 0.7174, Predictions: 2018
# Processed 6300/99879 users (6.3%) - Elapsed: 134.23s - Est. remaining: 1577.74s
# Evaluating batch 64: users 6301-6400 of 99879
# Batch metrics - RMSE: 0.9715, MAE: 0.7573, Predictions: 3449
# Processed 6400/99879 users (6.4%) - Elapsed: 136.12s - Est. remaining: 1628.40s
# Evaluating batch 65: users 6401-6500 of 99879
# Batch metrics - RMSE: 0.9708, MAE: 0.7553, Predictions: 2368
# Processed 6500/99879 users (6.5%) - Elapsed: 138.17s - Est. remaining: 1775.13s
# Evaluating batch 66: users 6501-6600 of 99879
# Batch metrics - RMSE: 0.9262, MAE: 0.7270, Predictions: 2435
# Processed 6600/99879 users (6.6%) - Elapsed: 140.29s - Est. remaining: 1845.99s
# Evaluating batch 67: users 6601-6700 of 99879
# Batch metrics - RMSE: 0.9849, MAE: 0.7707, Predictions: 2547
# Processed 6700/99879 users (6.7%) - Elapsed: 142.12s - Est. remaining: 1573.79s
# Evaluating batch 68: users 6701-6800 of 99879
# Batch metrics - RMSE: 1.0357, MAE: 0.8215, Predictions: 2860
# Processed 6800/99879 users (6.8%) - Elapsed: 143.98s - Est. remaining: 1599.09s
# Evaluating batch 69: users 6801-6900 of 99879
# Batch metrics - RMSE: 0.9492, MAE: 0.7491, Predictions: 2667
# Processed 6900/99879 users (6.9%) - Elapsed: 145.91s - Est. remaining: 1562.97s
# Evaluating batch 70: users 6901-7000 of 99879
# Batch metrics - RMSE: 1.0340, MAE: 0.8287, Predictions: 2692
# Processed 7000/99879 users (7.0%) - Elapsed: 147.82s - Est. remaining: 1642.99s
# Evaluating batch 71: users 7001-7100 of 99879
# Batch metrics - RMSE: 0.9078, MAE: 0.7140, Predictions: 2628
# Processed 7100/99879 users (7.1%) - Elapsed: 149.63s - Est. remaining: 1547.55s
# Evaluating batch 72: users 7101-7200 of 99879
# Batch metrics - RMSE: 0.9093, MAE: 0.6976, Predictions: 3012
# Processed 7200/99879 users (7.2%) - Elapsed: 151.49s - Est. remaining: 1594.08s
# Evaluating batch 73: users 7201-7300 of 99879
# Batch metrics - RMSE: 0.9993, MAE: 0.7775, Predictions: 2375
# Processed 7300/99879 users (7.3%) - Elapsed: 153.37s - Est. remaining: 1585.88s
# Evaluating batch 74: users 7301-7400 of 99879
# Batch metrics - RMSE: 1.0119, MAE: 0.7898, Predictions: 2367
# Processed 7400/99879 users (7.4%) - Elapsed: 155.41s - Est. remaining: 1748.78s
# Evaluating batch 75: users 7401-7500 of 99879
# Batch metrics - RMSE: 0.9809, MAE: 0.7708, Predictions: 2961
# Processed 7500/99879 users (7.5%) - Elapsed: 157.29s - Est. remaining: 1609.24s
# Evaluating batch 76: users 7501-7600 of 99879
# Batch metrics - RMSE: 0.9518, MAE: 0.7479, Predictions: 2879
# Processed 7600/99879 users (7.6%) - Elapsed: 159.25s - Est. remaining: 1679.48s
# Evaluating batch 77: users 7601-7700 of 99879
# Batch metrics - RMSE: 0.9878, MAE: 0.7914, Predictions: 2736
# Processed 7700/99879 users (7.7%) - Elapsed: 161.09s - Est. remaining: 1537.54s
# Evaluating batch 78: users 7701-7800 of 99879
# Batch metrics - RMSE: 0.9024, MAE: 0.6951, Predictions: 3298
# Processed 7800/99879 users (7.8%) - Elapsed: 162.95s - Est. remaining: 1586.52s
# Evaluating batch 79: users 7801-7900 of 99879
# Batch metrics - RMSE: 0.9479, MAE: 0.7349, Predictions: 2790
# Processed 7900/99879 users (7.9%) - Elapsed: 164.77s - Est. remaining: 1536.93s
# Evaluating batch 80: users 7901-8000 of 99879
# Batch metrics - RMSE: 1.0015, MAE: 0.7981, Predictions: 2367
# Processed 8000/99879 users (8.0%) - Elapsed: 166.59s - Est. remaining: 1528.87s
# Evaluating batch 81: users 8001-8100 of 99879
# Batch metrics - RMSE: 0.9678, MAE: 0.7498, Predictions: 3130
# Processed 8100/99879 users (8.1%) - Elapsed: 168.42s - Est. remaining: 1548.31s
# Evaluating batch 82: users 8101-8200 of 99879
# Batch metrics - RMSE: 0.9261, MAE: 0.7125, Predictions: 2795
# Processed 8200/99879 users (8.2%) - Elapsed: 170.24s - Est. remaining: 1542.95s
# Evaluating batch 83: users 8201-8300 of 99879
# Batch metrics - RMSE: 0.9269, MAE: 0.7208, Predictions: 2383
# Processed 8300/99879 users (8.3%) - Elapsed: 172.12s - Est. remaining: 1565.08s
# Evaluating batch 84: users 8301-8400 of 99879
# Batch metrics - RMSE: 0.9579, MAE: 0.7787, Predictions: 4142
# Processed 8400/99879 users (8.4%) - Elapsed: 173.99s - Est. remaining: 1573.44s
# Evaluating batch 85: users 8401-8500 of 99879
# Batch metrics - RMSE: 0.9861, MAE: 0.7710, Predictions: 3021
# Processed 8500/99879 users (8.5%) - Elapsed: 175.86s - Est. remaining: 1584.51s
# Evaluating batch 86: users 8501-8600 of 99879
# Batch metrics - RMSE: 0.9966, MAE: 0.7726, Predictions: 2947
# Processed 8600/99879 users (8.6%) - Elapsed: 177.70s - Est. remaining: 1541.70s
# Evaluating batch 87: users 8601-8700 of 99879
# Batch metrics - RMSE: 1.0400, MAE: 0.8141, Predictions: 3216
# Processed 8700/99879 users (8.7%) - Elapsed: 179.55s - Est. remaining: 1526.33s
# Evaluating batch 88: users 8701-8800 of 99879
# Batch metrics - RMSE: 0.9969, MAE: 0.7633, Predictions: 2952
# Processed 8800/99879 users (8.8%) - Elapsed: 181.41s - Est. remaining: 1556.54s
# Evaluating batch 89: users 8801-8900 of 99879
# Batch metrics - RMSE: 0.9454, MAE: 0.7410, Predictions: 2138
# Processed 8900/99879 users (8.9%) - Elapsed: 183.22s - Est. remaining: 1519.35s
# Evaluating batch 90: users 8901-9000 of 99879
# Batch metrics - RMSE: 0.9370, MAE: 0.7178, Predictions: 3758
# Processed 9000/99879 users (9.0%) - Elapsed: 185.09s - Est. remaining: 1562.21s
# Evaluating batch 91: users 9001-9100 of 99879
# Batch metrics - RMSE: 0.9639, MAE: 0.7544, Predictions: 3532
# Processed 9100/99879 users (9.1%) - Elapsed: 186.92s - Est. remaining: 1525.99s
# Evaluating batch 92: users 9101-9200 of 99879
# Batch metrics - RMSE: 1.0003, MAE: 0.7854, Predictions: 3904
# Processed 9200/99879 users (9.2%) - Elapsed: 188.93s - Est. remaining: 1632.22s
# Evaluating batch 93: users 9201-9300 of 99879
# Batch metrics - RMSE: 0.9629, MAE: 0.7420, Predictions: 2727
# Processed 9300/99879 users (9.3%) - Elapsed: 190.74s - Est. remaining: 1512.67s
# Evaluating batch 94: users 9301-9400 of 99879
# Batch metrics - RMSE: 0.9657, MAE: 0.7633, Predictions: 2490
# Processed 9400/99879 users (9.4%) - Elapsed: 192.63s - Est. remaining: 1545.38s
# Evaluating batch 95: users 9401-9500 of 99879
# Batch metrics - RMSE: 0.9847, MAE: 0.7755, Predictions: 3302
# Processed 9500/99879 users (9.5%) - Elapsed: 194.47s - Est. remaining: 1530.11s
# Evaluating batch 96: users 9501-9600 of 99879
# Batch metrics - RMSE: 0.8758, MAE: 0.6696, Predictions: 4046
# Processed 9600/99879 users (9.6%) - Elapsed: 196.37s - Est. remaining: 1593.42s
# Evaluating batch 97: users 9601-9700 of 99879
# Batch metrics - RMSE: 0.9415, MAE: 0.7411, Predictions: 2580
# Processed 9700/99879 users (9.7%) - Elapsed: 198.31s - Est. remaining: 1625.92s
# Evaluating batch 98: users 9701-9800 of 99879
# Batch metrics - RMSE: 0.9317, MAE: 0.7254, Predictions: 2846
# Processed 9800/99879 users (9.8%) - Elapsed: 200.21s - Est. remaining: 1550.26s
# Evaluating batch 99: users 9801-9900 of 99879
# Batch metrics - RMSE: 0.9289, MAE: 0.7269, Predictions: 2426
# Processed 9900/99879 users (9.9%) - Elapsed: 202.11s - Est. remaining: 1576.43s
# Evaluating batch 100: users 9901-10000 of 99879
# Batch metrics - RMSE: 0.9299, MAE: 0.7197, Predictions: 2972
# Processed 10000/99879 users (10.0%) - Elapsed: 205.12s - Est. remaining: 2573.23s
# Evaluating batch 101: users 10001-10100 of 99879
# Batch metrics - RMSE: 0.9859, MAE: 0.7713, Predictions: 3002
# Processed 10100/99879 users (10.1%) - Elapsed: 207.49s - Est. remaining: 1893.44s
# Evaluating batch 102: users 10101-10200 of 99879
# Batch metrics - RMSE: 0.9664, MAE: 0.7523, Predictions: 3067
# Processed 10200/99879 users (10.2%) - Elapsed: 209.41s - Est. remaining: 1596.28s
# Evaluating batch 103: users 10201-10300 of 99879
# Batch metrics - RMSE: 0.9767, MAE: 0.7711, Predictions: 3030
# Processed 10300/99879 users (10.3%) - Elapsed: 211.37s - Est. remaining: 1586.44s
# Evaluating batch 104: users 10301-10400 of 99879
# Batch metrics - RMSE: 1.0625, MAE: 0.8412, Predictions: 2867
# Processed 10400/99879 users (10.4%) - Elapsed: 213.33s - Est. remaining: 1630.30s
# Evaluating batch 105: users 10401-10500 of 99879
# Batch metrics - RMSE: 1.0035, MAE: 0.7887, Predictions: 3167
# Processed 10500/99879 users (10.5%) - Elapsed: 215.63s - Est. remaining: 1861.76s
# Evaluating batch 106: users 10501-10600 of 99879
# Batch metrics - RMSE: 0.9801, MAE: 0.7749, Predictions: 3177
# Processed 10600/99879 users (10.6%) - Elapsed: 217.79s - Est. remaining: 1779.33s
# Evaluating batch 107: users 10601-10700 of 99879
# Batch metrics - RMSE: 0.9111, MAE: 0.7118, Predictions: 3449
# Processed 10700/99879 users (10.7%) - Elapsed: 220.09s - Est. remaining: 1904.86s
# Evaluating batch 108: users 10701-10800 of 99879
# Batch metrics - RMSE: 0.9760, MAE: 0.7736, Predictions: 3440
# Processed 10800/99879 users (10.8%) - Elapsed: 222.31s - Est. remaining: 1833.24s
# Evaluating batch 109: users 10801-10900 of 99879
# Batch metrics - RMSE: 1.0068, MAE: 0.7885, Predictions: 2329
# Processed 10900/99879 users (10.9%) - Elapsed: 224.30s - Est. remaining: 1649.67s
# Evaluating batch 110: users 10901-11000 of 99879
# Batch metrics - RMSE: 0.9800, MAE: 0.7726, Predictions: 2965
# Processed 11000/99879 users (11.0%) - Elapsed: 226.12s - Est. remaining: 1485.17s
# Evaluating batch 111: users 11001-11100 of 99879
# Batch metrics - RMSE: 0.8987, MAE: 0.6936, Predictions: 2649
# Processed 11100/99879 users (11.1%) - Elapsed: 227.93s - Est. remaining: 1461.30s
# Evaluating batch 112: users 11101-11200 of 99879
# Batch metrics - RMSE: 0.9365, MAE: 0.7268, Predictions: 2620
# Processed 11200/99879 users (11.2%) - Elapsed: 229.80s - Est. remaining: 1517.30s
# Evaluating batch 113: users 11201-11300 of 99879
# Batch metrics - RMSE: 0.9537, MAE: 0.7482, Predictions: 3461
# Processed 11300/99879 users (11.3%) - Elapsed: 231.64s - Est. remaining: 1494.33s
# Evaluating batch 114: users 11301-11400 of 99879
# Batch metrics - RMSE: 0.8948, MAE: 0.6776, Predictions: 2706
# Processed 11400/99879 users (11.4%) - Elapsed: 233.47s - Est. remaining: 1491.75s
# Evaluating batch 115: users 11401-11500 of 99879
# Batch metrics - RMSE: 0.9439, MAE: 0.7139, Predictions: 2791
# Processed 11500/99879 users (11.5%) - Elapsed: 235.88s - Est. remaining: 1958.48s
# Evaluating batch 116: users 11501-11600 of 99879
# Batch metrics - RMSE: 1.0121, MAE: 0.7956, Predictions: 3521
# Processed 11600/99879 users (11.6%) - Elapsed: 238.36s - Est. remaining: 1989.81s
# Evaluating batch 117: users 11601-11700 of 99879
# Batch metrics - RMSE: 0.9515, MAE: 0.7407, Predictions: 2129
# Processed 11700/99879 users (11.7%) - Elapsed: 241.76s - Est. remaining: 2733.54s
# Evaluating batch 118: users 11701-11800 of 99879
# Batch metrics - RMSE: 0.9459, MAE: 0.7446, Predictions: 3087
# Processed 11800/99879 users (11.8%) - Elapsed: 244.33s - Est. remaining: 2046.95s
# Evaluating batch 119: users 11801-11900 of 99879
# Batch metrics - RMSE: 0.9789, MAE: 0.7680, Predictions: 3355
# Processed 11900/99879 users (11.9%) - Elapsed: 247.12s - Est. remaining: 2204.75s
# Evaluating batch 120: users 11901-12000 of 99879
# Batch metrics - RMSE: 0.9445, MAE: 0.7215, Predictions: 1954
# Processed 12000/99879 users (12.0%) - Elapsed: 249.74s - Est. remaining: 1996.61s
# Evaluating batch 121: users 12001-12100 of 99879
# Batch metrics - RMSE: 0.9896, MAE: 0.7800, Predictions: 3475
# Processed 12100/99879 users (12.1%) - Elapsed: 252.16s - Est. remaining: 1932.89s
# Evaluating batch 122: users 12101-12200 of 99879
# Batch metrics - RMSE: 0.9586, MAE: 0.7509, Predictions: 4162
# Processed 12200/99879 users (12.2%) - Elapsed: 254.45s - Est. remaining: 1837.75s
# Evaluating batch 123: users 12201-12300 of 99879
# Batch metrics - RMSE: 0.9900, MAE: 0.7797, Predictions: 2882
# Processed 12300/99879 users (12.3%) - Elapsed: 256.73s - Est. remaining: 1857.55s
# Evaluating batch 124: users 12301-12400 of 99879
# Batch metrics - RMSE: 0.9268, MAE: 0.7167, Predictions: 2442
# Processed 12400/99879 users (12.4%) - Elapsed: 259.07s - Est. remaining: 1850.18s
# Evaluating batch 125: users 12401-12500 of 99879
# Batch metrics - RMSE: 0.9301, MAE: 0.7137, Predictions: 2504
# Processed 12500/99879 users (12.5%) - Elapsed: 261.16s - Est. remaining: 1688.16s
# Evaluating batch 126: users 12501-12600 of 99879
# Batch metrics - RMSE: 0.9577, MAE: 0.7417, Predictions: 2927
# Processed 12600/99879 users (12.6%) - Elapsed: 263.32s - Est. remaining: 1755.18s
# Evaluating batch 127: users 12601-12700 of 99879
# Batch metrics - RMSE: 1.0133, MAE: 0.7968, Predictions: 3100
# Processed 12700/99879 users (12.7%) - Elapsed: 265.56s - Est. remaining: 1800.24s
# Evaluating batch 128: users 12701-12800 of 99879
# Batch metrics - RMSE: 0.9286, MAE: 0.7188, Predictions: 3831
# Processed 12800/99879 users (12.8%) - Elapsed: 267.83s - Est. remaining: 1819.95s
# Evaluating batch 129: users 12801-12900 of 99879
# Batch metrics - RMSE: 0.9520, MAE: 0.7422, Predictions: 2545
# Processed 12900/99879 users (12.9%) - Elapsed: 270.18s - Est. remaining: 1855.26s
# Evaluating batch 130: users 12901-13000 of 99879
# Batch metrics - RMSE: 0.9671, MAE: 0.7651, Predictions: 2445
# Processed 13000/99879 users (13.0%) - Elapsed: 272.29s - Est. remaining: 1674.16s
# Evaluating batch 131: users 13001-13100 of 99879
# Batch metrics - RMSE: 0.9521, MAE: 0.7463, Predictions: 2856
# Processed 13100/99879 users (13.1%) - Elapsed: 274.80s - Est. remaining: 2032.36s
# Evaluating batch 132: users 13101-13200 of 99879
# Batch metrics - RMSE: 0.9826, MAE: 0.7730, Predictions: 2701
# Processed 13200/99879 users (13.2%) - Elapsed: 277.01s - Est. remaining: 1699.77s
# Evaluating batch 133: users 13201-13300 of 99879
# Batch metrics - RMSE: 0.9549, MAE: 0.7533, Predictions: 2708
# Processed 13300/99879 users (13.3%) - Elapsed: 278.94s - Est. remaining: 1512.53s
# Evaluating batch 134: users 13301-13400 of 99879
# Batch metrics - RMSE: 0.9238, MAE: 0.7143, Predictions: 2726
# Processed 13400/99879 users (13.4%) - Elapsed: 280.84s - Est. remaining: 1496.09s
# Evaluating batch 135: users 13401-13500 of 99879
# Batch metrics - RMSE: 1.0352, MAE: 0.8061, Predictions: 3180
# Processed 13500/99879 users (13.5%) - Elapsed: 283.30s - Est. remaining: 2000.54s
# Evaluating batch 136: users 13501-13600 of 99879
# Batch metrics - RMSE: 0.9536, MAE: 0.7488, Predictions: 3177
# Processed 13600/99879 users (13.6%) - Elapsed: 285.84s - Est. remaining: 2007.26s
# Evaluating batch 137: users 13601-13700 of 99879
# Batch metrics - RMSE: 0.8777, MAE: 0.6730, Predictions: 3204
# Processed 13700/99879 users (13.7%) - Elapsed: 288.25s - Est. remaining: 1859.74s
# Evaluating batch 138: users 13701-13800 of 99879
# Batch metrics - RMSE: 0.9309, MAE: 0.7188, Predictions: 3195
# Processed 13800/99879 users (13.8%) - Elapsed: 290.58s - Est. remaining: 1858.31s
# Evaluating batch 139: users 13801-13900 of 99879
# Batch metrics - RMSE: 0.9715, MAE: 0.7568, Predictions: 2376
# Processed 13900/99879 users (13.9%) - Elapsed: 292.53s - Est. remaining: 1508.07s
# Evaluating batch 140: users 13901-14000 of 99879
# Batch metrics - RMSE: 0.9736, MAE: 0.7594, Predictions: 3370
# Processed 14000/99879 users (14.0%) - Elapsed: 294.54s - Est. remaining: 1582.75s
# Evaluating batch 141: users 14001-14100 of 99879
# Batch metrics - RMSE: 0.9973, MAE: 0.7861, Predictions: 3480
# Processed 14100/99879 users (14.1%) - Elapsed: 296.50s - Est. remaining: 1546.59s
# Evaluating batch 142: users 14101-14200 of 99879
# Batch metrics - RMSE: 0.9570, MAE: 0.7396, Predictions: 2720
# Processed 14200/99879 users (14.2%) - Elapsed: 298.47s - Est. remaining: 1549.08s
# Evaluating batch 143: users 14201-14300 of 99879
# Batch metrics - RMSE: 1.0202, MAE: 0.7993, Predictions: 2816
# Processed 14300/99879 users (14.3%) - Elapsed: 300.38s - Est. remaining: 1495.92s
# Evaluating batch 144: users 14301-14400 of 99879
# Batch metrics - RMSE: 0.9590, MAE: 0.7473, Predictions: 2611
# Processed 14400/99879 users (14.4%) - Elapsed: 302.36s - Est. remaining: 1559.99s
# Evaluating batch 145: users 14401-14500 of 99879
# Batch metrics - RMSE: 0.9146, MAE: 0.7092, Predictions: 3935
# Processed 14500/99879 users (14.5%) - Elapsed: 304.52s - Est. remaining: 1694.77s
# Evaluating batch 146: users 14501-14600 of 99879
# Batch metrics - RMSE: 0.9297, MAE: 0.7229, Predictions: 2656
# Processed 14600/99879 users (14.6%) - Elapsed: 306.58s - Est. remaining: 1597.27s
# Evaluating batch 147: users 14601-14700 of 99879
# Batch metrics - RMSE: 0.9680, MAE: 0.7627, Predictions: 2902
# Processed 14700/99879 users (14.7%) - Elapsed: 308.58s - Est. remaining: 1567.29s
# Evaluating batch 148: users 14701-14800 of 99879
# Batch metrics - RMSE: 0.9346, MAE: 0.7166, Predictions: 2181
# Processed 14800/99879 users (14.8%) - Elapsed: 310.58s - Est. remaining: 1568.85s
# Evaluating batch 149: users 14801-14900 of 99879
# Batch metrics - RMSE: 0.9724, MAE: 0.7681, Predictions: 2975
# Processed 14900/99879 users (14.9%) - Elapsed: 312.67s - Est. remaining: 1629.05s
# Evaluating batch 150: users 14901-15000 of 99879
# Batch metrics - RMSE: 0.9592, MAE: 0.7389, Predictions: 2401
# Processed 15000/99879 users (15.0%) - Elapsed: 314.73s - Est. remaining: 1604.20s
# Evaluating batch 151: users 15001-15100 of 99879
# Batch metrics - RMSE: 0.9728, MAE: 0.7699, Predictions: 2562
# Processed 15100/99879 users (15.1%) - Elapsed: 316.86s - Est. remaining: 1599.78s
# Evaluating batch 152: users 15101-15200 of 99879
# Batch metrics - RMSE: 1.0594, MAE: 0.8364, Predictions: 2868
# Processed 15200/99879 users (15.2%) - Elapsed: 318.93s - Est. remaining: 1630.07s
# Evaluating batch 153: users 15201-15300 of 99879
# Batch metrics - RMSE: 1.0213, MAE: 0.8134, Predictions: 2747
# Processed 15300/99879 users (15.3%) - Elapsed: 321.16s - Est. remaining: 1720.34s
# Evaluating batch 154: users 15301-15400 of 99879
# Batch metrics - RMSE: 0.9886, MAE: 0.7706, Predictions: 2530
# Processed 15400/99879 users (15.4%) - Elapsed: 323.57s - Est. remaining: 1656.63s
# Evaluating batch 155: users 15401-15500 of 99879
# Batch metrics - RMSE: 0.9816, MAE: 0.7692, Predictions: 3814
# Processed 15500/99879 users (15.5%) - Elapsed: 325.47s - Est. remaining: 1449.63s
# Evaluating batch 156: users 15501-15600 of 99879
# Batch metrics - RMSE: 0.8726, MAE: 0.6754, Predictions: 4207
# Processed 15600/99879 users (15.6%) - Elapsed: 327.34s - Est. remaining: 1445.42s
# Evaluating batch 157: users 15601-15700 of 99879
# Batch metrics - RMSE: 0.9733, MAE: 0.7632, Predictions: 2915
# Processed 15700/99879 users (15.7%) - Elapsed: 329.22s - Est. remaining: 1463.91s
# Evaluating batch 158: users 15701-15800 of 99879
# Batch metrics - RMSE: 0.9222, MAE: 0.7115, Predictions: 3244
# Processed 15800/99879 users (15.8%) - Elapsed: 331.02s - Est. remaining: 1378.89s
# Evaluating batch 159: users 15801-15900 of 99879
# Batch metrics - RMSE: 1.0031, MAE: 0.7919, Predictions: 2975
# Processed 15900/99879 users (15.9%) - Elapsed: 332.94s - Est. remaining: 1462.07s
# Evaluating batch 160: users 15901-16000 of 99879
# Batch metrics - RMSE: 1.0001, MAE: 0.7891, Predictions: 2659
# Processed 16000/99879 users (16.0%) - Elapsed: 334.69s - Est. remaining: 1332.80s
# Evaluating batch 161: users 16001-16100 of 99879
# Batch metrics - RMSE: 0.9223, MAE: 0.7267, Predictions: 3122
# Processed 16100/99879 users (16.1%) - Elapsed: 336.31s - Est. remaining: 1233.23s
# Evaluating batch 162: users 16101-16200 of 99879
# Batch metrics - RMSE: 0.9453, MAE: 0.7301, Predictions: 3667
# Processed 16200/99879 users (16.2%) - Elapsed: 338.16s - Est. remaining: 1376.52s
# Evaluating batch 163: users 16201-16300 of 99879
# Batch metrics - RMSE: 0.9267, MAE: 0.7158, Predictions: 3034
# Processed 16300/99879 users (16.3%) - Elapsed: 340.10s - Est. remaining: 1508.60s
# Evaluating batch 164: users 16301-16400 of 99879
# Batch metrics - RMSE: 1.0019, MAE: 0.7838, Predictions: 2681
# Processed 16400/99879 users (16.4%) - Elapsed: 341.79s - Est. remaining: 1273.05s
# Evaluating batch 165: users 16401-16500 of 99879
# Batch metrics - RMSE: 1.0031, MAE: 0.7835, Predictions: 2538
# Processed 16500/99879 users (16.5%) - Elapsed: 343.41s - Est. remaining: 1224.84s
# Evaluating batch 166: users 16501-16600 of 99879
# Batch metrics - RMSE: 0.9084, MAE: 0.7095, Predictions: 3198
# Processed 16600/99879 users (16.6%) - Elapsed: 345.23s - Est. remaining: 1350.78s
# Evaluating batch 167: users 16601-16700 of 99879
# Batch metrics - RMSE: 0.9410, MAE: 0.7375, Predictions: 2826
# Processed 16700/99879 users (16.7%) - Elapsed: 347.13s - Est. remaining: 1457.34s
# Evaluating batch 168: users 16701-16800 of 99879
# Batch metrics - RMSE: 0.9925, MAE: 0.7696, Predictions: 2285
# Processed 16800/99879 users (16.8%) - Elapsed: 349.12s - Est. remaining: 1523.67s
# Evaluating batch 169: users 16801-16900 of 99879
# Batch metrics - RMSE: 1.0100, MAE: 0.8079, Predictions: 2554
# Processed 16900/99879 users (16.9%) - Elapsed: 351.06s - Est. remaining: 1488.64s
# Evaluating batch 170: users 16901-17000 of 99879
# Batch metrics - RMSE: 0.9776, MAE: 0.7678, Predictions: 3783
# Processed 17000/99879 users (17.0%) - Elapsed: 352.78s - Est. remaining: 1286.28s
# Evaluating batch 171: users 17001-17100 of 99879
# Batch metrics - RMSE: 0.9272, MAE: 0.7224, Predictions: 3333
# Processed 17100/99879 users (17.1%) - Elapsed: 354.63s - Est. remaining: 1384.06s
# Evaluating batch 172: users 17101-17200 of 99879
# Batch metrics - RMSE: 1.0145, MAE: 0.7860, Predictions: 3012
# Processed 17200/99879 users (17.2%) - Elapsed: 356.42s - Est. remaining: 1345.18s
# Evaluating batch 173: users 17201-17300 of 99879
# Batch metrics - RMSE: 0.9670, MAE: 0.7504, Predictions: 1998
# Processed 17300/99879 users (17.3%) - Elapsed: 358.28s - Est. remaining: 1397.23s
# Evaluating batch 174: users 17301-17400 of 99879
# Batch metrics - RMSE: 0.9015, MAE: 0.7092, Predictions: 2622
# Processed 17400/99879 users (17.4%) - Elapsed: 359.89s - Est. remaining: 1201.72s
# Evaluating batch 175: users 17401-17500 of 99879
# Batch metrics - RMSE: 0.9721, MAE: 0.7589, Predictions: 3269
# Processed 17500/99879 users (17.5%) - Elapsed: 361.60s - Est. remaining: 1308.18s
# Evaluating batch 176: users 17501-17600 of 99879
# Batch metrics - RMSE: 0.9837, MAE: 0.7605, Predictions: 2885
# Processed 17600/99879 users (17.6%) - Elapsed: 363.26s - Est. remaining: 1245.70s
# Evaluating batch 177: users 17601-17700 of 99879
# Batch metrics - RMSE: 0.9364, MAE: 0.7336, Predictions: 2321
# Processed 17700/99879 users (17.7%) - Elapsed: 364.97s - Est. remaining: 1298.43s
# Evaluating batch 178: users 17701-17800 of 99879
# Batch metrics - RMSE: 0.8833, MAE: 0.6909, Predictions: 2929
# Processed 17800/99879 users (17.8%) - Elapsed: 366.73s - Est. remaining: 1332.11s
# Evaluating batch 179: users 17801-17900 of 99879
# Batch metrics - RMSE: 0.9476, MAE: 0.7370, Predictions: 2799
# Processed 17900/99879 users (17.9%) - Elapsed: 368.37s - Est. remaining: 1245.26s
# Evaluating batch 180: users 17901-18000 of 99879
# Batch metrics - RMSE: 0.9963, MAE: 0.7798, Predictions: 2571
# Processed 18000/99879 users (18.0%) - Elapsed: 369.91s - Est. remaining: 1137.30s
# Evaluating batch 181: users 18001-18100 of 99879
# Batch metrics - RMSE: 1.0179, MAE: 0.7880, Predictions: 2916
# Processed 18100/99879 users (18.1%) - Elapsed: 371.58s - Est. remaining: 1256.12s
# Evaluating batch 182: users 18101-18200 of 99879
# Batch metrics - RMSE: 0.9721, MAE: 0.7607, Predictions: 3996
# Processed 18200/99879 users (18.2%) - Elapsed: 373.38s - Est. remaining: 1332.18s
# Evaluating batch 183: users 18201-18300 of 99879
# Batch metrics - RMSE: 0.9853, MAE: 0.7703, Predictions: 2700
# Processed 18300/99879 users (18.3%) - Elapsed: 375.18s - Est. remaining: 1365.63s
# Evaluating batch 184: users 18301-18400 of 99879
# Batch metrics - RMSE: 0.9535, MAE: 0.7355, Predictions: 3614
# Processed 18400/99879 users (18.4%) - Elapsed: 376.83s - Est. remaining: 1236.85s
# Evaluating batch 185: users 18401-18500 of 99879
# Batch metrics - RMSE: 0.9622, MAE: 0.7459, Predictions: 2626
# Processed 18500/99879 users (18.5%) - Elapsed: 378.51s - Est. remaining: 1241.03s
# Evaluating batch 186: users 18501-18600 of 99879
# Batch metrics - RMSE: 1.0415, MAE: 0.8171, Predictions: 3736
# Processed 18600/99879 users (18.6%) - Elapsed: 380.09s - Est. remaining: 1178.54s
# Evaluating batch 187: users 18601-18700 of 99879
# Batch metrics - RMSE: 0.9895, MAE: 0.7809, Predictions: 3237
# Processed 18700/99879 users (18.7%) - Elapsed: 381.74s - Est. remaining: 1216.06s
# Evaluating batch 188: users 18701-18800 of 99879
# Batch metrics - RMSE: 0.9542, MAE: 0.7461, Predictions: 2634
# Processed 18800/99879 users (18.8%) - Elapsed: 383.38s - Est. remaining: 1221.05s
# Evaluating batch 189: users 18801-18900 of 99879
# Batch metrics - RMSE: 0.9728, MAE: 0.7509, Predictions: 2913
# Processed 18900/99879 users (18.9%) - Elapsed: 385.03s - Est. remaining: 1229.26s
# Evaluating batch 190: users 18901-19000 of 99879
# Batch metrics - RMSE: 0.9931, MAE: 0.7816, Predictions: 3143
# Processed 19000/99879 users (19.0%) - Elapsed: 386.61s - Est. remaining: 1169.51s
# Evaluating batch 191: users 19001-19100 of 99879
# Batch metrics - RMSE: 0.9286, MAE: 0.7110, Predictions: 2129
# Processed 19100/99879 users (19.1%) - Elapsed: 388.26s - Est. remaining: 1214.11s
# Evaluating batch 192: users 19101-19200 of 99879
# Batch metrics - RMSE: 0.9838, MAE: 0.7779, Predictions: 2682
# Processed 19200/99879 users (19.2%) - Elapsed: 389.84s - Est. remaining: 1169.84s
# Evaluating batch 193: users 19201-19300 of 99879
# Batch metrics - RMSE: 0.9102, MAE: 0.7030, Predictions: 3451
# Processed 19300/99879 users (19.3%) - Elapsed: 391.58s - Est. remaining: 1250.58s
# Evaluating batch 194: users 19301-19400 of 99879
# Batch metrics - RMSE: 0.9405, MAE: 0.7438, Predictions: 2408
# Processed 19400/99879 users (19.4%) - Elapsed: 393.20s - Est. remaining: 1194.31s
# Evaluating batch 195: users 19401-19500 of 99879
# Batch metrics - RMSE: 0.9749, MAE: 0.7558, Predictions: 2263
# Processed 19500/99879 users (19.5%) - Elapsed: 394.83s - Est. remaining: 1198.45s
# Evaluating batch 196: users 19501-19600 of 99879
# Batch metrics - RMSE: 1.0407, MAE: 0.8174, Predictions: 3376
# Processed 19600/99879 users (19.6%) - Elapsed: 396.42s - Est. remaining: 1170.47s
# Evaluating batch 197: users 19601-19700 of 99879
# Batch metrics - RMSE: 0.9560, MAE: 0.7412, Predictions: 2697
# Processed 19700/99879 users (19.7%) - Elapsed: 398.05s - Est. remaining: 1205.09s
# Evaluating batch 198: users 19701-19800 of 99879
# Batch metrics - RMSE: 0.9388, MAE: 0.7281, Predictions: 2414
# Processed 19800/99879 users (19.8%) - Elapsed: 399.69s - Est. remaining: 1192.38s
# Evaluating batch 199: users 19801-19900 of 99879
# Batch metrics - RMSE: 0.9366, MAE: 0.7305, Predictions: 2687
# Processed 19900/99879 users (19.9%) - Elapsed: 401.49s - Est. remaining: 1334.05s
# Evaluating batch 200: users 19901-20000 of 99879
# Batch metrics - RMSE: 0.9064, MAE: 0.6842, Predictions: 2563
# Processed 20000/99879 users (20.0%) - Elapsed: 403.15s - Est. remaining: 1221.35s
# Evaluating batch 201: users 20001-20100 of 99879
# Batch metrics - RMSE: 0.9070, MAE: 0.6929, Predictions: 2497
# Processed 20100/99879 users (20.1%) - Elapsed: 404.78s - Est. remaining: 1187.91s
# Evaluating batch 202: users 20101-20200 of 99879
# Batch metrics - RMSE: 1.0979, MAE: 0.8755, Predictions: 4255
# Processed 20200/99879 users (20.2%) - Elapsed: 406.57s - Est. remaining: 1308.33s
# Evaluating batch 203: users 20201-20300 of 99879
# Batch metrics - RMSE: 0.9178, MAE: 0.7176, Predictions: 3840
# Processed 20300/99879 users (20.3%) - Elapsed: 408.61s - Est. remaining: 1410.14s
# Evaluating batch 204: users 20301-20400 of 99879
# Batch metrics - RMSE: 0.9689, MAE: 0.7579, Predictions: 2383
# Processed 20400/99879 users (20.4%) - Elapsed: 410.34s - Est. remaining: 1270.87s
# Evaluating batch 205: users 20401-20500 of 99879
# Batch metrics - RMSE: 0.9892, MAE: 0.7586, Predictions: 2381
# Processed 20500/99879 users (20.5%) - Elapsed: 411.98s - Est. remaining: 1184.33s
# Evaluating batch 206: users 20501-20600 of 99879
# Batch metrics - RMSE: 1.0115, MAE: 0.7943, Predictions: 2295
# Processed 20600/99879 users (20.6%) - Elapsed: 413.57s - Est. remaining: 1133.69s
# Evaluating batch 207: users 20601-20700 of 99879
# Batch metrics - RMSE: 1.0019, MAE: 0.7857, Predictions: 2163
# Processed 20700/99879 users (20.7%) - Elapsed: 415.31s - Est. remaining: 1266.82s
# Evaluating batch 208: users 20701-20800 of 99879
# Batch metrics - RMSE: 0.9408, MAE: 0.7403, Predictions: 2351
# Processed 20800/99879 users (20.8%) - Elapsed: 417.10s - Est. remaining: 1241.54s
# Evaluating batch 209: users 20801-20900 of 99879
# Batch metrics - RMSE: 0.9253, MAE: 0.7153, Predictions: 2368
# Processed 20900/99879 users (20.9%) - Elapsed: 418.85s - Est. remaining: 1271.56s
# Evaluating batch 210: users 20901-21000 of 99879
# Batch metrics - RMSE: 0.9584, MAE: 0.7499, Predictions: 2450
# Processed 21000/99879 users (21.0%) - Elapsed: 420.43s - Est. remaining: 1123.21s
# Evaluating batch 211: users 21001-21100 of 99879
# Batch metrics - RMSE: 0.9455, MAE: 0.7304, Predictions: 3294
# Processed 21100/99879 users (21.1%) - Elapsed: 422.11s - Est. remaining: 1228.95s
# Evaluating batch 212: users 21101-21200 of 99879
# Batch metrics - RMSE: 0.9987, MAE: 0.7816, Predictions: 3408
# Processed 21200/99879 users (21.2%) - Elapsed: 423.99s - Est. remaining: 1376.88s
# Evaluating batch 213: users 21201-21300 of 99879
# Batch metrics - RMSE: 0.9600, MAE: 0.7403, Predictions: 2268
# Processed 21300/99879 users (21.3%) - Elapsed: 425.91s - Est. remaining: 1329.55s
# Evaluating batch 214: users 21301-21400 of 99879
# Batch metrics - RMSE: 0.8804, MAE: 0.6756, Predictions: 3798
# Processed 21400/99879 users (21.4%) - Elapsed: 428.70s - Est. remaining: 2060.07s
# Evaluating batch 215: users 21401-21500 of 99879
# Batch metrics - RMSE: 1.0107, MAE: 0.7907, Predictions: 1928
# Processed 21500/99879 users (21.5%) - Elapsed: 431.00s - Est. remaining: 1667.90s
# Evaluating batch 216: users 21501-21600 of 99879
# Batch metrics - RMSE: 1.0353, MAE: 0.8013, Predictions: 2411
# Processed 21600/99879 users (21.6%) - Elapsed: 433.36s - Est. remaining: 1708.83s
# Evaluating batch 217: users 21601-21700 of 99879
# Batch metrics - RMSE: 0.9428, MAE: 0.7361, Predictions: 2987
# Processed 21700/99879 users (21.7%) - Elapsed: 436.06s - Est. remaining: 1974.02s
# Evaluating batch 218: users 21701-21800 of 99879
# Batch metrics - RMSE: 1.0181, MAE: 0.7987, Predictions: 2336
# Processed 21800/99879 users (21.8%) - Elapsed: 438.47s - Est. remaining: 1715.39s
# Evaluating batch 219: users 21801-21900 of 99879
# Batch metrics - RMSE: 1.0049, MAE: 0.7809, Predictions: 3422
# Processed 21900/99879 users (21.9%) - Elapsed: 440.82s - Est. remaining: 1671.87s
# Evaluating batch 220: users 21901-22000 of 99879
# Batch metrics - RMSE: 0.9591, MAE: 0.7296, Predictions: 2304
# Processed 22000/99879 users (22.0%) - Elapsed: 442.85s - Est. remaining: 1454.00s
# Evaluating batch 221: users 22001-22100 of 99879
# Batch metrics - RMSE: 0.8907, MAE: 0.6977, Predictions: 2722
# Processed 22100/99879 users (22.1%) - Elapsed: 445.67s - Est. remaining: 1998.14s
# Evaluating batch 222: users 22101-22200 of 99879
# Batch metrics - RMSE: 0.9698, MAE: 0.7543, Predictions: 3645
# Processed 22200/99879 users (22.2%) - Elapsed: 448.45s - Est. remaining: 1972.27s
# Evaluating batch 223: users 22201-22300 of 99879
# Batch metrics - RMSE: 0.9625, MAE: 0.7405, Predictions: 2809
# Processed 22300/99879 users (22.3%) - Elapsed: 451.43s - Est. remaining: 2158.25s
# Evaluating batch 224: users 22301-22400 of 99879
# Batch metrics - RMSE: 0.9706, MAE: 0.7680, Predictions: 3391
# Processed 22400/99879 users (22.4%) - Elapsed: 454.18s - Est. remaining: 1958.67s
# Evaluating batch 225: users 22401-22500 of 99879
# Batch metrics - RMSE: 1.0419, MAE: 0.8191, Predictions: 2503
# Processed 22500/99879 users (22.5%) - Elapsed: 456.69s - Est. remaining: 1783.58s
# Evaluating batch 226: users 22501-22600 of 99879
# Batch metrics - RMSE: 0.9180, MAE: 0.7001, Predictions: 2501
# Processed 22600/99879 users (22.6%) - Elapsed: 459.34s - Est. remaining: 1799.83s
# Evaluating batch 227: users 22601-22700 of 99879
# Batch metrics - RMSE: 0.9047, MAE: 0.7074, Predictions: 3396
# Processed 22700/99879 users (22.7%) - Elapsed: 461.84s - Est. remaining: 1762.77s
# Evaluating batch 228: users 22701-22800 of 99879
# Batch metrics - RMSE: 1.0052, MAE: 0.7735, Predictions: 2408
# Processed 22800/99879 users (22.8%) - Elapsed: 464.13s - Est. remaining: 1620.20s
# Evaluating batch 229: users 22801-22900 of 99879
# Batch metrics - RMSE: 1.0101, MAE: 0.7961, Predictions: 2811
# Processed 22900/99879 users (22.9%) - Elapsed: 466.37s - Est. remaining: 1584.22s
# Evaluating batch 230: users 22901-23000 of 99879
# Batch metrics - RMSE: 1.0200, MAE: 0.8139, Predictions: 3279
# Processed 23000/99879 users (23.0%) - Elapsed: 468.41s - Est. remaining: 1431.49s
# Evaluating batch 231: users 23001-23100 of 99879
# Batch metrics - RMSE: 0.9248, MAE: 0.7233, Predictions: 3754
# Processed 23100/99879 users (23.1%) - Elapsed: 470.56s - Est. remaining: 1511.77s
# Evaluating batch 232: users 23101-23200 of 99879
# Batch metrics - RMSE: 0.8697, MAE: 0.6799, Predictions: 3695
# Processed 23200/99879 users (23.2%) - Elapsed: 472.60s - Est. remaining: 1436.19s
# Evaluating batch 233: users 23201-23300 of 99879
# Batch metrics - RMSE: 0.9980, MAE: 0.7800, Predictions: 3377
# Processed 23300/99879 users (23.3%) - Elapsed: 474.75s - Est. remaining: 1505.54s
# Evaluating batch 234: users 23301-23400 of 99879
# Batch metrics - RMSE: 0.9240, MAE: 0.7191, Predictions: 2759
# Processed 23400/99879 users (23.4%) - Elapsed: 476.80s - Est. remaining: 1442.39s
# Evaluating batch 235: users 23401-23500 of 99879
# Batch metrics - RMSE: 1.0188, MAE: 0.8035, Predictions: 3585
# Processed 23500/99879 users (23.5%) - Elapsed: 478.95s - Est. remaining: 1495.50s
# Evaluating batch 236: users 23501-23600 of 99879
# Batch metrics - RMSE: 0.9898, MAE: 0.7684, Predictions: 2557
# Processed 23600/99879 users (23.6%) - Elapsed: 481.04s - Est. remaining: 1429.47s
# Evaluating batch 237: users 23601-23700 of 99879
# Batch metrics - RMSE: 0.9389, MAE: 0.7319, Predictions: 2871
# Processed 23700/99879 users (23.7%) - Elapsed: 483.13s - Est. remaining: 1464.16s
# Evaluating batch 238: users 23701-23800 of 99879
# Batch metrics - RMSE: 0.9584, MAE: 0.7535, Predictions: 2380
# Processed 23800/99879 users (23.8%) - Elapsed: 485.30s - Est. remaining: 1521.58s
# Evaluating batch 239: users 23801-23900 of 99879
# Batch metrics - RMSE: 1.0361, MAE: 0.8070, Predictions: 3048
# Processed 23900/99879 users (23.9%) - Elapsed: 487.51s - Est. remaining: 1549.21s
# Evaluating batch 240: users 23901-24000 of 99879
# Batch metrics - RMSE: 0.9769, MAE: 0.7719, Predictions: 2629
# Processed 24000/99879 users (24.0%) - Elapsed: 489.51s - Est. remaining: 1387.82s
# Evaluating batch 241: users 24001-24100 of 99879
# Batch metrics - RMSE: 0.9766, MAE: 0.7674, Predictions: 3028
# Processed 24100/99879 users (24.1%) - Elapsed: 492.06s - Est. remaining: 1790.65s
# Evaluating batch 242: users 24101-24200 of 99879
# Batch metrics - RMSE: 0.9432, MAE: 0.7286, Predictions: 3515
# Processed 24200/99879 users (24.2%) - Elapsed: 494.55s - Est. remaining: 1741.37s
# Evaluating batch 243: users 24201-24300 of 99879
# Batch metrics - RMSE: 0.9705, MAE: 0.7701, Predictions: 2313
# Processed 24300/99879 users (24.3%) - Elapsed: 496.37s - Est. remaining: 1244.79s
# Evaluating batch 244: users 24301-24400 of 99879
# Batch metrics - RMSE: 1.0324, MAE: 0.8156, Predictions: 2417
# Processed 24400/99879 users (24.4%) - Elapsed: 498.23s - Est. remaining: 1268.04s
# Evaluating batch 245: users 24401-24500 of 99879
# Batch metrics - RMSE: 1.0035, MAE: 0.7805, Predictions: 2310
# Processed 24500/99879 users (24.5%) - Elapsed: 499.91s - Est. remaining: 1131.44s
# Evaluating batch 246: users 24501-24600 of 99879
# Batch metrics - RMSE: 0.9308, MAE: 0.7306, Predictions: 2491
# Processed 24600/99879 users (24.6%) - Elapsed: 501.75s - Est. remaining: 1203.71s
# Evaluating batch 247: users 24601-24700 of 99879
# Batch metrics - RMSE: 0.9574, MAE: 0.7421, Predictions: 4383
# Processed 24700/99879 users (24.7%) - Elapsed: 503.36s - Est. remaining: 1117.16s
# Evaluating batch 248: users 24701-24800 of 99879
# Batch metrics - RMSE: 0.9356, MAE: 0.7413, Predictions: 3742
# Processed 24800/99879 users (24.8%) - Elapsed: 505.06s - Est. remaining: 1160.72s
# Evaluating batch 249: users 24801-24900 of 99879
# Batch metrics - RMSE: 0.9936, MAE: 0.7766, Predictions: 3020
# Processed 24900/99879 users (24.9%) - Elapsed: 506.96s - Est. remaining: 1317.38s
# Evaluating batch 250: users 24901-25000 of 99879
# Batch metrics - RMSE: 0.9400, MAE: 0.7174, Predictions: 2860
# Processed 25000/99879 users (25.0%) - Elapsed: 508.75s - Est. remaining: 1174.14s
# Evaluating batch 251: users 25001-25100 of 99879
# Batch metrics - RMSE: 1.0976, MAE: 0.8684, Predictions: 3469
# ...
# Evaluating batch 918: users 91701-91800 of 99879
# Batch metrics - RMSE: 1.0551, MAE: 0.8421, Predictions: 3340
# Processed 91800/99879 users (91.9%) - Elapsed: 1917.94s - Est. remaining: 186.54s
# Evaluating batch 919: users 91801-91900 of 99879
# Batch metrics - RMSE: 0.9918, MAE: 0.7846, Predictions: 3708
# Processed 91900/99879 users (92.0%) - Elapsed: 1920.35s - Est. remaining: 173.30s
# Evaluating batch 920: users 91901-92000 of 99879
# Batch metrics - RMSE: 0.9678, MAE: 0.7613, Predictions: 2333
# Processed 92000/99879 users (92.1%) - Elapsed: 1922.28s - Est. remaining: 138.12s
# Evaluating batch 921: users 92001-92100 of 99879
# Batch metrics - RMSE: 0.9562, MAE: 0.7529, Predictions: 2352
# Processed 92100/99879 users (92.2%) - Elapsed: 1924.14s - Est. remaining: 132.55s
# Evaluating batch 922: users 92101-92200 of 99879
# Batch metrics - RMSE: 1.0573, MAE: 0.8434, Predictions: 2853
# Processed 92200/99879 users (92.3%) - Elapsed: 1926.54s - Est. remaining: 173.39s
# Evaluating batch 923: users 92201-92300 of 99879
# Batch metrics - RMSE: 0.8868, MAE: 0.6958, Predictions: 2769
# Processed 92300/99879 users (92.4%) - Elapsed: 1928.77s - Est. remaining: 146.58s
# Evaluating batch 924: users 92301-92400 of 99879
# Batch metrics - RMSE: 1.0315, MAE: 0.8190, Predictions: 3053
# Processed 92400/99879 users (92.5%) - Elapsed: 1930.72s - Est. remaining: 134.02s
# Evaluating batch 925: users 92401-92500 of 99879
# Batch metrics - RMSE: 0.8999, MAE: 0.6978, Predictions: 2799
# Processed 92500/99879 users (92.6%) - Elapsed: 1932.58s - Est. remaining: 123.60s
# Evaluating batch 926: users 92501-92600 of 99879
# Batch metrics - RMSE: 0.9912, MAE: 0.7819, Predictions: 3157
# Processed 92600/99879 users (92.7%) - Elapsed: 1934.55s - Est. remaining: 130.95s
# Evaluating batch 927: users 92601-92700 of 99879
# Batch metrics - RMSE: 0.9613, MAE: 0.7533, Predictions: 3187
# Processed 92700/99879 users (92.8%) - Elapsed: 1936.49s - Est. remaining: 125.49s
# Evaluating batch 928: users 92701-92800 of 99879
# Batch metrics - RMSE: 0.9675, MAE: 0.7557, Predictions: 2840
# Processed 92800/99879 users (92.9%) - Elapsed: 1938.55s - Est. remaining: 134.64s
# Evaluating batch 929: users 92801-92900 of 99879
# Batch metrics - RMSE: 1.0117, MAE: 0.8034, Predictions: 3432
# Processed 92900/99879 users (93.0%) - Elapsed: 1941.02s - Est. remaining: 156.05s
# Evaluating batch 930: users 92901-93000 of 99879
# Batch metrics - RMSE: 1.0589, MAE: 0.8438, Predictions: 2511
# Processed 93000/99879 users (93.1%) - Elapsed: 1943.06s - Est. remaining: 130.49s
# Evaluating batch 931: users 93001-93100 of 99879
# Batch metrics - RMSE: 0.9830, MAE: 0.7731, Predictions: 2960
# Processed 93100/99879 users (93.2%) - Elapsed: 1945.26s - Est. remaining: 138.56s
# Evaluating batch 932: users 93101-93200 of 99879
# Batch metrics - RMSE: 1.0480, MAE: 0.8278, Predictions: 3106
# Processed 93200/99879 users (93.3%) - Elapsed: 1947.65s - Est. remaining: 136.85s
# Evaluating batch 933: users 93201-93300 of 99879
# Batch metrics - RMSE: 0.9744, MAE: 0.7692, Predictions: 3211
# Processed 93300/99879 users (93.4%) - Elapsed: 1949.76s - Est. remaining: 128.42s
# Evaluating batch 934: users 93301-93400 of 99879
# Batch metrics - RMSE: 0.9911, MAE: 0.7760, Predictions: 2440
# Processed 93400/99879 users (93.5%) - Elapsed: 1951.94s - Est. remaining: 127.25s
# Evaluating batch 935: users 93401-93500 of 99879
# Batch metrics - RMSE: 0.9607, MAE: 0.7482, Predictions: 3055
# Processed 93500/99879 users (93.6%) - Elapsed: 1954.21s - Est. remaining: 132.30s
# Evaluating batch 936: users 93501-93600 of 99879
# Batch metrics - RMSE: 0.9663, MAE: 0.7524, Predictions: 3618
# Processed 93600/99879 users (93.7%) - Elapsed: 1956.56s - Est. remaining: 137.64s
# Evaluating batch 937: users 93601-93700 of 99879
# Batch metrics - RMSE: 0.9396, MAE: 0.7330, Predictions: 2941
# Processed 93700/99879 users (93.8%) - Elapsed: 1958.98s - Est. remaining: 140.94s
# Evaluating batch 938: users 93701-93800 of 99879
# Batch metrics - RMSE: 0.9929, MAE: 0.7848, Predictions: 2368
# Processed 93800/99879 users (93.9%) - Elapsed: 1961.29s - Est. remaining: 125.17s
# Evaluating batch 939: users 93801-93900 of 99879
# Batch metrics - RMSE: 0.9431, MAE: 0.7401, Predictions: 3223
# Processed 93900/99879 users (94.0%) - Elapsed: 1963.97s - Est. remaining: 146.60s
# Evaluating batch 940: users 93901-94000 of 99879
# Batch metrics - RMSE: 0.9673, MAE: 0.7591, Predictions: 3256
# Processed 94000/99879 users (94.1%) - Elapsed: 1966.48s - Est. remaining: 138.33s
# Evaluating batch 941: users 94001-94100 of 99879
# Batch metrics - RMSE: 0.9760, MAE: 0.7521, Predictions: 2223
# Processed 94100/99879 users (94.2%) - Elapsed: 1968.99s - Est. remaining: 133.15s
# Evaluating batch 942: users 94101-94200 of 99879
# Batch metrics - RMSE: 0.9488, MAE: 0.7397, Predictions: 2606
# Processed 94200/99879 users (94.3%) - Elapsed: 1971.58s - Est. remaining: 133.74s
# Evaluating batch 943: users 94201-94300 of 99879
# Batch metrics - RMSE: 0.9988, MAE: 0.7799, Predictions: 3141
# Processed 94300/99879 users (94.4%) - Elapsed: 1974.60s - Est. remaining: 134.14s
# Evaluating batch 944: users 94301-94400 of 99879
# Batch metrics - RMSE: 1.0137, MAE: 0.8039, Predictions: 2500
# Processed 94400/99879 users (94.5%) - Elapsed: 1976.75s - Est. remaining: 104.31s
# Evaluating batch 945: users 94401-94500 of 99879
# Batch metrics - RMSE: 0.9893, MAE: 0.7912, Predictions: 2671
# Processed 94500/99879 users (94.6%) - Elapsed: 1978.79s - Est. remaining: 100.80s
# Evaluating batch 946: users 94501-94600 of 99879
# Batch metrics - RMSE: 0.8857, MAE: 0.6835, Predictions: 2739
# Processed 94600/99879 users (94.7%) - Elapsed: 1980.74s - Est. remaining: 94.34s
# Evaluating batch 947: users 94601-94700 of 99879
# Batch metrics - RMSE: 0.9783, MAE: 0.7814, Predictions: 3149
# Processed 94700/99879 users (94.8%) - Elapsed: 1982.56s - Est. remaining: 86.80s
# Evaluating batch 948: users 94701-94800 of 99879
# Batch metrics - RMSE: 0.9475, MAE: 0.7415, Predictions: 3142
# Processed 94800/99879 users (94.9%) - Elapsed: 1984.79s - Est. remaining: 102.69s
# Evaluating batch 949: users 94801-94900 of 99879
# Batch metrics - RMSE: 0.9867, MAE: 0.7754, Predictions: 3333
# Processed 94900/99879 users (95.0%) - Elapsed: 1987.44s - Est. remaining: 104.47s
# Evaluating batch 950: users 94901-95000 of 99879
# Batch metrics - RMSE: 0.9743, MAE: 0.7625, Predictions: 2259
# Processed 95000/99879 users (95.1%) - Elapsed: 1989.31s - Est. remaining: 82.40s
# Evaluating batch 951: users 95001-95100 of 99879
# Batch metrics - RMSE: 0.9291, MAE: 0.7249, Predictions: 2097
# Processed 95100/99879 users (95.2%) - Elapsed: 1991.84s - Est. remaining: 114.05s
# Evaluating batch 952: users 95101-95200 of 99879
# Batch metrics - RMSE: 0.9031, MAE: 0.6953, Predictions: 3952
# Processed 95200/99879 users (95.3%) - Elapsed: 1994.41s - Est. remaining: 108.12s
# Evaluating batch 953: users 95201-95300 of 99879
# Batch metrics - RMSE: 0.9797, MAE: 0.7624, Predictions: 3106
# Processed 95300/99879 users (95.4%) - Elapsed: 1996.90s - Est. remaining: 103.45s
# Evaluating batch 954: users 95301-95400 of 99879
# Batch metrics - RMSE: 0.9899, MAE: 0.7677, Predictions: 2791
# Processed 95400/99879 users (95.5%) - Elapsed: 1999.36s - Est. remaining: 100.92s
# Evaluating batch 955: users 95401-95500 of 99879
# Batch metrics - RMSE: 0.9055, MAE: 0.7129, Predictions: 2946
# Processed 95500/99879 users (95.6%) - Elapsed: 2001.79s - Est. remaining: 98.03s
# Evaluating batch 956: users 95501-95600 of 99879
# Batch metrics - RMSE: 0.9830, MAE: 0.7765, Predictions: 2526
# Processed 95600/99879 users (95.7%) - Elapsed: 2004.21s - Est. remaining: 94.78s
# Evaluating batch 957: users 95601-95700 of 99879
# Batch metrics - RMSE: 0.9856, MAE: 0.7804, Predictions: 2439
# Processed 95700/99879 users (95.8%) - Elapsed: 2006.63s - Est. remaining: 92.96s
# Evaluating batch 958: users 95701-95800 of 99879
# Batch metrics - RMSE: 0.9467, MAE: 0.7198, Predictions: 2700
# Processed 95800/99879 users (95.9%) - Elapsed: 2009.22s - Est. remaining: 96.71s
# Evaluating batch 959: users 95801-95900 of 99879
# Batch metrics - RMSE: 0.9704, MAE: 0.7642, Predictions: 4151
# Processed 95900/99879 users (96.0%) - Elapsed: 2011.66s - Est. remaining: 89.42s
# Evaluating batch 960: users 95901-96000 of 99879
# Batch metrics - RMSE: 0.9530, MAE: 0.7377, Predictions: 2643
# Processed 96000/99879 users (96.1%) - Elapsed: 2013.97s - Est. remaining: 81.94s
# Evaluating batch 961: users 96001-96100 of 99879
# Batch metrics - RMSE: 0.9582, MAE: 0.7379, Predictions: 2616
# Processed 96100/99879 users (96.2%) - Elapsed: 2016.59s - Est. remaining: 90.70s
# Evaluating batch 962: users 96101-96200 of 99879
# Batch metrics - RMSE: 1.0011, MAE: 0.7809, Predictions: 2851
# Processed 96200/99879 users (96.3%) - Elapsed: 2018.99s - Est. remaining: 80.19s
# Evaluating batch 963: users 96201-96300 of 99879
# Batch metrics - RMSE: 0.9045, MAE: 0.6941, Predictions: 2861
# Processed 96300/99879 users (96.4%) - Elapsed: 2021.45s - Est. remaining: 80.28s
# Evaluating batch 964: users 96301-96400 of 99879
# Batch metrics - RMSE: 0.9734, MAE: 0.7722, Predictions: 2516
# Processed 96400/99879 users (96.5%) - Elapsed: 2023.58s - Est. remaining: 67.39s
# Evaluating batch 965: users 96401-96500 of 99879
# Batch metrics - RMSE: 0.9159, MAE: 0.7094, Predictions: 3685
# Processed 96500/99879 users (96.6%) - Elapsed: 2026.00s - Est. remaining: 76.04s
# Evaluating batch 966: users 96501-96600 of 99879
# Batch metrics - RMSE: 0.9677, MAE: 0.7439, Predictions: 3181
# Processed 96600/99879 users (96.7%) - Elapsed: 2028.41s - Est. remaining: 74.10s
# Evaluating batch 967: users 96601-96700 of 99879
# Batch metrics - RMSE: 0.9648, MAE: 0.7599, Predictions: 3061
# Processed 96700/99879 users (96.8%) - Elapsed: 2031.03s - Est. remaining: 75.50s
# Evaluating batch 968: users 96701-96800 of 99879
# Batch metrics - RMSE: 0.8867, MAE: 0.6839, Predictions: 2888
# Processed 96800/99879 users (96.9%) - Elapsed: 2033.34s - Est. remaining: 64.58s
# Evaluating batch 969: users 96801-96900 of 99879
# Batch metrics - RMSE: 0.9526, MAE: 0.7402, Predictions: 2767
# Processed 96900/99879 users (97.0%) - Elapsed: 2035.63s - Est. remaining: 61.28s
# Evaluating batch 970: users 96901-97000 of 99879
# Batch metrics - RMSE: 0.9149, MAE: 0.7062, Predictions: 2112
# Processed 97000/99879 users (97.1%) - Elapsed: 2037.75s - Est. remaining: 55.45s
# Evaluating batch 971: users 97001-97100 of 99879
# Batch metrics - RMSE: 0.9976, MAE: 0.7888, Predictions: 3710
# Processed 97100/99879 users (97.2%) - Elapsed: 2039.87s - Est. remaining: 53.51s
# Evaluating batch 972: users 97101-97200 of 99879
# Batch metrics - RMSE: 0.9772, MAE: 0.7628, Predictions: 3392
# Processed 97200/99879 users (97.3%) - Elapsed: 2042.08s - Est. remaining: 53.70s
# Evaluating batch 973: users 97201-97300 of 99879
# Batch metrics - RMSE: 0.9844, MAE: 0.7599, Predictions: 2523
# Processed 97300/99879 users (97.4%) - Elapsed: 2044.66s - Est. remaining: 60.48s
# Evaluating batch 974: users 97301-97400 of 99879
# Batch metrics - RMSE: 0.9197, MAE: 0.7063, Predictions: 2785
# Processed 97400/99879 users (97.5%) - Elapsed: 2047.12s - Est. remaining: 56.48s
# Evaluating batch 975: users 97401-97500 of 99879
# Batch metrics - RMSE: 1.0007, MAE: 0.7883, Predictions: 3313
# Processed 97500/99879 users (97.6%) - Elapsed: 2049.16s - Est. remaining: 44.77s
# Evaluating batch 976: users 97501-97600 of 99879
# Batch metrics - RMSE: 0.9228, MAE: 0.7111, Predictions: 2879
# Processed 97600/99879 users (97.7%) - Elapsed: 2051.31s - Est. remaining: 44.12s
# Evaluating batch 977: users 97601-97700 of 99879
# Batch metrics - RMSE: 0.9400, MAE: 0.7412, Predictions: 3367
# Processed 97700/99879 users (97.8%) - Elapsed: 2053.80s - Est. remaining: 50.66s
# Evaluating batch 978: users 97701-97800 of 99879
# Batch metrics - RMSE: 0.9117, MAE: 0.7041, Predictions: 3611
# Processed 97800/99879 users (97.9%) - Elapsed: 2055.79s - Est. remaining: 38.05s
# Evaluating batch 979: users 97801-97900 of 99879
# Batch metrics - RMSE: 0.9481, MAE: 0.7467, Predictions: 2668
# Processed 97900/99879 users (98.0%) - Elapsed: 2057.85s - Est. remaining: 37.42s
# Evaluating batch 980: users 97901-98000 of 99879
# Batch metrics - RMSE: 0.9856, MAE: 0.7827, Predictions: 2568
# Processed 98000/99879 users (98.1%) - Elapsed: 2059.86s - Est. remaining: 34.42s
# Evaluating batch 981: users 98001-98100 of 99879
# Batch metrics - RMSE: 1.0495, MAE: 0.8273, Predictions: 3047
# Processed 98100/99879 users (98.2%) - Elapsed: 2062.00s - Est. remaining: 33.64s
# Evaluating batch 982: users 98101-98200 of 99879
# Batch metrics - RMSE: 1.0357, MAE: 0.8183, Predictions: 2460
# Processed 98200/99879 users (98.3%) - Elapsed: 2063.97s - Est. remaining: 29.99s
# Evaluating batch 983: users 98201-98300 of 99879
# Batch metrics - RMSE: 0.9846, MAE: 0.7758, Predictions: 2773
# Processed 98300/99879 users (98.4%) - Elapsed: 2066.20s - Est. remaining: 31.85s
# Evaluating batch 984: users 98301-98400 of 99879
# Batch metrics - RMSE: 0.9547, MAE: 0.7470, Predictions: 3214
# Processed 98400/99879 users (98.5%) - Elapsed: 2068.24s - Est. remaining: 27.54s
# Evaluating batch 985: users 98401-98500 of 99879
# Batch metrics - RMSE: 0.9740, MAE: 0.7654, Predictions: 2684
# Processed 98500/99879 users (98.6%) - Elapsed: 2070.30s - Est. remaining: 26.13s
# Evaluating batch 986: users 98501-98600 of 99879
# Batch metrics - RMSE: 0.9331, MAE: 0.7255, Predictions: 2435
# Processed 98600/99879 users (98.7%) - Elapsed: 2072.96s - Est. remaining: 31.96s
# Evaluating batch 987: users 98601-98700 of 99879
# Batch metrics - RMSE: 1.0284, MAE: 0.7997, Predictions: 2790
# Processed 98700/99879 users (98.8%) - Elapsed: 2075.58s - Est. remaining: 27.84s
# Evaluating batch 988: users 98701-98800 of 99879
# Batch metrics - RMSE: 0.9876, MAE: 0.7783, Predictions: 2848
# Processed 98800/99879 users (98.9%) - Elapsed: 2078.13s - Est. remaining: 25.29s
# Evaluating batch 989: users 98801-98900 of 99879
# Batch metrics - RMSE: 0.9486, MAE: 0.7522, Predictions: 2923
# Processed 98900/99879 users (99.0%) - Elapsed: 2080.64s - Est. remaining: 22.51s
# Evaluating batch 990: users 98901-99000 of 99879
# Batch metrics - RMSE: 0.9684, MAE: 0.7579, Predictions: 2328
# Processed 99000/99879 users (99.1%) - Elapsed: 2083.11s - Est. remaining: 19.98s
# Evaluating batch 991: users 99001-99100 of 99879
# Batch metrics - RMSE: 0.9332, MAE: 0.7280, Predictions: 3054
# Processed 99100/99879 users (99.2%) - Elapsed: 2085.62s - Est. remaining: 17.77s
# Evaluating batch 992: users 99101-99200 of 99879
# Batch metrics - RMSE: 1.0019, MAE: 0.7965, Predictions: 2367
# Processed 99200/99879 users (99.3%) - Elapsed: 2087.93s - Est. remaining: 14.26s
# Evaluating batch 993: users 99201-99300 of 99879
# Batch metrics - RMSE: 0.9403, MAE: 0.7355, Predictions: 2946
# Processed 99300/99879 users (99.4%) - Elapsed: 2090.29s - Est. remaining: 12.51s
# Evaluating batch 994: users 99301-99400 of 99879
# Batch metrics - RMSE: 0.9627, MAE: 0.7548, Predictions: 3666
# Processed 99400/99879 users (99.5%) - Elapsed: 2092.68s - Est. remaining: 10.37s
# Evaluating batch 995: users 99401-99500 of 99879
# Batch metrics - RMSE: 0.9296, MAE: 0.7252, Predictions: 3118
# Processed 99500/99879 users (99.6%) - Elapsed: 2094.96s - Est. remaining: 7.98s
# Evaluating batch 996: users 99501-99600 of 99879
# Batch metrics - RMSE: 1.0044, MAE: 0.7828, Predictions: 1962
# Processed 99600/99879 users (99.7%) - Elapsed: 2097.38s - Est. remaining: 6.21s
# Evaluating batch 997: users 99601-99700 of 99879
# Batch metrics - RMSE: 0.9461, MAE: 0.7161, Predictions: 3516
# Processed 99700/99879 users (99.8%) - Elapsed: 2099.73s - Est. remaining: 3.81s
# Evaluating batch 998: users 99701-99800 of 99879
# Batch metrics - RMSE: 1.0075, MAE: 0.7905, Predictions: 2250
# Processed 99800/99879 users (99.9%) - Elapsed: 2102.11s - Est. remaining: 1.61s
# Evaluating batch 999: users 99801-99879 of 99879
# Batch metrics - RMSE: 0.9693, MAE: 0.7595, Predictions: 2296
# Processed 99879/99879 users (100.0%) - Elapsed: 2103.92s - Est. remaining: 0.00s
#
# Evaluation results:
# Users evaluated: 99879
# Total predictions: 2894342
# RMSE: 0.9655
# MAE: 0.7531
#
# Stored evaluation metrics:
#   rmse: 0.9654972382625541
#   mae: 0.75314974432059
#   num_users_evaluated: 99879
#   num_predictions: 2894342
# Saved evaluation metrics to CSV files

# %%
# Saved files
print("\nSaved Files:")
for file in os.listdir(output_path):
    file_path = os.path.join(output_path, file)
    file_size = os.path.getsize(file_path) / (1024 * 1024)  # Size in MB
    print(f"- {file} ({file_size:.2f} MB)")

# Memory usage information
import psutil 
process = psutil.Process(os.getpid())
memory_usage = process.memory_info().rss / (1024 * 1024)  # MB
print(f"\nFinal memory usage: {memory_usage:.2f} MB")

print("\nContent-Based Filtering Model Successfully Implemented!")
# Out:
# Saved Files:
# - actual_vs_predicted.png (0.39 MB)
# - classification_metrics.png (0.02 MB)
# - confusion_matrix.png (0.03 MB)
# - content_based_evaluation.csv (0.00 MB)
# - content_based_recommendations.csv (16.64 MB)
# - content_based_recommendations.pkl (4.25 MB)
# - corpus_word_counts.pkl (1.61 MB)
# - error_distribution.png (0.12 MB)
# - error_histogram.png (0.02 MB)
# - movie_id_to_idx.pkl (0.16 MB)
# - movie_ll_values.pkl (15.27 MB)
# - movie_vectors.pkl (19.45 MB)
# - prediction_scatter.png (0.09 MB)
# - user_id_to_idx.pkl (2.16 MB)
# - user_movie_similarities.pkl (228.90 MB)
# - user_vectors.pkl (81.26 MB)
# - word2vec_model (67.02 MB)
#
# Final memory usage: 1626.40 MB
#
# Content-Based Filtering Model Successfully Implemented!

# %%
import numpy as np
import pandas as pd
import os
import pickle
import logging
import heapq
from datetime import datetime
from collections import Counter, defaultdict
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
import seaborn as sns
import time
import math
from gensim.models import Word2Vec
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import ast
import sys
import gc
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
logger = logging.getLogger(__name__)

input_path = "../"
output_path = "../rec/content-recommendations"
top_n = 20

if not os.path.exists(output_path):
    os.makedirs(output_path)

# Improved similarity threshold based on empirical testing
similarity_threshold = 0.25
word2vec_dim = 100
rating_threshold = 3.5  # Threshold for binary classification (like/dislike)

# Memory monitoring function
def log_memory_usage(message="Current memory usage"):
    """Log current memory usage"""
    try:
        import psutil
        process = psutil.Process(os.getpid())
        memory_info = process.memory_info()
        memory_usage_mb = memory_info.rss / 1024 / 1024
        logger.info(f"{message}: {memory_usage_mb:.2f} MB")
    except ImportError:
        logger.warning("psutil not available for memory monitoring")

def load_data():
    data = {}
    
    movie_features_path = os.path.join(input_path, 'processed/processed_movie_features.csv')
    if os.path.exists(movie_features_path):
        # Use optimized loading for large CSV files
        data['movie_features'] = pd.read_csv(movie_features_path, 
                                            dtype={'movieId': int, 'token_count': int})
        
        # Use safer and more memory-efficient parsing of lists
        data['movie_features']['tokens'] = data['movie_features']['tokens'].apply(
            lambda x: ast.literal_eval(x) if isinstance(x, str) else []
        )
        data['movie_features']['top_keywords'] = data['movie_features']['top_keywords'].apply(
            lambda x: ast.literal_eval(x) if isinstance(x, str) else []
        )
        logger.info(f"Loaded features for {len(data['movie_features'])} movies")
    else:
        logger.error(f"File not found: {movie_features_path}")
        sys.exit(1)
    
    ratings_path = os.path.join(input_path, 'processed/normalized_ratings.csv')
    if os.path.exists(ratings_path):
        # Load ratings in chunks to save memory
        chunk_size = 100000
        chunks = []
        for chunk in pd.read_csv(ratings_path, chunksize=chunk_size):
            chunks.append(chunk)
            # Force garbage collection after each chunk
            gc.collect()
        
        data['ratings'] = pd.concat(chunks)
        logger.info(f"Loaded {len(data['ratings'])} ratings from {len(data['ratings']['userId'].unique())} users")
    else:
        logger.error(f"File not found: {ratings_path}")
        sys.exit(1)
    
    if 'ratings' in data:
        # Sort by timestamp if available for temporal split
        if 'timestamp' in data['ratings'].columns:
            data['ratings'] = data['ratings'].sort_values('timestamp')
        
        # Use a more robust user-level train-test split
        # Create a user-level split instead of randomly dividing all ratings
        all_user_ids = data['ratings']['userId'].unique()

        # Set a random seed for reproducibility
        np.random.seed(42)
        np.random.shuffle(all_user_ids)

        # 80% of users for training, 20% for testing
        split_idx = int(len(all_user_ids) * 0.8)
        train_users = all_user_ids[:split_idx]
        test_users = all_user_ids[split_idx:]

        # For users in test set, take 80% of their ratings for training
        train_ratings_main = data['ratings'][data['ratings']['userId'].isin(train_users)]
        
        # For users in test set, split their ratings 80/20
        test_user_ratings = data['ratings'][data['ratings']['userId'].isin(test_users)]
        test_user_train = []
        test_user_test = []
        
        for user_id in test_users:
            user_data = test_user_ratings[test_user_ratings['userId'] == user_id]
            if len(user_data) < 5:  # Skip users with very few ratings
                continue
                
            # Sort by timestamp if available for a more realistic test
            if 'timestamp' in user_data.columns:
                user_data = user_data.sort_values('timestamp')
                
            # Take first 80% for training, last 20% for testing
            split_idx = int(len(user_data) * 0.8)
            test_user_train.append(user_data.iloc[:split_idx])
            test_user_test.append(user_data.iloc[split_idx:])
        
        # Combine all training sets
        data['train_ratings'] = pd.concat([train_ratings_main] + test_user_train) if test_user_train else train_ratings_main
        data['test_ratings'] = pd.concat(test_user_test) if test_user_test else pd.DataFrame()
        
        logger.info(f"Created train set with {len(data['train_ratings'])} ratings from {len(data['train_ratings']['userId'].unique())} users")
        logger.info(f"Created test set with {len(data['test_ratings'])} ratings from {len(data['test_ratings']['userId'].unique())} users")
        
        # Force garbage collection
        gc.collect()
    
    return data

def calculate_log_likelihood(movie_features, corpus_word_counts, batch_size=100):
    """
    Calculate log-likelihood scores for words in each movie.
    Optimized implementation with TF-IDF weighting.
    """
    start_time = time.time()
    
    total_corpus_size = sum(corpus_word_counts.values())
    total_movies = len(movie_features)
    
    # Calculate document frequency for each word
    doc_freq = defaultdict(int)
    for _, row in movie_features.iterrows():
        tokens = row['tokens']
        unique_tokens = set(tokens)
        for word in unique_tokens:
            doc_freq[word] += 1
    
    # Calculate IDF values
    idf_values = {}
    for word, df in doc_freq.items():
        idf_values[word] = math.log(total_movies / (df + 1))
    
    movie_ll_values = {}
    
    for batch_start in range(0, total_movies, batch_size):
        batch_end = min(batch_start + batch_size, total_movies)
        batch = movie_features.iloc[batch_start:batch_end]
        
        for _, row in batch.iterrows():
            movie_id = row['movieId']
            tokens = row['tokens']
            
            if not tokens:
                continue
            
            movie_word_counts = Counter(tokens)
            movie_size = sum(movie_word_counts.values())
            
            movie_ll_tfidf = {}
            
            for word, count in movie_word_counts.items():
                # Calculate log-likelihood
                a = count
                b = corpus_word_counts[word] - count
                c = movie_size
                d = total_corpus_size - movie_size
                
                e1 = c * (a + b) / (c + d)
                e2 = d * (a + b) / (c + d)
                
                ll = 0
                if a > 0 and e1 > 0:
                    ll += a * math.log(a / e1)
                if b > 0 and e2 > 0:
                    ll += b * math.log(b / e2)
                
                # Scale by 2
                ll = 2 * ll
                
                # Get IDF value
                idf = idf_values.get(word, 0)
                
                # Multiply LL by IDF for combined weighting
                movie_ll_tfidf[word] = ll * idf
            
            movie_ll_values[movie_id] = movie_ll_tfidf
        
        elapsed = time.time() - start_time
        progress = batch_end / total_movies * 100
        remaining = elapsed / (batch_end - batch_start) * (total_movies - batch_end) if batch_end < total_movies else 0
        logger.info(f"Processed {batch_end}/{total_movies} movies ({progress:.1f}%) - Elapsed: {elapsed:.2f}s - Est. remaining: {remaining:.2f}s")
        
        # Garbage collection
        gc.collect()
    
    return movie_ll_values

def train_word2vec(movie_features, vector_size=100, batch_size=1000):
    """
    Train a Word2Vec model on movie tokens with improved parameters.
    """
    start_time = time.time()
    
    tokenized_corpus = []
    total_movies = len(movie_features)
    
    # Process in batches to save memory
    for i in range(0, total_movies, batch_size):
        batch_end = min(i + batch_size, total_movies)
        batch = movie_features.iloc[i:batch_end]
        
        batch_tokens = list(batch['tokens'])
        tokenized_corpus.extend(batch_tokens)
        
        # Log progress
        progress = batch_end / total_movies * 100
        logger.info(f"Preparing corpus: {batch_end}/{total_movies} movies ({progress:.1f}%)")
        
        # Garbage collection after each batch
        gc.collect()
    
    total_tokens = sum(len(tokens) for tokens in tokenized_corpus)
    logger.info(f"Training Word2Vec on corpus with {total_tokens} tokens")
    
    # Improved Word2Vec parameters
    word2vec_model = Word2Vec(
        sentences=tokenized_corpus,
        vector_size=vector_size,
        window=8,        # Increased context window 
        min_count=3,     # Include words that appear at least 3 times
        workers=8,       # Parallelize training
        epochs=20,       # More training epochs for better vectors
        sg=1,            # Use skip-gram (better for semantic relations)
        hs=1,            # Use hierarchical softmax for efficiency
        negative=15      # Number of negative samples
    )
    
    # Clean up the corpus to save memory
    del tokenized_corpus
    gc.collect()
    
    elapsed = time.time() - start_time
    logger.info(f"Word2Vec model training completed in {elapsed:.2f}s")
    
    return word2vec_model

def generate_movie_vectors(movie_ll_values, word2vec_model, movie_features, corpus_word_counts, batch_size=100):
    """
    Generate movie feature vectors combining log-likelihood and Word2Vec.
    Improved with TF-IDF weighting and normalization.
    """
    start_time = time.time()
    
    movie_vectors = {}
    successful_vectors = 0
    no_words_found = 0
    low_ll_sum = 0
    
    movie_ids = list(movie_ll_values.keys())
    total_movies = len(movie_ids)
    total_corpus_size = sum(corpus_word_counts.values())
    
    for batch_start in range(0, total_movies, batch_size):
        batch_end = min(batch_start + batch_size, total_movies)
        batch_movie_ids = movie_ids[batch_start:batch_end]

        for movie_id in batch_movie_ids:
            ll_values = movie_ll_values[movie_id]
            
            # Calculate IDF for each word in this movie
            idf = {word: math.log(total_corpus_size/(corpus_word_counts[word]+1)) 
                  for word in ll_values.keys()}
            
            # Combined score: LL * IDF
            combined_scores = {word: ll * idf[word] 
                              for word, ll in ll_values.items()}
            
            # Get top words by combined score
            top_words = sorted(combined_scores.items(), key=lambda x: x[1], reverse=True)[:500]
            
            if not top_words:
                no_words_found += 1
                continue
            
            weighted_vectors = []
            ll_sum = 0
            words_used = 0
            
            # Combine word vectors weighted by their scores
            for word, score in top_words:
                if score <= 0:
                    continue
                
                if word in word2vec_model.wv:
                    weighted_vectors.append(word2vec_model.wv[word] * score)
                    ll_sum += score
                    words_used += 1
            
            # Create the final vector as weighted average
            if weighted_vectors and ll_sum > 0:
                movie_vector = np.sum(weighted_vectors, axis=0) / ll_sum
                
                # Normalize to unit length for cosine similarity
                norm = np.linalg.norm(movie_vector)
                if norm > 0:
                    movie_vector = movie_vector / norm
                    movie_vectors[movie_id] = movie_vector
                    successful_vectors += 1
            else:
                low_ll_sum += 1
        
        elapsed = time.time() - start_time
        progress = batch_end / total_movies * 100
        remaining = elapsed / (batch_end - batch_start) * (total_movies - batch_end) if batch_end < total_movies else 0
        
        logger.info(f"Generated vectors: {batch_end}/{total_movies} movies ({progress:.1f}%) - Success: {successful_vectors}")
        
        # Garbage collection
        gc.collect()
    
    logger.info(f"Vector generation summary: Success: {successful_vectors}, No words: {no_words_found}, Low scores: {low_ll_sum}")
    return movie_vectors

def generate_user_vectors(movie_vectors, train_ratings, batch_size=100):
    """
    Generate user feature vectors based on rated movies.
    Improved with better weighting and bias adjustments.
    """
    start_time = time.time()
    
    user_vectors = {}
    successful_vectors = 0
    no_ratings_found = 0
    no_vectors_for_movies = 0
    low_weight_sum = 0
    
    # Create user_ratings_dict for faster lookups
    user_ratings_dict = defaultdict(dict)
    
    # Use chunks to process ratings to avoid memory issues
    ratings_chunks = np.array_split(train_ratings, max(1, len(train_ratings) // 100000))
    for chunk in ratings_chunks:
        for _, row in chunk.iterrows():
            user_id = row['userId']
            movie_id = row['movieId']
            rating = row['rating']
            user_ratings_dict[user_id][movie_id] = rating
        
        # Garbage collection after each chunk
        gc.collect()
    
    user_ids = list(user_ratings_dict.keys())
    total_users = len(user_ids)
    
    # Calculate global average rating
    all_ratings = [r for user_ratings in user_ratings_dict.values() for r in user_ratings.values()]
    global_avg_rating = np.mean(all_ratings) if all_ratings else 3.0
    
    for batch_start in range(0, total_users, batch_size):
        batch_end = min(batch_start + batch_size, total_users)
        batch_user_ids = user_ids[batch_start:batch_end]
        
        for user_id in batch_user_ids:
            user_ratings = user_ratings_dict[user_id]
            
            if len(user_ratings) == 0:
                no_ratings_found += 1
                continue
            
            # Calculate user's average rating
            user_avg_rating = np.mean(list(user_ratings.values()))
            # Calculate rating bias (how much higher/lower this user rates compared to global average)
            user_bias = user_avg_rating - global_avg_rating
            
            weighted_vectors = []
            weight_sum = 0
            movies_with_vectors = 0
            movies_without_vectors = 0
            
            for movie_id, rating in user_ratings.items():
                # Calculate normalized weight: adjust rating relative to user's average
                adjusted_rating = rating - user_avg_rating
                weight = adjusted_rating
                
                if movie_id not in movie_vectors:
                    movies_without_vectors += 1
                    continue
                else:
                    movies_with_vectors += 1
                
                if abs(weight) > 0.1:  # Only consider significant preferences
                    weighted_vectors.append(movie_vectors[movie_id] * weight)
                    weight_sum += abs(weight)
            
            if weighted_vectors and weight_sum > 0:
                user_vector = np.sum(weighted_vectors, axis=0) / weight_sum
                
                # Normalize vector
                norm = np.linalg.norm(user_vector)
                if norm > 0:
                    user_vector = user_vector / norm
                    user_vectors[user_id] = user_vector
                    successful_vectors += 1
            else:
                low_weight_sum += 1
        
        elapsed = time.time() - start_time
        progress = batch_end / total_users * 100
        remaining = elapsed / (batch_end - batch_start) * (total_users - batch_end) if batch_end < total_users else 0
        
        logger.info(f"Generated vectors: {batch_end}/{total_users} users ({progress:.1f}%) - Success: {successful_vectors}")
        
        # Garbage collection
        gc.collect()
    
    logger.info(f"User vector generation summary: Success: {successful_vectors}, No ratings: {no_ratings_found}, No movie vectors: {no_vectors_for_movies}, Low weights: {low_weight_sum}")
    
    # More aggressive cleanup
    del user_ratings_dict
    gc.collect()
    
    return user_vectors

def calculate_user_movie_similarity(user_vectors, movie_vectors, threshold=0.3, batch_size=50):
    """
    Calculate similarity between users and movies using improved methods.
    """
    start_time = time.time()
    
    user_movie_similarities = {}
    
    user_ids = list(user_vectors.keys())
    total_users = len(user_ids)
    total_movies = len(movie_vectors)
    
    # Convert movie vectors to a numpy array for faster batch computation
    movie_ids = list(movie_vectors.keys())
    movie_id_to_idx = {movie_id: i for i, movie_id in enumerate(movie_ids)}
    movie_vectors_array = np.array([movie_vectors[mid] for mid in movie_ids])
    
    for batch_start in range(0, total_users, batch_size):
        batch_end = min(batch_start + batch_size, total_users)
        batch_user_ids = user_ids[batch_start:batch_end]
        
        for user_id in batch_user_ids:
            user_vector = user_vectors[user_id]
            user_sims = {}
            
            # Fast matrix multiplication for all movies at once
            user_vector_array = np.array(user_vector).reshape(1, -1)
            similarities = np.dot(user_vector_array, movie_vectors_array.T)[0]
            
            # Apply threshold and store result
            for i, sim in enumerate(similarities):
                if sim > threshold:
                    movie_id = movie_ids[i]
                    user_sims[movie_id] = float(sim)
            
            user_movie_similarities[user_id] = user_sims
        
        elapsed = time.time() - start_time
        progress = batch_end / total_users * 100
        remaining = (elapsed / (batch_end - batch_start)) * (total_users - batch_end) if batch_end < total_users else 0
        
        avg_similarities = np.mean([len(user_sims) for user_sims in user_movie_similarities.values() if user_sims])
        logger.info(f"Calculated similarities: {batch_end}/{total_users} users ({progress:.1f}%) - Avg similarities per user: {avg_similarities:.1f}")
        
        # Garbage collection
        gc.collect()
    
    return user_movie_similarities

def get_user_rated_movies(user_id, train_ratings, cached_rated_movies=None):
    """Get movies rated by a user from training data"""
    if cached_rated_movies is None:
        cached_rated_movies = {}
        
    if user_id in cached_rated_movies:
        return cached_rated_movies[user_id]
    
    if train_ratings is None:
        return set()
    
    user_data = train_ratings[train_ratings['userId'] == user_id]
    rated_movies = set(user_data['movieId'].values)
    
    cached_rated_movies[user_id] = rated_movies
    
    return rated_movies

def get_top_n_recommendations(user_id, user_movie_similarities, train_ratings, cached_rated_movies=None, n=10):
    """Generate top N movie recommendations for a user"""
    if user_id not in user_movie_similarities:
        return []
    
    rated_movies = get_user_rated_movies(user_id, train_ratings, cached_rated_movies)
    
    user_sims = user_movie_similarities[user_id]
    
    # Exclude already rated movies
    candidates = [(movie_id, sim) for movie_id, sim in user_sims.items() 
                 if movie_id not in rated_movies]
    
    # Sort by similarity score
    recommendations = sorted(candidates, key=lambda x: x[1], reverse=True)
    
    return recommendations[:n]

def predict_rating(user_id, movie_id, user_movie_similarities, train_ratings, user_bias_dict=None):
    """
    Predict a user's rating for a movie with improved methods.
    Adds user bias correction for more accurate predictions.
    """
    # If no user bias dictionary is provided, create an empty one
    if user_bias_dict is None:
        user_bias_dict = {}
    
    # If we don't have similarity data for this user, use fallback
    if user_id not in user_movie_similarities:
        # If we have rating data, return user average
        user_train = train_ratings[train_ratings['userId'] == user_id]
        if len(user_train) > 0:
            return user_train['rating'].mean()
        return 3.0  # Default average
    
    # Get the user's bias if we have it, otherwise calculate it
    if user_id in user_bias_dict:
        user_bias = user_bias_dict[user_id]
    else:
        user_train = train_ratings[train_ratings['userId'] == user_id]
        if len(user_train) > 0:
            user_avg = user_train['rating'].mean()
            # Calculate global average
            global_avg = train_ratings['rating'].mean()
            user_bias = user_avg - global_avg
        else:
            user_bias = 0.0
        user_bias_dict[user_id] = user_bias
    
    # If we have similarity for this movie, use it
    if movie_id in user_movie_similarities[user_id]:
        sim_score = user_movie_similarities[user_id][movie_id]
        
        # Convert similarity (0-1) to rating scale (0.5-5.0)
        base_prediction = 0.5 + 4.5 * sim_score
        
        # Apply user bias correction (damped to avoid extreme predictions)
        bias_weight = 0.7  # How much to consider user bias (0-1)
        predicted_rating = base_prediction + (bias_weight * user_bias)
        
        # Ensure the rating is within bounds
        return max(0.5, min(5.0, predicted_rating))
    
    # If we don't have similarity for this movie, use user average
    user_train = train_ratings[train_ratings['userId'] == user_id]
    if len(user_train) > 0:
        return user_train['rating'].mean()
    
    # Last resort - global average
    return train_ratings['rating'].mean() if len(train_ratings) > 0 else 3.0

def generate_recommendations_for_all_users(user_movie_similarities, train_ratings, movie_features, n=10, batch_size=100):
    """Generate recommendations for all users with improved batch processing"""
    start_time = time.time()
    
    cached_rated_movies = {}
    
    user_ids = list(user_movie_similarities.keys())
    total_users = len(user_ids)
    
    all_recommendations = {}
    users_with_recommendations = 0
    
    for batch_start in range(0, total_users, batch_size):
        batch_end = min(batch_start + batch_size, total_users)
        batch_user_ids = user_ids[batch_start:batch_end]
        
        batch_start_time = time.time()
        
        for user_id in batch_user_ids:
            recommendations = get_top_n_recommendations(
                user_id, 
                user_movie_similarities, 
                train_ratings, 
                cached_rated_movies,
                n
            )
            
            if recommendations:
                all_recommendations[user_id] = recommendations
                users_with_recommendations += 1
        
        batch_time = time.time() - batch_start_time
        elapsed = time.time() - start_time
        progress = batch_end / total_users * 100
        remaining = batch_time * ((total_users - batch_end) / len(batch_user_ids)) if batch_end < total_users else 0
        
        logger.info(f"Generated recommendations: {batch_end}/{total_users} users ({progress:.1f}%) - Users with recs: {users_with_recommendations}")
        
        # Garbage collection
        gc.collect()
    
    return all_recommendations

def evaluate_with_rmse_mae(user_movie_similarities, train_ratings, test_ratings, batch_size=100, rating_threshold=3.5):
    """
    Evaluate recommendation model using RMSE, MAE, and classification metrics.
    Added precision, recall, F1, and accuracy calculations.
    """
    print("Evaluating recommendation model using enhanced metrics with batching...")
    start_time = time.time()
    
    # Initialize metrics
    squared_errors_sum = 0
    absolute_errors_sum = 0
    total_predictions = 0
    users_evaluated = 0
    
    # Classification metrics
    true_positives = 0
    false_positives = 0
    true_negatives = 0
    false_negatives = 0
    
    # Dictionary to cache user biases
    user_bias_dict = {}
    
    # Calculate global stats once
    global_avg_rating = train_ratings['rating'].mean()
    
    # Calculate user biases in advance
    for user_id in train_ratings['userId'].unique():
        user_ratings = train_ratings[train_ratings['userId'] == user_id]
        if len(user_ratings) > 0:
            user_avg = user_ratings['rating'].mean()
            user_bias_dict[user_id] = user_avg - global_avg_rating
    
    # Find common users between training and test sets that have similarity data
    test_users = set(test_ratings['userId'].unique())
    train_users = set(train_ratings['userId'].unique())
    similarity_users = set(user_movie_similarities.keys())
    
    common_users = test_users.intersection(train_users).intersection(similarity_users)
    
    logger.info(f"Train users: {len(train_users)}, Test users: {len(test_users)}, Similarity users: {len(similarity_users)}")
    logger.info(f"Common users for evaluation: {len(common_users)}")
    
    if len(common_users) == 0:
        logger.warning("No common users between train, test, and similarity data")
        # Use baseline prediction (global average) for all test ratings
        predictions = np.full(len(test_ratings), global_avg_rating)
        actuals = test_ratings['rating'].values
        
        # Calculate RMSE and MAE
        rmse = np.sqrt(np.mean((predictions - actuals) ** 2))
        mae = np.mean(np.abs(predictions - actuals))
        
        # Convert to binary for classification metrics
        binary_preds = (predictions > rating_threshold).astype(int)
        binary_actuals = (actuals > rating_threshold).astype(int)
        
        # Calculate classification metrics
        accuracy = np.mean(binary_preds == binary_actuals)
        
        true_pos = np.sum((binary_preds == 1) & (binary_actuals == 1))
        false_pos = np.sum((binary_preds == 1) & (binary_actuals == 0))
        true_neg = np.sum((binary_preds == 0) & (binary_actuals == 0))
        false_neg = np.sum((binary_preds == 0) & (binary_actuals == 1))
        
        precision = true_pos / (true_pos + false_pos) if (true_pos + false_pos) > 0 else 0
        recall = true_pos / (true_pos + false_neg) if (true_pos + false_neg) > 0 else 0
        f1 = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0
        
        logger.info(f"Baseline evaluation with global average ({global_avg_rating:.2f}):")
        logger.info(f"RMSE: {rmse:.4f}, MAE: {mae:.4f}")
        logger.info(f"Accuracy: {accuracy:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}, F1: {f1:.4f}")
        
        return {
            'rmse': rmse,
            'mae': mae,
            'accuracy': accuracy,
            'precision': precision,
            'recall': recall,
            'f1_score': f1,
            'num_predictions': len(test_ratings)
        }
    
    # Process common users in batches
    user_list = list(common_users)
    for batch_start in range(0, len(user_list), batch_size):
        batch_end = min(batch_start + batch_size, len(user_list))
        batch_users = user_list[batch_start:batch_end]
        
        logger.info(f"Evaluating batch {batch_start//batch_size + 1}: users {batch_start+1}-{batch_end} of {len(user_list)}")
        batch_start_time = time.time()
        
        batch_squared_errors = 0
        batch_absolute_errors = 0
        batch_predictions = 0
        batch_true_positives = 0
        batch_false_positives = 0
        batch_true_negatives = 0
        batch_false_negatives = 0
        
        for user_id in batch_users:
            user_test_ratings = test_ratings[test_ratings['userId'] == user_id]
            
            if len(user_test_ratings) == 0:
                continue
            
            for _, row in user_test_ratings.iterrows():
                movie_id = row['movieId']
                true_rating = row['rating']
                
                # Make prediction
                predicted_rating = predict_rating(user_id, movie_id, user_movie_similarities, train_ratings, user_bias_dict)
                
                # Calculate error
                squared_error = (predicted_rating - true_rating) ** 2
                absolute_error = abs(predicted_rating - true_rating)
                
                # Classification metrics
                binary_prediction = 1 if predicted_rating > rating_threshold else 0
                binary_actual = 1 if true_rating > rating_threshold else 0
                
                if binary_prediction == 1 and binary_actual == 1:
                    batch_true_positives += 1
                elif binary_prediction == 1 and binary_actual == 0:
                    batch_false_positives += 1
                elif binary_prediction == 0 and binary_actual == 0:
                    batch_true_negatives += 1
                elif binary_prediction == 0 and binary_actual == 1:
                    batch_false_negatives += 1
                
                # Accumulate errors
                batch_squared_errors += squared_error
                batch_absolute_errors += absolute_error
                batch_predictions += 1
            
            users_evaluated += 1
        
        # Accumulate batch results
        squared_errors_sum += batch_squared_errors
        absolute_errors_sum += batch_absolute_errors
        total_predictions += batch_predictions
        true_positives += batch_true_positives
        false_positives += batch_false_positives
        true_negatives += batch_true_negatives
        false_negatives += batch_false_negatives
        
        batch_time = time.time() - batch_start_time
        elapsed = time.time() - start_time
        progress = batch_end / len(user_list) * 100
        remaining = batch_time * ((len(user_list) - batch_end) / len(batch_users)) if batch_end < len(user_list) else 0
        
        if batch_predictions > 0:
            batch_rmse = np.sqrt(batch_squared_errors / batch_predictions)
            batch_mae = batch_absolute_errors / batch_predictions
            batch_accuracy = (batch_true_positives + batch_true_negatives) / batch_predictions
            
            logger.info(f"Batch metrics - RMSE: {batch_rmse:.4f}, MAE: {batch_mae:.4f}, Accuracy: {batch_accuracy:.4f}")
            logger.info(f"TP: {batch_true_positives}, FP: {batch_false_positives}, TN: {batch_true_negatives}, FN: {batch_false_negatives}")
        
        logger.info(f"Processed {batch_end}/{len(user_list)} users ({progress:.1f}%) - Elapsed: {elapsed:.2f}s - Est. remaining: {remaining:.2f}s")
        
        # Garbage collection
        gc.collect()
    
    # Calculate final metrics
    if total_predictions > 0:
        rmse = np.sqrt(squared_errors_sum / total_predictions)
        mae = absolute_errors_sum / total_predictions
        
        # Classification metrics
        accuracy = (true_positives + true_negatives) / total_predictions
        precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) > 0 else 0
        recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) > 0 else 0
        f1 = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0
    else:
        rmse = 0.0
        mae = 0.0
        accuracy = 0.0
        precision = 0.0
        recall = 0.0
        f1 = 0.0
    
    logger.info("\nEvaluation results:")
    logger.info(f"Users evaluated: {users_evaluated}")
    logger.info(f"Total predictions: {total_predictions}")
    logger.info(f"RMSE: {rmse:.4f}")
    logger.info(f"MAE: {mae:.4f}")
    logger.info(f"Accuracy: {accuracy:.4f}")
    logger.info(f"Precision: {precision:.4f}")
    logger.info(f"Recall: {recall:.4f}")
    logger.info(f"F1 Score: {f1:.4f}")
    logger.info(f"Confusion Matrix: [TP: {true_positives}, FP: {false_positives}, TN: {true_negatives}, FN: {false_negatives}]")
    
    metrics = {
        'rmse': rmse,
        'mae': mae,
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1,
        'true_positives': true_positives,
        'false_positives': false_positives,
        'true_negatives': true_negatives,
        'false_negatives': false_negatives,
        'num_users_evaluated': users_evaluated,
        'num_predictions': total_predictions
    }
    
    return metrics

# Main execution flow with all optimizations
log_memory_usage("Initial memory usage")

# Load data
data = load_data()
log_memory_usage("After loading data")

# Corpus word counts
if 'movie_features' in data:
    corpus_word_counts = Counter()
    
    batch_size = 1000
    total_movies = len(data['movie_features'])
    
    for i in range(0, total_movies, batch_size):
        batch_end = min(i + batch_size, total_movies)
        batch = data['movie_features'].iloc[i:batch_end]
        
        for tokens in batch['tokens']:
            corpus_word_counts.update(tokens)
    
    data['corpus_word_counts'] = corpus_word_counts
    
    with open(os.path.join(output_path, 'corpus_word_counts.pkl'), 'wb') as f:
        pickle.dump(corpus_word_counts, f)
    
    logger.info(f"Created corpus word counts with {len(corpus_word_counts)} unique words")
    gc.collect()
    log_memory_usage("After corpus word count")

# Calculate Log-Likelihood values
if 'movie_features' in data and 'corpus_word_counts' in data:
    movie_ll_values = calculate_log_likelihood(data['movie_features'], data['corpus_word_counts'], batch_size=100)
    data['movie_ll_values'] = movie_ll_values
    
    with open(os.path.join(output_path, 'movie_ll_values.pkl'), 'wb') as f:
        pickle.dump(movie_ll_values, f)
    
    logger.info(f"Calculated LL values for {len(movie_ll_values)} movies")
    gc.collect()
    log_memory_usage("After LL calculation")

# Train Word2Vec model
if 'movie_features' in data:
    word2vec_model = train_word2vec(data['movie_features'], word2vec_dim)
    data['word2vec_model'] = word2vec_model
    
    word2vec_path = os.path.join(output_path, 'word2vec_model')
    word2vec_model.save(word2vec_path)
    
    logger.info(f"Trained Word2Vec model with vector size {word2vec_dim}")
    gc.collect()
    log_memory_usage("After Word2Vec training")

# Generate movie vectors
if 'word2vec_model' in data and 'movie_ll_values' in data and 'corpus_word_counts' in data:
    movie_vectors = generate_movie_vectors(
        data['movie_ll_values'], 
        data['word2vec_model'],
        data['movie_features'],
        data['corpus_word_counts'],
        batch_size=100
    )
    data['movie_vectors'] = movie_vectors
    
    with open(os.path.join(output_path, 'movie_vectors.pkl'), 'wb') as f:
        pickle.dump(movie_vectors, f)
    
    logger.info(f"Generated vectors for {len(movie_vectors)} movies")
    
    # Create movie ID to index mapping
    movie_id_to_idx = {movie_id: i for i, movie_id in enumerate(movie_vectors.keys())}
    data['movie_id_to_idx'] = movie_id_to_idx
    
    with open(os.path.join(output_path, 'movie_id_to_idx.pkl'), 'wb') as f:
        pickle.dump(movie_id_to_idx, f)
    
    gc.collect()
    log_memory_usage("After movie vector generation")

# Generate user vectors
if 'movie_vectors' in data and 'train_ratings' in data:
    user_vectors = generate_user_vectors(data['movie_vectors'], data['train_ratings'], batch_size=100)
    data['user_vectors'] = user_vectors
    
    with open(os.path.join(output_path, 'user_vectors.pkl'), 'wb') as f:
        pickle.dump(user_vectors, f)
    
    logger.info(f"Generated vectors for {len(user_vectors)} users")
    
    # Create user ID to index mapping
    user_id_to_idx = {user_id: i for i, user_id in enumerate(user_vectors.keys())}
    data['user_id_to_idx'] = user_id_to_idx
    
    with open(os.path.join(output_path, 'user_id_to_idx.pkl'), 'wb') as f:
        pickle.dump(user_id_to_idx, f)
    
    gc.collect()
    log_memory_usage("After user vector generation")

# Calculate user-movie similarities
if 'user_vectors' in data and 'movie_vectors' in data:
    user_movie_similarities = calculate_user_movie_similarity(
        data['user_vectors'], 
        data['movie_vectors'], 
        threshold=similarity_threshold,
        batch_size=50
    )
    data['user_movie_similarities'] = user_movie_similarities
    
    with open(os.path.join(output_path, 'user_movie_similarities.pkl'), 'wb') as f:
        pickle.dump(user_movie_similarities, f)
    
    logger.info(f"Calculated similarities for {len(user_movie_similarities)} users")
    gc.collect()
    log_memory_usage("After similarity calculation")

# Generate recommendations
if 'user_movie_similarities' in data and 'train_ratings' in data:
    all_recommendations = generate_recommendations_for_all_users(
        data['user_movie_similarities'], 
        data['train_ratings'],
        data['movie_features'],
        n=top_n,
        batch_size=100
    )
    data['all_recommendations'] = all_recommendations
    
    with open(os.path.join(output_path, 'content_based_recommendations.pkl'), 'wb') as f:
        pickle.dump(all_recommendations, f)
    
    logger.info(f"Generated recommendations for {len(all_recommendations)} users")
    
    # Save to CSV in chunks for better memory handling
    recommendations_list = []
    
    chunk_size = 1000
    user_ids = list(all_recommendations.keys())
    total_users = len(user_ids)
    
    for chunk_start in range(0, total_users, chunk_size):
        chunk_end = min(chunk_start + chunk_size, total_users)
        user_chunk = user_ids[chunk_start:chunk_end]
        
        chunk_recommendations = []
        for user_id in user_chunk:
            for rank, (movie_id, score) in enumerate(all_recommendations[user_id], 1):
                movie_title = "Unknown"
                if 'movie_features' in data:
                    movie_row = data['movie_features'][data['movie_features']['movieId'] == movie_id]
                    if not movie_row.empty and 'title' in movie_row.columns:
                        movie_title = movie_row.iloc[0]['title']
                        
                chunk_recommendations.append({
                    'userId': user_id,
                    'movieId': movie_id,
                    'title': movie_title,
                    'rank': rank,
                    'similarity_score': score
                })
        
        recommendations_list.extend(chunk_recommendations)
        gc.collect()
    
    if recommendations_list:
        chunk_size = 10000
        total_recs = len(recommendations_list)
        
        for chunk_start in range(0, total_recs, chunk_size):
            chunk_end = min(chunk_start + chunk_size, total_recs)
            chunk = recommendations_list[chunk_start:chunk_end]
            
            chunk_df = pd.DataFrame(chunk)
            
            # Write header only for the first chunk
            if chunk_start == 0:
                chunk_df.to_csv(os.path.join(output_path, 'content_based_recommendations.csv'), index=False, mode='w')
            else:
                chunk_df.to_csv(os.path.join(output_path, 'content_based_recommendations.csv'), index=False, mode='a', header=False)
    
    del recommendations_list
    gc.collect()
    log_memory_usage("After recommendation generation")

# Evaluate the model
if 'user_movie_similarities' in data and 'train_ratings' in data and 'test_ratings' in data:
    logger.info("Running evaluation with enhanced metrics...")
    evaluation_metrics = evaluate_with_rmse_mae(
        data['user_movie_similarities'],
        data['train_ratings'],
        data['test_ratings'],
        batch_size=100,
        rating_threshold=rating_threshold
    )
    
    data['evaluation_metrics'] = evaluation_metrics
    
    logger.info("\nStored evaluation metrics:")
    for key, value in evaluation_metrics.items():
        logger.info(f"  {key}: {value}")
    
    # Save evaluation results
    evaluation_results = pd.DataFrame([evaluation_metrics])
    evaluation_results.to_csv(os.path.join(output_path, 'content_based_evaluation.csv'), index=False)
    
    # Create visualizations for evaluation metrics
    if 'rmse' in evaluation_metrics:
        # Plot confusion matrix
        plt.figure(figsize=(10, 8))
        cm = np.array([
            [evaluation_metrics.get('true_negatives', 0), evaluation_metrics.get('false_positives', 0)],
            [evaluation_metrics.get('false_negatives', 0), evaluation_metrics.get('true_positives', 0)]
        ])
        
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                   xticklabels=['Predicted Negative', 'Predicted Positive'],
                   yticklabels=['Actual Negative', 'Actual Positive'])
        plt.title('Confusion Matrix')
        plt.savefig(os.path.join(output_path, 'confusion_matrix.png'))
        plt.close()
        
        # Create a bar chart comparing all metrics
        metrics_to_plot = ['accuracy', 'precision', 'recall', 'f1_score']
        values = [evaluation_metrics.get(metric, 0) for metric in metrics_to_plot]
        
        plt.figure(figsize=(10, 6))
        colors = ['skyblue', 'lightgreen', 'salmon', 'gold']
        plt.bar(metrics_to_plot, values, color=colors)
        plt.ylim(0, 1)
        plt.title('Classification Performance Metrics')
        plt.grid(axis='y', alpha=0.3)
        plt.savefig(os.path.join(output_path, 'classification_metrics.png'))
        plt.close()
        
        logger.info("Created evaluation visualizations")
    
    gc.collect()
    log_memory_usage("After evaluation")

logger.info("Content-based recommendation pipeline completed successfully!")
# Out:
# 2025-04-28 03:04:30,507 : INFO : Initial memory usage: 201.16 MB
# 2025-04-28 03:04:32,398 : INFO : Loaded features for 24378 movies
# 2025-04-28 03:04:50,044 : INFO : Loaded 14472091 ratings from 100000 users
# 2025-04-28 03:05:44,036 : INFO : Created train set with 13875887 ratings from 100000 users
# 2025-04-28 03:05:44,051 : INFO : Created test set with 596204 ratings from 20000 users
# 2025-04-28 03:05:44,411 : INFO : After loading data: 1409.02 MB
# 2025-04-28 03:05:44,606 : INFO : Created corpus word counts with 95445 unique words
# 2025-04-28 03:05:44,709 : INFO : After corpus word count: 1408.93 MB
# 2025-04-28 03:05:45,302 : INFO : Processed 100/24378 movies (0.4%) - Elapsed: 0.59s - Est. remaining: 143.90s
# 2025-04-28 03:05:45,409 : INFO : Processed 200/24378 movies (0.8%) - Elapsed: 0.70s - Est. remaining: 169.25s
# 2025-04-28 03:05:45,514 : INFO : Processed 300/24378 movies (1.2%) - Elapsed: 0.80s - Est. remaining: 193.79s
# 2025-04-28 03:05:45,584 : INFO : Processed 400/24378 movies (1.6%) - Elapsed: 0.87s - Est. remaining: 209.77s
# 2025-04-28 03:05:45,682 : INFO : Processed 500/24378 movies (2.1%) - Elapsed: 0.97s - Est. remaining: 232.27s
# 2025-04-28 03:05:45,771 : INFO : Processed 600/24378 movies (2.5%) - Elapsed: 1.06s - Est. remaining: 252.55s
# 2025-04-28 03:05:45,864 : INFO : Processed 700/24378 movies (2.9%) - Elapsed: 1.16s - Est. remaining: 273.57s
# 2025-04-28 03:05:45,991 : INFO : Processed 800/24378 movies (3.3%) - Elapsed: 1.28s - Est. remaining: 302.24s
# 2025-04-28 03:05:46,090 : INFO : Processed 900/24378 movies (3.7%) - Elapsed: 1.38s - Est. remaining: 324.30s
# 2025-04-28 03:05:46,182 : INFO : Processed 1000/24378 movies (4.1%) - Elapsed: 1.47s - Est. remaining: 344.49s
# 2025-04-28 03:05:46,281 : INFO : Processed 1100/24378 movies (4.5%) - Elapsed: 1.57s - Est. remaining: 365.86s
# 2025-04-28 03:05:46,364 : INFO : Processed 1200/24378 movies (4.9%) - Elapsed: 1.65s - Est. remaining: 383.56s
# 2025-04-28 03:05:46,458 : INFO : Processed 1300/24378 movies (5.3%) - Elapsed: 1.75s - Est. remaining: 403.71s
# 2025-04-28 03:05:46,536 : INFO : Processed 1400/24378 movies (5.7%) - Elapsed: 1.83s - Est. remaining: 419.93s
# 2025-04-28 03:05:46,630 : INFO : Processed 1500/24378 movies (6.2%) - Elapsed: 1.92s - Est. remaining: 439.53s
# 2025-04-28 03:05:46,726 : INFO : Processed 1600/24378 movies (6.6%) - Elapsed: 2.02s - Est. remaining: 459.40s
# 2025-04-28 03:05:46,833 : INFO : Processed 1700/24378 movies (7.0%) - Elapsed: 2.12s - Est. remaining: 481.79s
# 2025-04-28 03:05:46,928 : INFO : Processed 1800/24378 movies (7.4%) - Elapsed: 2.22s - Est. remaining: 501.12s
# 2025-04-28 03:05:47,021 : INFO : Processed 1900/24378 movies (7.8%) - Elapsed: 2.31s - Est. remaining: 519.70s
# 2025-04-28 03:05:47,103 : INFO : Processed 2000/24378 movies (8.2%) - Elapsed: 2.39s - Est. remaining: 535.73s
# 2025-04-28 03:05:47,193 : INFO : Processed 2100/24378 movies (8.6%) - Elapsed: 2.48s - Est. remaining: 553.39s
# 2025-04-28 03:05:47,295 : INFO : Processed 2200/24378 movies (9.0%) - Elapsed: 2.59s - Est. remaining: 573.54s
# 2025-04-28 03:05:47,411 : INFO : Processed 2300/24378 movies (9.4%) - Elapsed: 2.70s - Est. remaining: 596.63s
# 2025-04-28 03:05:47,505 : INFO : Processed 2400/24378 movies (9.8%) - Elapsed: 2.80s - Est. remaining: 614.54s
# 2025-04-28 03:05:47,593 : INFO : Processed 2500/24378 movies (10.3%) - Elapsed: 2.88s - Est. remaining: 630.94s
# 2025-04-28 03:05:47,683 : INFO : Processed 2600/24378 movies (10.7%) - Elapsed: 2.97s - Est. remaining: 647.60s
# 2025-04-28 03:05:47,755 : INFO : Processed 2700/24378 movies (11.1%) - Elapsed: 3.05s - Est. remaining: 660.38s
# 2025-04-28 03:05:47,840 : INFO : Processed 2800/24378 movies (11.5%) - Elapsed: 3.13s - Est. remaining: 675.58s
# 2025-04-28 03:05:47,943 : INFO : Processed 2900/24378 movies (11.9%) - Elapsed: 3.23s - Est. remaining: 694.62s
# 2025-04-28 03:05:48,021 : INFO : Processed 3000/24378 movies (12.3%) - Elapsed: 3.31s - Est. remaining: 708.17s
# 2025-04-28 03:05:48,123 : INFO : Processed 3100/24378 movies (12.7%) - Elapsed: 3.41s - Est. remaining: 726.38s
# 2025-04-28 03:05:48,201 : INFO : Processed 3200/24378 movies (13.1%) - Elapsed: 3.49s - Est. remaining: 739.60s
# 2025-04-28 03:05:48,295 : INFO : Processed 3300/24378 movies (13.5%) - Elapsed: 3.59s - Est. remaining: 755.95s
# 2025-04-28 03:05:48,422 : INFO : Processed 3400/24378 movies (13.9%) - Elapsed: 3.71s - Est. remaining: 779.00s
# 2025-04-28 03:05:48,506 : INFO : Processed 3500/24378 movies (14.4%) - Elapsed: 3.80s - Est. remaining: 792.68s
# 2025-04-28 03:05:48,584 : INFO : Processed 3600/24378 movies (14.8%) - Elapsed: 3.88s - Est. remaining: 805.19s
# 2025-04-28 03:05:48,684 : INFO : Processed 3700/24378 movies (15.2%) - Elapsed: 3.98s - Est. remaining: 822.05s
# 2025-04-28 03:05:48,777 : INFO : Processed 3800/24378 movies (15.6%) - Elapsed: 4.07s - Est. remaining: 837.15s
# 2025-04-28 03:05:48,868 : INFO : Processed 3900/24378 movies (16.0%) - Elapsed: 4.16s - Est. remaining: 851.70s
# 2025-04-28 03:05:48,957 : INFO : Processed 4000/24378 movies (16.4%) - Elapsed: 4.25s - Est. remaining: 865.59s
# 2025-04-28 03:05:49,036 : INFO : Processed 4100/24378 movies (16.8%) - Elapsed: 4.33s - Est. remaining: 877.54s
# 2025-04-28 03:05:49,120 : INFO : Processed 4200/24378 movies (17.2%) - Elapsed: 4.41s - Est. remaining: 890.17s
# 2025-04-28 03:05:49,215 : INFO : Processed 4300/24378 movies (17.6%) - Elapsed: 4.51s - Est. remaining: 904.68s
# 2025-04-28 03:05:49,293 : INFO : Processed 4400/24378 movies (18.0%) - Elapsed: 4.58s - Est. remaining: 915.86s
# 2025-04-28 03:05:49,387 : INFO : Processed 4500/24378 movies (18.5%) - Elapsed: 4.68s - Est. remaining: 929.83s
# 2025-04-28 03:05:49,474 : INFO : Processed 4600/24378 movies (18.9%) - Elapsed: 4.76s - Est. remaining: 942.35s
# 2025-04-28 03:05:49,552 : INFO : Processed 4700/24378 movies (19.3%) - Elapsed: 4.84s - Est. remaining: 953.03s
# 2025-04-28 03:05:49,645 : INFO : Processed 4800/24378 movies (19.7%) - Elapsed: 4.94s - Est. remaining: 966.37s
# 2025-04-28 03:05:49,723 : INFO : Processed 4900/24378 movies (20.1%) - Elapsed: 5.01s - Est. remaining: 976.73s
# 2025-04-28 03:05:49,802 : INFO : Processed 5000/24378 movies (20.5%) - Elapsed: 5.09s - Est. remaining: 986.99s
# 2025-04-28 03:05:49,908 : INFO : Processed 5100/24378 movies (20.9%) - Elapsed: 5.20s - Est. remaining: 1002.30s
# 2025-04-28 03:05:50,021 : INFO : Processed 5200/24378 movies (21.3%) - Elapsed: 5.31s - Est. remaining: 1018.77s
# 2025-04-28 03:05:50,100 : INFO : Processed 5300/24378 movies (21.7%) - Elapsed: 5.39s - Est. remaining: 1028.61s
# 2025-04-28 03:05:50,193 : INFO : Processed 5400/24378 movies (22.2%) - Elapsed: 5.48s - Est. remaining: 1040.54s
# 2025-04-28 03:05:50,282 : INFO : Processed 5500/24378 movies (22.6%) - Elapsed: 5.57s - Est. remaining: 1052.05s
# 2025-04-28 03:05:50,364 : INFO : Processed 5600/24378 movies (23.0%) - Elapsed: 5.66s - Est. remaining: 1061.98s
# 2025-04-28 03:05:50,458 : INFO : Processed 5700/24378 movies (23.4%) - Elapsed: 5.75s - Est. remaining: 1073.84s
# 2025-04-28 03:05:50,536 : INFO : Processed 5800/24378 movies (23.8%) - Elapsed: 5.83s - Est. remaining: 1082.59s
# 2025-04-28 03:05:50,630 : INFO : Processed 5900/24378 movies (24.2%) - Elapsed: 5.92s - Est. remaining: 1094.12s
# 2025-04-28 03:05:50,730 : INFO : Processed 6000/24378 movies (24.6%) - Elapsed: 6.02s - Est. remaining: 1106.50s
# 2025-04-28 03:05:50,818 : INFO : Processed 6100/24378 movies (25.0%) - Elapsed: 6.11s - Est. remaining: 1116.66s
# 2025-04-28 03:05:50,912 : INFO : Processed 6200/24378 movies (25.4%) - Elapsed: 6.20s - Est. remaining: 1127.62s
# 2025-04-28 03:05:50,989 : INFO : Processed 6300/24378 movies (25.8%) - Elapsed: 6.28s - Est. remaining: 1135.26s
# 2025-04-28 03:05:51,094 : INFO : Processed 6400/24378 movies (26.3%) - Elapsed: 6.38s - Est. remaining: 1147.83s
# 2025-04-28 03:05:51,176 : INFO : Processed 6500/24378 movies (26.7%) - Elapsed: 6.47s - Est. remaining: 1156.27s
# 2025-04-28 03:05:51,268 : INFO : Processed 6600/24378 movies (27.1%) - Elapsed: 6.56s - Est. remaining: 1166.10s
# 2025-04-28 03:05:51,349 : INFO : Processed 6700/24378 movies (27.5%) - Elapsed: 6.64s - Est. remaining: 1173.77s
# 2025-04-28 03:05:51,476 : INFO : Processed 6800/24378 movies (27.9%) - Elapsed: 6.77s - Est. remaining: 1189.56s
# 2025-04-28 03:05:51,574 : INFO : Processed 6900/24378 movies (28.3%) - Elapsed: 6.86s - Est. remaining: 1199.83s
# 2025-04-28 03:05:51,661 : INFO : Processed 7000/24378 movies (28.7%) - Elapsed: 6.95s - Est. remaining: 1208.21s
# 2025-04-28 03:05:51,755 : INFO : Processed 7100/24378 movies (29.1%) - Elapsed: 7.05s - Est. remaining: 1217.47s
# 2025-04-28 03:05:51,833 : INFO : Processed 7200/24378 movies (29.5%) - Elapsed: 7.12s - Est. remaining: 1223.83s
# 2025-04-28 03:05:51,934 : INFO : Processed 7300/24378 movies (29.9%) - Elapsed: 7.22s - Est. remaining: 1233.84s
# 2025-04-28 03:05:52,023 : INFO : Processed 7400/24378 movies (30.4%) - Elapsed: 7.31s - Est. remaining: 1241.74s
# 2025-04-28 03:05:52,107 : INFO : Processed 7500/24378 movies (30.8%) - Elapsed: 7.40s - Est. remaining: 1248.58s
# 2025-04-28 03:05:52,193 : INFO : Processed 7600/24378 movies (31.2%) - Elapsed: 7.48s - Est. remaining: 1255.76s
# 2025-04-28 03:05:52,270 : INFO : Processed 7700/24378 movies (31.6%) - Elapsed: 7.56s - Est. remaining: 1261.08s
# 2025-04-28 03:05:52,370 : INFO : Processed 7800/24378 movies (32.0%) - Elapsed: 7.66s - Est. remaining: 1270.11s
# 2025-04-28 03:05:52,443 : INFO : Processed 7900/24378 movies (32.4%) - Elapsed: 7.73s - Est. remaining: 1274.46s
# 2025-04-28 03:05:52,572 : INFO : Processed 8000/24378 movies (32.8%) - Elapsed: 7.86s - Est. remaining: 1287.78s
# 2025-04-28 03:05:52,661 : INFO : Processed 8100/24378 movies (33.2%) - Elapsed: 7.95s - Est. remaining: 1294.46s
# 2025-04-28 03:05:52,739 : INFO : Processed 8200/24378 movies (33.6%) - Elapsed: 8.03s - Est. remaining: 1299.16s
# 2025-04-28 03:05:52,833 : INFO : Processed 8300/24378 movies (34.0%) - Elapsed: 8.12s - Est. remaining: 1306.21s
# 2025-04-28 03:05:52,925 : INFO : Processed 8400/24378 movies (34.5%) - Elapsed: 8.22s - Est. remaining: 1312.74s
# 2025-04-28 03:05:53,005 : INFO : Processed 8500/24378 movies (34.9%) - Elapsed: 8.30s - Est. remaining: 1317.33s
# 2025-04-28 03:05:53,101 : INFO : Processed 8600/24378 movies (35.3%) - Elapsed: 8.39s - Est. remaining: 1324.17s
# 2025-04-28 03:05:53,216 : INFO : Processed 8700/24378 movies (35.7%) - Elapsed: 8.51s - Est. remaining: 1333.70s
# 2025-04-28 03:05:53,302 : INFO : Processed 8800/24378 movies (36.1%) - Elapsed: 8.59s - Est. remaining: 1338.71s
# 2025-04-28 03:05:53,380 : INFO : Processed 8900/24378 movies (36.5%) - Elapsed: 8.67s - Est. remaining: 1342.19s
# 2025-04-28 03:05:53,474 : INFO : Processed 9000/24378 movies (36.9%) - Elapsed: 8.76s - Est. remaining: 1347.84s
# 2025-04-28 03:05:53,570 : INFO : Processed 9100/24378 movies (37.3%) - Elapsed: 8.86s - Est. remaining: 1353.79s
# 2025-04-28 03:05:53,663 : INFO : Processed 9200/24378 movies (37.7%) - Elapsed: 8.95s - Est. remaining: 1359.06s
# 2025-04-28 03:05:53,740 : INFO : Processed 9300/24378 movies (38.1%) - Elapsed: 9.03s - Est. remaining: 1361.74s
# 2025-04-28 03:05:53,834 : INFO : Processed 9400/24378 movies (38.6%) - Elapsed: 9.12s - Est. remaining: 1366.70s
# 2025-04-28 03:05:53,911 : INFO : Processed 9500/24378 movies (39.0%) - Elapsed: 9.20s - Est. remaining: 1369.17s
# 2025-04-28 03:05:54,012 : INFO : Processed 9600/24378 movies (39.4%) - Elapsed: 9.30s - Est. remaining: 1374.83s
# 2025-04-28 03:05:54,102 : INFO : Processed 9700/24378 movies (39.8%) - Elapsed: 9.39s - Est. remaining: 1378.72s
# 2025-04-28 03:05:54,181 : INFO : Processed 9800/24378 movies (40.2%) - Elapsed: 9.47s - Est. remaining: 1380.81s
# 2025-04-28 03:05:54,271 : INFO : Processed 9900/24378 movies (40.6%) - Elapsed: 9.56s - Est. remaining: 1384.42s
# 2025-04-28 03:05:54,349 : INFO : Processed 10000/24378 movies (41.0%) - Elapsed: 9.64s - Est. remaining: 1386.01s
# 2025-04-28 03:05:54,445 : INFO : Processed 10100/24378 movies (41.4%) - Elapsed: 9.74s - Est. remaining: 1390.12s
# 2025-04-28 03:05:54,565 : INFO : Processed 10200/24378 movies (41.8%) - Elapsed: 9.86s - Est. remaining: 1397.35s
# 2025-04-28 03:05:54,654 : INFO : Processed 10300/24378 movies (42.3%) - Elapsed: 9.95s - Est. remaining: 1400.14s
# 2025-04-28 03:05:54,725 : INFO : Processed 10400/24378 movies (42.7%) - Elapsed: 10.02s - Est. remaining: 1400.03s
# 2025-04-28 03:05:54,817 : INFO : Processed 10500/24378 movies (43.1%) - Elapsed: 10.11s - Est. remaining: 1402.84s
# 2025-04-28 03:05:54,911 : INFO : Processed 10600/24378 movies (43.5%) - Elapsed: 10.20s - Est. remaining: 1405.63s
# 2025-04-28 03:05:55,004 : INFO : Processed 10700/24378 movies (43.9%) - Elapsed: 10.29s - Est. remaining: 1408.02s
# 2025-04-28 03:05:55,085 : INFO : Processed 10800/24378 movies (44.3%) - Elapsed: 10.38s - Est. remaining: 1408.88s
# 2025-04-28 03:05:55,176 : INFO : Processed 10900/24378 movies (44.7%) - Elapsed: 10.47s - Est. remaining: 1410.82s
# 2025-04-28 03:05:55,255 : INFO : Processed 11000/24378 movies (45.1%) - Elapsed: 10.55s - Est. remaining: 1410.82s
# 2025-04-28 03:05:55,348 : INFO : Processed 11100/24378 movies (45.5%) - Elapsed: 10.64s - Est. remaining: 1412.71s
# 2025-04-28 03:05:55,445 : INFO : Processed 11200/24378 movies (45.9%) - Elapsed: 10.74s - Est. remaining: 1414.85s
# 2025-04-28 03:05:55,533 : INFO : Processed 11300/24378 movies (46.4%) - Elapsed: 10.82s - Est. remaining: 1415.58s
# 2025-04-28 03:05:55,615 : INFO : Processed 11400/24378 movies (46.8%) - Elapsed: 10.91s - Est. remaining: 1415.40s
# 2025-04-28 03:05:55,743 : INFO : Processed 11500/24378 movies (47.2%) - Elapsed: 11.03s - Est. remaining: 1420.99s
# 2025-04-28 03:05:55,818 : INFO : Processed 11600/24378 movies (47.6%) - Elapsed: 11.11s - Est. remaining: 1419.56s
# 2025-04-28 03:05:55,912 : INFO : Processed 11700/24378 movies (48.0%) - Elapsed: 11.20s - Est. remaining: 1420.33s
# 2025-04-28 03:05:56,005 : INFO : Processed 11800/24378 movies (48.4%) - Elapsed: 11.30s - Est. remaining: 1420.82s
# 2025-04-28 03:05:56,099 : INFO : Processed 11900/24378 movies (48.8%) - Elapsed: 11.39s - Est. remaining: 1421.28s
# 2025-04-28 03:05:56,179 : INFO : Processed 12000/24378 movies (49.2%) - Elapsed: 11.47s - Est. remaining: 1419.82s
# 2025-04-28 03:05:56,270 : INFO : Processed 12100/24378 movies (49.6%) - Elapsed: 11.56s - Est. remaining: 1419.48s
# 2025-04-28 03:05:56,349 : INFO : Processed 12200/24378 movies (50.0%) - Elapsed: 11.64s - Est. remaining: 1417.56s
# 2025-04-28 03:05:56,443 : INFO : Processed 12300/24378 movies (50.5%) - Elapsed: 11.73s - Est. remaining: 1417.22s
# 2025-04-28 03:05:56,536 : INFO : Processed 12400/24378 movies (50.9%) - Elapsed: 11.83s - Est. remaining: 1416.63s
# 2025-04-28 03:05:56,614 : INFO : Processed 12500/24378 movies (51.3%) - Elapsed: 11.91s - Est. remaining: 1414.13s
# 2025-04-28 03:05:56,708 : INFO : Processed 12600/24378 movies (51.7%) - Elapsed: 12.00s - Est. remaining: 1413.28s
# 2025-04-28 03:05:56,793 : INFO : Processed 12700/24378 movies (52.1%) - Elapsed: 12.08s - Est. remaining: 1411.19s
# 2025-04-28 03:05:56,912 : INFO : Processed 12800/24378 movies (52.5%) - Elapsed: 12.20s - Est. remaining: 1412.82s
# 2025-04-28 03:05:57,005 : INFO : Processed 12900/24378 movies (52.9%) - Elapsed: 12.30s - Est. remaining: 1411.30s
# 2025-04-28 03:05:57,091 : INFO : Processed 13000/24378 movies (53.3%) - Elapsed: 12.38s - Est. remaining: 1408.83s
# 2025-04-28 03:05:57,181 : INFO : Processed 13100/24378 movies (53.7%) - Elapsed: 12.47s - Est. remaining: 1406.58s
# 2025-04-28 03:05:57,263 : INFO : Processed 13200/24378 movies (54.1%) - Elapsed: 12.55s - Est. remaining: 1403.33s
# 2025-04-28 03:05:57,341 : INFO : Processed 13300/24378 movies (54.6%) - Elapsed: 12.63s - Est. remaining: 1399.41s
# 2025-04-28 03:05:57,420 : INFO : Processed 13400/24378 movies (55.0%) - Elapsed: 12.71s - Est. remaining: 1395.38s
# 2025-04-28 03:05:57,514 : INFO : Processed 13500/24378 movies (55.4%) - Elapsed: 12.80s - Est. remaining: 1392.91s
# 2025-04-28 03:05:57,601 : INFO : Processed 13600/24378 movies (55.8%) - Elapsed: 12.89s - Est. remaining: 1389.51s
# 2025-04-28 03:05:57,697 : INFO : Processed 13700/24378 movies (56.2%) - Elapsed: 12.99s - Est. remaining: 1386.85s
# 2025-04-28 03:05:57,811 : INFO : Processed 13800/24378 movies (56.6%) - Elapsed: 13.10s - Est. remaining: 1385.96s
# 2025-04-28 03:05:57,880 : INFO : Processed 13900/24378 movies (57.0%) - Elapsed: 13.17s - Est. remaining: 1380.06s
# 2025-04-28 03:05:57,987 : INFO : Processed 14000/24378 movies (57.4%) - Elapsed: 13.28s - Est. remaining: 1377.99s
# 2025-04-28 03:05:58,067 : INFO : Processed 14100/24378 movies (57.8%) - Elapsed: 13.36s - Est. remaining: 1372.95s
# 2025-04-28 03:05:58,144 : INFO : Processed 14200/24378 movies (58.2%) - Elapsed: 13.44s - Est. remaining: 1367.42s
# 2025-04-28 03:05:58,223 : INFO : Processed 14300/24378 movies (58.7%) - Elapsed: 13.51s - Est. remaining: 1361.91s
# 2025-04-28 03:05:58,318 : INFO : Processed 14400/24378 movies (59.1%) - Elapsed: 13.61s - Est. remaining: 1357.89s
# 2025-04-28 03:05:58,414 : INFO : Processed 14500/24378 movies (59.5%) - Elapsed: 13.70s - Est. remaining: 1353.75s
# 2025-04-28 03:05:58,504 : INFO : Processed 14600/24378 movies (59.9%) - Elapsed: 13.80s - Est. remaining: 1348.94s
# 2025-04-28 03:05:58,583 : INFO : Processed 14700/24378 movies (60.3%) - Elapsed: 13.87s - Est. remaining: 1342.70s
# 2025-04-28 03:05:58,682 : INFO : Processed 14800/24378 movies (60.7%) - Elapsed: 13.97s - Est. remaining: 1338.34s
# 2025-04-28 03:05:58,754 : INFO : Processed 14900/24378 movies (61.1%) - Elapsed: 14.05s - Est. remaining: 1331.24s
# 2025-04-28 03:05:58,850 : INFO : Processed 15000/24378 movies (61.5%) - Elapsed: 14.14s - Est. remaining: 1326.18s
# 2025-04-28 03:05:58,967 : INFO : Processed 15100/24378 movies (61.9%) - Elapsed: 14.26s - Est. remaining: 1322.86s
# 2025-04-28 03:05:59,052 : INFO : Processed 15200/24378 movies (62.4%) - Elapsed: 14.34s - Est. remaining: 1316.38s
# 2025-04-28 03:05:59,132 : INFO : Processed 15300/24378 movies (62.8%) - Elapsed: 14.42s - Est. remaining: 1309.30s
# 2025-04-28 03:05:59,210 : INFO : Processed 15400/24378 movies (63.2%) - Elapsed: 14.50s - Est. remaining: 1301.92s
# 2025-04-28 03:05:59,305 : INFO : Processed 15500/24378 movies (63.6%) - Elapsed: 14.60s - Est. remaining: 1295.82s
# 2025-04-28 03:05:59,395 : INFO : Processed 15600/24378 movies (64.0%) - Elapsed: 14.69s - Est. remaining: 1289.19s
# 2025-04-28 03:05:59,483 : INFO : Processed 15700/24378 movies (64.4%) - Elapsed: 14.77s - Est. remaining: 1282.09s
# 2025-04-28 03:05:59,568 : INFO : Processed 15800/24378 movies (64.8%) - Elapsed: 14.86s - Est. remaining: 1274.61s
# 2025-04-28 03:05:59,646 : INFO : Processed 15900/24378 movies (65.2%) - Elapsed: 14.94s - Est. remaining: 1266.41s
# 2025-04-28 03:05:59,725 : INFO : Processed 16000/24378 movies (65.6%) - Elapsed: 15.02s - Est. remaining: 1258.02s
# 2025-04-28 03:05:59,817 : INFO : Processed 16100/24378 movies (66.0%) - Elapsed: 15.11s - Est. remaining: 1250.68s
# 2025-04-28 03:05:59,910 : INFO : Processed 16200/24378 movies (66.5%) - Elapsed: 15.20s - Est. remaining: 1243.19s
# 2025-04-28 03:05:59,998 : INFO : Processed 16300/24378 movies (66.9%) - Elapsed: 15.29s - Est. remaining: 1235.08s
# 2025-04-28 03:06:00,073 : INFO : Processed 16400/24378 movies (67.3%) - Elapsed: 15.36s - Est. remaining: 1225.78s
# 2025-04-28 03:06:00,186 : INFO : Processed 16500/24378 movies (67.7%) - Elapsed: 15.48s - Est. remaining: 1219.26s
# 2025-04-28 03:06:00,271 : INFO : Processed 16600/24378 movies (68.1%) - Elapsed: 15.56s - Est. remaining: 1210.39s
# 2025-04-28 03:06:00,365 : INFO : Processed 16700/24378 movies (68.5%) - Elapsed: 15.66s - Est. remaining: 1202.04s
# 2025-04-28 03:06:00,456 : INFO : Processed 16800/24378 movies (68.9%) - Elapsed: 15.75s - Est. remaining: 1193.33s
# 2025-04-28 03:06:00,544 : INFO : Processed 16900/24378 movies (69.3%) - Elapsed: 15.84s - Est. remaining: 1184.14s
# 2025-04-28 03:06:00,615 : INFO : Processed 17000/24378 movies (69.7%) - Elapsed: 15.91s - Est. remaining: 1173.58s
# 2025-04-28 03:06:00,706 : INFO : Processed 17100/24378 movies (70.1%) - Elapsed: 16.00s - Est. remaining: 1164.31s
# 2025-04-28 03:06:00,787 : INFO : Processed 17200/24378 movies (70.6%) - Elapsed: 16.08s - Est. remaining: 1154.07s
# 2025-04-28 03:06:00,878 : INFO : Processed 17300/24378 movies (71.0%) - Elapsed: 16.17s - Est. remaining: 1144.48s
# 2025-04-28 03:06:00,958 : INFO : Processed 17400/24378 movies (71.4%) - Elapsed: 16.25s - Est. remaining: 1133.89s
# 2025-04-28 03:06:01,039 : INFO : Processed 17500/24378 movies (71.8%) - Elapsed: 16.33s - Est. remaining: 1123.21s
# 2025-04-28 03:06:01,122 : INFO : Processed 17600/24378 movies (72.2%) - Elapsed: 16.41s - Est. remaining: 1112.51s
# 2025-04-28 03:06:01,208 : INFO : Processed 17700/24378 movies (72.6%) - Elapsed: 16.50s - Est. remaining: 1101.79s
# 2025-04-28 03:06:01,305 : INFO : Processed 17800/24378 movies (73.0%) - Elapsed: 16.60s - Est. remaining: 1091.67s
# 2025-04-28 03:06:01,421 : INFO : Processed 17900/24378 movies (73.4%) - Elapsed: 16.71s - Est. remaining: 1082.61s
# 2025-04-28 03:06:01,489 : INFO : Processed 18000/24378 movies (73.8%) - Elapsed: 16.78s - Est. remaining: 1070.27s
# 2025-04-28 03:06:01,593 : INFO : Processed 18100/24378 movies (74.2%) - Elapsed: 16.88s - Est. remaining: 1059.97s
# 2025-04-28 03:06:01,671 : INFO : Processed 18200/24378 movies (74.7%) - Elapsed: 16.96s - Est. remaining: 1047.94s
# 2025-04-28 03:06:01,755 : INFO : Processed 18300/24378 movies (75.1%) - Elapsed: 17.05s - Est. remaining: 1036.08s
# 2025-04-28 03:06:01,845 : INFO : Processed 18400/24378 movies (75.5%) - Elapsed: 17.14s - Est. remaining: 1024.40s
# 2025-04-28 03:06:01,927 : INFO : Processed 18500/24378 movies (75.9%) - Elapsed: 17.22s - Est. remaining: 1012.08s
# 2025-04-28 03:06:02,018 : INFO : Processed 18600/24378 movies (76.3%) - Elapsed: 17.31s - Est. remaining: 1000.13s
# 2025-04-28 03:06:02,104 : INFO : Processed 18700/24378 movies (76.7%) - Elapsed: 17.40s - Est. remaining: 987.72s
# 2025-04-28 03:06:02,187 : INFO : Processed 18800/24378 movies (77.1%) - Elapsed: 17.48s - Est. remaining: 974.95s
# 2025-04-28 03:06:02,266 : INFO : Processed 18900/24378 movies (77.5%) - Elapsed: 17.56s - Est. remaining: 961.77s
# 2025-04-28 03:06:02,344 : INFO : Processed 19000/24378 movies (77.9%) - Elapsed: 17.64s - Est. remaining: 948.42s
# 2025-04-28 03:06:02,427 : INFO : Processed 19100/24378 movies (78.3%) - Elapsed: 17.72s - Est. remaining: 935.15s
# 2025-04-28 03:06:02,527 : INFO : Processed 19200/24378 movies (78.8%) - Elapsed: 17.82s - Est. remaining: 922.63s
# 2025-04-28 03:06:02,609 : INFO : Processed 19300/24378 movies (79.2%) - Elapsed: 17.90s - Est. remaining: 908.98s
# 2025-04-28 03:06:02,693 : INFO : Processed 19400/24378 movies (79.6%) - Elapsed: 17.98s - Est. remaining: 895.23s
# 2025-04-28 03:06:02,809 : INFO : Processed 19500/24378 movies (80.0%) - Elapsed: 18.10s - Est. remaining: 882.93s
# 2025-04-28 03:06:02,896 : INFO : Processed 19600/24378 movies (80.4%) - Elapsed: 18.19s - Est. remaining: 868.97s
# 2025-04-28 03:06:02,974 : INFO : Processed 19700/24378 movies (80.8%) - Elapsed: 18.27s - Est. remaining: 854.46s
# 2025-04-28 03:06:03,068 : INFO : Processed 19800/24378 movies (81.2%) - Elapsed: 18.36s - Est. remaining: 840.46s
# 2025-04-28 03:06:03,158 : INFO : Processed 19900/24378 movies (81.6%) - Elapsed: 18.45s - Est. remaining: 826.15s
# 2025-04-28 03:06:03,240 : INFO : Processed 20000/24378 movies (82.0%) - Elapsed: 18.53s - Est. remaining: 811.28s
# 2025-04-28 03:06:03,318 : INFO : Processed 20100/24378 movies (82.5%) - Elapsed: 18.61s - Est. remaining: 796.10s
# 2025-04-28 03:06:03,411 : INFO : Processed 20200/24378 movies (82.9%) - Elapsed: 18.70s - Est. remaining: 781.37s
# 2025-04-28 03:06:03,501 : INFO : Processed 20300/24378 movies (83.3%) - Elapsed: 18.79s - Est. remaining: 766.36s
# 2025-04-28 03:06:03,583 : INFO : Processed 20400/24378 movies (83.7%) - Elapsed: 18.87s - Est. remaining: 750.83s
# 2025-04-28 03:06:03,662 : INFO : Processed 20500/24378 movies (84.1%) - Elapsed: 18.95s - Est. remaining: 734.99s
# 2025-04-28 03:06:03,739 : INFO : Processed 20600/24378 movies (84.5%) - Elapsed: 19.03s - Est. remaining: 718.96s
# 2025-04-28 03:06:03,827 : INFO : Processed 20700/24378 movies (84.9%) - Elapsed: 19.12s - Est. remaining: 703.18s
# 2025-04-28 03:06:03,943 : INFO : Processed 20800/24378 movies (85.3%) - Elapsed: 19.23s - Est. remaining: 688.19s
# 2025-04-28 03:06:04,035 : INFO : Processed 20900/24378 movies (85.7%) - Elapsed: 19.33s - Est. remaining: 672.18s
# 2025-04-28 03:06:04,119 : INFO : Processed 21000/24378 movies (86.1%) - Elapsed: 19.41s - Est. remaining: 655.68s
# 2025-04-28 03:06:04,214 : INFO : Processed 21100/24378 movies (86.6%) - Elapsed: 19.51s - Est. remaining: 639.38s
# 2025-04-28 03:06:04,318 : INFO : Processed 21200/24378 movies (87.0%) - Elapsed: 19.61s - Est. remaining: 623.19s
# 2025-04-28 03:06:04,395 : INFO : Processed 21300/24378 movies (87.4%) - Elapsed: 19.69s - Est. remaining: 605.95s
# 2025-04-28 03:06:04,483 : INFO : Processed 21400/24378 movies (87.8%) - Elapsed: 19.77s - Est. remaining: 588.87s
# 2025-04-28 03:06:04,562 : INFO : Processed 21500/24378 movies (88.2%) - Elapsed: 19.85s - Est. remaining: 571.37s
# 2025-04-28 03:06:04,646 : INFO : Processed 21600/24378 movies (88.6%) - Elapsed: 19.94s - Est. remaining: 553.84s
# 2025-04-28 03:06:04,738 : INFO : Processed 21700/24378 movies (89.0%) - Elapsed: 20.03s - Est. remaining: 536.38s
# 2025-04-28 03:06:04,829 : INFO : Processed 21800/24378 movies (89.4%) - Elapsed: 20.12s - Est. remaining: 518.70s
# 2025-04-28 03:06:04,928 : INFO : Processed 21900/24378 movies (89.8%) - Elapsed: 20.22s - Est. remaining: 501.02s
# 2025-04-28 03:06:05,012 : INFO : Processed 22000/24378 movies (90.2%) - Elapsed: 20.30s - Est. remaining: 482.81s
# 2025-04-28 03:06:05,098 : INFO : Processed 22100/24378 movies (90.7%) - Elapsed: 20.39s - Est. remaining: 464.47s
# 2025-04-28 03:06:05,176 : INFO : Processed 22200/24378 movies (91.1%) - Elapsed: 20.47s - Est. remaining: 445.78s
# 2025-04-28 03:06:05,272 : INFO : Processed 22300/24378 movies (91.5%) - Elapsed: 20.56s - Est. remaining: 427.31s
# 2025-04-28 03:06:05,353 : INFO : Processed 22400/24378 movies (91.9%) - Elapsed: 20.64s - Est. remaining: 408.33s
# 2025-04-28 03:06:05,440 : INFO : Processed 22500/24378 movies (92.3%) - Elapsed: 20.73s - Est. remaining: 389.34s
# 2025-04-28 03:06:05,521 : INFO : Processed 22600/24378 movies (92.7%) - Elapsed: 20.81s - Est. remaining: 370.03s
# 2025-04-28 03:06:05,598 : INFO : Processed 22700/24378 movies (93.1%) - Elapsed: 20.89s - Est. remaining: 350.53s
# 2025-04-28 03:06:05,677 : INFO : Processed 22800/24378 movies (93.5%) - Elapsed: 20.97s - Est. remaining: 330.88s
# 2025-04-28 03:06:05,804 : INFO : Processed 22900/24378 movies (93.9%) - Elapsed: 21.10s - Est. remaining: 311.79s
# 2025-04-28 03:06:05,871 : INFO : Processed 23000/24378 movies (94.3%) - Elapsed: 21.16s - Est. remaining: 291.61s
# 2025-04-28 03:06:05,965 : INFO : Processed 23100/24378 movies (94.8%) - Elapsed: 21.26s - Est. remaining: 271.65s
# 2025-04-28 03:06:06,043 : INFO : Processed 23200/24378 movies (95.2%) - Elapsed: 21.33s - Est. remaining: 251.32s
# 2025-04-28 03:06:06,130 : INFO : Processed 23300/24378 movies (95.6%) - Elapsed: 21.42s - Est. remaining: 230.92s
# 2025-04-28 03:06:06,219 : INFO : Processed 23400/24378 movies (96.0%) - Elapsed: 21.51s - Est. remaining: 210.36s
# 2025-04-28 03:06:06,303 : INFO : Processed 23500/24378 movies (96.4%) - Elapsed: 21.59s - Est. remaining: 189.60s
# 2025-04-28 03:06:06,385 : INFO : Processed 23600/24378 movies (96.8%) - Elapsed: 21.68s - Est. remaining: 168.64s
# 2025-04-28 03:06:06,458 : INFO : Processed 23700/24378 movies (97.2%) - Elapsed: 21.75s - Est. remaining: 147.46s
# 2025-04-28 03:06:06,553 : INFO : Processed 23800/24378 movies (97.6%) - Elapsed: 21.84s - Est. remaining: 126.26s
# 2025-04-28 03:06:06,640 : INFO : Processed 23900/24378 movies (98.0%) - Elapsed: 21.93s - Est. remaining: 104.83s
# 2025-04-28 03:06:06,715 : INFO : Processed 24000/24378 movies (98.4%) - Elapsed: 22.01s - Est. remaining: 83.18s
# 2025-04-28 03:06:06,802 : INFO : Processed 24100/24378 movies (98.9%) - Elapsed: 22.09s - Est. remaining: 61.42s
# 2025-04-28 03:06:06,880 : INFO : Processed 24200/24378 movies (99.3%) - Elapsed: 22.17s - Est. remaining: 39.46s
# 2025-04-28 03:06:06,958 : INFO : Processed 24300/24378 movies (99.7%) - Elapsed: 22.25s - Est. remaining: 17.35s
# 2025-04-28 03:06:07,053 : INFO : Processed 24378/24378 movies (100.0%) - Elapsed: 22.34s - Est. remaining: 0.00s
# 2025-04-28 03:06:07,334 : INFO : Calculated LL values for 24378 movies
# 2025-04-28 03:06:07,416 : INFO : After LL calculation: 1440.36 MB
# 2025-04-28 03:06:07,417 : INFO : Preparing corpus: 1000/24378 movies (4.1%)
# 2025-04-28 03:06:07,490 : INFO : Preparing corpus: 2000/24378 movies (8.2%)
# 2025-04-28 03:06:07,569 : INFO : Preparing corpus: 3000/24378 movies (12.3%)
# 2025-04-28 03:06:07,645 : INFO : Preparing corpus: 4000/24378 movies (16.4%)
# 2025-04-28 03:06:07,724 : INFO : Preparing corpus: 5000/24378 movies (20.5%)
# 2025-04-28 03:06:07,802 : INFO : Preparing corpus: 6000/24378 movies (24.6%)
# 2025-04-28 03:06:07,927 : INFO : Preparing corpus: 7000/24378 movies (28.7%)
# 2025-04-28 03:06:07,990 : INFO : Preparing corpus: 8000/24378 movies (32.8%)
# 2025-04-28 03:06:08,078 : INFO : Preparing corpus: 9000/24378 movies (36.9%)
# 2025-04-28 03:06:08,153 : INFO : Preparing corpus: 10000/24378 movies (41.0%)
# 2025-04-28 03:06:08,240 : INFO : Preparing corpus: 11000/24378 movies (45.1%)
# 2025-04-28 03:06:08,302 : INFO : Preparing corpus: 12000/24378 movies (49.2%)
# 2025-04-28 03:06:08,397 : INFO : Preparing corpus: 13000/24378 movies (53.3%)
# 2025-04-28 03:06:08,475 : INFO : Preparing corpus: 14000/24378 movies (57.4%)
# 2025-04-28 03:06:08,552 : INFO : Preparing corpus: 15000/24378 movies (61.5%)
# 2025-04-28 03:06:08,630 : INFO : Preparing corpus: 16000/24378 movies (65.6%)
# 2025-04-28 03:06:08,708 : INFO : Preparing corpus: 17000/24378 movies (69.7%)
# 2025-04-28 03:06:08,818 : INFO : Preparing corpus: 18000/24378 movies (73.8%)
# 2025-04-28 03:06:08,896 : INFO : Preparing corpus: 19000/24378 movies (77.9%)
# 2025-04-28 03:06:08,991 : INFO : Preparing corpus: 20000/24378 movies (82.0%)
# 2025-04-28 03:06:09,063 : INFO : Preparing corpus: 21000/24378 movies (86.1%)
# 2025-04-28 03:06:09,139 : INFO : Preparing corpus: 22000/24378 movies (90.2%)
# 2025-04-28 03:06:09,218 : INFO : Preparing corpus: 23000/24378 movies (94.3%)
# 2025-04-28 03:06:09,302 : INFO : Preparing corpus: 24000/24378 movies (98.4%)
# 2025-04-28 03:06:09,380 : INFO : Preparing corpus: 24378/24378 movies (100.0%)
# 2025-04-28 03:06:09,458 : INFO : Training Word2Vec on corpus with 1563519 tokens
# 2025-04-28 03:06:09,458 : INFO : collecting all words and their counts
# 2025-04-28 03:06:09,458 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2025-04-28 03:06:09,563 : INFO : PROGRESS: at sentence #10000, processed 788641 words, keeping 53383 word types
# 2025-04-28 03:06:09,631 : INFO : PROGRESS: at sentence #20000, processed 1396870 words, keeping 84652 word types
# 2025-04-28 03:06:09,646 : INFO : collected 95445 word types from a corpus of 1563519 raw words and 24378 sentences
# 2025-04-28 03:06:09,646 : INFO : Creating a fresh vocabulary
# 2025-04-28 03:06:09,708 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=3 retains 27637 unique words (28.96% of original 95445, drops 67808)', 'datetime': '2025-04-28T03:06:09.708344', 'gensim': '4.3.3', 'python': '3.10.1 (tags/v3.10.1:2cd268a, Dec  6 2021, 19:10:37) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'prepare_vocab'}
# 2025-04-28 03:06:09,718 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=3 leaves 1473966 word corpus (94.27% of original 1563519, drops 89553)', 'datetime': '2025-04-28T03:06:09.718846', 'gensim': '4.3.3', 'python': '3.10.1 (tags/v3.10.1:2cd268a, Dec  6 2021, 19:10:37) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'prepare_vocab'}
# 2025-04-28 03:06:09,796 : INFO : deleting the raw counts dictionary of 95445 items
# 2025-04-28 03:06:09,798 : INFO : sample=0.001 downsamples 23 most-common words
# 2025-04-28 03:06:09,799 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 1437387.653062624 word corpus (97.5%% of prior 1473966)', 'datetime': '2025-04-28T03:06:09.799450', 'gensim': '4.3.3', 'python': '3.10.1 (tags/v3.10.1:2cd268a, Dec  6 2021, 19:10:37) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'prepare_vocab'}
# 2025-04-28 03:06:09,808 : INFO : constructing a huffman tree from 27637 words
# 2025-04-28 03:06:10,219 : INFO : built huffman tree with maximum node depth 19
# 2025-04-28 03:06:10,319 : INFO : estimated required memory for 27637 words and 100 dimensions: 52510300 bytes
# 2025-04-28 03:06:10,319 : INFO : resetting layer weights
# 2025-04-28 03:06:10,334 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2025-04-28T03:06:10.334716', 'gensim': '4.3.3', 'python': '3.10.1 (tags/v3.10.1:2cd268a, Dec  6 2021, 19:10:37) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'build_vocab'}
# 2025-04-28 03:06:10,334 : WARNING : Both hierarchical softmax and negative sampling are activated. This is probably a mistake. You should set either 'hs=0' or 'negative=0' to disable one of them.
# 2025-04-28 03:06:10,334 : INFO : Word2Vec lifecycle event {'msg': 'training model with 8 workers on 27637 vocabulary and 100 features, using sg=1 hs=1 sample=0.001 negative=15 window=8 shrink_windows=True', 'datetime': '2025-04-28T03:06:10.334716', 'gensim': '4.3.3', 'python': '3.10.1 (tags/v3.10.1:2cd268a, Dec  6 2021, 19:10:37) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'train'}
# 2025-04-28 03:06:11,349 : INFO : EPOCH 0 - PROGRESS: at 7.24% examples, 204427 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:06:12,397 : INFO : EPOCH 0 - PROGRESS: at 19.49% examples, 212764 words/s, in_qsize 16, out_qsize 0
# 2025-04-28 03:06:13,458 : INFO : EPOCH 0 - PROGRESS: at 34.28% examples, 210057 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:06:14,481 : INFO : EPOCH 0 - PROGRESS: at 49.29% examples, 210514 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:06:15,497 : INFO : EPOCH 0 - PROGRESS: at 64.21% examples, 211255 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:06:16,508 : INFO : EPOCH 0 - PROGRESS: at 87.76% examples, 217897 words/s, in_qsize 11, out_qsize 0
# 2025-04-28 03:06:16,927 : INFO : EPOCH 0: training on 1563519 raw words (1437319 effective words) took 6.6s, 218347 effective words/s
# 2025-04-28 03:06:17,932 : INFO : EPOCH 1 - PROGRESS: at 5.88% examples, 179862 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:06:18,936 : INFO : EPOCH 1 - PROGRESS: at 18.49% examples, 208615 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:06:20,036 : INFO : EPOCH 1 - PROGRESS: at 28.67% examples, 184235 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:06:21,279 : INFO : EPOCH 1 - PROGRESS: at 44.57% examples, 181722 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:06:22,386 : INFO : EPOCH 1 - PROGRESS: at 56.37% examples, 181345 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:06:23,441 : INFO : EPOCH 1 - PROGRESS: at 74.51% examples, 185443 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:06:24,347 : INFO : EPOCH 1: training on 1563519 raw words (1437657 effective words) took 7.4s, 193885 effective words/s
# 2025-04-28 03:06:25,371 : INFO : EPOCH 2 - PROGRESS: at 5.37% examples, 158989 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:06:26,508 : INFO : EPOCH 2 - PROGRESS: at 15.66% examples, 172500 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:06:27,655 : INFO : EPOCH 2 - PROGRESS: at 29.63% examples, 178940 words/s, in_qsize 16, out_qsize 0
# 2025-04-28 03:06:28,722 : INFO : EPOCH 2 - PROGRESS: at 45.74% examples, 184715 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:06:29,870 : INFO : EPOCH 2 - PROGRESS: at 64.59% examples, 198974 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:06:30,927 : INFO : EPOCH 2 - PROGRESS: at 92.32% examples, 210380 words/s, in_qsize 6, out_qsize 1
# 2025-04-28 03:06:31,041 : INFO : EPOCH 2: training on 1563519 raw words (1437259 effective words) took 6.7s, 214838 effective words/s
# 2025-04-28 03:06:32,278 : INFO : EPOCH 3 - PROGRESS: at 5.00% examples, 124341 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:06:33,278 : INFO : EPOCH 3 - PROGRESS: at 15.03% examples, 162761 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:06:34,314 : INFO : EPOCH 3 - PROGRESS: at 25.19% examples, 158622 words/s, in_qsize 16, out_qsize 0
# 2025-04-28 03:06:35,319 : INFO : EPOCH 3 - PROGRESS: at 40.92% examples, 170197 words/s, in_qsize 16, out_qsize 0
# 2025-04-28 03:06:36,367 : INFO : EPOCH 3 - PROGRESS: at 54.12% examples, 179062 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:06:37,392 : INFO : EPOCH 3 - PROGRESS: at 76.90% examples, 194517 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:06:38,290 : INFO : EPOCH 3: training on 1563519 raw words (1437536 effective words) took 7.2s, 198457 effective words/s
# 2025-04-28 03:06:39,479 : INFO : EPOCH 4 - PROGRESS: at 8.01% examples, 189727 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:06:40,549 : INFO : EPOCH 4 - PROGRESS: at 19.93% examples, 197327 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:06:41,562 : INFO : EPOCH 4 - PROGRESS: at 40.92% examples, 222458 words/s, in_qsize 16, out_qsize 0
# 2025-04-28 03:06:42,580 : INFO : EPOCH 4 - PROGRESS: at 51.24% examples, 211565 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:06:43,594 : INFO : EPOCH 4 - PROGRESS: at 64.88% examples, 207051 words/s, in_qsize 16, out_qsize 0
# 2025-04-28 03:06:44,618 : INFO : EPOCH 4 - PROGRESS: at 84.98% examples, 208055 words/s, in_qsize 14, out_qsize 0
# 2025-04-28 03:06:45,104 : INFO : EPOCH 4: training on 1563519 raw words (1437415 effective words) took 6.8s, 211074 effective words/s
# 2025-04-28 03:06:46,117 : INFO : EPOCH 5 - PROGRESS: at 6.59% examples, 187514 words/s, in_qsize 15, out_qsize 1
# 2025-04-28 03:06:47,207 : INFO : EPOCH 5 - PROGRESS: at 15.66% examples, 177459 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:06:48,267 : INFO : EPOCH 5 - PROGRESS: at 28.15% examples, 178536 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:06:49,319 : INFO : EPOCH 5 - PROGRESS: at 42.00% examples, 176978 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:06:50,466 : INFO : EPOCH 5 - PROGRESS: at 54.82% examples, 179496 words/s, in_qsize 16, out_qsize 0
# 2025-04-28 03:06:51,531 : INFO : EPOCH 5 - PROGRESS: at 67.86% examples, 176603 words/s, in_qsize 16, out_qsize 1
# 2025-04-28 03:06:52,543 : INFO : EPOCH 5 - PROGRESS: at 86.02% examples, 178199 words/s, in_qsize 13, out_qsize 0
# 2025-04-28 03:06:52,955 : INFO : EPOCH 5: training on 1563519 raw words (1437579 effective words) took 7.8s, 183207 effective words/s
# 2025-04-28 03:06:53,972 : INFO : EPOCH 6 - PROGRESS: at 5.88% examples, 178092 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:06:54,983 : INFO : EPOCH 6 - PROGRESS: at 15.66% examples, 183912 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:06:55,994 : INFO : EPOCH 6 - PROGRESS: at 33.67% examples, 212767 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:06:57,001 : INFO : EPOCH 6 - PROGRESS: at 46.09% examples, 202032 words/s, in_qsize 16, out_qsize 0
# 2025-04-28 03:06:58,082 : INFO : EPOCH 6 - PROGRESS: at 63.16% examples, 210775 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:06:59,133 : INFO : EPOCH 6 - PROGRESS: at 89.68% examples, 220425 words/s, in_qsize 9, out_qsize 0
# 2025-04-28 03:06:59,412 : INFO : EPOCH 6: training on 1563519 raw words (1437400 effective words) took 6.5s, 222760 effective words/s
# 2025-04-28 03:07:00,423 : INFO : EPOCH 7 - PROGRESS: at 5.00% examples, 151983 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:01,539 : INFO : EPOCH 7 - PROGRESS: at 19.93% examples, 209693 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:02,576 : INFO : EPOCH 7 - PROGRESS: at 35.35% examples, 210093 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:03,609 : INFO : EPOCH 7 - PROGRESS: at 49.29% examples, 207732 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:04,622 : INFO : EPOCH 7 - PROGRESS: at 60.41% examples, 200315 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:05,692 : INFO : EPOCH 7 - PROGRESS: at 84.98% examples, 209701 words/s, in_qsize 14, out_qsize 0
# 2025-04-28 03:07:06,084 : INFO : EPOCH 7: training on 1563519 raw words (1437498 effective words) took 6.7s, 215567 effective words/s
# 2025-04-28 03:07:07,299 : INFO : EPOCH 8 - PROGRESS: at 8.01% examples, 186409 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:08,525 : INFO : EPOCH 8 - PROGRESS: at 19.93% examples, 182667 words/s, in_qsize 16, out_qsize 0
# 2025-04-28 03:07:09,550 : INFO : EPOCH 8 - PROGRESS: at 36.35% examples, 194317 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:10,560 : INFO : EPOCH 8 - PROGRESS: at 48.27% examples, 190620 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:11,562 : INFO : EPOCH 8 - PROGRESS: at 61.87% examples, 193854 words/s, in_qsize 14, out_qsize 1
# 2025-04-28 03:07:12,607 : INFO : EPOCH 8 - PROGRESS: at 78.45% examples, 192153 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:13,339 : INFO : EPOCH 8: training on 1563519 raw words (1437273 effective words) took 7.2s, 198247 effective words/s
# 2025-04-28 03:07:14,548 : INFO : EPOCH 9 - PROGRESS: at 8.01% examples, 187263 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:15,703 : INFO : EPOCH 9 - PROGRESS: at 25.19% examples, 219461 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:16,767 : INFO : EPOCH 9 - PROGRESS: at 45.74% examples, 235755 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:17,772 : INFO : EPOCH 9 - PROGRESS: at 63.16% examples, 243836 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:18,841 : INFO : EPOCH 9 - PROGRESS: at 84.98% examples, 239286 words/s, in_qsize 14, out_qsize 0
# 2025-04-28 03:07:19,144 : INFO : EPOCH 9: training on 1563519 raw words (1437275 effective words) took 5.8s, 247754 effective words/s
# 2025-04-28 03:07:20,232 : INFO : EPOCH 10 - PROGRESS: at 8.01% examples, 208067 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:21,323 : INFO : EPOCH 10 - PROGRESS: at 24.46% examples, 233888 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:22,478 : INFO : EPOCH 10 - PROGRESS: at 44.57% examples, 237072 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:23,593 : INFO : EPOCH 10 - PROGRESS: at 57.53% examples, 226547 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:24,657 : INFO : EPOCH 10 - PROGRESS: at 83.10% examples, 235503 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:25,073 : INFO : EPOCH 10: training on 1563519 raw words (1437297 effective words) took 5.9s, 242553 effective words/s
# 2025-04-28 03:07:26,149 : INFO : EPOCH 11 - PROGRESS: at 8.01% examples, 210252 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:27,235 : INFO : EPOCH 11 - PROGRESS: at 25.19% examples, 239998 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:28,322 : INFO : EPOCH 11 - PROGRESS: at 45.74% examples, 248727 words/s, in_qsize 16, out_qsize 0
# 2025-04-28 03:07:29,378 : INFO : EPOCH 11 - PROGRESS: at 64.59% examples, 255210 words/s, in_qsize 16, out_qsize 0
# 2025-04-28 03:07:30,388 : INFO : EPOCH 11 - PROGRESS: at 92.32% examples, 260370 words/s, in_qsize 6, out_qsize 1
# 2025-04-28 03:07:30,494 : INFO : EPOCH 11: training on 1563519 raw words (1437118 effective words) took 5.4s, 265266 effective words/s
# 2025-04-28 03:07:31,524 : INFO : EPOCH 12 - PROGRESS: at 5.00% examples, 149142 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:32,578 : INFO : EPOCH 12 - PROGRESS: at 19.53% examples, 209554 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:33,677 : INFO : EPOCH 12 - PROGRESS: at 40.92% examples, 228701 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:34,842 : INFO : EPOCH 12 - PROGRESS: at 57.53% examples, 231786 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:35,928 : INFO : EPOCH 12 - PROGRESS: at 83.07% examples, 238916 words/s, in_qsize 15, out_qsize 1
# 2025-04-28 03:07:36,359 : INFO : EPOCH 12: training on 1563519 raw words (1437190 effective words) took 5.9s, 245202 effective words/s
# 2025-04-28 03:07:37,427 : INFO : EPOCH 13 - PROGRESS: at 8.01% examples, 211959 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:38,505 : INFO : EPOCH 13 - PROGRESS: at 23.89% examples, 233351 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:39,646 : INFO : EPOCH 13 - PROGRESS: at 43.49% examples, 234972 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:40,688 : INFO : EPOCH 13 - PROGRESS: at 58.98% examples, 237032 words/s, in_qsize 16, out_qsize 0
# 2025-04-28 03:07:41,712 : INFO : EPOCH 13 - PROGRESS: at 77.61% examples, 232429 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:42,481 : INFO : EPOCH 13: training on 1563519 raw words (1437556 effective words) took 6.1s, 234935 effective words/s
# 2025-04-28 03:07:43,604 : INFO : EPOCH 14 - PROGRESS: at 7.61% examples, 192972 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:44,755 : INFO : EPOCH 14 - PROGRESS: at 24.46% examples, 224117 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:45,759 : INFO : EPOCH 14 - PROGRESS: at 44.57% examples, 241202 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:46,796 : INFO : EPOCH 14 - PROGRESS: at 62.37% examples, 248282 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:47,809 : INFO : EPOCH 14 - PROGRESS: at 87.76% examples, 252139 words/s, in_qsize 11, out_qsize 0
# 2025-04-28 03:07:48,214 : INFO : EPOCH 14: training on 1563519 raw words (1437448 effective words) took 5.7s, 250837 effective words/s
# 2025-04-28 03:07:49,285 : INFO : EPOCH 15 - PROGRESS: at 8.01% examples, 211457 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:50,357 : INFO : EPOCH 15 - PROGRESS: at 24.46% examples, 237906 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:51,363 : INFO : EPOCH 15 - PROGRESS: at 44.57% examples, 251139 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:52,370 : INFO : EPOCH 15 - PROGRESS: at 62.37% examples, 257890 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:53,405 : INFO : EPOCH 15 - PROGRESS: at 83.07% examples, 250147 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:53,886 : INFO : EPOCH 15: training on 1563519 raw words (1437583 effective words) took 5.7s, 253624 effective words/s
# 2025-04-28 03:07:55,156 : INFO : EPOCH 16 - PROGRESS: at 8.15% examples, 177982 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:56,304 : INFO : EPOCH 16 - PROGRESS: at 25.19% examples, 214571 words/s, in_qsize 16, out_qsize 0
# 2025-04-28 03:07:57,467 : INFO : EPOCH 16 - PROGRESS: at 45.74% examples, 225711 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:58,542 : INFO : EPOCH 16 - PROGRESS: at 64.59% examples, 236035 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:07:59,562 : INFO : EPOCH 16 - PROGRESS: at 92.32% examples, 243865 words/s, in_qsize 6, out_qsize 1
# 2025-04-28 03:07:59,664 : INFO : EPOCH 16: training on 1563519 raw words (1437401 effective words) took 5.8s, 248896 effective words/s
# 2025-04-28 03:08:00,743 : INFO : EPOCH 17 - PROGRESS: at 8.03% examples, 209824 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:08:01,821 : INFO : EPOCH 17 - PROGRESS: at 25.19% examples, 240758 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:08:02,880 : INFO : EPOCH 17 - PROGRESS: at 45.74% examples, 251481 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:08:03,972 : INFO : EPOCH 17 - PROGRESS: at 64.59% examples, 255185 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:08:05,014 : INFO : EPOCH 17 - PROGRESS: at 92.88% examples, 259669 words/s, in_qsize 6, out_qsize 1
# 2025-04-28 03:08:05,122 : INFO : EPOCH 17: training on 1563519 raw words (1437464 effective words) took 5.5s, 263598 effective words/s
# 2025-04-28 03:08:06,208 : INFO : EPOCH 18 - PROGRESS: at 8.01% examples, 208309 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:08:07,299 : INFO : EPOCH 18 - PROGRESS: at 25.19% examples, 238416 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:08:08,358 : INFO : EPOCH 18 - PROGRESS: at 45.74% examples, 249842 words/s, in_qsize 15, out_qsize 0
# 2025-04-28 03:08:09,466 : INFO : EPOCH 18 - PROGRESS: at 64.59% examples, 252950 words/s, in_qsize 15, out_qsize 0
# ...
# 2025-04-28 06:29:14,017 : INFO : Evaluating batch 161: users 16001-16100 of 19986
# 2025-04-28 06:29:49,084 : INFO : Batch metrics - RMSE: 1.0392, MAE: 0.7970, Accuracy: 0.6143
# 2025-04-28 06:29:49,085 : INFO : TP: 834, FP: 517, TN: 1213, FN: 768
# 2025-04-28 06:29:49,085 : INFO : Processed 16100/19986 users (80.6%) - Elapsed: 6211.14s - Est. remaining: 1362.69s
# 2025-04-28 06:29:49,225 : INFO : Evaluating batch 162: users 16101-16200 of 19986
# 2025-04-28 06:30:30,750 : INFO : Batch metrics - RMSE: 1.0663, MAE: 0.8333, Accuracy: 0.6319
# 2025-04-28 06:30:30,751 : INFO : TP: 1110, FP: 641, TN: 1304, FN: 765
# 2025-04-28 06:30:30,751 : INFO : Processed 16200/19986 users (81.1%) - Elapsed: 6252.80s - Est. remaining: 1572.09s
# 2025-04-28 06:30:30,937 : INFO : Evaluating batch 163: users 16201-16300 of 19986
# 2025-04-28 06:31:00,766 : INFO : Batch metrics - RMSE: 0.9768, MAE: 0.7355, Accuracy: 0.6586
# 2025-04-28 06:31:00,767 : INFO : TP: 984, FP: 524, TN: 878, FN: 441
# 2025-04-28 06:31:00,767 : INFO : Processed 16300/19986 users (81.6%) - Elapsed: 6282.82s - Est. remaining: 1099.50s
# 2025-04-28 06:31:00,908 : INFO : Evaluating batch 164: users 16301-16400 of 19986
# 2025-04-28 06:31:24,942 : INFO : Batch metrics - RMSE: 1.0519, MAE: 0.7932, Accuracy: 0.6383
# 2025-04-28 06:31:24,943 : INFO : TP: 900, FP: 445, TN: 540, FN: 371
# 2025-04-28 06:31:24,943 : INFO : Processed 16400/19986 users (82.1%) - Elapsed: 6307.00s - Est. remaining: 861.84s
# 2025-04-28 06:31:25,080 : INFO : Evaluating batch 165: users 16401-16500 of 19986
# 2025-04-28 06:31:56,116 : INFO : Batch metrics - RMSE: 1.0322, MAE: 0.7899, Accuracy: 0.6429
# 2025-04-28 06:31:56,117 : INFO : TP: 803, FP: 396, TN: 1116, FN: 670
# 2025-04-28 06:31:56,117 : INFO : Processed 16500/19986 users (82.6%) - Elapsed: 6338.17s - Est. remaining: 1081.89s
# 2025-04-28 06:31:56,289 : INFO : Evaluating batch 166: users 16501-16600 of 19986
# 2025-04-28 06:32:22,888 : INFO : Batch metrics - RMSE: 1.1037, MAE: 0.8357, Accuracy: 0.6342
# 2025-04-28 06:32:22,889 : INFO : TP: 886, FP: 424, TN: 733, FN: 510
# 2025-04-28 06:32:22,889 : INFO : Processed 16600/19986 users (83.1%) - Elapsed: 6364.94s - Est. remaining: 900.61s
# 2025-04-28 06:32:23,035 : INFO : Evaluating batch 167: users 16601-16700 of 19986
# 2025-04-28 06:32:57,485 : INFO : Batch metrics - RMSE: 1.0236, MAE: 0.7718, Accuracy: 0.6203
# 2025-04-28 06:32:57,485 : INFO : TP: 961, FP: 634, TN: 1047, FN: 595
# 2025-04-28 06:32:57,486 : INFO : Processed 16700/19986 users (83.6%) - Elapsed: 6399.54s - Est. remaining: 1132.02s
# 2025-04-28 06:32:57,644 : INFO : Evaluating batch 168: users 16701-16800 of 19986
# 2025-04-28 06:33:22,848 : INFO : Batch metrics - RMSE: 1.1363, MAE: 0.8846, Accuracy: 0.6117
# 2025-04-28 06:33:22,849 : INFO : TP: 881, FP: 456, TN: 565, FN: 462
# 2025-04-28 06:33:22,849 : INFO : Processed 16800/19986 users (84.1%) - Elapsed: 6424.90s - Est. remaining: 803.01s
# 2025-04-28 06:33:22,991 : INFO : Evaluating batch 169: users 16801-16900 of 19986
# 2025-04-28 06:33:49,505 : INFO : Batch metrics - RMSE: 1.1836, MAE: 0.9156, Accuracy: 0.5537
# 2025-04-28 06:33:49,505 : INFO : TP: 652, FP: 548, TN: 791, FN: 615
# 2025-04-28 06:33:49,506 : INFO : Processed 16900/19986 users (84.6%) - Elapsed: 6451.56s - Est. remaining: 818.17s
# 2025-04-28 06:33:49,674 : INFO : Evaluating batch 170: users 16901-17000 of 19986
# 2025-04-28 06:34:19,567 : INFO : Batch metrics - RMSE: 1.0018, MAE: 0.7672, Accuracy: 0.6024
# 2025-04-28 06:34:19,568 : INFO : TP: 1134, FP: 674, TN: 589, FN: 463
# 2025-04-28 06:34:19,568 : INFO : Processed 17000/19986 users (85.1%) - Elapsed: 6481.62s - Est. remaining: 892.61s
# 2025-04-28 06:34:19,715 : INFO : Evaluating batch 171: users 17001-17100 of 19986
# 2025-04-28 06:34:49,804 : INFO : Batch metrics - RMSE: 1.0813, MAE: 0.8277, Accuracy: 0.5796
# 2025-04-28 06:34:49,805 : INFO : TP: 1104, FP: 702, TN: 574, FN: 515
# 2025-04-28 06:34:49,805 : INFO : Processed 17100/19986 users (85.6%) - Elapsed: 6511.86s - Est. remaining: 868.38s
# 2025-04-28 06:34:49,952 : INFO : Evaluating batch 172: users 17101-17200 of 19986
# 2025-04-28 06:35:19,465 : INFO : Batch metrics - RMSE: 1.0867, MAE: 0.8509, Accuracy: 0.6275
# 2025-04-28 06:35:19,465 : INFO : TP: 790, FP: 468, TN: 923, FN: 549
# 2025-04-28 06:35:19,466 : INFO : Processed 17200/19986 users (86.1%) - Elapsed: 6541.52s - Est. remaining: 822.19s
# 2025-04-28 06:35:19,638 : INFO : Evaluating batch 173: users 17201-17300 of 19986
# 2025-04-28 06:35:48,317 : INFO : Batch metrics - RMSE: 1.0158, MAE: 0.7652, Accuracy: 0.6370
# 2025-04-28 06:35:48,318 : INFO : TP: 970, FP: 503, TN: 806, FN: 509
# 2025-04-28 06:35:48,318 : INFO : Processed 17300/19986 users (86.6%) - Elapsed: 6570.37s - Est. remaining: 770.30s
# 2025-04-28 06:35:48,460 : INFO : Evaluating batch 174: users 17301-17400 of 19986
# 2025-04-28 06:36:22,665 : INFO : Batch metrics - RMSE: 1.0490, MAE: 0.7884, Accuracy: 0.6159
# 2025-04-28 06:36:22,665 : INFO : TP: 947, FP: 558, TN: 1202, FN: 782
# 2025-04-28 06:36:22,665 : INFO : Processed 17400/19986 users (87.1%) - Elapsed: 6604.72s - Est. remaining: 884.50s
# 2025-04-28 06:36:22,809 : INFO : Evaluating batch 175: users 17401-17500 of 19986
# 2025-04-28 06:37:00,801 : INFO : Batch metrics - RMSE: 1.0364, MAE: 0.7896, Accuracy: 0.6299
# 2025-04-28 06:37:00,801 : INFO : TP: 1112, FP: 563, TN: 1172, FN: 779
# 2025-04-28 06:37:00,802 : INFO : Processed 17500/19986 users (87.6%) - Elapsed: 6642.85s - Est. remaining: 944.49s
# 2025-04-28 06:37:00,979 : INFO : Evaluating batch 176: users 17501-17600 of 19986
# 2025-04-28 06:37:31,950 : INFO : Batch metrics - RMSE: 1.0331, MAE: 0.7773, Accuracy: 0.6306
# 2025-04-28 06:37:31,951 : INFO : TP: 1148, FP: 642, TN: 677, FN: 427
# 2025-04-28 06:37:31,951 : INFO : Processed 17600/19986 users (88.1%) - Elapsed: 6674.00s - Est. remaining: 738.98s
# 2025-04-28 06:37:32,090 : INFO : Evaluating batch 177: users 17601-17700 of 19986
# 2025-04-28 06:38:03,186 : INFO : Batch metrics - RMSE: 1.0612, MAE: 0.8020, Accuracy: 0.6453
# 2025-04-28 06:38:03,187 : INFO : TP: 1057, FP: 564, TN: 846, FN: 482
# 2025-04-28 06:38:03,187 : INFO : Processed 17700/19986 users (88.6%) - Elapsed: 6705.24s - Est. remaining: 710.85s
# 2025-04-28 06:38:03,331 : INFO : Evaluating batch 178: users 17701-17800 of 19986
# 2025-04-28 06:38:46,308 : INFO : Batch metrics - RMSE: 1.0642, MAE: 0.8184, Accuracy: 0.6087
# 2025-04-28 06:38:46,309 : INFO : TP: 901, FP: 526, TN: 1589, FN: 1075
# 2025-04-28 06:38:46,309 : INFO : Processed 17800/19986 users (89.1%) - Elapsed: 6748.36s - Est. remaining: 939.48s
# 2025-04-28 06:38:46,479 : INFO : Evaluating batch 179: users 17801-17900 of 19986
# 2025-04-28 06:39:21,658 : INFO : Batch metrics - RMSE: 0.9656, MAE: 0.7097, Accuracy: 0.6168
# 2025-04-28 06:39:21,659 : INFO : TP: 1219, FP: 716, TN: 795, FN: 535
# 2025-04-28 06:39:21,659 : INFO : Processed 17900/19986 users (89.6%) - Elapsed: 6783.71s - Est. remaining: 733.81s
# 2025-04-28 06:39:21,802 : INFO : Evaluating batch 180: users 17901-18000 of 19986
# 2025-04-28 06:39:54,172 : INFO : Batch metrics - RMSE: 1.0920, MAE: 0.8466, Accuracy: 0.6083
# 2025-04-28 06:39:54,173 : INFO : TP: 927, FP: 603, TN: 989, FN: 631
# 2025-04-28 06:39:54,174 : INFO : Processed 18000/19986 users (90.1%) - Elapsed: 6816.22s - Est. remaining: 642.85s
# 2025-04-28 06:39:54,323 : INFO : Evaluating batch 181: users 18001-18100 of 19986
# 2025-04-28 06:40:17,455 : INFO : Batch metrics - RMSE: 1.0351, MAE: 0.7986, Accuracy: 0.6301
# 2025-04-28 06:40:17,456 : INFO : TP: 981, FP: 539, TN: 421, FN: 284
# 2025-04-28 06:40:17,456 : INFO : Processed 18100/19986 users (90.6%) - Elapsed: 6839.51s - Est. remaining: 436.28s
# 2025-04-28 06:40:17,637 : INFO : Evaluating batch 182: users 18101-18200 of 19986
# 2025-04-28 06:40:44,761 : INFO : Batch metrics - RMSE: 1.0336, MAE: 0.7828, Accuracy: 0.6309
# 2025-04-28 06:40:44,762 : INFO : TP: 976, FP: 589, TN: 687, FN: 384
# 2025-04-28 06:40:44,762 : INFO : Processed 18200/19986 users (91.1%) - Elapsed: 6866.81s - Est. remaining: 484.44s
# 2025-04-28 06:40:44,902 : INFO : Evaluating batch 183: users 18201-18300 of 19986
# 2025-04-28 06:41:18,100 : INFO : Batch metrics - RMSE: 1.0563, MAE: 0.8088, Accuracy: 0.5926
# 2025-04-28 06:41:18,101 : INFO : TP: 1032, FP: 562, TN: 795, FN: 694
# 2025-04-28 06:41:18,101 : INFO : Processed 18300/19986 users (91.6%) - Elapsed: 6900.15s - Est. remaining: 559.72s
# 2025-04-28 06:41:18,239 : INFO : Evaluating batch 184: users 18301-18400 of 19986
# 2025-04-28 06:41:50,281 : INFO : Batch metrics - RMSE: 1.0310, MAE: 0.7777, Accuracy: 0.6220
# 2025-04-28 06:41:50,281 : INFO : TP: 1094, FP: 643, TN: 843, FN: 534
# 2025-04-28 06:41:50,282 : INFO : Processed 18400/19986 users (92.1%) - Elapsed: 6932.33s - Est. remaining: 508.15s
# 2025-04-28 06:41:50,457 : INFO : Evaluating batch 185: users 18401-18500 of 19986
# 2025-04-28 06:42:26,395 : INFO : Batch metrics - RMSE: 1.1010, MAE: 0.8628, Accuracy: 0.5500
# 2025-04-28 06:42:26,396 : INFO : TP: 832, FP: 968, TN: 1064, FN: 583
# 2025-04-28 06:42:26,397 : INFO : Processed 18500/19986 users (92.6%) - Elapsed: 6968.45s - Est. remaining: 534.03s
# 2025-04-28 06:42:26,532 : INFO : Evaluating batch 186: users 18501-18600 of 19986
# 2025-04-28 06:43:09,656 : INFO : Batch metrics - RMSE: 1.0546, MAE: 0.8155, Accuracy: 0.5399
# 2025-04-28 06:43:09,657 : INFO : TP: 1088, FP: 831, TN: 1069, FN: 1007
# 2025-04-28 06:43:09,657 : INFO : Processed 18600/19986 users (93.1%) - Elapsed: 7011.71s - Est. remaining: 597.70s
# 2025-04-28 06:43:09,812 : INFO : Evaluating batch 187: users 18601-18700 of 19986
# 2025-04-28 06:43:35,582 : INFO : Batch metrics - RMSE: 1.0934, MAE: 0.8458, Accuracy: 0.6283
# 2025-04-28 06:43:35,583 : INFO : TP: 862, FP: 441, TN: 683, FN: 473
# 2025-04-28 06:43:35,584 : INFO : Processed 18700/19986 users (93.6%) - Elapsed: 7037.63s - Est. remaining: 331.40s
# 2025-04-28 06:43:35,722 : INFO : Evaluating batch 188: users 18701-18800 of 19986
# 2025-04-28 06:44:09,075 : INFO : Batch metrics - RMSE: 1.0397, MAE: 0.7892, Accuracy: 0.5938
# 2025-04-28 06:44:09,076 : INFO : TP: 1119, FP: 706, TN: 764, FN: 582
# 2025-04-28 06:44:09,076 : INFO : Processed 18800/19986 users (94.1%) - Elapsed: 7071.13s - Est. remaining: 395.56s
# 2025-04-28 06:44:09,212 : INFO : Evaluating batch 189: users 18801-18900 of 19986
# 2025-04-28 06:44:34,081 : INFO : Batch metrics - RMSE: 1.1379, MAE: 0.8751, Accuracy: 0.5890
# 2025-04-28 06:44:34,081 : INFO : TP: 620, FP: 414, TN: 810, FN: 584
# 2025-04-28 06:44:34,082 : INFO : Processed 18900/19986 users (94.6%) - Elapsed: 7096.13s - Est. remaining: 270.08s
# 2025-04-28 06:44:34,221 : INFO : Evaluating batch 190: users 18901-19000 of 19986
# 2025-04-28 06:45:05,554 : INFO : Batch metrics - RMSE: 1.0655, MAE: 0.8211, Accuracy: 0.5832
# 2025-04-28 06:45:05,555 : INFO : TP: 1084, FP: 771, TN: 650, FN: 468
# 2025-04-28 06:45:05,555 : INFO : Processed 19000/19986 users (95.1%) - Elapsed: 7127.61s - Est. remaining: 308.94s
# 2025-04-28 06:45:05,788 : INFO : Evaluating batch 191: users 19001-19100 of 19986
# 2025-04-28 06:45:32,893 : INFO : Batch metrics - RMSE: 1.0882, MAE: 0.8222, Accuracy: 0.6289
# 2025-04-28 06:45:32,893 : INFO : TP: 519, FP: 330, TN: 1064, FN: 604
# 2025-04-28 06:45:32,894 : INFO : Processed 19100/19986 users (95.6%) - Elapsed: 7154.95s - Est. remaining: 240.15s
# 2025-04-28 06:45:33,087 : INFO : Evaluating batch 192: users 19101-19200 of 19986
# 2025-04-28 06:46:08,110 : INFO : Batch metrics - RMSE: 1.0978, MAE: 0.8626, Accuracy: 0.6409
# 2025-04-28 06:46:08,110 : INFO : TP: 808, FP: 411, TN: 1307, FN: 774
# 2025-04-28 06:46:08,111 : INFO : Processed 19200/19986 users (96.1%) - Elapsed: 7190.16s - Est. remaining: 275.28s
# 2025-04-28 06:46:08,252 : INFO : Evaluating batch 193: users 19201-19300 of 19986
# 2025-04-28 06:46:32,767 : INFO : Batch metrics - RMSE: 1.0096, MAE: 0.7709, Accuracy: 0.5963
# 2025-04-28 06:46:32,768 : INFO : TP: 685, FP: 349, TN: 720, FN: 602
# 2025-04-28 06:46:32,768 : INFO : Processed 19300/19986 users (96.6%) - Elapsed: 7214.82s - Est. remaining: 168.17s
# 2025-04-28 06:46:32,946 : INFO : Evaluating batch 194: users 19301-19400 of 19986
# 2025-04-28 06:46:58,858 : INFO : Batch metrics - RMSE: 1.0626, MAE: 0.8189, Accuracy: 0.5778
# 2025-04-28 06:46:58,858 : INFO : TP: 881, FP: 540, TN: 553, FN: 508
# 2025-04-28 06:46:58,858 : INFO : Processed 19400/19986 users (97.1%) - Elapsed: 7240.91s - Est. remaining: 151.85s
# 2025-04-28 06:46:59,027 : INFO : Evaluating batch 195: users 19401-19500 of 19986
# 2025-04-28 06:47:39,816 : INFO : Batch metrics - RMSE: 1.0054, MAE: 0.7766, Accuracy: 0.6627
# 2025-04-28 06:47:39,817 : INFO : TP: 943, FP: 498, TN: 1529, FN: 760
# 2025-04-28 06:47:39,817 : INFO : Processed 19500/19986 users (97.6%) - Elapsed: 7281.87s - Est. remaining: 198.24s
# 2025-04-28 06:47:39,977 : INFO : Evaluating batch 196: users 19501-19600 of 19986
# 2025-04-28 06:48:13,337 : INFO : Batch metrics - RMSE: 1.0668, MAE: 0.8085, Accuracy: 0.6208
# 2025-04-28 06:48:13,337 : INFO : TP: 797, FP: 565, TN: 1169, FN: 636
# 2025-04-28 06:48:13,338 : INFO : Processed 19600/19986 users (98.1%) - Elapsed: 7315.39s - Est. remaining: 128.76s
# 2025-04-28 06:48:13,481 : INFO : Evaluating batch 197: users 19601-19700 of 19986
# 2025-04-28 06:48:39,035 : INFO : Batch metrics - RMSE: 1.0669, MAE: 0.8248, Accuracy: 0.5987
# 2025-04-28 06:48:39,036 : INFO : TP: 868, FP: 518, TN: 603, FN: 468
# 2025-04-28 06:48:39,036 : INFO : Processed 19700/19986 users (98.6%) - Elapsed: 7341.09s - Est. remaining: 73.08s
# 2025-04-28 06:48:39,211 : INFO : Evaluating batch 198: users 19701-19800 of 19986
# 2025-04-28 06:49:12,956 : INFO : Batch metrics - RMSE: 1.1009, MAE: 0.8561, Accuracy: 0.6093
# 2025-04-28 06:49:12,957 : INFO : TP: 1173, FP: 810, TN: 733, FN: 412
# 2025-04-28 06:49:12,957 : INFO : Processed 19800/19986 users (99.1%) - Elapsed: 7375.01s - Est. remaining: 62.76s
# 2025-04-28 06:49:13,103 : INFO : Evaluating batch 199: users 19801-19900 of 19986
# 2025-04-28 06:49:54,181 : INFO : Batch metrics - RMSE: 1.0016, MAE: 0.7710, Accuracy: 0.5874
# 2025-04-28 06:49:54,187 : INFO : TP: 973, FP: 688, TN: 1271, FN: 888
# 2025-04-28 06:49:54,187 : INFO : Processed 19900/19986 users (99.6%) - Elapsed: 7416.23s - Est. remaining: 35.33s
# 2025-04-28 06:49:54,328 : INFO : Evaluating batch 200: users 19901-19986 of 19986
# 2025-04-28 06:50:21,145 : INFO : Batch metrics - RMSE: 1.0971, MAE: 0.8324, Accuracy: 0.6226
# 2025-04-28 06:50:21,145 : INFO : TP: 786, FP: 570, TN: 803, FN: 393
# 2025-04-28 06:50:21,146 : INFO : Processed 19986/19986 users (100.0%) - Elapsed: 7443.20s - Est. remaining: 0.00s
# 2025-04-28 06:50:21,318 : INFO :
# Evaluation results:
# 2025-04-28 06:50:21,319 : INFO : Users evaluated: 19986
# 2025-04-28 06:50:21,319 : INFO : Total predictions: 596109
# 2025-04-28 06:50:21,320 : INFO : RMSE: 1.0569
# 2025-04-28 06:50:21,320 : INFO : MAE: 0.8075
# 2025-04-28 06:50:21,321 : INFO : Accuracy: 0.6168
# 2025-04-28 06:50:21,322 : INFO : Precision: 0.6179
# 2025-04-28 06:50:21,322 : INFO : Recall: 0.6352
# 2025-04-28 06:50:21,322 : INFO : F1 Score: 0.6264
# 2025-04-28 06:50:21,323 : INFO : Confusion Matrix: [TP: 191510, FP: 118430, TN: 176164, FN: 110005]
# 2025-04-28 06:50:21,328 : INFO :
# Stored evaluation metrics:
# 2025-04-28 06:50:21,329 : INFO :   rmse: 1.0568560408809509
# 2025-04-28 06:50:21,329 : INFO :   mae: 0.8074874716312546
# 2025-04-28 06:50:21,329 : INFO :   accuracy: 0.6167898823872815
# 2025-04-28 06:50:21,330 : INFO :   precision: 0.617893785894044
# 2025-04-28 06:50:21,330 : INFO :   recall: 0.635159113145283
# 2025-04-28 06:50:21,330 : INFO :   f1_score: 0.626407503413988
# 2025-04-28 06:50:21,330 : INFO :   true_positives: 191510
# 2025-04-28 06:50:21,331 : INFO :   false_positives: 118430
# 2025-04-28 06:50:21,331 : INFO :   true_negatives: 176164
# 2025-04-28 06:50:21,331 : INFO :   false_negatives: 110005
# 2025-04-28 06:50:21,332 : INFO :   num_users_evaluated: 19986
# 2025-04-28 06:50:21,332 : INFO :   num_predictions: 596109
# 2025-04-28 06:50:21,546 : INFO : Created evaluation visualizations
# 2025-04-28 06:50:21,687 : INFO : After evaluation: 2556.45 MB
# 2025-04-28 06:50:21,687 : INFO : Content-based recommendation pipeline completed successfully!
